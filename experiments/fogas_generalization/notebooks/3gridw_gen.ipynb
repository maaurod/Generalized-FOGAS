# %% [markdown]
# # Problem

# %% [markdown]
# **State space.**
# The states are encoded as integers
# $$\mathcal{X} = {0,1,\dots,8} $$
# corresponding to the grid in row-major order (top-left corner to bottom-right corner).
# - State $8$ is the terminal goal state and is absorbing.
# - State $5$ is the pit state and is absorbing.
# - State $4$ is a wall.
#
#
# **Action space.**
# Actions are represented as integers
#
# $$ \mathcal{A} = {0,1,2,3} $$
#
# where $0 =$ Up, $1 =$ Down, $2 =$ Left, $3 =$ Right.
#
# **Transition dynamics.**
# Transitions are deterministic. For any state $x$ and action $a$, the state index is first mapped to its grid coordinates $(r,c)$, the action moves the agent one step (unless this would leave the grid), and the result is mapped back to a state index. The goal state $8$ always transitions to itself.
# The transition matrix $P$ has shape $(|\mathcal{X}||\mathcal{A}|) \times |\mathcal{X}| = 36 \times 9$, where each row corresponds to a pair $(x,a)$ and contains a one-hot vector indicating the unique next state:
#
# $$P[(x,a),x'] = 1 \quad \text{iff } x' = \text{next\_state}(x,a)$$
#
# and $0$ otherwise.
#
# **Reward model.**
# - $r(x,a) = 1$ if x is a goal state.
# - $r(x,a) = -1$ if x is the pit state.
# - $r(x,a) = -0.01$ otherwise.
#
# **Initial state.**
# The initial state is fixed as $x_0 = 0$.

# %%
# %load_ext autoreload
# %autoreload 2

import os
import random
import numpy as np
import pandas as pd
import sys
import torch
from pathlib import Path

SEED = 42
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.set_default_dtype(torch.float64)

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
if torch.backends.cudnn.is_available():
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

def find_root(current_path, marker="setup.py"):
    current_path = Path(current_path).resolve()
    for parent in [current_path] + list(current_path.parents):
        if (parent / marker).exists():
            return parent
    return current_path

PROJECT_ROOT = find_root(Path.cwd())
DATASETS_DIR = PROJECT_ROOT / "data" / "datasets"
RESULTS_DIR = PROJECT_ROOT / "data" / "results"
ASSETS_DIR = PROJECT_ROOT / "experiments" / "shared" / "assets"
# Add project root to the Python path
if str(PROJECT_ROOT / "src") not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / "src"))

from rl_methods import TabularPolicyFeatures, LinearPolicyFOGAS, VBetaLogitSolver, VBetaObjectivePolicySolver, VBetaSolver, FOGASHyperOptimizer, FOGASEvaluator, PolicySolver, FOGASSolverBetaVectorized
from rl_methods.dataset_collection.env_data_collector import EnvDataCollector
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Problem

# %%
states = torch.arange(9, dtype=torch.long)
actions = torch.arange(4, dtype=torch.long)
N = len(states) # number of states
A = len(actions) # number of actions
gamma = 0.9

x_0 = 0 # fixed initial state
dataset_path = str(DATASETS_DIR / "3gridw_tab_gen.csv") # path where to download the dataset

goal = 8   # absorbing terminal state
pit = 5   # absorbing terminal state

def phi(x, a):
    vec = torch.zeros(N * A, dtype=torch.float64)
    vec[int(x) * A + int(a)] = 1.0
    return vec

step_cost = -0.01
goal_reward = 1.0
pit_reward  = -1.0

omega = torch.full((N * A,), step_cost, dtype=torch.float64)

# terminals: you can either keep step cost or override; usually override
omega[goal * A : goal * A + A] = goal_reward
omega[pit  * A : pit  * A + A] = pit_reward


# Helper to convert index <-> (row, col)
def to_rc(s):  return divmod(int(s), 3)
def to_s(r,c): return r*3 + c

wall = 4

def next_state(s, a):
    s = int(s)
    a = int(a)

    # absorbing terminals
    if s == goal or s == pit:
        return s

    r, c = to_rc(s)

    if a == 0:      # Up
        r2, c2 = max(0, r-1), c
    elif a == 1:    # Down
        r2, c2 = min(2, r+1), c
    elif a == 2:    # Left
        r2, c2 = r, max(0, c-1)
    elif a == 3:    # Right
        r2, c2 = r, min(2, c+1)

    sp = to_s(r2, c2)

    # wall blocks transition
    if sp == wall:
        return s

    return sp

def psi(xp):
    v = torch.zeros(N * A, dtype=torch.float64)
    for x in states:
        for a in actions:
            if next_state(x, a) == int(xp):
                v[int(x) * A + int(a)] = 1.0
    return v

mdp = PolicySolver(states=states, actions=actions, phi=phi, omega=omega, gamma=gamma, x0=x_0, psi=psi)

# %% [markdown]
# # Dataset Collection

# %%
collector = EnvDataCollector(
    mdp=mdp,
    max_steps=30,
    terminal_states=[goal],
    seed=42,
)

df = collector.collect_mixed_dataset(
    policies=[
        (mdp.pi_star, 0.3),   
        "random",
    ],
    proportions=[0.7, 0.3],
    n_steps=1000,
    save_path=dataset_path,
    verbose=True,
    episode_based=True,
)
# Out:
# ============================================================
#   MIXED DATASET COLLECTION SUMMARY (TORCH)
# ============================================================
# Total transitions: 1000
# Total episodes: 93
# Mode: Episode-based
#
# Policy Distribution:
#   Policy 0:   432 steps (43.2%) | Target: 70.0% | Episodes: 72
#   Policy 1:   568 steps (56.8%) | Target: 30.0% | Episodes: 22
# ============================================================
#
# ✅ Mixed dataset saved to: /home/mauro/Desktop/EMAI/Ljubljana/Thesis/Code/datasets/3gridw_tab_gen.csv

# %% [markdown]
# # Empirical

# %% [markdown]
# ## Beta

# %%
solver_e = VBetaSolver(mdp=mdp, print_params=True, csv_path=dataset_path, T=1000, seed=SEED, device=DEVICE)
evaluator_e = FOGASEvaluator(solver_e)
optimizer_e = FOGASHyperOptimizer(solver=solver_e,metric_callable=evaluator_e.get_metric("reward"))
# Out:
# Device: cpu
# Dataset: /home/mauro/Desktop/EMAI/Ljubljana/Thesis/Code/data/datasets/3gridw_tab_gen.csv (n=1000)
#
# ================ FOGAS PARAMETER SUMMARY ================
#
# Basic Information
# -----------------
# Dataset size n:           1000
# Feature norm bound R:     1.0000
# Num states N:             9
# Num actions A:            4
# Feature dim d:            36
# Discount γ:               0.9
# Confidence δ:             0.05
#
# Theoretical Quantities
# ----------------------
# T_min (theoretical):      925.5128526390366
# T (iterations):                1000   (overridden → 1000)
#
# FOGAS Hyperparameters
# ---------------------
# alpha:                        0.000878
# rho:                            596.628481
# eta:                            0.000017
# D_theta:                    18.973666
# beta (ridge):             0.000028
# D_pi (derived):           16.651092
#
# =========================================================

# %%
solver_e.run(alpha=1e-3, eta=2e-4, rho=0.5, T = 2000, tqdm_print=True)
evaluator_e.compare_value_functions()
evaluator_e.compare_final_rewards()
evaluator_e.print_policy()
# Out:
# FOGAS:   0%|          | 0/2000 [00:00<?, ?it/s]
# FOGAS: 100%|██████████| 2000/2000 [00:00<00:00, 2137.43it/s]
# ========== VALUE FUNCTION COMPARISON ==========
#
# State-wise V comparison:
# State 0: V*(x) =  6.526610 | V^π(x) =  1.257598 | Δ = -5.269012e+00
# State 1: V*(x) =  5.863949 | V^π(x) = -5.824322 | Δ = -1.168827e+01
# State 2: V*(x) =  5.267554 | V^π(x) = -7.895416 | Δ = -1.316297e+01
# State 3: V*(x) =  7.262900 | V^π(x) =  5.536337 | Δ = -1.726563e+00
# State 4: V*(x) =  8.081000 | V^π(x) = -0.495994 | Δ = -8.576994e+00
# State 5: V*(x) = -10.000000 | V^π(x) = -10.000000 | Δ =  2.309264e-14
# State 6: V*(x) =  8.081000 | V^π(x) =  6.803479 | Δ = -1.277521e+00
# State 7: V*(x) =  8.990000 | V^π(x) =  8.128010 | Δ = -8.619903e-01
# State 8: V*(x) =  10.000000 | V^π(x) =  10.000000 | Δ =  0.000000e+00
#
# Action-value Q comparison:
# (x=0, a=0): Q*(x,a) =  5.863949 | Q^π(x,a) =  1.121838 | Δ = -4.742111e+00
# (x=0, a=1): Q*(x,a) =  6.526610 | Q^π(x,a) =  4.972704 | Δ = -1.553906e+00
# (x=0, a=2): Q*(x,a) =  5.863949 | Q^π(x,a) =  1.121838 | Δ = -4.742111e+00
# (x=0, a=3): Q*(x,a) =  5.267554 | Q^π(x,a) = -5.251890 | Δ = -1.051944e+01
# (x=1, a=0): Q*(x,a) =  5.267554 | Q^π(x,a) = -5.251890 | Δ = -1.051944e+01
# (x=1, a=1): Q*(x,a) =  5.267554 | Q^π(x,a) = -5.251890 | Δ = -1.051944e+01
# (x=1, a=2): Q*(x,a) =  5.863949 | Q^π(x,a) =  1.121838 | Δ = -4.742111e+00
# (x=1, a=3): Q*(x,a) =  4.730799 | Q^π(x,a) = -7.115874 | Δ = -1.184667e+01
# (x=2, a=0): Q*(x,a) =  4.730799 | Q^π(x,a) = -7.115874 | Δ = -1.184667e+01
# (x=2, a=1): Q*(x,a) = -9.010000 | Q^π(x,a) = -9.010000 | Δ =  2.131628e-14
# (x=2, a=2): Q*(x,a) =  5.267554 | Q^π(x,a) = -5.251890 | Δ = -1.051944e+01
# (x=2, a=3): Q*(x,a) =  4.730799 | Q^π(x,a) = -7.115874 | Δ = -1.184667e+01
# (x=3, a=0): Q*(x,a) =  5.863949 | Q^π(x,a) =  1.121838 | Δ = -4.742111e+00
# (x=3, a=1): Q*(x,a) =  7.262900 | Q^π(x,a) =  6.113131 | Δ = -1.149769e+00
# (x=3, a=2): Q*(x,a) =  6.526610 | Q^π(x,a) =  4.972704 | Δ = -1.553906e+00
# (x=3, a=3): Q*(x,a) =  6.526610 | Q^π(x,a) =  4.972704 | Δ = -1.553906e+00
# (x=4, a=0): Q*(x,a) =  5.267554 | Q^π(x,a) = -5.251890 | Δ = -1.051944e+01
# (x=4, a=1): Q*(x,a) =  8.081000 | Q^π(x,a) =  7.305209 | Δ = -7.757912e-01
# (x=4, a=2): Q*(x,a) =  6.526610 | Q^π(x,a) =  4.972704 | Δ = -1.553906e+00
# (x=4, a=3): Q*(x,a) = -9.010000 | Q^π(x,a) = -9.010000 | Δ =  2.131628e-14
# (x=5, a=0): Q*(x,a) = -10.000000 | Q^π(x,a) = -10.000000 | Δ =  2.131628e-14
# (x=5, a=1): Q*(x,a) = -10.000000 | Q^π(x,a) = -10.000000 | Δ =  2.131628e-14
# (x=5, a=2): Q*(x,a) = -10.000000 | Q^π(x,a) = -10.000000 | Δ =  2.131628e-14
# (x=5, a=3): Q*(x,a) = -10.000000 | Q^π(x,a) = -10.000000 | Δ =  2.131628e-14
# (x=6, a=0): Q*(x,a) =  6.526610 | Q^π(x,a) =  4.972704 | Δ = -1.553906e+00
# (x=6, a=1): Q*(x,a) =  7.262900 | Q^π(x,a) =  6.113131 | Δ = -1.149769e+00
# (x=6, a=2): Q*(x,a) =  7.262900 | Q^π(x,a) =  6.113131 | Δ = -1.149769e+00
# (x=6, a=3): Q*(x,a) =  8.081000 | Q^π(x,a) =  7.305209 | Δ = -7.757912e-01
# (x=7, a=0): Q*(x,a) =  8.081000 | Q^π(x,a) =  7.305209 | Δ = -7.757912e-01
# (x=7, a=1): Q*(x,a) =  8.081000 | Q^π(x,a) =  7.305209 | Δ = -7.757912e-01
# (x=7, a=2): Q*(x,a) =  7.262900 | Q^π(x,a) =  6.113131 | Δ = -1.149769e+00
# (x=7, a=3): Q*(x,a) =  8.990000 | Q^π(x,a) =  8.990000 | Δ =  0.000000e+00
# (x=8, a=0): Q*(x,a) =  10.000000 | Q^π(x,a) =  10.000000 | Δ =  0.000000e+00
# (x=8, a=1): Q*(x,a) =  10.000000 | Q^π(x,a) =  10.000000 | Δ =  0.000000e+00
# (x=8, a=2): Q*(x,a) =  10.000000 | Q^π(x,a) =  10.000000 | Δ =  0.000000e+00
# (x=8, a=3): Q*(x,a) =  10.000000 | Q^π(x,a) =  10.000000 | Δ =  0.000000e+00
#
# Norm diagnostics:
# ||V^π - V*||_2 = 2.040987e+01
# ||Q^π - Q*||_2 = 3.292481e+01
#
# ===============================================
#
#
# ========== FINAL REWARD COMPARISON ==========
#
# J*(π*)   = 0.652661
# J(π_FOGAS) = 0.125760
# Gap (J* − J) = 5.269012e-01
#
# ============================================
#
#   State 0: π(a=0|s=0) = 0.12  π(a=1|s=0) = 0.49  π(a=2|s=0) = 0.12  π(a=3|s=0) = 0.27  --> best action: 1
#   State 1: π(a=0|s=1) = 0.22  π(a=1|s=1) = 0.24  π(a=2|s=1) = 0.05  π(a=3|s=1) = 0.49  --> best action: 3
#   State 2: π(a=0|s=2) = 0.26  π(a=1|s=2) = 0.45  π(a=2|s=2) = 0.04  π(a=3|s=2) = 0.24  --> best action: 1
#   State 3: π(a=0|s=3) = 0.04  π(a=1|s=3) = 0.64  π(a=2|s=3) = 0.15  π(a=3|s=3) = 0.17  --> best action: 1
#   State 4: π(a=0|s=4) = 0.25  π(a=1|s=4) = 0.25  π(a=2|s=4) = 0.25  π(a=3|s=4) = 0.25  --> best action: 0
#   State 5: π(a=0|s=5) = 0.65  π(a=1|s=5) = 0.13  π(a=2|s=5) = 0.09  π(a=3|s=5) = 0.13  --> best action: 0
#   State 6: π(a=0|s=6) = 0.05  π(a=1|s=6) = 0.16  π(a=2|s=6) = 0.16  π(a=3|s=6) = 0.63  --> best action: 3
#   State 7: π(a=0|s=7) = 0.19  π(a=1|s=7) = 0.19  π(a=2|s=7) = 0.08  π(a=3|s=7) = 0.54  --> best action: 3
#   State 8: π(a=0|s=8) = 0.25  π(a=1|s=8) = 0.25  π(a=2|s=8) = 0.25  π(a=3|s=8) = 0.25  --> best action: 0

# %% [markdown]
# ### Objective update

# %%
solver_e = VBetaObjectivePolicySolver(
    mdp=mdp,
    csv_path=dataset_path,
    beta=1e-2,          # ridge
    print_params=True,  
    seed=SEED,
    device=DEVICE,
)

evaluator_e = FOGASEvaluator(solver_e)
optimizer_e = FOGASHyperOptimizer(solver=solver_e,metric_callable=evaluator_e.get_metric("reward"))
# Out:
# Device: cpu
# Dataset: /home/mauro/Desktop/EMAI/Ljubljana/Thesis/Code/data/datasets/3gridw_tab_gen.csv (n=1000)
#
# ================ FOGAS PARAMETER SUMMARY ================
#
# Basic Information
# -----------------
# Dataset size n:           1000
# Feature norm bound R:     1.0000
# Num states N:             9
# Num actions A:            4
# Feature dim d:            36
# Discount γ:               0.9
# Confidence δ:             0.05
#
# Theoretical Quantities
# ----------------------
# T_min (theoretical):      925.5128526390366
# T (iterations):                926
#
# FOGAS Hyperparameters
# ---------------------
# alpha:                        0.000912
# rho:                            594.460202
# eta:                            0.000018
# D_theta:                    18.973666
# beta (ridge):             0.000030   (overridden → 0.010000)
# D_pi (derived):           16.023162
#
# =========================================================

# %%
solver_e.run(
    alpha=1e-3,
    eta=2e-4,
    rho=0.5,
    tqdm_print=False,
    verbose=True,
    log_interval=50,
    T=2000,
)
evaluator_e.print_policy()
# Out:
# [FOGAS objective-policy] Iter 1/2000 total_loss=-9.486833e-01 policy_loss=-9.486833e-01 theta_norm=1.897367e+01 beta_norm=3.395861e-03 grad_norm=1.698100e+01 policy_grad_norm=1.897367e+00 state_weight_min=0.000000e+00 state_weight_max=1.000000e-01 state_weight_neg=0
# [FOGAS objective-policy] Iter 51/2000 total_loss=-8.052905e-01 policy_loss=-9.268526e-01 theta_norm=1.897367e+01 beta_norm=1.558281e-01 grad_norm=1.377745e+01 policy_grad_norm=1.853917e+00 state_weight_min=-1.007000e-03 state_weight_max=9.893208e-02 state_weight_neg=2
# [FOGAS objective-policy] Iter 101/2000 total_loss=-7.202632e-01 policy_loss=-9.051878e-01 theta_norm=1.897367e+01 beta_norm=2.763833e-01 grad_norm=1.131549e+01 policy_grad_norm=1.809791e+00 state_weight_min=-1.988142e-03 state_weight_max=9.971768e-02 state_weight_neg=1
# [FOGAS objective-policy] Iter 151/2000 total_loss=-6.653952e-01 policy_loss=-8.938959e-01 theta_norm=1.897367e+01 beta_norm=3.733718e-01 grad_norm=9.856743e+00 policy_grad_norm=1.777179e+00 state_weight_min=-2.938920e-03 state_weight_max=1.018910e-01 state_weight_neg=1
-01 state_weight_neg=0
# [FOGAS objective-policy] Iter 1751/2000 total_loss=-1.233571e-01 policy_loss=-5.561799e-01 theta_norm=1.897367e+01 beta_norm=1.788972e+00 grad_norm=4.333880e+00 policy_grad_norm=6.614454e-01 state_weight_min=0.000000e+00 state_weight_max=1.715638e-01 state_weight_neg=0
# [FOGAS objective-policy] Iter 1801/2000 total_loss=-6.079579e-02 policy_loss=-5.821634e-01 theta_norm=1.897367e+01 beta_norm=1.787880e+00 grad_norm=2.340700e+01 policy_grad_norm=2.531625e+00 state_weight_min=0.000000e+00 state_weight_max=1.715432e-01 state_weight_neg=0
# [FOGAS objective-policy] Iter 1851/2000 total_loss=-6.348150e-02 policy_loss=-5.914519e-01 theta_norm=1.897367e+01 beta_norm=1.787128e+00 grad_norm=2.317149e+01 policy_grad_norm=2.510845e+00 state_weight_min=0.000000e+00 state_weight_max=1.714812e-01 state_weight_neg=0
# [FOGAS objective-policy] Iter 1901/2000 total_loss=-6.376359e-02 policy_loss=-5.923035e-01 theta_norm=1.897367e+01 beta_norm=1.786541e+00 grad_norm=2.314505e+01 policy_grad_norm=2.507210e+00 state_weight_min=0.000000e+00 state_weight_max=1.714247e-01 state_weight_neg=0
# [FOGAS objective-policy] Iter 1951/2000 total_loss=-6.380237e-02 policy_loss=-5.924042e-01 theta_norm=1.897367e+01 beta_norm=1.785972e+00 grad_norm=2.314491e+01 policy_grad_norm=2.505885e+00 state_weight_min=0.000000e+00 state_weight_max=1.713688e-01 state_weight_neg=0
#   State 0: π(a=0|s=0) = 0.21  π(a=1|s=0) = 0.31  π(a=2|s=0) = 0.21  π(a=3|s=0) = 0.27  --> best action: 1
#   State 1: π(a=0|s=1) = 0.25  π(a=1|s=1) = 0.25  π(a=2|s=1) = 0.24  π(a=3|s=1) = 0.26  --> best action: 3
#   State 2: π(a=0|s=2) = 0.25  π(a=1|s=2) = 0.25  π(a=2|s=2) = 0.25  π(a=3|s=2) = 0.25  --> best action: 3
#   State 3: π(a=0|s=3) = 0.23  π(a=1|s=3) = 0.28  π(a=2|s=3) = 0.24  π(a=3|s=3) = 0.25  --> best action: 1
#   State 4: π(a=0|s=4) = 0.25  π(a=1|s=4) = 0.25  π(a=2|s=4) = 0.25  π(a=3|s=4) = 0.25  --> best action: 0
#   State 5: π(a=0|s=5) = 0.25  π(a=1|s=5) = 0.25  π(a=2|s=5) = 0.25  π(a=3|s=5) = 0.25  --> best action: 2
#   State 6: π(a=0|s=6) = 0.24  π(a=1|s=6) = 0.25  π(a=2|s=6) = 0.25  π(a=3|s=6) = 0.26  --> best action: 3
#   State 7: π(a=0|s=7) = 0.25  π(a=1|s=7) = 0.25  π(a=2|s=7) = 0.25  π(a=3|s=7) = 0.25  --> best action: 3
#   State 8: π(a=0|s=8) = 0.25  π(a=1|s=8) = 0.25  π(a=2|s=8) = 0.25  π(a=3|s=8) = 0.25  --> best action: 0

# %% [markdown]
# Same thing! This new weights do that the policy update is not that strong in the not that well covered states.

# %%
policy_grad_norm=9.486833e+00 state_weight_update=clipped state_weight_min=0.000000e+00 state_weight_max=1.465089e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS objective-policy] Iter 1451/2000 total_loss=-1.029982e-01 policy_loss=-7.729432e+00 theta_norm=1.897367e+01 beta_norm=1.575539e+00 grad_norm=4.472584e+00 policy_grad_norm=9.486833e+00 state_weight_update=clipped state_weight_min=0.000000e+00 state_weight_max=1.468250e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS objective-policy] Iter 1501/2000 total_loss=-3.344818e-02 policy_loss=-1.494954e+00 theta_norm=1.897367e+01 beta_norm=1.579063e+00 grad_norm=2.438755e+01 policy_grad_norm=9.486833e+00 state_weight_update=clipped state_weight_min=0.000000e+00 state_weight_max=1.467977e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS objective-policy] Iter 1551/2000 total_loss=-3.445209e-02 policy_loss=-1.640894e+00 theta_norm=1.897367e+01 beta_norm=1.578338e+00 grad_norm=2.416010e+01 policy_grad_norm=9.486833e+00 state_weight_update=clipped state_weight_min=0.000000e+00 state_weight_max=1.467246e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS objective-policy] Iter 1601/2000 total_loss=-3.442477e-02 policy_loss=-1.674813e+00 theta_norm=1.897367e+01 beta_norm=1.577702e+00 grad_norm=2.413127e+01 policy_grad_norm=9.486833e+00 state_weight_update=clipped state_weight_min=0.000000e+00 state_weight_max=1.466549e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS objective-policy] Iter 1651/2000 total_loss=-3.418501e-02 policy_loss=-1.679928e+00 theta_norm=1.897367e+01 beta_norm=1.577102e+00 grad_norm=2.414124e+01 policy_grad_norm=9.486833e+00 state_weight_update=clipped state_weight_min=0.000000e+00 state_weight_max=1.465857e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS objective-policy] Iter 1701/2000 total_loss=-3.389339e-02 policy_loss=-1.678641e+00 theta_norm=1.897367e+01 beta_norm=1.576520e+00 grad_norm=2.415909e+01 policy_grad_norm=9.486833e+00 state_weight_update=clipped state_weight_min=0.000000e+00 state_weight_max=1.465167e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS objective-policy] Iter 1751/2000 total_loss=-3.359129e-02 policy_loss=-1.676031e+00 theta_norm=1.897367e+01 beta_norm=1.575951e+00 grad_norm=2.417856e+01 policy_grad_norm=9.486833e+00 state_weight_update=clipped state_weight_min=0.000000e+00 state_weight_max=1.464477e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS objective-policy] Iter 1801/2000 total_loss=-3.328835e-02 policy_loss=-1.673189e+00 theta_norm=1.897367e+01 beta_norm=1.575393e+00 grad_norm=2.419839e+01 policy_grad_norm=9.486833e+00 state_weight_update=clipped state_weight_min=0.000000e+00 state_weight_max=1.463788e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS objective-policy] Iter 1851/2000 total_loss=-3.298668e-02 policy_loss=-1.670345e+00 theta_norm=1.897367e+01 beta_norm=1.574847e+00 grad_norm=2.421831e+01 policy_grad_norm=9.486833e+00 state_weight_update=clipped state_weight_min=0.000000e+00 state_weight_max=1.463098e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS objective-policy] Iter 1901/2000 total_loss=-3.268671e-02 policy_loss=-1.667546e+00 theta_norm=1.897367e+01 beta_norm=1.574311e+00 grad_norm=2.423828e+01 policy_grad_norm=9.486833e+00 state_weight_update=clipped state_weight_min=0.000000e+00 state_weight_max=1.462409e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS objective-policy] Iter 1951/2000 total_loss=-3.238856e-02 policy_loss=-1.664801e+00 theta_norm=1.897367e+01 beta_norm=1.573787e+00 grad_norm=2.425828e+01 policy_grad_norm=9.486833e+00 state_weight_update=clipped state_weight_min=0.000000e+00 state_weight_max=1.461720e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
#   State 0: π(a=0|s=0) = 0.17  π(a=1|s=0) = 0.39  π(a=2|s=0) = 0.17  π(a=3|s=0) = 0.27  --> best action: 1
#   State 1: π(a=0|s=1) = 0.25  π(a=1|s=1) = 0.26  π(a=2|s=1) = 0.14  π(a=3|s=1) = 0.35  --> best action: 3
#   State 2: π(a=0|s=2) = 0.30  π(a=1|s=2) = 0.18  π(a=2|s=2) = 0.21  π(a=3|s=2) = 0.31  --> best action: 3
#   State 3: π(a=0|s=3) = 0.12  π(a=1|s=3) = 0.46  π(a=2|s=3) = 0.20  π(a=3|s=3) = 0.21  --> best action: 1
#   State 4: π(a=0|s=4) = 0.25  π(a=1|s=4) = 0.25  π(a=2|s=4) = 0.25  π(a=3|s=4) = 0.25  --> best action: 0
#   State 5: π(a=0|s=5) = 0.26  π(a=1|s=5) = 0.25  π(a=2|s=5) = 0.24  π(a=3|s=5) = 0.25  --> best action: 0
#   State 6: π(a=0|s=6) = 0.13  π(a=1|s=6) = 0.21  π(a=2|s=6) = 0.21  π(a=3|s=6) = 0.45  --> best action: 3
#   State 7: π(a=0|s=7) = 0.20  π(a=1|s=7) = 0.21  π(a=2|s=7) = 0.14  π(a=3|s=7) = 0.45  --> best action: 3
#   State 8: π(a=0|s=8) = 0.25  π(a=1|s=8) = 0.25  π(a=2|s=8) = 0.25  π(a=3|s=8) = 0.25  --> best action: 0

# %% [markdown]
# Much better clipping!

# %% [markdown]
# ### Tabular softmax MA

# %%
solver_e = VBetaLogitSolver(
    mdp=mdp,
    csv_path=dataset_path,
    beta=1e-2,          # ridge
    seed=SEED,
    device=DEVICE,
)

evaluator_e = FOGASEvaluator(solver_e)
optimizer_e = FOGASHyperOptimizer(solver=solver_e,metric_callable=evaluator_e.get_metric("reward"))

# %%
solver_e.run(
    alpha=1e-3,
    eta=2e-4,
    rho=0.5,
    tqdm_print=False,
    verbose=True,
    log_interval=50,
    T=2000,
    state_weight_update="clipped",
    c_min=0.5,
)
evaluator_e.print_policy()
# Out:
# [FOGAS logit-policy] Iter 1/2000 total_loss=-9.486833e-01 policy_loss=-4.743416e+00 theta_norm=1.897367e+01 beta_norm=3.395861e-03 grad_norm=1.698100e+01 policy_grad_norm=9.486833e+00 psi_norm=9.486833e-03 state_weight_update=clipped state_weight_min=0.000000e+00 state_weight_max=1.000000e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS logit-policy] Iter 51/2000 total_loss=-8.031148e-01 policy_loss=-5.582587e+00 theta_norm=1.897367e+01 beta_norm=1.561470e-01 grad_norm=1.384958e+01 policy_grad_norm=9.486833e+00 psi_norm=4.829003e-01 state_weight_update=clipped state_weight_min=-1.006989e-03 state_weight_max=9.890862e-02 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS logit-policy] Iter 101/2000 total_loss=-7.088651e-01 policy_loss=-6.225919e+00 theta_norm=1.897367e+01 beta_norm=2.782550e-01 grad_norm=1.143437e+01 policy_grad_norm=9.486833e+00 psi_norm=9.524642e-01 state_weight_update=clipped state_weight_min=-1.987821e-03 state_weight_max=9.956981e-02 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS logit-policy] Iter 151/2000 total_loss=-6.415036e-01 policy_loss=-6.730720e+00 theta_norm=1.897367e+01 beta_norm=3.773071e-01 grad_norm=9.887552e+00 policy_grad_norm=9.486833e+00 psi_norm=1.417633e+00 state_weight_update=clipped state_weight_min=-2.936861e-03 state_weight_max=1.015103e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS logit-policy] Iter 201/2000 total_loss=-5.899186e-01 policy_loss=-7.164415e+00 theta_norm=1.897367e+01 beta_norm=4.607603e-01 grad_norm=8.950815e+00 policy_grad_norm=9.486833e+00 psi_norm=1.878865e+00 state_weight_update=clipped state_weight_min=-3.848960e-03 state_weight_max=1.042219e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS logit-policy] Iter 251/2000 total_loss=-5.488712e-01 policy_loss=-7.559564e+00 theta_norm=1.897367e+01 beta_norm=5.338317e-01 grad_norm=8.368855e+00 policy_grad_norm=9.486833e+00 psi_norm=2.336412e+00 state_weight_update=clipped state_weight_min=-4.719239e-03 state_weight_max=1.073060e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS logit-policy] Iter
-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS logit-policy] Iter 1851/2000 total_loss=-3.298667e-02 policy_loss=-1.670344e+00 theta_norm=1.897367e+01 beta_norm=1.574847e+00 grad_norm=2.421831e+01 policy_grad_norm=9.486833e+00 psi_norm=1.318721e+01 state_weight_update=clipped state_weight_min=0.000000e+00 state_weight_max=1.463099e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS logit-policy] Iter 1901/2000 total_loss=-3.268672e-02 policy_loss=-1.667546e+00 theta_norm=1.897367e+01 beta_norm=1.574311e+00 grad_norm=2.423828e+01 policy_grad_norm=9.486833e+00 psi_norm=1.329922e+01 state_weight_update=clipped state_weight_min=0.000000e+00 state_weight_max=1.462409e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS logit-policy] Iter 1951/2000 total_loss=-3.238857e-02 policy_loss=-1.664801e+00 theta_norm=1.897367e+01 beta_norm=1.573787e+00 grad_norm=2.425828e+01 policy_grad_norm=9.486833e+00 psi_norm=1.341213e+01 state_weight_update=clipped state_weight_min=0.000000e+00 state_weight_max=1.461720e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
#   State 0: π(a=0|s=0) = 0.17  π(a=1|s=0) = 0.39  π(a=2|s=0) = 0.17  π(a=3|s=0) = 0.27  --> best action: 1
#   State 1: π(a=0|s=1) = 0.25  π(a=1|s=1) = 0.26  π(a=2|s=1) = 0.14  π(a=3|s=1) = 0.35  --> best action: 3
#   State 2: π(a=0|s=2) = 0.30  π(a=1|s=2) = 0.18  π(a=2|s=2) = 0.21  π(a=3|s=2) = 0.31  --> best action: 3
#   State 3: π(a=0|s=3) = 0.12  π(a=1|s=3) = 0.46  π(a=2|s=3) = 0.20  π(a=3|s=3) = 0.21  --> best action: 1
#   State 4: π(a=0|s=4) = 0.25  π(a=1|s=4) = 0.25  π(a=2|s=4) = 0.25  π(a=3|s=4) = 0.25  --> best action: 0
#   State 5: π(a=0|s=5) = 0.26  π(a=1|s=5) = 0.25  π(a=2|s=5) = 0.24  π(a=3|s=5) = 0.25  --> best action: 0
#   State 6: π(a=0|s=6) = 0.13  π(a=1|s=6) = 0.21  π(a=2|s=6) = 0.21  π(a=3|s=6) = 0.45  --> best action: 3
#   State 7: π(a=0|s=7) = 0.20  π(a=1|s=7) = 0.21  π(a=2|s=7) = 0.14  π(a=3|s=7) = 0.45  --> best action: 3
#   State 8: π(a=0|s=8) = 0.25  π(a=1|s=8) = 0.25  π(a=2|s=8) = 0.25  π(a=3|s=8) = 0.25  --> best action: 0

# %% [markdown]
# ### Tabular SGD/Adam

# %%
policy_features = TabularPolicyFeatures(mdp.N, mdp.A)

solver_e = LinearPolicyFOGAS(
    mdp=mdp,
    csv_path=dataset_path,
    seed=SEED,
    device=DEVICE,
    policy_features=policy_features,
)


evaluator_e = FOGASEvaluator(solver_e)
optimizer_e = FOGASHyperOptimizer(
    solver=solver_e,
    metric_callable=evaluator_e.get_metric("reward"),
)

# %%
solver_e.run(
    alpha=1e-3,
    eta=2e-4,
    rho=0.5,
    policy_optimizer="adam",
    tqdm_print=False,
    verbose=True,
    log_interval=50,
    T=2000,
    state_weight_update="clipped",
    c_min=0.5,
)
evaluator_e.print_policy()
# Out:
# [FOGAS linear-policy] Iter 1/2000 total_loss=-9.486833e-01 policy_objective=-4.743416e+00 theta_norm=1.897367e+01 beta_norm=3.661792e-03 grad_norm=1.831079e+01 policy_grad_norm=0.000000e+00 psi_norm=0.000000e+00 policy_optimizer=adam state_weight_update=clipped state_weight_min
-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS linear-policy] Iter 1701/2000 total_loss=-2.547902e-01 policy_objective=-1.298968e+01 theta_norm=1.897367e+01 beta_norm=1.976579e+00 grad_norm=8.877830e+00 policy_grad_norm=2.152876e-02 psi_norm=5.799923e+00 policy_optimizer=adam state_weight_update=clipped state_weight_min=-1.681898e-02 state_weight_max=1.234590e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS linear-policy] Iter 1751/2000 total_loss=-2.531100e-01 policy_objective=-1.303069e+01 theta_norm=1.897367e+01 beta_norm=2.042998e+00 grad_norm=8.993645e+00 policy_grad_norm=2.050761e-02 psi_norm=5.822170e+00 policy_optimizer=adam state_weight_update=clipped state_weight_min=-1.710107e-02 state_weight_max=1.237610e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS linear-policy] Iter 1801/2000 total_loss=-2.515597e-01 policy_objective=-1.306607e+01 theta_norm=1.897367e+01 beta_norm=2.110670e+00 grad_norm=9.099449e+00 policy_grad_norm=1.972313e-02 psi_norm=5.841593e+00 policy_optimizer=adam state_weight_update=clipped state_weight_min=-1.738089e-02 state_weight_max=1.240501e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS linear-policy] Iter 1851/2000 total_loss=-2.501234e-01 policy_objective=-1.309664e+01 theta_norm=1.897367e+01 beta_norm=2.179494e+00 grad_norm=9.195735e+00 policy_grad_norm=1.909019e-02 psi_norm=5.858539e+00 policy_optimizer=adam state_weight_update=clipped state_weight_min=-1.765855e-02 state_weight_max=1.243275e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS linear-policy] Iter 1901/2000 total_loss=-2.487875e-01 policy_objective=-1.312285e+01 theta_norm=1.897367e+01 beta_norm=2.249373e+00 grad_norm=9.283036e+00 policy_grad_norm=1.859385e-02 psi_norm=5.873339e+00 policy_optimizer=adam state_weight_update=clipped state_weight_min=-1.793413e-02 state_weight_max=1.245945e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
# [FOGAS linear-policy] Iter 1951/2000 total_loss=-2.475400e-01 policy_objective=-1.314532e+01 theta_norm=1.897367e+01 beta_norm=2.320207e+00 grad_norm=9.361923e+00 policy_grad_norm=1.818739e-02 psi_norm=5.886310e+00 policy_optimizer=adam state_weight_update=clipped state_weight_min=-1.820772e-02 state_weight_max=1.248521e-01 policy_state_weight_min=5.000000e-01 policy_state_weight_max=5.000000e-01
#   State 0: π(a=0|s=0) = 0.12  π(a=1|s=0) = 0.48  π(a=2|s=0) = 0.13  π(a=3|s=0) = 0.27  --> best action: 1
#   State 1: π(a=0|s=1) = 0.19  π(a=1|s=1) = 0.22  π(a=2|s=1) = 0.09  π(a=3|s=1) = 0.50  --> best action: 3
#   State 2: π(a=0|s=2) = 0.24  π(a=1|s=2) = 0.53  π(a=2|s=2) = 0.01  π(a=3|s=2) = 0.21  --> best action: 1
#   State 3: π(a=0|s=3) = 0.08  π(a=1|s=3) = 0.67  π(a=2|s=3) = 0.12  π(a=3|s=3) = 0.13  --> best action: 1
#   State 4: π(a=0|s=4) = 0.25  π(a=1|s=4) = 0.25  π(a=2|s=4) = 0.25  π(a=3|s=4) = 0.25  --> best action: 0
#   State 5: π(a=0|s=5) = 0.03  π(a=1|s=5) = 0.48  π(a=2|s=5) = 0.01  π(a=3|s=5) = 0.48  --> best action: 1
#   State 6: π(a=0|s=6) = 0.04  π(a=1|s=6) = 0.12  π(a=2|s=6) = 0.12  π(a=3|s=6) = 0.72  --> best action: 3
#   State 7: π(a=0|s=7) = 0.16  π(a=1|s=7) = 0.16  π(a=2|s=7) = 0.04  π(a=3|s=7) = 0.63  --> best action: 3
#   State 8: π(a=0|s=8) = 0.25  π(a=1|s=8) = 0.25  π(a=2|s=8) = 0.25  π(a=3|s=8) = 0.25  --> best action: 0

# %% [markdown]
# Here Adam is much better than SGD and we can notice the accumulation of momentum and we have higuer probabilities in optimal states.

# %% [markdown]
# # RBF Features

# %%
# -----------------------------
# Problem definition
# -----------------------------
states = torch.arange(9, dtype=torch.long)
actions = torch.arange(4, dtype=torch.long)
N = len(states)
A = len(actions)
gamma = 0.9

x_0 = 0
dataset_path = str(DATASETS_DIR / "3gridw_rbf.csv")

goal = 8
pit  = 5
wall = 4

step_cost   = -0.01
goal_reward = 1.0
pit_reward  = -1.0

# -----------------------------
# Helpers
# -----------------------------
def to_rc(s):
    return divmod(int(s), 3)

def to_s(r, c):
    return int(r) * 3 + int(c)

def get_norm_coords(s):
    r, c = to_rc(s)
    return torch.tensor([r / 2.0, c / 2.0], dtype=torch.float64)

# -----------------------------
# Deterministic dynamics
# -----------------------------
def next_state(s, a):
    s = int(s)
    a = int(a)

    if s == goal or s == pit:
        return s

    r, c = to_rc(s)

    if a == 0:
        r2, c2 = max(0, r - 1), c      # up
    elif a == 1:
        r2, c2 = min(2, r + 1), c      # down
    elif a == 2:
        r2, c2 = r, max(0, c - 1)      # left
    elif a == 3:
        r2, c2 = r, min(2, c + 1)      # right
    else:
        raise ValueError("Invalid action")

    sp = to_s(r2, c2)
    if sp == wall:
        return s
    return sp

# -----------------------------
# Transition matrix
# -----------------------------
P = torch.zeros((N * A, N), dtype=torch.float64)
for x in states:
    for a in actions:
        idx = int(x) * A + int(a)
        xp = next_state(x, a)
        P[idx, xp] = 1.0

# -----------------------------
# Reward
# -----------------------------
def reward_fn(x, a):
    x = int(x)
    if x == goal:
        return goal_reward
    if x == pit:
        return pit_reward
    return step_cost

# -----------------------------
# RBF features
# phi(x,a) = e_a ⊗ phi_state(x)
# -----------------------------
grid_1d = torch.tensor([0.25, 0.75], dtype=torch.float64)
centers = torch.cartesian_prod(grid_1d, grid_1d)

def calculate_local_sigma(centers, k=2):
    dist_matrix = torch.cdist(centers, centers, p=2)
    topk_dists, _ = torch.topk(dist_matrix, k + 1, largest=False, dim=1)
    nearest_neighbor_dists = topk_dists[:, 1]
    return torch.mean(nearest_neighbor_dists)

rbf_sigma = calculate_local_sigma(centers, k=2) * 4

def phi_state(x):
    coords = get_norm_coords(x)
    dist_sq = torch.sum((coords - centers) ** 2, dim=1)
    rbf = torch.exp(-dist_sq / (2 * rbf_sigma ** 2))

    is_pit = 1.0 if int(x) == pit else 0.0
    is_goal = 1.0 if int(x) == goal else 0.0

    return torch.cat([
        rbf,
        torch.tensor([is_pit, is_goal], dtype=torch.float64),
    ])

def phi(x, a):
    s_feat = phi_state(x)
    e_a = torch.zeros(A, dtype=torch.float64)
    e_a[int(a)] = 1.0
    return torch.kron(e_a, s_feat)

d = int(phi(states[0], actions[0]).shape[0])
print("Feature dimension:", d)

# -----------------------------
# Build MDP / solver input
# -----------------------------
mdp = PolicySolver(
    states=states,
    actions=actions,
    phi=phi,
    reward_fn=reward_fn,
    gamma=gamma,
    x0=x_0,
    P=P,
)
# Out:
# Feature dimension: 24

# %% [markdown]
# ### Empirical

# %%
collector = EnvDataCollector(
    mdp=mdp,
    max_steps=30,
    terminal_states=[goal, pit],
    seed=42,
)

df = collector.collect_mixed_dataset_terminal_aware(
    policies=[
        (mdp.pi_star, 0.4),   # epsilon-greedy around pi_star
        "random",
    ],
    proportions=[0.8, 0.2],
    n_steps=1000,
    save_path=dataset_path,
    verbose=True,
    episode_based=True,
    extra_steps=2,
)
# Out:
# ============================================================
#   MIXED TERMINAL-AWARE DATASET COLLECTION SUMMARY (TORCH)
# ============================================================
# Total transitions: 1000
# Total episodes: 106
# Extra steps: 2
#
# Policy Distribution:
#   Policy 0:   791 steps (79.1%) | Target: 80.0% | Episodes: 91
#   Policy 1:   209 steps (20.9%) | Target: 20.0% | Episodes: 16
# ============================================================
#
# ✅ Mixed terminal-aware dataset saved to: /home/mauro/Desktop/EMAI/Ljubljana/Thesis/Code/datasets/3gridw_rbf.csv

# %%
solver_e = FOGASSolverBetaVectorized(mdp=mdp, print_params=True, csv_path=dataset_path, seed=SEED, device=DEVICE)
evaluator_e = FOGASEvaluator(solver_e)
optimizer_e = FOGASHyperOptimizer(solver=solver_e,metric_callable=evaluator_e.get_metric("reward"))
# Out:
# MDP omega not provided. Estimating from dataset...
#
# Device: cpu
# Dataset: /home/mauro/Desktop/EMAI/Ljubljana/Thesis/Code/datasets/3gridw_rbf.csv (n=1000)
#
# ================ FOGAS PARAMETER SUMMARY ================
#
# Basic Information
# -----------------
# Dataset size n:           1000
# Feature norm bound R:     2.1562
# Num states N:             9
# Num actions A:            4
# Feature dim d:            24
# Discount γ:               0.9
# Confidence δ:             0.05
#
# Theoretical Quantities
# ----------------------
# T_min (theoretical):      4302.854671800086
# T (iterations):                4303
#
# FOGAS Hyperparameters
# ---------------------
# alpha:                        0.000240
# rho:                            424.257383
# eta:                            0.000006
# D_theta:                    15.491933
# beta (ridge):             0.000045
# D_pi (derived):           16.019217
#
# =========================================================
#
# Estimated omega (first 5 components): tensor([-6.7756e-03, -8.1840e-03,  2.0385e-04,  4.1750e-03, -9.7534e-01])

# %%
solver_e.run(alpha=1e-2, eta=2e-4, rho=0.5, tqdm_print=True, T = 4000)
evaluator_e.compare_value_functions()
evaluator_e.compare_final_rewards()
evaluator_e.print_policy()
# Out:
# FOGAS:   0%|          | 0/4000 [00:00<?, ?it/s]
# FOGAS: 100%|██████████| 4000/4000 [00:01<00:00, 2368.62it/s]
# ========== VALUE FUNCTION COMPARISON ==========
#
# State-wise V comparison:
# State 0: V*(x) =  6.526610 | V^π(x) =  2.589096 | Δ = -3.937514e+00
# State 1: V*(x) =  5.863949 | V^π(x) =  0.382445 | Δ = -5.481504e+00
# State 2: V*(x) =  5.267554 | V^π(x) = -2.756923 | Δ = -8.024477e+00
# State 3: V*(x) =  7.262900 | V^π(x) =  3.872153 | Δ = -3.390747e+00
# State 4: V*(x) =  8.081000 | V^π(x) = -0.301057 | Δ = -8.382057e+00
# State 5: V*(x) = -10.000000 | V^π(x) = -10.000000 | Δ =  1.243450e-14
# State 6: V*(x) =  8.081000 | V^π(x) =  5.482169 | Δ = -2.598831e+00
# State 7: V*(x) =  8.990000 | V^π(x) =  7.566916 | Δ = -1.423084e+00
# State 8: V*(x) =  10.000000 | V^π(x) =  10.000000 | Δ = -1.243450e-14
#
# Action-value Q comparison:
# (x=0, a=0): Q*(x,a) =  5.863949 | Q^π(x,a) =  2.320187 | Δ = -3.543762e+00
# (x=0, a=1): Q*(x,a) =  6.526610 | Q^π(x,a) =  3.474938 | Δ = -3.051672e+00
# (x=0, a=2): Q*(x,a) =  5.863949 | Q^π(x,a) =  2.320187 | Δ = -3.543762e+00
# (x=0, a=3): Q*(x,a) =  5.267554 | Q^π(x,a) =  0.334201 | Δ = -4.933353e+00
# (x=1, a=0): Q*(x,a) =  5.267554 | Q^π(x,a) =  0.334201 | Δ = -4.933353e+00
# (x=1, a=1): Q*(x,a) =  5.267554 | Q^π(x,a) =  0.334201 | Δ = -4.933353e+00
# (x=1, a=2): Q*(x,a) =  5.863949 | Q^π(x,a) =  2.320187 | Δ = -3.543762e+00
# (x=1, a=3): Q*(x,a) =  4.730799 | Q^π(x,a) = -2.491230 | Δ = -7.222029e+00
# (x=2, a=0): Q*(x,a) =  4.730799 | Q^π(x,a) = -2.491230 | Δ = -7.222029e+00
# (x=2, a=1): Q*(x,a) = -9.010000 | Q^π(x,a) = -9.010000 | Δ =  1.065814e-14
# (x=2, a=2): Q*(x,a) =  5.267554 | Q^π(x,a) =  0.334201 | Δ = -4.933353e+00
# (x=2, a=3): Q*(x,a) =  4.730799 | Q^π(x,a) = -2.491230 | Δ = -7.222029e+00
# (x=3, a=0): Q*(x,a) =  5.863949 | Q^π(x,a) =  2.320187 | Δ = -3.543762e+00
# (x=3, a=1): Q*(x,a) =  7.262900 | Q^π(x,a) =  4.923952 | Δ = -2.338948e+00
# (x=3, a=2): Q*(x,a) =  6.526610 | Q^π(x,a) =  3.474938 | Δ = -3.051672e+00
# (x=3, a=3): Q*(x,a) =  6.526610 | Q^π(x,a) =  3.474938 | Δ = -3.051672e+00
# (x=4, a=0): Q*(x,a) =  5.267554 | Q^π(x,a) =  0.334201 | Δ = -4.933353e+00
# (x=4, a=1): Q*(x,a) =  8.081000 | Q^π(x,a) =  6.800225 | Δ = -1.280775e+00
# (x=4, a=2): Q*(x,a) =  6.526610 | Q^π(x,a) =  3.474938 | Δ = -3.051672e+00
# (x=4, a=3): Q*(x,a) = -9.010000 | Q^π(x,a) = -9.010000 | Δ =  1.065814e-14
# (x=5, a=0): Q*(x,a) = -10.000000 | Q^π(x,a) = -10.000000 | Δ =  1.065814e-14
# (x=5, a=1): Q*(x,a) = -10.000000 | Q^π(x,a) = -10.000000 | Δ =  1.065814e-14
# (x=5, a=2): Q*(x,a) = -10.000000 | Q^π(x,a) = -10.000000 | Δ =  1.065814e-14
# (x=5, a=3): Q*(x,a) = -10.000000 | Q^π(x,a) = -10.000000 | Δ =  1.065814e-14
# (x=6, a=0): Q*(x,a) =  6.526610 | Q^π(x,a) =  3.474938 | Δ = -3.051672e+00
# (x=6, a=1): Q*(x,a) =  7.262900 | Q^π(x,a) =  4.923952 | Δ = -2.338948e+00
# (x=6, a=2): Q*(x,a) =  7.262900 | Q^π(x,a) =  4.923952 | Δ = -2.338948e+00
# (x=6, a=3): Q*(x,a) =  8.081000 | Q^π(x,a) =  6.800225 | Δ = -1.280775e+00
# (x=7, a=0): Q*(x,a) =  8.081000 | Q^π(x,a) =  6.800225 | Δ = -1.280775e+00
# (x=7, a=1): Q*(x,a) =  8.081000 | Q^π(x,a) =  6.800225 | Δ = -1.280775e+00
# (x=7, a=2): Q*(x,a) =  7.262900 | Q^π(x,a) =  4.923952 | Δ = -2.338948e+00
# (x=7, a=3): Q*(x,a) =  8.990000 | Q^π(x,a) =  8.990000 | Δ = -1.065814e-14
# (x=8, a=0): Q*(x,a) =  10.000000 | Q^π(x,a) =  10.000000 | Δ = -1.065814e-14
# (x=8, a=1): Q*(x,a) =  10.000000 | Q^π(x,a) =  10.000000 | Δ = -1.065814e-14
# (x=8, a=2): Q*(x,a) =  10.000000 | Q^π(x,a) =  10.000000 | Δ = -1.065814e-14
# (x=8, a=3): Q*(x,a) =  10.000000 | Q^π(x,a) =  10.000000 | Δ = -1.065814e-14
#
# Norm diagnostics:
# ||V^π - V*||_2 = 1.415903e+01
# ||Q^π - Q*||_2 = 2.008491e+01
#
# ===============================================
#
#
# ========== FINAL REWARD COMPARISON ==========
#
# J*(π*)   = 0.652661
# J(π_FOGAS) = 0.258910
# Gap (J* − J) = 3.937514e-01
#
# ============================================
#
#   State 0: π(a=0|s=0) = 0.18  π(a=1|s=0) = 0.47  π(a=2|s=0) = 0.21  π(a=3|s=0) = 0.14  --> best action: 1
#   State 1: π(a=0|s=1) = 0.18  π(a=1|s=1) = 0.33  π(a=2|s=1) = 0.30  π(a=3|s=1) = 0.19  --> best action: 1
#   State 2: π(a=0|s=2) = 0.18  π(a=1|s=2) = 0.20  π(a=2|s=2) = 0.38  π(a=3|s=2) = 0.24  --> best action: 2
#   State 3: π(a=0|s=3) = 0.16  π(a=1|s=3) = 0.40  π(a=2|s=3) = 0.18  π(a=3|s=3) = 0.25  --> best action: 1
#   State 4: π(a=0|s=4) = 0.16  π(a=1|s=4) = 0.26  π(a=2|s=4) = 0.24  π(a=3|s=4) = 0.33  --> best action: 3
#   State 5: π(a=0|s=5) = 0.27  π(a=1|s=5) = 0.20  π(a=2|s=5) = 0.28  π(a=3|s=5) = 0.26  --> best action: 2
#   State 6: π(a=0|s=6) = 0.14  π(a=1|s=6) = 0.31  π(a=2|s=6) = 0.14  π(a=3|s=6) = 0.41  --> best action: 3
#   State 7: π(a=0|s=7) = 0.13  π(a=1|s=7) = 0.18  π(a=2|s=7) = 0.18  π(a=3|s=7) = 0.50  --> best action: 3
#   State 8: π(a=0|s=8) = 0.70  π(a=1|s=8) = 0.13  π(a=2|s=8) = 0.09  π(a=3|s=8) = 0.09  --> best action: 0
