# %%
# %load_ext autoreload
# %autoreload 2

import os
import random
import numpy as np
import pandas as pd
import sys
import torch
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches

SEED = 42
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.set_default_dtype(torch.float64)

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
if torch.backends.cudnn.is_available():
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

def find_root(current_path, marker="setup.py"):
    current_path = Path(current_path).resolve()
    for parent in [current_path] + list(current_path.parents):
        if (parent / marker).exists():
            return parent
    return current_path

PROJECT_ROOT = find_root(Path.cwd())

DATASETS_DIR = PROJECT_ROOT / "data" / "datasets_clean" / "generalization"
RESULTS_DIR = PROJECT_ROOT / "data" / "results_clean" / "generalization"
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

# Add project root to the Python path
if str(PROJECT_ROOT / "src") not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / "src"))

from rl_methods.mdp_clean import DiscreteMDP, Planner
from rl_methods.fogas_clean import FOGASEvaluator, FOGASHyperOptimizer
from rl_methods.fogas_generalization_clean import *
from rl_methods.fogas_generalization_clean import (
    FinalLinearSolver,
    TabularFeatures,
    LinearFunction,
    LinearQFunction,
)
from rl_methods.data_collection_clean import DiscreteDataBuffer
from rl_methods.fogas_clean import FOGASEvaluator
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 5grid

# %%
states = torch.arange(25, dtype=torch.long)
actions = torch.arange(4, dtype=torch.long)

N = len(states)
A = len(actions)
gamma = 0.99
x_0 = 0

dataset_path_5grid = str(DATASETS_DIR / "5grid.csv")

grid_size = 5
goal_grid = 24

wall_states = {6, 7, 12}
terminal_states = {goal_grid}


def state_to_pos(s):
    return divmod(int(s), grid_size)


def pos_to_state(row, col):
    return row * grid_size + col


def move_deterministic(s, a):
    s = int(s)
    a = int(a)

    if s in terminal_states:
        return s

    row, col = state_to_pos(s)

    if a == 0:      # Up
        new_row, new_col = row - 1, col
    elif a == 1:    # Down
        new_row, new_col = row + 1, col
    elif a == 2:    # Left
        new_row, new_col = row, col - 1
    elif a == 3:    # Right
        new_row, new_col = row, col + 1
    else:
        raise ValueError("action must be in {0, 1, 2, 3}")

    if not (0 <= new_row < grid_size and 0 <= new_col < grid_size):
        return s

    sp = pos_to_state(new_row, new_col)

    if sp in wall_states:
        return s

    return sp


def next_state(s, a):
    return move_deterministic(s, a)


def transition_fn(s, a):
    probs = torch.zeros(N, dtype=torch.float64)
    probs[next_state(s, a)] = 1.0
    return probs


def reward_fn(s, a):
    sp = next_state(s, a)

    if sp == goal_grid:
        return 1.0

    return -0.01


mdp = DiscreteMDP(
    states=states,
    actions=actions,
    gamma=gamma,
    x0=x_0,
    reward_fn=reward_fn,
    transition_fn=transition_fn,
    terminal_states=list(terminal_states),
).to(DEVICE)

planner = Planner(mdp)

# %%
def plot_5grid(values=None, policy=None, title="5x5 Grid World"):
    grid_data = np.full((grid_size, grid_size), ".", dtype="<U1")

    for s in wall_states:
        r, c = state_to_pos(s)
        grid_data[r, c] = "#"

    r, c = state_to_pos(x_0)
    grid_data[r, c] = "S"

    r, c = state_to_pos(goal_grid)
    grid_data[r, c] = "G"

    mapping = {".": 0, "#": 1, "S": 2, "G": 3}
    labels = {0: "Empty", 1: "Wall", 2: "Start", 3: "Goal"}
    colors = ["#F5F5F5", "#2C2C2C", "#457B9D", "#2DC653"]

    numeric_grid = np.vectorize(mapping.get)(grid_data)
    cmap = mcolors.ListedColormap(colors)

    fig, ax = plt.subplots(figsize=(7, 7))
    ax.imshow(
        numeric_grid,
        cmap=cmap,
        vmin=0,
        vmax=3,
        interpolation="nearest",
        origin="upper",
    )

    ax.set_xticks(np.arange(-0.5, grid_size, 1), minor=True)
    ax.set_yticks(np.arange(-0.5, grid_size, 1), minor=True)
    ax.grid(which="minor", color="#888888", linewidth=0.8, alpha=0.6)
    ax.tick_params(which="minor", bottom=False, left=False)

    ax.set_xticks(np.arange(grid_size))
    ax.set_yticks(np.arange(grid_size))
    ax.set_xlabel("Column", fontsize=10)
    ax.set_ylabel("Row", fontsize=10)

    if values is not None:
        if hasattr(values, "detach"):
            values = values.detach().cpu().numpy()
        values = np.asarray(values).reshape(-1)

    if policy is not None:
        if hasattr(policy, "detach"):
            policy = policy.detach().cpu().numpy()
        policy = np.asarray(policy)
        best_actions = policy.argmax(axis=1) if policy.ndim == 2 else policy

    arrow_delta = {
        0: (0.0, -0.28),  # Up
        1: (0.0, 0.28),   # Down
        2: (-0.28, 0.0),  # Left
        3: (0.28, 0.0),   # Right
    }

    for s in range(N):
        r, c = state_to_pos(s)

        if s == goal_grid:
            ax.text(c, r, "G", ha="center", va="center", fontsize=14, fontweight="bold", color="white")
        elif s in wall_states:
            ax.text(c, r, "#", ha="center", va="center", fontsize=14, fontweight="bold", color="white")
        elif s == x_0:
            ax.text(c, r, "S", ha="center", va="center", fontsize=14, fontweight="bold", color="white")
        else:
            ax.text(c - 0.38, r - 0.34, str(s), fontsize=8, color="#666666")

        if values is not None and s not in wall_states:
            ax.text(c, r + 0.28, f"{values[s]:.2f}", ha="center", va="center", fontsize=9)

        if policy is not None and s not in terminal_states and s not in wall_states:
            dx, dy = arrow_delta[int(best_actions[s])]
            ax.arrow(
                c,
                r,
                dx,
                dy,
                head_width=0.10,
                head_length=0.10,
                fc="black",
                ec="black",
                linewidth=1.4,
                length_includes_head=True,
                zorder=5,
            )

    patches = [
        mpatches.Patch(color=colors[i], label=f"{symbol}  {labels[i]}")
        for symbol, i in mapping.items()
    ]

    ax.legend(
        handles=patches,
        bbox_to_anchor=(1.02, 1),
        loc="upper left",
        fontsize=9,
        framealpha=0.9,
    )

    ax.set_title(title, fontsize=14, pad=12)
    plt.tight_layout()
    plt.show()


plot_5grid()

# %% [markdown]
# ## Data collection

# %%
# Initialize the clean collector.
# every episode starts from state 0.
collector = DiscreteDataBuffer(
    mdp=mdp,
    reset_probs={"custom": 1.0},
    initial_states=[x_0],              
    restricted_states=wall_states,     
    max_steps=50,
    terminal_states={goal_grid},
    seed=SEED,
)

# Epsilon-greedy around the optimal policy.
# epsilon=0.3 means 70% planner.pi_star, 30% random action.
epsilon_policy = (planner.pi_star, 0.3)

df = collector.collect(
    policies=[epsilon_policy, "random"],
    proportions=[0.9, 0.1],
    n_steps=8000,
    extra_terminal_steps=3,
    episode_based=True,
    save_path=str(dataset_path_5grid),
    verbose=True,
)

df.head()
# Out:
# Collected 8000 transitions over 461 episodes.
# Policy distribution:
# policy_id
# 0    0.746
# 1    0.254
# Name: proportion, dtype: float64
# Reset mode distribution:
# reset_mode
# custom    1.0
# Name: proportion, dtype: float64
# Saved FOGAS dataset to /home/mauro/Desktop/EMAI/Ljubljana/Thesis/Code/data/datasets_clean/generalization/5grid.csv
#    episode  step  state  action  reward  next_state  policy_id reset_mode  \
# 0        0     0      0       1   -0.01           5          0     custom
# 1        0     1      5       1   -0.01          10          0     custom
# 2        0     2     10       3   -0.01          11          0     custom
# 3        0     3     11       1   -0.01          16          0     custom
# 4        0     4     16       1   -0.01          21          0     custom
#
#    restricted_start
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %% [markdown]
# ## Solver

# %%
NN_SEED = 123
EVAL_SEED = 42

random.seed(NN_SEED)
np.random.seed(NN_SEED)
torch.manual_seed(NN_SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(NN_SEED)

state_inputs = torch.tensor(
    [[r / 4.0, c / 4.0] for r in range(grid_size) for c in range(grid_size)],
    dtype=torch.float64,
)

hidden_sizes = (8,)

u_param = NeuralUParam(
    StateActionMLPModule(
        n_states=N,
        n_actions=A,
        state_inputs=state_inputs,
        hidden_sizes=hidden_sizes,
        dtype=torch.float64,
    )
)

q_param = NeuralQParam(
    StateActionMLPModule(
        n_states=N,
        n_actions=A,
        state_inputs=state_inputs,
        hidden_sizes=hidden_sizes,
        dtype=torch.float64,
    )
)

policy_param = NeuralPolicyParam(
    StateMLPPolicyModule(
        n_states=N,
        n_actions=A,
        state_inputs=state_inputs,
        hidden_sizes=hidden_sizes,
        dtype=torch.float64,
    )
)

solver_e = FinalParametrizedSolver(
    n_states=N,
    n_actions=A,
    gamma=gamma,
    x0=x_0,
    csv_path=dataset_path_5grid,
    u_param=u_param,
    q_param=q_param,
    policy_param=policy_param,
    seed=NN_SEED,
    device=DEVICE,

    theta_include_beta_cov=False,

    theta_mode="reg_fixed",
    theta_lambda=1e-3,
    theta_optimizer="adam",
    theta_inner_steps=3,
    theta_lr=3e-3,
    theta_start_mode="warm",

    beta_update="fogas_diag",
    beta_reg=1e-4,
)

solver_e.run(
    alpha=1e-3,
    eta=3e-5,
    rho=0.01,
    policy_optimizer="adam",
    policy_gradient="exact",
    reinforce_samples=1,
    tqdm_print=False,
    verbose=True,
    log_interval=50,
    T=1000,
    state_weight_update="normal",
)

mdp.print_policy(solver_e.pi)

evaluator = FOGASEvaluator(
    solver=solver_e,
    mdp=mdp,
    planner=planner,
)

solver_stats = evaluator.average_return_stats(
    policy_mode="solver",
    num_trajectories=100,
    max_steps=20,
    seed=EVAL_SEED,
    terminal_states=terminal_states,
    compare_with_optimal=True,
)

greedy_stats = evaluator.average_return_stats(
    policy_mode="greedy",
    num_trajectories=100,
    max_steps=20,
    seed=EVAL_SEED,
    terminal_states=terminal_states,
    compare_with_optimal=True,
)

print(f"Solver avg reward:  {solver_stats['policy']:.4f} +- {solver_stats['policy_std']:.4f}")
print(f"Greedy avg reward:  {greedy_stats['policy']:.4f} +- {greedy_stats['policy_std']:.4f}")
print(f"Optimal avg reward: {solver_stats['optimal']:.4f} +- {solver_stats['optimal_std']:.4f}")
# Out:
# [FinalParametrizedSolver] Iter 1/1000 iter=0 total_loss=-9.791755e-02 policy_objective=-8.612625e-03 beta_objective=-9.747879e-02 q_objective=-1.146592e-02 policy_grad_norm=2.929940e-02 policy_direction_norm=2.929940e-02 beta_grad_norm=4.058274e-01 beta_direction_norm=2.017986e+01 theta_grad_norm=8.313617e-02 theta_norm=1.883720e+00 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-03 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=1 D_theta=8.062258e+01 effective_D_theta=8.062258e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.495232e-03 beta_diag_max=1.000100e+00
# [FinalParametrizedSolver] Iter 51/1000 iter=50 total_loss=-3.390317e-01 policy_objective=3.629509e-01 beta_objective=-3.107118e-01 q_objective=-2.622666e-01 policy_grad_norm=4.634457e-01 policy_direction_norm=4.634457e-01 beta_grad_norm=1.650165e+00 beta_direction_norm=8.051128e+01 theta_grad_norm=1.653502e-01 theta_norm=4.203687e+00 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-03 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=1 D_theta=8.062258e+01 effective_D_theta=8.062258e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.612579e-03 beta_diag_max=1.000100e+00
# [FinalParametrizedSolver] Iter 101/1000 iter=100 total_loss=-2.475967e-01 policy_objective=1.159265e+00 beta_objective=-1.712001e-01 q_objective=-1.889909e-01 policy_grad_norm=6.548767e-01 policy_direction_norm=6.548767e-01 beta_grad_norm=2.270866e+00 beta_direction_norm=1.317360e+02 theta_grad_norm=7.922600e-02 theta_norm=7.029739e+00 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-03 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=1 D_theta=8.062258e+01 effective_D_theta=8.062258e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.853827e-03 beta_diag_max=1.000100e+00
# [FinalParametrizedSolver] Iter 151/1000 iter=150 total_loss=-2.230263e-01 policy_objective=1.550839e+00 beta_objective=-1.009544e-01 q_objective=-1.810638e-01 policy_grad_norm=2.081334e-01 policy_direction_norm=2.081334e-01 beta_grad_norm=2.639675e+00 beta_direction_norm=1.098904e+02 theta_grad_norm=1.385918e-01 theta_norm=8.391058e+00 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-03 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=1 D_theta=8.062258e+01 effective_D_theta=8.062258e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=2.019411e-03 beta_diag_max=1.000100e+00
# [FinalParametrizedSolver] Iter 201/1000 iter=200 total_loss=-3.955631e-01 policy_objective=9.980963e-01 beta_objective=-2.429841e-01 q_objective=-3.725425e-01 policy_grad_norm=9.122973e-02 policy_direction_norm=9.122973e-02 beta_grad_norm=3.393158e+00 beta_direction_norm=9.784076e+01 theta_grad_norm=1.499817e-01 theta_norm=9.511987e+00 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-03 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=1 D_theta=8.062258e+01 effective_D_theta=8.062258e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.948787e-03 beta_diag_max=1.000100e+00
# [FinalParametrizedSolver] Iter 251/1000 iter=250 total_loss=-6.227367e-01 policy_objective=4.912250e-01 beta_objective=-4.762567e-01 q_objective=-6.175457e-01 policy_grad_norm=2.671331e-01 policy_direction_norm=2.671331e-01 beta_grad_norm=1.825362e+00 beta_direction_norm=1.607293e+02 theta_grad_norm=1.549485e-01 theta_norm=1.001749e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-03 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=1 D_theta=8.062258e+01 effective_D_theta=8.062258e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.758478e-03 beta_diag_max=1.000100e+00
# [FinalParametrizedSolver] Iter 301/1000 iter=300 total_loss=-4.695178e-01 policy_objective=6.402796e-01 beta_objective=-3.036377e-01 q_objective=-4.652044e-01 policy_grad_norm=4.373713e-01 policy_direction_norm=4.373713e-01 beta_grad_norm=1.644716e+00 beta_direction_norm=2.456235e+02 theta_grad_norm=1.014597e-01 theta_norm=1.137932e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-03 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=1 D_theta=8.062258e+01 effective_D_theta=8.062258e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.647727e-03 beta_diag_max=1.000100e+00
# [FinalParametrizedSolver] Iter 351/1000 iter=350 total_loss=-2.457004e-01 policy_objective=9.602513e-01 beta_objective=-1.937386e-03 q_objective=-2.447240e-01 policy_grad_norm=2.349871e-01 policy_direction_norm=2.349871e-01 beta_grad_norm=1.184205e+00 beta_direction_norm=1.814391e+02 theta_grad_norm=8.076856e-02 theta_norm=1.256097e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-03 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=1 D_theta=8.062258e+01 effective_D_theta=8.062258e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.551765e-03 beta_diag_max=1.000100e+00
# [FinalParametrizedSolver] Iter 401/1000 iter=400 total_loss=-3.953122e-01 policy_objective=1.056795e+00 beta_objective=-1.117389e-01 q_objective=-3.937900e-01 policy_grad_norm=1.457117e-01 policy_direction_norm=1.457117e-01 beta_grad_norm=9.287637e-01 beta_direction_norm=6.935877e+01 theta_grad_norm=1.049950e-01 theta_norm=1.354639e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-03 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=1 D_theta=8.062258e+01 effective_D_theta=8.062258e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.276406e-03 beta_diag_max=1.000100e+00
# [FinalParametrizedSolver] Iter 451/1000 iter=450 total_loss=-4.944966e-01 policy_objective=7.930891e-01 beta_objective=-1.840672e-01 q_objective=-5.110104e-01 policy_grad_norm=2.160696e-01 policy_direction_norm=2.160696e-01 beta_grad_norm=3.017260e+00 beta_direction_norm=1.921480e+02 theta_grad_norm=7.096807e-02 theta_norm=1.508549e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-03 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=1 D_theta=8.062258e+01 effective_D_theta=8.062258e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.326371e-03 beta_diag_max=1.000100e+00
# [FinalParametrizedSolver] Iter 501/1000 iter=500 total_loss=-4.113472e-01 policy_objective=1.268583e+00 beta_objective=-8.424556e-02 q_objective=-4.410740e-01 policy_grad_norm=1.212456e-01 policy_direction_norm=1.212456e-01 beta_grad_norm=1.166405e+00 beta_direction_norm=1.354826e+02 theta_grad_norm=7.928748e-02 theta_norm=1.673240e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-03 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=1 D_theta=8.062258e+01 effective_D_theta=8.062258e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.256450e-03 beta_diag_max=1.000100e+00
# [FinalParametrizedSolver] Iter 551/1000 iter=550 total_loss=-5.319460e-01 policy_objective=1.373804e+00 beta_objective=-1.420281e-01 q_objective=-5.618004e-01 policy_grad_norm=1.516949e-01 policy_direction_norm=1.516949e-01 beta_grad_norm=6.979276e-01 beta_direction_norm=6.450863e+01 theta_grad_norm=7.861928e-02 theta_norm=1.823655e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-03 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=1 D_theta=8.062258e+01 effective_D_theta=8.062258e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.159130e-03 beta_diag_max=1.000100e+00
# [FinalParametrizedSolver] Iter 601/1000 iter=600 total_loss=-5.281737e-01 policy_objective=1.025414e+00 beta_objective=-9.813572e-02 q_objective=-5.515484e-01 policy_grad_norm=3.548091e-01 policy_direction_norm=3.548091e-01 beta_grad_norm=1.723809e+00 beta_direction_norm=2.094964e+02 theta_grad_norm=4.266289e-02 theta_norm=1.920084e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-03 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=1 D_theta=8.062258e+01 effective_D_theta=8.062258e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.310677e-03 beta_diag_max=1.000100e+00
# [FinalParametrizedSolver] Iter 651/1000 iter=650 total_loss=-1.968029e-01 policy_objective=1.625533e+00 beta_objective=2.289924e-01 q_objective=-2.288178e-01 policy_grad_norm=4.677255e-01 policy_direction_norm=4.677255e-01 beta_grad_norm=4.984269e+00 beta_direction_norm=2.061806e+02 theta_grad_norm=1.119944e-01 theta_norm=2.006435e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-03 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=1 D_theta=8.062258e+01 effective_D_theta=8.062258e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=8.584713e-04 beta_diag_max=1.000100e+00
# [FinalParametrizedSolver] Iter 701/1000 iter=700 total_loss=1.114655e-01 policy_objective=3.612653e+00 beta_objective=4.950582e-01 q_objective=5.402703e-02 policy_grad_norm=2.696731e-01 policy_direction_norm=2.696731e-01 beta_grad_norm=6.226375e+00 beta_direction_norm=2.753428e+02 theta_grad_norm=3.035910e-01 theta_norm=2.008925e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-03 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=1 D_theta=8.062258e+01 effective_D_theta=8.062258e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=6.538199e-04 beta_diag_max=1.000100e+00
# [FinalParametrizedSolver] Iter 751/1000 iter=750 total_loss=-2.007752e-01 policy_objective=3.230220e+00 beta_objective=4.972041e-02 q_objective=-2.552057e-01 policy_grad_norm=4.585239e-01 policy_direction_norm=4.585239e-01 beta_grad_norm=1.918896e+00 beta_direction_norm=2.164340e+02 theta_grad_norm=4.267808e-01 theta_norm=1.985312e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-03 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=1 D_theta=8.062258e+01 effective_D_theta=8.062258e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=5.828579e-04 beta_diag_max=1.000100e+00
# [FinalParametrizedSolver] Iter 801/1000 iter=800 total_loss=-1.708850e-01 policy_objective=2.319442e+00 beta_objective=-9.182077e-02 q_objective=-2.080544e-01 policy_grad_norm=6.446864e-01 policy_direction_norm=6.446864e-01 beta_grad_norm=1.402145e+00 beta_direction_norm=1.438605e+02 theta_grad_norm=1.159318e-01 theta_norm=1.989491e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-03 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=1 D_theta=8.062258e+01 effective_D_theta=8.062258e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=5.700570e-04 beta_diag_max=1.000100e+00
# [FinalParametrizedSolver] Iter 851/1000 iter=850 total_loss=3.519527e-02 policy_objective=1.515190e+00 beta_objective=5.805804e-02 q_objective=3.321448e-03 policy_grad_norm=5.509989e-01 policy_direction_norm=5.509989e-01 beta_grad_norm=1.759389e+00 beta_direction_norm=1.327639e+02 theta_grad_norm=1.127351e-01 theta_norm=1.996170e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-03 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=1 D_theta=8.062258e+01 effective_D_theta=8.062258e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=5.464291e-04 beta_diag_max=1.000100e+00
# [FinalParametrizedSolver] Iter 901/1000 iter=900 total_loss=7.874863e-02 policy_objective=3.893739e-01 beta_objective=1.020818e-01 q_objective=6.001227e-02 policy_grad_norm=2.986029e-01 policy_direction_norm=2.986029e-01 beta_grad_norm=1.541933e+00 beta_direction_norm=1.233183e+02 theta_grad_norm=1.112921e-01 theta_norm=2.007196e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-03 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=1 D_theta=8.062258e+01 effective_D_theta=8.062258e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=6.379008e-04 beta_diag_max=1.000100e+00
# [FinalParametrizedSolver] Iter 951/1000 iter=950 total_loss=7.891515e-02 policy_objective=-6.470411e-01 beta_objective=1.463334e-01 q_objective=6.556593e-02 policy_grad_norm=1.528889e-01 policy_direction_norm=1.528889e-01 beta_grad_norm=9.956930e-01 beta_direction_norm=1.009019e+02 theta_grad_norm=6.831155e-02 theta_norm=1.932274e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-03 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=1 D_theta=8.062258e+01 effective_D_theta=8.062258e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=6.844062e-04 beta_diag_max=1.000100e+00
#   State 0: pi(a=0|s=0) = 0.01  pi(a=1|s=0) = 0.89  pi(a=2|s=0) = 0.04  pi(a=3|s=0) = 0.06  --> best action: 1
#   State 1: pi(a=0|s=1) = 0.02  pi(a=1|s=1) = 0.86  pi(a=2|s=1) = 0.05  pi(a=3|s=1) = 0.07  --> best action: 1
#   State 2: pi(a=0|s=2) = 0.03  pi(a=1|s=2) = 0.82  pi(a=2|s=2) = 0.06  pi(a=3|s=2) = 0.09  --> best action: 1
#   State 3: pi(a=0|s=3) = 0.04  pi(a=1|s=3) = 0.76  pi(a=2|s=3) = 0.08  pi(a=3|s=3) = 0.12  --> best action: 1
#   State 4: pi(a=0|s=4) = 0.07  pi(a=1|s=4) = 0.68  pi(a=2|s=4) = 0.10  pi(a=3|s=4) = 0.15  --> best action: 1
#   State 5: pi(a=0|s=5) = 0.01  pi(a=1|s=5) = 0.83  pi(a=2|s=5) = 0.04  pi(a=3|s=5) = 0.11  --> best action: 1
#   State 6: pi(a=0|s=6) = 0.02  pi(a=1|s=6) = 0.79  pi(a=2|s=6) = 0.05  pi(a=3|s=6) = 0.14  --> best action: 1
#   State 7: pi(a=0|s=7) = 0.03  pi(a=1|s=7) = 0.73  pi(a=2|s=7) = 0.06  pi(a=3|s=7) = 0.18  --> best action: 1
#   State 8: pi(a=0|s=8) = 0.05  pi(a=1|s=8) = 0.65  pi(a=2|s=8) = 0.08  pi(a=3|s=8) = 0.22  --> best action: 1
#   State 9: pi(a=0|s=9) = 0.07  pi(a=1|s=9) = 0.56  pi(a=2|s=9) = 0.09  pi(a=3|s=9) = 0.27  --> best action: 1
#   State 10: pi(a=0|s=10) = 0.02  pi(a=1|s=10) = 0.73  pi(a=2|s=10) = 0.04  pi(a=3|s=10) = 0.21  --> best action: 1
#   State 11: pi(a=0|s=11) = 0.02  pi(a=1|s=11) = 0.67  pi(a=2|s=11) = 0.05  pi(a=3|s=11) = 0.26  --> best action: 1
#   State 12: pi(a=0|s=12) = 0.04  pi(a=1|s=12) = 0.59  pi(a=2|s=12) = 0.06  pi(a=3|s=12) = 0.31  --> best action: 1
#   State 13: pi(a=0|s=13) = 0.05  pi(a=1|s=13) = 0.50  pi(a=2|s=13) = 0.07  pi(a=3|s=13) = 0.37  --> best action: 1
#   State 14: pi(a=0|s=14) = 0.08  pi(a=1|s=14) = 0.41  pi(a=2|s=14) = 0.08  pi(a=3|s=14) = 0.43  --> best action: 3
#   State 15: pi(a=0|s=15) = 0.02  pi(a=1|s=15) = 0.58  pi(a=2|s=15) = 0.04  pi(a=3|s=15) = 0.36  --> best action: 1
#   State 16: pi(a=0|s=16) = 0.03  pi(a=1|s=16) = 0.51  pi(a=2|s=16) = 0.05  pi(a=3|s=16) = 0.41  --> best action: 1
#   State 17: pi(a=0|s=17) = 0.04  pi(a=1|s=17) = 0.44  pi(a=2|s=17) = 0.05  pi(a=3|s=17) = 0.47  --> best action: 3
#   State 18: pi(a=0|s=18) = 0.05  pi(a=1|s=18) = 0.36  pi(a=2|s=18) = 0.06  pi(a=3|s=18) = 0.53  --> best action: 3
#   State 19: pi(a=0|s=19) = 0.07  pi(a=1|s=19) = 0.29  pi(a=2|s=19) = 0.06  pi(a=3|s=19) = 0.58  --> best action: 3
#   State 20: pi(a=0|s=20) = 0.02  pi(a=1|s=20) = 0.43  pi(a=2|s=20) = 0.04  pi(a=3|s=20) = 0.51  --> best action: 3
#   State 21: pi(a=0|s=21) = 0.03  pi(a=1|s=21) = 0.37  pi(a=2|s=21) = 0.04  pi(a=3|s=21) = 0.56  --> best action: 3
#   State 22: pi(a=0|s=22) = 0.04  pi(a=1|s=22) = 0.31  pi(a=2|s=22) = 0.04  pi(a=3|s=22) = 0.61  --> best action: 3
#   State 23: pi(a=0|s=23) = 0.05  pi(a=1|s=23) = 0.25  pi(a=2|s=23) = 0.05  pi(a=3|s=23) = 0.66  --> best action: 3
#   State 24: pi(a=0|s=24) = 0.07  pi(a=1|s=24) = 0.20  pi(a=2|s=24) = 0.05  pi(a=3|s=24) = 0.69  --> best action: 3
#
# Solver avg reward:  0.7617 +- 0.2007
# Greedy avg reward:  0.8641 +- 0.0000
# Optimal avg reward: 0.8641 +- 0.0000

# %% [markdown]
# # 5 stochastic grid

# %%
DEVICE = torch.device("cuda:1" if torch.cuda.device_count() > 1 else "cuda" if torch.cuda.is_available() else "cpu")

states = torch.arange(25, dtype=torch.long)
actions = torch.arange(4, dtype=torch.long)

N = len(states)
A = len(actions)
gamma = 0.9
x_0 = 0

dataset_path_5grid_stoch = str(DATASETS_DIR / "5grid_stochastic.csv")

grid_size = 5
goal_grid = 24
pit_grid = 18

wall_states = {6, 7, 12}
terminal_states = {goal_grid, pit_grid}


def state_to_pos(s):
    return divmod(int(s), grid_size)


def pos_to_state(row, col):
    return row * grid_size + col


def move_deterministic(s, a):
    s = int(s)
    a = int(a)

    if s in terminal_states:
        return s

    row, col = state_to_pos(s)

    if a == 0:      # Up
        new_row, new_col = row - 1, col
    elif a == 1:    # Down
        new_row, new_col = row + 1, col
    elif a == 2:    # Left
        new_row, new_col = row, col - 1
    elif a == 3:    # Right
        new_row, new_col = row, col + 1
    else:
        raise ValueError("action must be in {0, 1, 2, 3}")

    if not (0 <= new_row < grid_size and 0 <= new_col < grid_size):
        return s

    sp = pos_to_state(new_row, new_col)

    if sp in wall_states:
        return s

    return sp


def transition_probs(s, a, intended_prob=0.8):
    """
    Stochastic transition:
    intended_prob goes to the requested action.
    The remaining probability is uniform over all actions.
    
    With intended_prob=0.8 and A=4:
      intended action: 0.8 + 0.2 / 4 = 0.85
      other actions:   0.2 / 4 = 0.05 each
    """
    s = int(s)
    a = int(a)

    probs_by_state = {}

    for candidate_a in range(A):
        prob = (1.0 - intended_prob) / A
        if candidate_a == a:
            prob += intended_prob

        sp = move_deterministic(s, candidate_a)
        probs_by_state[sp] = probs_by_state.get(sp, 0.0) + prob

    return probs_by_state


def transition_fn(s, a):
    probs = torch.zeros(N, dtype=torch.float64)

    for sp, prob in transition_probs(s, a).items():
        probs[sp] = prob

    return probs


def next_state(s, a):
    """
    Sample one next state from the stochastic transition.
    Useful for manual rollouts, not used by DiscreteMDP planning.
    """
    probs = transition_fn(s, a)
    return int(torch.multinomial(probs.float(), num_samples=1).item())


def reward_from_next_state(sp):
    sp = int(sp)

    if sp == goal_grid:
        return 1.0

    if sp == pit_grid:
        return -1.0

    return -0.1


def reward_fn(s, a):
    """
    Expected one-step reward under P(. | s, a).
    """
    return sum(
        prob * reward_from_next_state(sp)
        for sp, prob in transition_probs(s, a).items()
    )


mdp = DiscreteMDP(
    states=states,
    actions=actions,
    gamma=gamma,
    x0=x_0,
    reward_fn=reward_fn,
    transition_fn=transition_fn,
    terminal_states=list(terminal_states),
).to(DEVICE)

planner = Planner(mdp)

# %%
def plot_5grid(values=None, policy=None, title="5x5 Grid World"):
    grid_data = np.full((grid_size, grid_size), ".", dtype="<U1")

    for s in wall_states:
        r, c = state_to_pos(s)
        grid_data[r, c] = "#"

    r, c = state_to_pos(pit_grid)
    grid_data[r, c] = "P"

    r, c = state_to_pos(x_0)
    grid_data[r, c] = "S"

    r, c = state_to_pos(goal_grid)
    grid_data[r, c] = "G"

    mapping = {".": 0, "#": 1, "S": 2, "G": 3, "P": 4}
    labels = {0: "Empty", 1: "Wall", 2: "Start", 3: "Goal", 4: "Pit"}
    colors = ["#F5F5F5", "#2C2C2C", "#457B9D", "#2DC653", "#E63946"]

    numeric_grid = np.vectorize(mapping.get)(grid_data)
    cmap = mcolors.ListedColormap(colors)

    fig, ax = plt.subplots(figsize=(7, 7))
    ax.imshow(
        numeric_grid,
        cmap=cmap,
        vmin=0,
        vmax=4,
        interpolation="nearest",
        origin="upper",
    )

    ax.set_xticks(np.arange(-0.5, grid_size, 1), minor=True)
    ax.set_yticks(np.arange(-0.5, grid_size, 1), minor=True)
    ax.grid(which="minor", color="#888888", linewidth=0.8, alpha=0.6)
    ax.tick_params(which="minor", bottom=False, left=False)

    ax.set_xticks(np.arange(grid_size))
    ax.set_yticks(np.arange(grid_size))
    ax.set_xlabel("Column", fontsize=10)
    ax.set_ylabel("Row", fontsize=10)

    if values is not None:
        if hasattr(values, "detach"):
            values = values.detach().cpu().numpy()
        values = np.asarray(values).reshape(-1)

    if policy is not None:
        if hasattr(policy, "detach"):
            policy = policy.detach().cpu().numpy()
        policy = np.asarray(policy)
        best_actions = policy.argmax(axis=1) if policy.ndim == 2 else policy

    arrow_delta = {
        0: (0.0, -0.28),  # Up
        1: (0.0, 0.28),   # Down
        2: (-0.28, 0.0),  # Left
        3: (0.28, 0.0),   # Right
    }

    for s in range(N):
        r, c = state_to_pos(s)

        if s == goal_grid:
            ax.text(c, r, "G", ha="center", va="center", fontsize=14, fontweight="bold", color="white")
        elif s == pit_grid:
            ax.text(c, r, "P", ha="center", va="center", fontsize=14, fontweight="bold", color="white")
        elif s in wall_states:
            ax.text(c, r, "#", ha="center", va="center", fontsize=14, fontweight="bold", color="white")
        elif s == x_0:
            ax.text(c, r, "S", ha="center", va="center", fontsize=14, fontweight="bold", color="white")
        else:
            ax.text(c - 0.38, r - 0.34, str(s), fontsize=8, color="#666666")

        if values is not None and s not in wall_states:
            ax.text(c, r + 0.28, f"{values[s]:.2f}", ha="center", va="center", fontsize=9)

        if policy is not None and s not in terminal_states and s not in wall_states:
            dx, dy = arrow_delta[int(best_actions[s])]
            ax.arrow(
                c,
                r,
                dx,
                dy,
                head_width=0.10,
                head_length=0.10,
                fc="black",
                ec="black",
                linewidth=1.4,
                length_includes_head=True,
                zorder=5,
            )

    patches = [
        mpatches.Patch(color=colors[i], label=f"{symbol}  {labels[i]}")
        for symbol, i in mapping.items()
    ]

    ax.legend(
        handles=patches,
        bbox_to_anchor=(1.02, 1),
        loc="upper left",
        fontsize=9,
        framealpha=0.9,
    )

    ax.set_title(title, fontsize=14, pad=12)
    plt.tight_layout()
    plt.show()


plot_5grid()

# %% [markdown]
# ## Data

# %%
# Initialize the clean collector.
# every episode starts from state 0.
collector = DiscreteDataBuffer(
    mdp=mdp,
    reset_probs={"occupancy": 1.0},
    occupancy=planner.mu_star,          # shape N*A is accepted
    restricted_states=wall_states,
    max_steps=50,
    terminal_states={goal_grid},
    seed=SEED,
)

# Epsilon-greedy around the optimal policy.
# epsilon=0.3 means 70% planner.pi_star, 30% random action.
epsilon_policy = (planner.pi_star, 0.3)

df = collector.collect(
    policies=[epsilon_policy, "random"],
    proportions=[0.7, 0.3],
    n_steps=8000,
    extra_terminal_steps=3,
    episode_based=True,
    save_path=str(dataset_path_5grid_stoch),
    verbose=True,
)

df.head()
# Out:
# Collected 8000 transitions over 460 episodes.
# Policy distribution:
# policy_id
# 0    0.40425
# 1    0.59575
# Name: proportion, dtype: float64
# Reset mode distribution:
# reset_mode
# occupancy    1.0
# Name: proportion, dtype: float64
# Saved FOGAS dataset to /home/mauro/Desktop/EMAI/Ljubljana/Thesis/Code/data/datasets_clean/generalization/5grid_stochastic.csv
#    episode  step  state  action  reward  next_state  policy_id reset_mode  \
# 0        0     0     15       0   -0.01          10          1  occupancy
# 1        0     1     10       2   -0.01          10          1  occupancy
# 2        0     2     10       2   -0.01          10          1  occupancy
# 3        0     3     10       3   -0.01          11          1  occupancy
# 4        0     4     11       3   -0.01          11          1  occupancy
#
#    restricted_start
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %% [markdown]
# ## Solver

# %%
NN_SEED = 123
EVAL_SEED = 42

random.seed(NN_SEED)
np.random.seed(NN_SEED)
torch.manual_seed(NN_SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(NN_SEED)

state_inputs = torch.tensor(
    [[r / 4.0, c / 4.0] for r in range(grid_size) for c in range(grid_size)],
    dtype=torch.float64,
)

hidden_sizes = (8,)

u_param = NeuralUParam(
    StateActionMLPModule(
        n_states=N,
        n_actions=A,
        state_inputs=state_inputs,
        hidden_sizes=hidden_sizes,
        dtype=torch.float64,
    )
)

q_param = NeuralQParam(
    StateActionMLPModule(
        n_states=N,
        n_actions=A,
        state_inputs=state_inputs,
        hidden_sizes=hidden_sizes,
        dtype=torch.float64,
    )
)

policy_param = NeuralPolicyParam(
    StateMLPPolicyModule(
        n_states=N,
        n_actions=A,
        state_inputs=state_inputs,
        hidden_sizes=hidden_sizes,
        dtype=torch.float64,
    )
)

if DEVICE.type == "cuda" and DEVICE.index is not None:
    torch.cuda.set_device(DEVICE)

solver_e_stoch = FinalParametrizedSolver(
    n_states=N,
    n_actions=A,
    gamma=gamma,
    x0=x_0,
    csv_path=dataset_path_5grid_stoch,
    u_param=u_param,
    q_param=q_param,
    policy_param=policy_param,
    seed=NN_SEED,
    device=DEVICE,

    theta_include_beta_cov=False,

    theta_mode="reg_fixed",
    theta_lambda=1e-4,
    theta_optimizer="adam",
    theta_inner_steps=2,
    theta_lr=3e-2,
    theta_start_mode="warm",

    beta_update="fogas_diag",
    beta_reg=1e-3,
)

solver_e_stoch.run(
    alpha=5e-4,
    eta=1e-5,
    rho=0.1,
    policy_optimizer="adam",
    policy_gradient="reinforce",
    reinforce_samples=1,
    tqdm_print=False,
    verbose=True,
    log_interval=50,
    T=1500,
    state_weight_update="normal",
)

mdp.print_policy(solver_e_stoch.pi)

evaluator_stoch = FOGASEvaluator(
    solver=solver_e_stoch,
    mdp=mdp,
    planner=planner,
)

solver_stats = evaluator_stoch.average_return_stats(
    policy_mode="solver",
    num_trajectories=100,
    max_steps=20,
    seed=EVAL_SEED,
    terminal_states=terminal_states,
    compare_with_optimal=True,
)

greedy_stats = evaluator_stoch.average_return_stats(
    policy_mode="greedy",
    num_trajectories=100,
    max_steps=20,
    seed=EVAL_SEED,
    terminal_states=terminal_states,
    compare_with_optimal=True,
)

print(f"Solver avg reward:  {solver_stats['policy']:.4f} +- {solver_stats['policy_std']:.4f}")
print(f"Greedy avg reward:  {greedy_stats['policy']:.4f} +- {greedy_stats['policy_std']:.4f}")
print(f"Optimal avg reward: {solver_stats['optimal']:.4f} +- {solver_stats['optimal_std']:.4f}")
# Out:
# [FinalParametrizedSolver] Iter 1/1500 iter=0 total_loss=-1.490561e-01 policy_objective=9.093246e-02 beta_objective=-1.185651e-01 q_objective=-7.004275e-02 policy_grad_norm=3.857510e-02 policy_direction_norm=3.857510e-02 beta_grad_norm=4.854615e-01 beta_direction_norm=1.810078e+01 theta_grad_norm=2.459120e-01 theta_norm=2.038629e+00 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=3.084495e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 51/1500 iter=50 total_loss=-5.326903e+00 policy_objective=8.036511e-01 beta_objective=-2.508602e+00 q_objective=-5.267964e+00 policy_grad_norm=3.274566e+00 policy_direction_norm=3.274566e+00 beta_grad_norm=1.529988e+01 beta_direction_norm=5.683039e+02 theta_grad_norm=5.569627e-01 theta_norm=1.943240e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=3.475170e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 101/1500 iter=100 total_loss=-6.930868e+00 policy_objective=2.575265e+00 beta_objective=-1.385931e+00 q_objective=-6.918714e+00 policy_grad_norm=6.133696e-01 policy_direction_norm=6.133696e-01 beta_grad_norm=1.847330e+01 beta_direction_norm=5.918624e+02 theta_grad_norm=3.725640e-01 theta_norm=3.340732e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=3.389987e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 151/1500 iter=150 total_loss=-9.731150e+00 policy_objective=2.030390e-01 beta_objective=-1.486531e+00 q_objective=-9.730659e+00 policy_grad_norm=7.554698e-01 policy_direction_norm=7.554698e-01 beta_grad_norm=5.707178e+00 beta_direction_norm=3.762527e+02 theta_grad_norm=3.595461e-01 theta_norm=3.834793e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=3.073850e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 201/1500 iter=200 total_loss=-1.180997e+01 policy_objective=-2.653823e+00 beta_objective=-8.654676e-01 q_objective=-1.179903e+01 policy_grad_norm=1.206510e+00 policy_direction_norm=1.206510e+00 beta_grad_norm=6.632911e+00 beta_direction_norm=3.765294e+02 theta_grad_norm=3.276392e-01 theta_norm=4.669876e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=3.128022e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 251/1500 iter=250 total_loss=-1.367669e+01 policy_objective=-1.077521e+01 beta_objective=-3.361241e-02 q_objective=-1.369136e+01 policy_grad_norm=8.253148e-01 policy_direction_norm=8.253148e-01 beta_grad_norm=1.475803e+01 beta_direction_norm=7.227306e+02 theta_grad_norm=3.240147e-01 theta_norm=5.304663e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=2.612530e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 301/1500 iter=300 total_loss=-1.683513e+01 policy_objective=-2.020292e+01 beta_objective=-5.193926e-01 q_objective=-1.685501e+01 policy_grad_norm=1.601969e+00 policy_direction_norm=1.601969e+00 beta_grad_norm=8.556427e+00 beta_direction_norm=6.518027e+02 theta_grad_norm=4.127401e-01 theta_norm=6.032606e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=2.383759e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 351/1500 iter=350 total_loss=-1.963324e+01 policy_objective=-2.288452e+01 beta_objective=-6.243166e-01 q_objective=-1.964741e+01 policy_grad_norm=1.603490e+00 policy_direction_norm=1.603490e+00 beta_grad_norm=9.235257e+00 beta_direction_norm=6.186895e+02 theta_grad_norm=3.872980e-01 theta_norm=7.002962e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=2.391803e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 401/1500 iter=400 total_loss=-2.189397e+01 policy_objective=-2.556694e+01 beta_objective=-1.932389e-01 q_objective=-2.190573e+01 policy_grad_norm=1.672175e+00 policy_direction_norm=1.672175e+00 beta_grad_norm=9.702070e+00 beta_direction_norm=7.442147e+02 theta_grad_norm=2.987216e-01 theta_norm=8.227275e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=2.165061e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 451/1500 iter=450 total_loss=-2.378686e+01 policy_objective=-3.054107e+01 beta_objective=6.265917e-01 q_objective=-2.378932e+01 policy_grad_norm=1.369363e+00 policy_direction_norm=1.369363e+00 beta_grad_norm=7.626156e+00 beta_direction_norm=5.213858e+02 theta_grad_norm=2.970017e-01 theta_norm=9.101191e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=2.011885e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 501/1500 iter=500 total_loss=-2.623976e+01 policy_objective=-3.847926e+01 beta_objective=8.357306e-01 q_objective=-2.624586e+01 policy_grad_norm=1.062559e+00 policy_direction_norm=1.062559e+00 beta_grad_norm=1.483368e+01 beta_direction_norm=5.383477e+02 theta_grad_norm=2.888556e-01 theta_norm=9.991256e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.902413e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 551/1500 iter=550 total_loss=-2.864761e+01 policy_objective=-4.512991e+01 beta_objective=1.081765e+00 q_objective=-2.865351e+01 policy_grad_norm=2.743313e+00 policy_direction_norm=2.743313e+00 beta_grad_norm=1.032326e+01 beta_direction_norm=8.575386e+02 theta_grad_norm=2.883408e-01 theta_norm=1.093126e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.817762e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 601/1500 iter=600 total_loss=-3.097880e+01 policy_objective=-5.036543e+01 beta_objective=1.445926e+00 q_objective=-3.098835e+01 policy_grad_norm=1.661185e+00 policy_direction_norm=1.661185e+00 beta_grad_norm=8.916875e+00 beta_direction_norm=7.397555e+02 theta_grad_norm=2.840252e-01 theta_norm=1.194376e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.652508e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 651/1500 iter=650 total_loss=-3.235248e+01 policy_objective=-6.590959e+01 beta_objective=2.808021e+00 q_objective=-3.236745e+01 policy_grad_norm=4.752228e+00 policy_direction_norm=4.752228e+00 beta_grad_norm=1.411428e+01 beta_direction_norm=7.440490e+02 theta_grad_norm=2.734310e-01 theta_norm=1.300128e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.518328e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 701/1500 iter=700 total_loss=-3.333627e+01 policy_objective=-7.010203e+01 beta_objective=4.513386e+00 q_objective=-3.335343e+01 policy_grad_norm=3.974922e+00 policy_direction_norm=3.974922e+00 beta_grad_norm=2.084366e+01 beta_direction_norm=9.386238e+02 theta_grad_norm=3.605449e-01 theta_norm=1.399696e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.382049e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 751/1500 iter=750 total_loss=-3.332437e+01 policy_objective=-8.592364e+01 beta_objective=7.240966e+00 q_objective=-3.333857e+01 policy_grad_norm=7.300983e+00 policy_direction_norm=7.300983e+00 beta_grad_norm=2.162303e+01 beta_direction_norm=1.027454e+03 theta_grad_norm=2.409283e-01 theta_norm=1.500458e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.296241e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 801/1500 iter=800 total_loss=-3.362611e+01 policy_objective=-8.677747e+01 beta_objective=9.507602e+00 q_objective=-3.364916e+01 policy_grad_norm=5.202033e+00 policy_direction_norm=5.202033e+00 beta_grad_norm=3.142913e+01 beta_direction_norm=1.082936e+03 theta_grad_norm=4.746273e-01 theta_norm=1.596313e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.202850e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 851/1500 iter=850 total_loss=-3.455167e+01 policy_objective=-9.359068e+01 beta_objective=1.124910e+01 q_objective=-3.456439e+01 policy_grad_norm=4.635868e+00 policy_direction_norm=4.635868e+00 beta_grad_norm=2.394770e+01 beta_direction_norm=7.330879e+02 theta_grad_norm=3.011942e-01 theta_norm=1.689811e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.166055e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 901/1500 iter=900 total_loss=-3.308541e+01 policy_objective=-1.109783e+02 beta_objective=1.521690e+01 q_objective=-3.310741e+01 policy_grad_norm=4.772562e+00 policy_direction_norm=4.772562e+00 beta_grad_norm=3.305521e+01 beta_direction_norm=7.506573e+02 theta_grad_norm=3.187615e-01 theta_norm=1.797615e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.115684e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 951/1500 iter=950 total_loss=-3.043334e+01 policy_objective=-1.271474e+02 beta_objective=2.064369e+01 q_objective=-3.046117e+01 policy_grad_norm=6.607163e+00 policy_direction_norm=6.607163e+00 beta_grad_norm=4.206953e+01 beta_direction_norm=8.115720e+02 theta_grad_norm=2.290150e-01 theta_norm=1.906789e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.086420e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 1001/1500 iter=1000 total_loss=-2.497559e+01 policy_objective=-1.590792e+02 beta_objective=2.833368e+01 q_objective=-2.503375e+01 policy_grad_norm=1.086636e+01 policy_direction_norm=1.086636e+01 beta_grad_norm=5.106428e+01 beta_direction_norm=8.355181e+02 theta_grad_norm=3.077992e-01 theta_norm=1.998034e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.059749e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 1051/1500 iter=1050 total_loss=-1.513373e+01 policy_objective=-1.921326e+02 beta_objective=4.048607e+01 q_objective=-1.520743e+01 policy_grad_norm=1.521006e+01 policy_direction_norm=1.521006e+01 beta_grad_norm=6.048706e+01 beta_direction_norm=9.641339e+02 theta_grad_norm=1.735119e-01 theta_norm=2.093695e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.048873e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 1101/1500 iter=1100 total_loss=-2.385301e-01 policy_objective=-2.128805e+02 beta_objective=5.517378e+01 q_objective=-3.310246e-01 policy_grad_norm=1.724540e+01 policy_direction_norm=1.724540e+01 beta_grad_norm=6.898667e+01 beta_direction_norm=1.096554e+03 theta_grad_norm=1.745313e-01 theta_norm=2.101302e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.044144e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 1151/1500 iter=1150 total_loss=1.299250e+01 policy_objective=-2.172836e+02 beta_objective=6.717128e+01 q_objective=1.287193e+01 policy_grad_norm=1.834113e+01 policy_direction_norm=1.834113e+01 beta_grad_norm=7.374207e+01 beta_direction_norm=1.004089e+03 theta_grad_norm=5.202527e-01 theta_norm=2.082195e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.041377e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 1201/1500 iter=1200 total_loss=1.910695e+01 policy_objective=-1.907075e+02 beta_objective=6.974520e+01 q_objective=1.895921e+01 policy_grad_norm=2.578469e+01 policy_direction_norm=2.578469e+01 beta_grad_norm=6.561904e+01 beta_direction_norm=9.395819e+02 theta_grad_norm=6.980470e-01 theta_norm=2.036626e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.036187e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 1251/1500 iter=1250 total_loss=1.867950e+01 policy_objective=-1.672478e+02 beta_objective=6.735249e+01 q_objective=1.851002e+01 policy_grad_norm=1.435128e+01 policy_direction_norm=1.435128e+01 beta_grad_norm=6.174361e+01 beta_direction_norm=6.472925e+02 theta_grad_norm=2.095221e+00 theta_norm=1.997383e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.029415e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 1301/1500 iter=1300 total_loss=7.676382e+00 policy_objective=-1.288855e+02 beta_objective=5.703327e+01 q_objective=7.490779e+00 policy_grad_norm=1.490041e+01 policy_direction_norm=1.490041e+01 beta_grad_norm=4.645835e+01 beta_direction_norm=5.556825e+02 theta_grad_norm=2.734289e+00 theta_norm=1.989863e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.024768e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 1351/1500 iter=1350 total_loss=-7.849063e+00 policy_objective=-6.010702e+01 beta_objective=4.079237e+01 q_objective=-8.029420e+00 policy_grad_norm=2.707814e+01 policy_direction_norm=2.707814e+01 beta_grad_norm=3.287638e+01 beta_direction_norm=4.996489e+02 theta_grad_norm=4.090452e+00 theta_norm=1.996080e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.019908e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 1401/1500 iter=1400 total_loss=-3.505462e+01 policy_objective=-3.364169e+01 beta_objective=1.380059e+01 q_objective=-3.522292e+01 policy_grad_norm=1.663387e+01 policy_direction_norm=1.663387e+01 beta_grad_norm=2.853331e+01 beta_direction_norm=6.338780e+02 theta_grad_norm=2.355123e+00 theta_norm=2.035987e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.015516e-03 beta_diag_max=1.001000e+00
# [FinalParametrizedSolver] Iter 1451/1500 iter=1450 total_loss=-5.080304e+01 policy_objective=7.186561e+00 beta_objective=-2.664518e+00 q_objective=-5.093616e+01 policy_grad_norm=1.642721e+01 policy_direction_norm=1.642721e+01 beta_grad_norm=4.303284e+01 beta_direction_norm=7.726131e+02 theta_grad_norm=3.047557e+00 theta_norm=2.089923e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=2.549510e+01 effective_D_theta=2.549510e+01 u_fast_path=False q_fast_path=False policy_fast_path=False beta_update=fogas_diag beta_diag_min=1.010829e-03 beta_diag_max=1.001000e+00
#   State 0: pi(a=0|s=0) = 0.14  pi(a=1|s=0) = 0.63  pi(a=2|s=0) = 0.22  pi(a=3|s=0) = 0.01  --> best action: 1
#   State 1: pi(a=0|s=1) = 0.13  pi(a=1|s=1) = 0.66  pi(a=2|s=1) = 0.20  pi(a=3|s=1) = 0.01  --> best action: 1
#   State 2: pi(a=0|s=2) = 0.11  pi(a=1|s=2) = 0.69  pi(a=2|s=2) = 0.19  pi(a=3|s=2) = 0.01  --> best action: 1
#   State 3: pi(a=0|s=3) = 0.10  pi(a=1|s=3) = 0.72  pi(a=2|s=3) = 0.17  pi(a=3|s=3) = 0.01  --> best action: 1
#   State 4: pi(a=0|s=4) = 0.09  pi(a=1|s=4) = 0.74  pi(a=2|s=4) = 0.16  pi(a=3|s=4) = 0.01  --> best action: 1
#   State 5: pi(a=0|s=5) = 0.07  pi(a=1|s=5) = 0.73  pi(a=2|s=5) = 0.18  pi(a=3|s=5) = 0.02  --> best action: 1
#   State 6: pi(a=0|s=6) = 0.06  pi(a=1|s=6) = 0.76  pi(a=2|s=6) = 0.16  pi(a=3|s=6) = 0.02  --> best action: 1
#   State 7: pi(a=0|s=7) = 0.06  pi(a=1|s=7) = 0.78  pi(a=2|s=7) = 0.15  pi(a=3|s=7) = 0.02  --> best action: 1
#   State 8: pi(a=0|s=8) = 0.05  pi(a=1|s=8) = 0.80  pi(a=2|s=8) = 0.14  pi(a=3|s=8) = 0.02  --> best action: 1
#   State 9: pi(a=0|s=9) = 0.05  pi(a=1|s=9) = 0.81  pi(a=2|s=9) = 0.13  pi(a=3|s=9) = 0.02  --> best action: 1
#   State 10: pi(a=0|s=10) = 0.03  pi(a=1|s=10) = 0.77  pi(a=2|s=10) = 0.14  pi(a=3|s=10) = 0.07  --> best action: 1
#   State 11: pi(a=0|s=11) = 0.03  pi(a=1|s=11) = 0.79  pi(a=2|s=11) = 0.13  pi(a=3|s=11) = 0.06  --> best action: 1
#   State 12: pi(a=0|s=12) = 0.03  pi(a=1|s=12) = 0.81  pi(a=2|s=12) = 0.12  pi(a=3|s=12) = 0.05  --> best action: 1
#   State 13: pi(a=0|s=13) = 0.03  pi(a=1|s=13) = 0.82  pi(a=2|s=13) = 0.11  pi(a=3|s=13) = 0.05  --> best action: 1
#   State 14: pi(a=0|s=14) = 0.03  pi(a=1|s=14) = 0.83  pi(a=2|s=14) = 0.10  pi(a=3|s=14) = 0.04  --> best action: 1
#   State 15: pi(a=0|s=15) = 0.01  pi(a=1|s=15) = 0.70  pi(a=2|s=15) = 0.10  pi(a=3|s=15) = 0.19  --> best action: 1
#   State 16: pi(a=0|s=16) = 0.01  pi(a=1|s=16) = 0.72  pi(a=2|s=16) = 0.09  pi(a=3|s=16) = 0.17  --> best action: 1
#   State 17: pi(a=0|s=17) = 0.01  pi(a=1|s=17) = 0.75  pi(a=2|s=17) = 0.09  pi(a=3|s=17) = 0.15  --> best action: 1
#   State 18: pi(a=0|s=18) = 0.01  pi(a=1|s=18) = 0.76  pi(a=2|s=18) = 0.08  pi(a=3|s=18) = 0.14  --> best action: 1
#   State 19: pi(a=0|s=19) = 0.01  pi(a=1|s=19) = 0.78  pi(a=2|s=19) = 0.08  pi(a=3|s=19) = 0.12  --> best action: 1
#   State 20: pi(a=0|s=20) = 0.01  pi(a=1|s=20) = 0.53  pi(a=2|s=20) = 0.07  pi(a=3|s=20) = 0.40  --> best action: 1
#   State 21: pi(a=0|s=21) = 0.01  pi(a=1|s=21) = 0.55  pi(a=2|s=21) = 0.07  pi(a=3|s=21) = 0.38  --> best action: 1
#   State 22: pi(a=0|s=22) = 0.01  pi(a=1|s=22) = 0.58  pi(a=2|s=22) = 0.06  pi(a=3|s=22) = 0.35  --> best action: 1
#   State 23: pi(a=0|s=23) = 0.01  pi(a=1|s=23) = 0.60  pi(a=2|s=23) = 0.06  pi(a=3|s=23) = 0.33  --> best action: 1
#   State 24: pi(a=0|s=24) = 0.01  pi(a=1|s=24) = 0.63  pi(a=2|s=24) = 0.06  pi(a=3|s=24) = 0.30  --> best action: 1
#
# Solver avg reward:  -0.7280 +- 0.1952
# Greedy avg reward:  -0.8764 +- 0.0394
# Optimal avg reward: -0.2388 +- 0.1414
