# %%
# %load_ext autoreload
# %autoreload 2

import os
import random
import numpy as np
import pandas as pd
import sys
import torch
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches

SEED = 42
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.set_default_dtype(torch.float64)

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
if torch.backends.cudnn.is_available():
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

def find_root(current_path, marker="setup.py"):
    current_path = Path(current_path).resolve()
    for parent in [current_path] + list(current_path.parents):
        if (parent / marker).exists():
            return parent
    return current_path

PROJECT_ROOT = find_root(Path.cwd())

DATASETS_DIR = PROJECT_ROOT / "data" / "datasets_clean" / "generalization"
RESULTS_DIR = PROJECT_ROOT / "data" / "results_clean" / "generalization"
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

# Add project root to the Python path
if str(PROJECT_ROOT / "src") not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / "src"))

from rl_methods.mdp_clean import DiscreteMDP, Planner
from rl_methods.fogas_clean import FOGASEvaluator, FOGASHyperOptimizer
from rl_methods.fogas_generalization_clean import *
from rl_methods.fogas_generalization_clean import (
    FinalLinearSolver,
    TabularFeatures,
    LinearFunction,
    LinearQFunction,
)
from rl_methods.data_collection_clean import DiscreteDataBuffer

# %% [markdown]
# # 3grid empty

# %%
states = torch.arange(9, dtype=torch.long)
actions = torch.arange(4, dtype=torch.long)

N = len(states)
A = len(actions)
gamma = 0.9
x_0 = 0

dataset_path = DATASETS_DIR / "3grid.csv"
goal_grid = 8


def phi(x, a):
    vec = torch.zeros(N * A, dtype=torch.float64, device=DEVICE)
    vec[int(x) * A + int(a)] = 1.0
    return vec


omega = torch.full(
    (N * A,),
    -0.1,
    dtype=torch.float64,
    device=DEVICE,
)
omega[goal_grid * A : goal_grid * A + A] = 1.0


def to_rc(s):
    return divmod(int(s), 3)


def to_s(r, c):
    return r * 3 + c


def next_state(s, a):
    s = int(s)
    a = int(a)

    if s == goal_grid:
        return goal_grid

    r, c = to_rc(s)

    if a == 0:      # Up
        r = max(0, r - 1)
    elif a == 1:    # Down
        r = min(2, r + 1)
    elif a == 2:    # Left
        c = max(0, c - 1)
    elif a == 3:    # Right
        c = min(2, c + 1)

    return to_s(r, c)


def psi(xp):
    v = torch.zeros(N * A, dtype=torch.float64, device=DEVICE)
    for x in states:
        for a in actions:
            if next_state(x, a) == int(xp):
                v[int(x) * A + int(a)] = 1.0
    return v


mdp = DiscreteMDP(
    states=states,
    actions=actions,
    gamma=gamma,
    x0=x_0,
    phi=phi,
    omega=omega,
    psi=psi,
    terminal_states=[goal_grid],
).to(DEVICE)

planner = Planner(mdp)

# %%
theta_lambda_grid = [
    1e-7,
    2e-7,
    5e-7,
    1e-6,
    2e-6,
    5e-6,
    1e-5,
    2e-5,
    5e-5,
    1e-4,
    2e-4,
    5e-4,
    1e-3,
    2e-3,
    5e-3,
    1e-2,
    2e-2,
    5e-2,
    1e-1,
    2e-1,
]

from rl_methods.fogas_generalization_clean import (
    FinalLinearSolver,
    RBFStateFeatures,
    RBFStateActionFeatures,
    LinearFunction,
    LinearQFunction,
)

grid_results = []
best = None

# Normalized 2D coordinates for each 3x3 grid state
state_coords = torch.tensor(
    [[r / 2.0, c / 2.0] for r in range(3) for c in range(3)],
    dtype=torch.float64,
)

rbf_centers = torch.tensor(
    [
        [0.25, 0.25],
        [0.75, 0.25],
        [0.25, 0.75],
        [0.75, 0.75],
    ],
    dtype=torch.float64,
)

for theta_lambda in theta_lambda_grid:
    print(f"\n{'=' * 80}")
    print(f"Trying RBF features with theta_mode='reg_fixed', theta_lambda={theta_lambda:.6e}")
    print(f"{'=' * 80}")

    state_rbf = RBFStateFeatures(
        n_states=N,
        centers=rbf_centers,
        state_coords=state_coords,
        bandwidth="nearest",
        bandwidth_scale=2.0,
        include_bias=True,
    )

    u_features = RBFStateActionFeatures(state_rbf, n_actions=A)
    q_features = RBFStateActionFeatures(state_rbf, n_actions=A)
    policy_features = RBFStateActionFeatures(state_rbf, n_actions=A)

    solver_e = FinalLinearSolver(
        n_states=N,
        n_actions=A,
        gamma=gamma,
        x0=x_0,
        csv_path=dataset_path,
        u_function=LinearFunction(u_features),
        q_function=LinearQFunction(q_features),
        policy_features=policy_features,
        seed=SEED,
        device=DEVICE,

        theta_include_beta_cov=False,

        theta_mode="reg_fixed",
        theta_lambda=float(theta_lambda),
        theta_optimizer="adam",
        theta_inner_steps=40,
        theta_lr=1e-2,
        theta_start_mode="warm",

        beta_update="fogas_full",
    )

    solver_e.run(
        alpha=1e-3,
        eta=1e-4,
        rho=0.005,
        policy_optimizer="npg",
        policy_gradient="exact",
        reinforce_samples=1,
        tqdm_print=False,
        verbose=True,
        log_interval=50,
        T=1000,
        state_weight_update="normal",
    )

    evaluator_e = FOGASEvaluator(
        solver=solver_e,
        mdp=mdp,
        planner=planner,
    )

    trajectory = evaluator_e.simulate_trajectory(
        policy_mode="greedy",
        max_steps=50,
        seed=SEED,
        goal_state=goal_grid,
        terminal_states=[goal_grid],
    )

    reached_goal = any(step["reached_goal"] for step in trajectory)
    final_state = trajectory[-1]["next_state"] if trajectory else x_0

    result = {
        "theta_lambda": float(theta_lambda),
        "reached_goal": reached_goal,
        "trajectory_length": len(trajectory),
        "final_state": final_state,
        "solver": solver_e,
        "evaluator": evaluator_e,
        "trajectory": trajectory,
    }
    grid_results.append(result)

    print(
        f"lambda={theta_lambda:.6e} | "
        f"reached_goal={reached_goal} | "
        f"steps={len(trajectory)} | "
        f"final_state={final_state}"
    )

    if reached_goal:
        best = result
        print(f"\nFOUND working theta_lambda: {theta_lambda:.6e}")
        break

if best is None:
    print(f"\nNo reg_fixed lambda in the {len(theta_lambda_grid)}-value grid reached goal state {goal_grid}.")
    best = max(
        grid_results,
        key=lambda r: (r["reached_goal"], -r["trajectory_length"], r["final_state"]),
    )

solver_e = best["solver"]
evaluator_e = best["evaluator"]

mdp.print_policy(solver_e.pi)

evaluator_e.print_solver_policy(policy_mode="solver")

evaluator_e.print_optimal_path(
    policy_mode="greedy",
    max_steps=50,
    seed=SEED,
    goal_state=goal_grid,
    terminal_states=[goal_grid],
    show_value_info=False,
)

summary = pd.DataFrame(
    [
        {
            "theta_lambda": r["theta_lambda"],
            "reached_goal": r["reached_goal"],
            "trajectory_length": r["trajectory_length"],
            "final_state": r["final_state"],
        }
        for r in grid_results
    ]
)

summary
# Out:
# ================================================================================
# Trying RBF features with theta_mode='reg_fixed', theta_lambda=1.000000e-07
# ================================================================================
# [FinalLinearSolver] Iter 1/1000 iter=0 total_loss=-1.588970e-01 policy_objective=-1.588970e-01 beta_objective=0.000000e+00 q_objective=-1.588968e-01 policy_grad_norm=1.776593e-17 policy_direction_norm=0.000000e+00 beta_grad_norm=6.724913e-02 beta_direction_norm=2.268849e+00 theta_grad_norm=9.052154e-02 theta_norm=1.788853e+00 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=0 cg_residual_norm=1.776593e-17 cg_relative_residual=0.000000e+00
# [FinalLinearSolver] Iter 51/1000 iter=50 total_loss=-7.872789e+00 policy_objective=-9.672309e+00 beta_objective=2.309563e-01 q_objective=-7.870329e+00 policy_grad_norm=4.414325e-08 policy_direction_norm=8.810789e-07 beta_grad_norm=8.059172e+00 beta_direction_norm=1.086762e+02 theta_grad_norm=8.803048e-02 theta_norm=9.123151e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=6 cg_residual_norm=3.240545e-17 cg_relative_residual=7.340975e-10
# [FinalLinearSolver] Iter 101/1000 iter=100 total_loss=-1.421290e+01 policy_objective=-2.850238e+01 beta_objective=1.835691e+00 q_objective=-1.420308e+01 policy_grad_norm=5.688292e-07 policy_direction_norm=7.672739e-06 beta_grad_norm=1.605229e+01 beta_direction_norm=2.150872e+02 theta_grad_norm=8.087711e-02 theta_norm=1.806742e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=6 cg_residual_norm=1.841730e-13 cg_relative_residual=3.237756e-07
# [FinalLinearSolver] Iter 151/1000 iter=150 total_loss=-1.781142e+01 policy_objective=-6.591775e+01 beta_objective=6.182021e+00 q_objective=-1.778932e+01 policy_grad_norm=3.703256e-06 policy_direction_norm=3.317598e-05 beta_grad_norm=2.404540e+01 beta_direction_norm=3.214982e+02 theta_grad_norm=7.023469e-02 theta_norm=2.701168e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=6 cg_residual_norm=9.532594e-11 cg_relative_residual=2.574112e-05
# [FinalLinearSolver] Iter 201/1000 iter=200 total_loss=-1.730057e+01 policy_objective=-1.311867e+02 beta_objective=1.463772e+01 q_objective=-1.726129e+01 policy_grad_norm=2.661651e-05 policy_direction_norm=1.641756e-04 beta_grad_norm=3.203851e+01 beta_direction_norm=4.279091e+02 theta_grad_norm=5.941005e-02 theta_norm=3.595594e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=7 cg_residual_norm=5.098861e-13 cg_relative_residual=1.915676e-08
# [FinalLinearSolver] Iter 251/1000 iter=250 total_loss=-1.149570e+01 policy_objective=-2.267429e+02 beta_objective=2.735064e+01 q_objective=-1.143502e+01 policy_grad_norm=1.925120e+00 policy_direction_norm=1.305889e+01 beta_grad_norm=3.897038e+01 beta_direction_norm=5.102326e+02 theta_grad_norm=3.502098e-02 theta_norm=4.366712e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=1.151373e-04 cg_relative_residual=5.980784e-05
# [FinalLinearSolver] Iter 301/1000 iter=300 total_loss=-1.698712e+00 policy_objective=-3.229786e+02 beta_objective=3.990139e+01 q_objective=-1.615761e+00 policy_grad_norm=4.058173e+00 policy_direction_norm=4.221654e+01 beta_grad_norm=4.186554e+01 beta_direction_norm=5.087606e+02 theta_grad_norm=2.468265e-02 theta_norm=4.663931e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=2.252438e-04 cg_relative_residual=5.550374e-05
# [FinalLinearSolver] Iter 351/1000 iter=350 total_loss=8.571383e+00 policy_objective=-3.764709e+02 beta_objective=4.752983e+01 q_objective=8.674266e+00 policy_grad_norm=1.363524e+00 policy_direction_norm=5.836384e+01 beta_grad_norm=3.981980e+01 beta_direction_norm=4.308874e+02 theta_grad_norm=4.499347e-02 theta_norm=4.392015e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=1.176278e-04 cg_relative_residual=8.626749e-05
# [FinalLinearSolver] Iter 401/1000 iter=400 total_loss=1.592867e+01 policy_objective=-3.874564e+02 beta_objective=4.990232e+01 q_objective=1.604916e+01 policy_grad_norm=1.801416e+00 policy_direction_norm=6.557564e+01 beta_grad_norm=3.588509e+01 beta_direction_norm=3.395304e+02 theta_grad_norm=7.139730e-02 theta_norm=3.894407e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=2.512906e-04 cg_relative_residual=1.394962e-04
# [FinalLinearSolver] Iter 451/1000 iter=450 total_loss=1.908263e+01 policy_objective=-3.603980e+02 beta_objective=4.706696e+01 q_objective=1.921807e+01 policy_grad_norm=2.762789e+00 policy_direction_norm=5.980829e+01 beta_grad_norm=3.007432e+01 beta_direction_norm=2.490827e+02 theta_grad_norm=8.487524e-02 theta_norm=3.298556e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=4.208277e-04 cg_relative_residual=1.523199e-04
# [FinalLinearSolver] Iter 501/1000 iter=500 total_loss=1.810385e+01 policy_objective=-3.095608e+02 beta_objective=4.029080e+01 q_objective=1.825153e+01 policy_grad_norm=3.097848e+00 policy_direction_norm=4.979224e+01 beta_grad_norm=2.359202e+01 beta_direction_norm=1.742869e+02 theta_grad_norm=1.044355e-01 theta_norm=2.724694e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=2.236430e-04 cg_relative_residual=7.219304e-05
# [FinalLinearSolver] Iter 551/1000 iter=550 total_loss=1.378442e+01 policy_objective=-2.370808e+02 beta_objective=2.993145e+01 q_objective=1.394133e+01 policy_grad_norm=3.618333e+00 policy_direction_norm=3.220096e+01 beta_grad_norm=1.718708e+01 beta_direction_norm=1.084662e+02 theta_grad_norm=1.151531e-01 theta_norm=2.184726e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=1.794674e-04 cg_relative_residual=4.959948e-05
# [FinalLinearSolver] Iter 601/1000 iter=600 total_loss=7.043886e+00 policy_objective=-1.502600e+02 beta_objective=1.713208e+01 q_objective=7.206987e+00 policy_grad_norm=4.429379e+00 policy_direction_norm=3.376048e+01 beta_grad_norm=1.123776e+01 beta_direction_norm=6.332809e+01 theta_grad_norm=1.195359e-01 theta_norm=1.786488e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=4.179400e-04 cg_relative_residual=9.435634e-05
# [FinalLinearSolver] Iter 651/1000 iter=650 total_loss=-4.363017e-01 policy_objective=-5.387989e+01 beta_objective=3.725999e+00 q_objective=-2.701225e-01 policy_grad_norm=3.654081e+00 policy_direction_norm=4.591170e+01 beta_grad_norm=6.098903e+00 beta_direction_norm=7.893574e+01 theta_grad_norm=1.424304e-01 theta_norm=1.604543e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=7.341294e-04 cg_relative_residual=2.009067e-04
# [FinalLinearSolver] Iter 701/1000 iter=700 total_loss=-7.894601e+00 policy_objective=5.177505e+01 beta_objective=-1.002860e+01 q_objective=-7.728426e+00 policy_grad_norm=4.355840e+00 policy_direction_norm=6.369199e+01 beta_grad_norm=6.633233e+00 beta_direction_norm=1.448735e+02 theta_grad_norm=1.384728e-01 theta_norm=1.706412e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=8.138941e-04 cg_relative_residual=1.868512e-04
# [FinalLinearSolver] Iter 751/1000 iter=750 total_loss=-1.388942e+01 policy_objective=1.500651e+02 beta_objective=-2.207610e+01 q_objective=-1.372610e+01 policy_grad_norm=4.768304e+00 policy_direction_norm=7.443025e+01 beta_grad_norm=1.134933e+01 beta_direction_norm=2.169409e+02 theta_grad_norm=1.296221e-01 theta_norm=2.078667e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=5.714535e-04 cg_relative_residual=1.198442e-04
# [FinalLinearSolver] Iter 801/1000 iter=800 total_loss=-1.804403e+01 policy_objective=2.397281e+02 beta_objective=-3.238406e+01 q_objective=-1.788621e+01 policy_grad_norm=3.905156e+00 policy_direction_norm=7.338910e+01 beta_grad_norm=1.642627e+01 beta_direction_norm=3.065703e+02 theta_grad_norm=1.171537e-01 theta_norm=2.557521e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=6.842331e-04 cg_relative_residual=1.752127e-04
# [FinalLinearSolver] Iter 851/1000 iter=850 total_loss=-2.022950e+01 policy_objective=3.115035e+02 beta_objective=-4.036334e+01 q_objective=-2.007970e+01 policy_grad_norm=4.316203e+00 policy_direction_norm=6.599170e+01 beta_grad_norm=2.171314e+01 beta_direction_norm=3.938398e+02 theta_grad_norm=1.077119e-01 theta_norm=3.063128e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=3.621933e-03 cg_relative_residual=8.391480e-04
# [FinalLinearSolver] Iter 901/1000 iter=900 total_loss=-1.964582e+01 policy_objective=3.577335e+02 beta_objective=-4.499472e+01 q_objective=-1.950649e+01 policy_grad_norm=4.011571e+00 policy_direction_norm=7.002263e+01 beta_grad_norm=2.647988e+01 beta_direction_norm=4.751863e+02 theta_grad_norm=9.481145e-02 theta_norm=3.568815e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=6.148833e-03 cg_relative_residual=1.532774e-03
# [FinalLinearSolver] Iter 951/1000 iter=950 total_loss=-1.499303e+01 policy_objective=3.737844e+02 beta_objective=-4.470763e+01 q_objective=-1.486652e+01 policy_grad_norm=6.568846e+00 policy_direction_norm=7.393374e+01 beta_grad_norm=3.054430e+01 beta_direction_norm=5.400260e+02 theta_grad_norm=6.528057e-02 theta_norm=4.008069e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=5.082366e-04 cg_relative_residual=7.737077e-05
# lambda=1.000000e-07 | reached_goal=False | steps=50 | final_state=0
#
# ================================================================================
# Trying RBF features with theta_mode='reg_fixed', theta_lambda=2.000000e-07
# ================================================================================
# [FinalLinearSolver] Iter 1/1000 iter=0 total_loss=-1.588969e-01 policy_objective=-1.588969e-01 beta_objective=0.000000e+00 q_objective=-1.588966e-01 policy_grad_norm=0.000000e+00 policy_direction_norm=0.000000e+00 beta_grad_norm=6.724909e-02 beta_direction_norm=2.268849e+00 theta_grad_norm=9.052136e-02 theta_norm=1.788853e+00 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=0 cg_residual_norm=0.000000e+00 cg_relative_residual=0.000000e+00
# [FinalLinearSolver] Iter 51/1000 iter=50 total_loss=-7.872788e+00 policy_objective=-9.672306e+00 beta_objective=2.309562e-01 q_objective=-7.869911e+00 policy_grad_norm=5.704054e-08 policy_direction_norm=1.138502e-06 beta_grad_norm=8.059170e+00 beta_direction_norm=1.086762e+02 theta_grad_norm=8.802154e-02 theta_norm=9.123149e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=6 cg_residual_norm=6.135715e-17 cg_relative_residual=1.075676e-09
# [FinalLinearSolver] Iter 101/1000 iter=100 total_loss=-1.421290e+01 policy_objective=-2.850237e+01 beta_objective=1.835690e+00 q_objective=-1.420144e+01 policy_grad_norm=7.351626e-07 policy_direction_norm=9.916288e-06 beta_grad_norm=1.605228e+01 beta_direction_norm=2.150871e+02 theta_grad_norm=8.085956e-02 theta_norm=1.806741e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=6 cg_residual_norm=3.975470e-13 cg_relative_residual=5.407606e-07
# [FinalLinearSolver] Iter 151/1000 iter=150 total_loss=-1.781142e+01 policy_objective=-6.591772e+01 beta_objective=6.182018e+00 q_objective=-1.778567e+01 policy_grad_norm=4.787569e-06 policy_direction_norm=4.288894e-05 beta_grad_norm=2.404540e+01 beta_direction_norm=3.214981e+02 theta_grad_norm=7.020937e-02 theta_norm=2.701167e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=7 cg_residual_norm=3.100702e-14 cg_relative_residual=6.476568e-09
# [FinalLinearSolver] Iter 201/1000 iter=200 total_loss=-1.730057e+01 policy_objective=-1.311867e+02 beta_objective=1.463771e+01 q_objective=-1.725482e+01 policy_grad_norm=3.448218e-05 policy_direction_norm=2.126441e-04 beta_grad_norm=3.203850e+01 beta_direction_norm=4.279090e+02 theta_grad_norm=5.938095e-02 theta_norm=3.595593e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=7 cg_residual_norm=8.539013e-13 cg_relative_residual=2.476355e-08
# [FinalLinearSolver] Iter 251/1000 iter=250 total_loss=-1.149569e+01 policy_objective=-2.267425e+02 beta_objective=2.735059e+01 q_objective=-1.142548e+01 policy_grad_norm=1.925216e+00 policy_direction_norm=1.305922e+01 beta_grad_norm=3.897036e+01 beta_direction_norm=5.102316e+02 theta_grad_norm=3.498894e-02 theta_norm=4.366704e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=1.283359e-04 cg_relative_residual=6.666051e-05
# [FinalLinearSolver] Iter 301/1000 iter=300 total_loss=-1.702421e+00 policy_objective=-3.223061e+02 beta_objective=3.980851e+01 q_objective=-1.608693e+00 policy_grad_norm=4.127705e+00 policy_direction_norm=4.232095e+01 beta_grad_norm=4.179615e+01 beta_direction_norm=5.076494e+02 theta_grad_norm=2.505413e-02 theta_norm=4.654276e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=2.482752e-04 cg_relative_residual=6.014849e-05
# [FinalLinearSolver] Iter 351/1000 iter=350 total_loss=8.602179e+00 policy_objective=-3.772691e+02 beta_objective=4.765154e+01 q_objective=8.714758e+00 policy_grad_norm=1.880666e+00 policy_direction_norm=5.902088e+01 beta_grad_norm=3.998080e+01 beta_direction_norm=4.338295e+02 theta_grad_norm=4.242073e-02 theta_norm=4.397291e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=7.884912e-05 cg_relative_residual=4.192616e-05
# [FinalLinearSolver] Iter 401/1000 iter=400 total_loss=1.581911e+01 policy_objective=-3.824867e+02 beta_objective=4.933664e+01 q_objective=1.594673e+01 policy_grad_norm=2.845059e+00 policy_direction_norm=6.661052e+01 beta_grad_norm=3.564137e+01 beta_direction_norm=3.347427e+02 theta_grad_norm=6.477288e-02 theta_norm=3.844067e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=2.641555e-04 cg_relative_residual=9.284712e-05
# [FinalLinearSolver] Iter 451/1000 iter=450 total_loss=1.875911e+01 policy_objective=-3.515462e+02 beta_objective=4.607616e+01 q_objective=1.889917e+01 policy_grad_norm=4.171034e+00 policy_direction_norm=6.109217e+01 beta_grad_norm=2.974314e+01 beta_direction_norm=2.441153e+02 theta_grad_norm=7.735173e-02 theta_norm=3.216924e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=3.036840e-04 cg_relative_residual=7.280785e-05
# [FinalLinearSolver] Iter 501/1000 iter=500 total_loss=1.747909e+01 policy_objective=-2.944039e+02 beta_objective=3.877067e+01 q_objective=1.762934e+01 policy_grad_norm=3.481978e+00 policy_direction_norm=5.327413e+01 beta_grad_norm=2.275012e+01 beta_direction_norm=1.656775e+02 theta_grad_norm=9.704654e-02 theta_norm=2.621643e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=2.418843e-04 cg_relative_residual=6.946749e-05
# [FinalLinearSolver] Iter 551/1000 iter=550 total_loss=1.270397e+01 policy_objective=-2.172585e+02 beta_objective=2.769486e+01 q_objective=1.286154e+01 policy_grad_norm=1.923194e+00 policy_direction_norm=3.456333e+01 beta_grad_norm=1.575189e+01 beta_direction_norm=9.879094e+01 theta_grad_norm=1.194266e-01 theta_norm=2.028172e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=5.804878e-04 cg_relative_residual=3.018353e-04
# [FinalLinearSolver] Iter 601/1000 iter=600 total_loss=5.769701e+00 policy_objective=-1.285457e+02 beta_objective=1.454196e+01 q_objective=5.932026e+00 policy_grad_norm=3.379637e+00 policy_direction_norm=2.674913e+01 beta_grad_norm=9.691433e+00 beta_direction_norm=5.669588e+01 theta_grad_norm=1.227487e-01 theta_norm=1.592689e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=5.744694e-04 cg_relative_residual=1.699796e-04
# [FinalLinearSolver] Iter 651/1000 iter=650 total_loss=-1.845606e+00 policy_objective=-3.181970e+01 beta_objective=1.040849e+00 q_objective=-1.681120e+00 policy_grad_norm=4.169830e+00 policy_direction_norm=4.393096e+01 beta_grad_norm=4.451370e+00 beta_direction_norm=7.948557e+01 theta_grad_norm=1.271208e-01 theta_norm=1.439589e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=3.647069e-04 cg_relative_residual=8.746325e-05
# [FinalLinearSolver] Iter 701/1000 iter=700 total_loss=-9.053825e+00 policy_objective=7.153988e+01 beta_objective=-1.253528e+01 q_objective=-8.889723e+00 policy_grad_norm=2.398622e+00 policy_direction_norm=6.216103e+01 beta_grad_norm=6.526172e+00 beta_direction_norm=1.450925e+02 theta_grad_norm=1.343788e-01 theta_norm=1.629601e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=2.115488e-04 cg_relative_residual=8.819596e-05
# [FinalLinearSolver] Iter 751/1000 iter=750 total_loss=-1.492221e+01 policy_objective=1.739012e+02 beta_objective=-2.501913e+01 q_objective=-1.476085e+01 policy_grad_norm=3.687897e+00 policy_direction_norm=7.617972e+01 beta_grad_norm=1.283196e+01 beta_direction_norm=2.250049e+02 theta_grad_norm=1.264361e-01 theta_norm=2.090892e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=3.571238e-04 cg_relative_residual=9.683670e-05
# [FinalLinearSolver] Iter 801/1000 iter=800 total_loss=-1.858796e+01 policy_objective=2.643243e+02 beta_objective=-3.525059e+01 q_objective=-1.843181e+01 policy_grad_norm=4.980965e+00 policy_direction_norm=7.166988e+01 beta_grad_norm=1.859171e+01 beta_direction_norm=3.121394e+02 theta_grad_norm=9.858692e-02 theta_norm=2.626922e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=8.654307e-04 cg_relative_residual=1.737476e-04
# [FinalLinearSolver] Iter 851/1000 iter=850 total_loss=-1.982812e+01 policy_objective=3.304205e+02 beta_objective=-4.262061e+01 q_objective=-1.967944e+01 policy_grad_norm=4.343081e+00 policy_direction_norm=6.046436e+01 beta_grad_norm=2.384160e+01 beta_direction_norm=4.057292e+02 theta_grad_norm=9.497580e-02 theta_norm=3.171509e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=4.964650e-03 cg_relative_residual=1.143117e-03
# [FinalLinearSolver] Iter 901/1000 iter=900 total_loss=-1.833541e+01 policy_objective=3.656274e+02 beta_objective=-4.575702e+01 q_objective=-1.819629e+01 policy_grad_norm=2.503420e+00 policy_direction_norm=5.697016e+01 beta_grad_norm=2.928235e+01 beta_direction_norm=4.883089e+02 theta_grad_norm=7.473699e-02 theta_norm=3.723098e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=1.932261e-03 cg_relative_residual=7.718486e-04
# [FinalLinearSolver] Iter 951/1000 iter=950 total_loss=-1.291197e+01 policy_objective=3.665298e+02 beta_objective=-4.397810e+01 q_objective=-1.278540e+01 policy_grad_norm=5.108321e+00 policy_direction_norm=7.688394e+01 beta_grad_norm=3.289012e+01 beta_direction_norm=5.559599e+02 theta_grad_norm=5.107310e-02 theta_norm=4.123064e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=3.113849e-03 cg_relative_residual=6.095642e-04
# lambda=2.000000e-07 | reached_goal=False | steps=50 | final_state=3
#
# ================================================================================
# Trying RBF features with theta_mode='reg_fixed', theta_lambda=5.000000e-07
# ================================================================================
# [FinalLinearSolver] Iter 1/1000 iter=0 total_loss=-1.588968e-01 policy_objective=-1.588968e-01 beta_objective=0.000000e+00 q_objective=-1.588960e-01 policy_grad_norm=1.776593e-17 policy_direction_norm=0.000000e+00 beta_grad_norm=6.724899e-02 beta_direction_norm=2.268847e+00 theta_grad_norm=9.052084e-02 theta_norm=1.788852e+00 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=0 cg_residual_norm=1.776593e-17 cg_relative_residual=0.000000e+00
# [FinalLinearSolver] Iter 51/1000 iter=50 total_loss=-7.872783e+00 policy_objective=-9.672299e+00 beta_objective=2.309559e-01 q_objective=-7.868658e+00 policy_grad_norm=9.575745e-08 policy_direction_norm=1.911268e-06 beta_grad_norm=8.059165e+00 beta_direction_norm=1.086761e+02 theta_grad_norm=8.799472e-02 theta_norm=9.123143e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=6 cg_residual_norm=2.675098e-16 cg_relative_residual=2.793618e-09
# [FinalLinearSolver] Iter 101/1000 iter=100 total_loss=-1.421289e+01 policy_objective=-2.850234e+01 beta_objective=1.835688e+00 q_objective=-1.419654e+01 policy_grad_norm=1.234863e-06 policy_direction_norm=1.665622e-05 beta_grad_norm=1.605227e+01 beta_direction_norm=2.150870e+02 theta_grad_norm=8.080689e-02 theta_norm=1.806740e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=6 cg_residual_norm=1.883373e-12 cg_relative_residual=1.525167e-06
# [FinalLinearSolver] Iter 151/1000 iter=150 total_loss=-1.781141e+01 policy_objective=-6.591765e+01 beta_objective=6.182009e+00 q_objective=-1.777472e+01 policy_grad_norm=8.048980e-06 policy_direction_norm=7.210108e-05 beta_grad_norm=2.404538e+01 beta_direction_norm=3.214978e+02 theta_grad_norm=7.013340e-02 theta_norm=2.701165e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=7 cg_residual_norm=8.760277e-14 cg_relative_residual=1.088371e-08
# [FinalLinearSolver] Iter 201/1000 iter=200 total_loss=-1.730057e+01 policy_objective=-1.311865e+02 beta_objective=1.463768e+01 q_objective=-1.723543e+01 policy_grad_norm=5.834488e-05 policy_direction_norm=3.595499e-04 beta_grad_norm=3.203847e+01 beta_direction_norm=4.279085e+02 theta_grad_norm=5.929368e-02 theta_norm=3.595589e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=7 cg_residual_norm=2.428306e-12 cg_relative_residual=4.161987e-08
# [FinalLinearSolver] Iter 251/1000 iter=250 total_loss=-1.149411e+01 policy_objective=-2.267485e+02 beta_objective=2.735546e+01 q_objective=-1.139530e+01 policy_grad_norm=1.921690e+00 policy_direction_norm=1.289410e+01 beta_grad_norm=3.897254e+01 beta_direction_norm=5.103271e+02 theta_grad_norm=3.500952e-02 theta_norm=4.366435e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=1.326264e-04 cg_relative_residual=6.901549e-05
# [FinalLinearSolver] Iter 301/1000 iter=300 total_loss=-1.750934e+00 policy_objective=-3.224456e+02 beta_objective=3.978526e+01 q_objective=-1.624685e+00 policy_grad_norm=3.921877e+00 policy_direction_norm=4.153568e+01 beta_grad_norm=4.173527e+01 beta_direction_norm=5.075409e+02 theta_grad_norm=2.497477e-02 theta_norm=4.655958e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=1.981677e-04 cg_relative_residual=5.052879e-05
# [FinalLinearSolver] Iter 351/1000 iter=350 total_loss=8.543002e+00 policy_objective=-3.766990e+02 beta_objective=4.754244e+01 q_objective=8.684502e+00 policy_grad_norm=1.391933e+00 policy_direction_norm=5.874633e+01 beta_grad_norm=3.982916e+01 beta_direction_norm=4.299914e+02 theta_grad_norm=4.315405e-02 theta_norm=4.394442e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=8.638383e-05 cg_relative_residual=6.206034e-05
# [FinalLinearSolver] Iter 401/1000 iter=400 total_loss=1.577556e+01 policy_objective=-3.803473e+02 beta_objective=4.914800e+01 q_objective=1.592525e+01 policy_grad_norm=1.352425e+00 policy_direction_norm=6.858808e+01 beta_grad_norm=3.545725e+01 beta_direction_norm=3.290011e+02 theta_grad_norm=6.565582e-02 theta_norm=3.841413e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=2.957293e-04 cg_relative_residual=2.186659e-04
# [FinalLinearSolver] Iter 451/1000 iter=450 total_loss=1.865296e+01 policy_objective=-3.502502e+02 beta_objective=4.586010e+01 q_objective=1.880876e+01 policy_grad_norm=3.525133e+00 policy_direction_norm=6.254616e+01 beta_grad_norm=2.973590e+01 beta_direction_norm=2.377325e+02 theta_grad_norm=8.345726e-02 theta_norm=3.231352e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=3.354197e-04 cg_relative_residual=9.515095e-05
# [FinalLinearSolver] Iter 501/1000 iter=500 total_loss=1.736635e+01 policy_objective=-2.939332e+02 beta_objective=3.857753e+01 q_objective=1.752704e+01 policy_grad_norm=3.469696e+00 policy_direction_norm=5.318966e+01 beta_grad_norm=2.282970e+01 beta_direction_norm=1.614862e+02 theta_grad_norm=1.058852e-01 theta_norm=2.635122e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=4.677310e-04 cg_relative_residual=1.348046e-04
# [FinalLinearSolver] Iter 551/1000 iter=550 total_loss=1.277865e+01 policy_objective=-2.183007e+02 beta_objective=2.778082e+01 q_objective=1.294283e+01 policy_grad_norm=3.136191e+00 policy_direction_norm=3.673384e+01 beta_grad_norm=1.616278e+01 beta_direction_norm=9.604550e+01 theta_grad_norm=1.133312e-01 theta_norm=2.068375e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=3.452218e-04 cg_relative_residual=1.100768e-04
# [FinalLinearSolver] Iter 601/1000 iter=600 total_loss=5.774906e+00 policy_objective=-1.248576e+02 beta_objective=1.428739e+01 q_objective=5.941281e+00 policy_grad_norm=3.464079e+00 policy_direction_norm=3.030937e+01 beta_grad_norm=9.752266e+00 beta_direction_norm=5.841939e+01 theta_grad_norm=1.223932e-01 theta_norm=1.612156e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=9.089298e-04 cg_relative_residual=2.623872e-04
# [FinalLinearSolver] Iter 651/1000 iter=650 total_loss=-1.990433e+00 policy_objective=-2.134526e+01 beta_objective=3.379325e-01 q_objective=-1.823027e+00 policy_grad_norm=2.412383e+00 policy_direction_norm=3.740747e+01 beta_grad_norm=3.268104e+00 beta_direction_norm=8.897924e+01 theta_grad_norm=1.344063e-01 theta_norm=1.407815e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=2.557029e-04 cg_relative_residual=1.059960e-04
# [FinalLinearSolver] Iter 701/1000 iter=700 total_loss=-9.748971e+00 policy_objective=8.183995e+01 beta_objective=-1.384081e+01 q_objective=-9.581423e+00 policy_grad_norm=2.317469e+00 policy_direction_norm=5.190144e+01 beta_grad_norm=7.251918e+00 beta_direction_norm=1.531395e+02 theta_grad_norm=1.389922e-01 theta_norm=1.585437e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=5.096944e-04 cg_relative_residual=2.199358e-04
# [FinalLinearSolver] Iter 751/1000 iter=750 total_loss=-1.556033e+01 policy_objective=1.743922e+02 beta_objective=-2.572345e+01 q_objective=-1.539337e+01 policy_grad_norm=3.413620e+00 policy_direction_norm=7.505206e+01 beta_grad_norm=1.305864e+01 beta_direction_norm=2.258475e+02 theta_grad_norm=1.307052e-01 theta_norm=2.045459e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=4.379254e-04 cg_relative_residual=1.282877e-04
# [FinalLinearSolver] Iter 801/1000 iter=800 total_loss=-1.844579e+01 policy_objective=2.589229e+02 beta_objective=-3.490124e+01 q_objective=-1.828046e+01 policy_grad_norm=2.944571e+00 policy_direction_norm=8.097411e+01 beta_grad_norm=1.836595e+01 beta_direction_norm=3.062687e+02 theta_grad_norm=1.032839e-01 theta_norm=2.588243e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=4.647058e-04 cg_relative_residual=1.578178e-04
# [FinalLinearSolver] Iter 851/1000 iter=850 total_loss=-1.921446e+01 policy_objective=3.179708e+02 beta_objective=-4.107117e+01 q_objective=-1.905254e+01 policy_grad_norm=1.605632e+00 policy_direction_norm=6.760983e+01 beta_grad_norm=2.330038e+01 beta_direction_norm=3.871614e+02 theta_grad_norm=1.140267e-01 theta_norm=3.095249e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=4.291445e-03 cg_relative_residual=2.672746e-03
# [FinalLinearSolver] Iter 901/1000 iter=900 total_loss=-1.768269e+01 policy_objective=3.484448e+02 beta_objective=-4.395592e+01 q_objective=-1.752563e+01 policy_grad_norm=4.040717e+00 policy_direction_norm=6.500369e+01 beta_grad_norm=2.847882e+01 beta_direction_norm=4.637443e+02 theta_grad_norm=8.755600e-02 theta_norm=3.584440e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=6.524715e-04 cg_relative_residual=1.614742e-04
# [FinalLinearSolver] Iter 951/1000 iter=950 total_loss=-1.228643e+01 policy_objective=3.553712e+02 beta_objective=-4.223317e+01 q_objective=-1.213515e+01 policy_grad_norm=5.600000e+00 policy_direction_norm=7.267858e+01 beta_grad_norm=3.299330e+01 beta_direction_norm=5.402257e+02 theta_grad_norm=4.825158e-02 theta_norm=4.071133e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=6.065488e-03 cg_relative_residual=1.083123e-03
# lambda=5.000000e-07 | reached_goal=False | steps=50 | final_state=3
#
# ================================================================================
# Trying RBF features with theta_mode='reg_fixed', theta_lambda=1.000000e-06
# ================================================================================
# [FinalLinearSolver] Iter 1/1000 iter=0 total_loss=-1.588967e-01 policy_objective=-1.588967e-01 beta_objective=0.000000e+00 q_objective=-1.588951e-01 policy_grad_norm=0.000000e+00 policy_direction_norm=0.000000e+00 beta_grad_norm=6.724882e-02 beta_direction_norm=2.268845e+00 theta_grad_norm=9.051996e-02 theta_norm=1.788850e+00 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=0 cg_residual_norm=0.000000e+00 cg_relative_residual=0.000000e+00
# ...
# [FinalLinearSolver] Iter 201/1000 iter=200 total_loss=-1.730057e+01 policy_objective=-1.311862e+02 beta_objective=1.463764e+01 q_objective=-1.720311e+01 policy_grad_norm=9.903993e-05 policy_direction_norm=6.095984e-04 beta_grad_norm=3.203842e+01 beta_direction_norm=4.279078e+02 theta_grad_norm=5.914837e-02 theta_norm=3.595584e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=7 cg_residual_norm=6.915763e-12 cg_relative_residual=6.982802e-08
# [FinalLinearSolver] Iter 251/1000 iter=250 total_loss=-1.149326e+01 policy_objective=-2.267467e+02 beta_objective=2.735648e+01 q_objective=-1.134677e+01 policy_grad_norm=2.014615e+00 policy_direction_norm=1.326162e+01 beta_grad_norm=3.898707e+01 beta_direction_norm=5.101903e+02 theta_grad_norm=3.481464e-02 theta_norm=4.366675e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=1.243676e-04 cg_relative_residual=6.173270e-05
# [FinalLinearSolver] Iter 301/1000 iter=300 total_loss=-1.703770e+00 policy_objective=-3.215290e+02 beta_objective=3.971918e+01 q_objective=-1.523849e+00 policy_grad_norm=3.858238e+00 policy_direction_norm=4.206827e+01 beta_grad_norm=4.170406e+01 beta_direction_norm=5.061370e+02 theta_grad_norm=2.494203e-02 theta_norm=4.644661e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=2.047655e-04 cg_relative_residual=5.307228e-05
# [FinalLinearSolver] Iter 351/1000 iter=350 total_loss=8.494129e+00 policy_objective=-3.731690e+02 beta_objective=4.713596e+01 q_objective=8.682513e+00 policy_grad_norm=2.348172e+00 policy_direction_norm=6.061268e+01 beta_grad_norm=3.986879e+01 beta_direction_norm=4.250624e+02 theta_grad_norm=4.762198e-02 theta_norm=4.364527e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=1.909699e-04 cg_relative_residual=8.132704e-05
# [FinalLinearSolver] Iter 401/1000 iter=400 total_loss=1.573207e+01 policy_objective=-3.824489e+02 beta_objective=4.934329e+01 q_objective=1.591902e+01 policy_grad_norm=3.441086e+00 policy_direction_norm=6.637851e+01 beta_grad_norm=3.554563e+01 beta_direction_norm=3.301189e+02 theta_grad_norm=5.810741e-02 theta_norm=3.854119e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=2.767551e-04 cg_relative_residual=8.042670e-05
# [FinalLinearSolver] Iter 451/1000 iter=450 total_loss=1.875768e+01 policy_objective=-3.573216e+02 beta_objective=4.670538e+01 q_objective=1.894149e+01 policy_grad_norm=3.710822e+00 policy_direction_norm=5.923996e+01 beta_grad_norm=2.980598e+01 beta_direction_norm=2.404700e+02 theta_grad_norm=9.185150e-02 theta_norm=3.290875e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=9.248839e-05 cg_relative_residual=2.492396e-05
# [FinalLinearSolver] Iter 501/1000 iter=500 total_loss=1.754724e+01 policy_objective=-3.041915e+02 beta_objective=3.945045e+01 q_objective=1.772756e+01 policy_grad_norm=4.228973e+00 policy_direction_norm=4.466488e+01 beta_grad_norm=2.342480e+01 beta_direction_norm=1.599734e+02 theta_grad_norm=9.767132e-02 theta_norm=2.710856e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=2.808235e-04 cg_relative_residual=6.640465e-05
# [FinalLinearSolver] Iter 551/1000 iter=550 total_loss=1.282147e+01 policy_objective=-2.276426e+02 beta_objective=2.854476e+01 q_objective=1.299851e+01 policy_grad_norm=3.558549e+00 policy_direction_norm=3.130177e+01 beta_grad_norm=1.626095e+01 beta_direction_norm=9.078119e+01 theta_grad_norm=1.170008e-01 theta_norm=2.149964e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=1.855602e-03 cg_relative_residual=5.214491e-04
# [FinalLinearSolver] Iter 601/1000 iter=600 total_loss=5.801469e+00 policy_objective=-1.286666e+02 beta_objective=1.470205e+01 q_objective=5.976249e+00 policy_grad_norm=2.534942e+00 policy_direction_norm=2.312386e+01 beta_grad_norm=9.599754e+00 beta_direction_norm=5.005210e+01 theta_grad_norm=1.212951e-01 theta_norm=1.689001e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=2.011703e-04 cg_relative_residual=7.935891e-05
# [FinalLinearSolver] Iter 651/1000 iter=650 total_loss=-2.053097e+00 policy_objective=-2.199073e+01 beta_objective=3.397731e-01 q_objective=-1.878429e+00 policy_grad_norm=2.096910e+00 policy_direction_norm=3.484447e+01 beta_grad_norm=3.720199e+00 beta_direction_norm=9.728279e+01 theta_grad_norm=1.270985e-01 theta_norm=1.509520e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=1.911872e-04 cg_relative_residual=9.117565e-05
# [FinalLinearSolver] Iter 701/1000 iter=700 total_loss=-1.000805e+01 policy_objective=8.526210e+01 beta_objective=-1.419596e+01 q_objective=-9.831950e+00 policy_grad_norm=2.149314e+00 policy_direction_norm=4.344628e+01 beta_grad_norm=6.930878e+00 beta_direction_norm=1.663800e+02 theta_grad_norm=1.320866e-01 theta_norm=1.666385e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=4.837120e-04 cg_relative_residual=2.250542e-04
# [FinalLinearSolver] Iter 751/1000 iter=750 total_loss=-1.640834e+01 policy_objective=1.896359e+02 beta_objective=-2.741440e+01 q_objective=-1.622814e+01 policy_grad_norm=1.956893e+00 policy_direction_norm=6.042173e+01 beta_grad_norm=1.378849e+01 beta_direction_norm=2.455034e+02 theta_grad_norm=1.212200e-01 theta_norm=2.137782e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=4.247932e-04 cg_relative_residual=2.170753e-04
# [FinalLinearSolver] Iter 801/1000 iter=800 total_loss=-2.011346e+01 policy_objective=2.804505e+02 beta_objective=-3.780543e+01 q_objective=-1.992682e+01 policy_grad_norm=1.705143e+00 policy_direction_norm=7.433868e+01 beta_grad_norm=2.010426e+01 beta_direction_norm=3.292258e+02 theta_grad_norm=1.149768e-01 theta_norm=2.746389e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=5.377284e-04 cg_relative_residual=3.153568e-04
# [FinalLinearSolver] Iter 851/1000 iter=850 total_loss=-2.038820e+01 policy_objective=3.497997e+02 beta_objective=-4.457960e+01 q_objective=-2.019486e+01 policy_grad_norm=4.148771e+00 policy_direction_norm=7.007097e+01 beta_grad_norm=2.566839e+01 beta_direction_norm=4.209827e+02 theta_grad_norm=8.435575e-02 theta_norm=3.347726e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=3.388582e-04 cg_relative_residual=8.167677e-05
# [FinalLinearSolver] Iter 901/1000 iter=900 total_loss=-1.758207e+01 policy_objective=3.863857e+02 beta_objective=-4.703711e+01 q_objective=-1.738119e+01 policy_grad_norm=3.964526e+00 policy_direction_norm=6.204699e+01 beta_grad_norm=3.180126e+01 beta_direction_norm=5.054619e+02 theta_grad_norm=6.029212e-02 theta_norm=3.949281e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=4.417786e-04 cg_relative_residual=1.114329e-04
# [FinalLinearSolver] Iter 951/1000 iter=950 total_loss=-1.096011e+01 policy_objective=3.898767e+02 beta_objective=-4.525296e+01 q_objective=-1.075427e+01 policy_grad_norm=4.108630e+00 policy_direction_norm=5.825545e+01 beta_grad_norm=3.523543e+01 beta_direction_norm=5.874905e+02 theta_grad_norm=3.793135e-02 theta_norm=4.467996e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=7.387512e-04 cg_relative_residual=1.798047e-04
# lambda=1.000000e-06 | reached_goal=True | steps=4 | final_state=8
#
# FOUND working theta_lambda: 1.000000e-06
#   State 0: pi(a=0|s=0) = 0.24  pi(a=1|s=0) = 0.31  pi(a=2|s=0) = 0.23  pi(a=3|s=0) = 0.22  --> best action: 1
#   State 1: pi(a=0|s=1) = 0.17  pi(a=1|s=1) = 0.34  pi(a=2|s=1) = 0.33  pi(a=3|s=1) = 0.16  --> best action: 1
#   State 2: pi(a=0|s=2) = 0.21  pi(a=1|s=2) = 0.32  pi(a=2|s=2) = 0.15  pi(a=3|s=2) = 0.32  --> best action: 3
#   State 3: pi(a=0|s=3) = 0.21  pi(a=1|s=3) = 0.32  pi(a=2|s=3) = 0.26  pi(a=3|s=3) = 0.22  --> best action: 1
#   State 4: pi(a=0|s=4) = 0.15  pi(a=1|s=4) = 0.35  pi(a=2|s=4) = 0.35  pi(a=3|s=4) = 0.16  --> best action: 2
#   State 5: pi(a=0|s=5) = 0.18  pi(a=1|s=5) = 0.33  pi(a=2|s=5) = 0.15  pi(a=3|s=5) = 0.33  --> best action: 3
#   State 6: pi(a=0|s=6) = 0.23  pi(a=1|s=6) = 0.23  pi(a=2|s=6) = 0.08  pi(a=3|s=6) = 0.46  --> best action: 3
#   State 7: pi(a=0|s=7) = 0.20  pi(a=1|s=7) = 0.28  pi(a=2|s=7) = 0.11  pi(a=3|s=7) = 0.42  --> best action: 3
#   State 8: pi(a=0|s=8) = 0.17  pi(a=1|s=8) = 0.20  pi(a=2|s=8) = 0.04  pi(a=3|s=8) = 0.58  --> best action: 3
#
#   State 0: pi(a=0|s=0) = 0.24  pi(a=1|s=0) = 0.31  pi(a=2|s=0) = 0.23  pi(a=3|s=0) = 0.22  --> best action: 1
#   State 1: pi(a=0|s=1) = 0.17  pi(a=1|s=1) = 0.34  pi(a=2|s=1) = 0.33  pi(a=3|s=1) = 0.16  --> best action: 1
#   State 2: pi(a=0|s=2) = 0.21  pi(a=1|s=2) = 0.32  pi(a=2|s=2) = 0.15  pi(a=3|s=2) = 0.32  --> best action: 3
#   State 3: pi(a=0|s=3) = 0.21  pi(a=1|s=3) = 0.32  pi(a=2|s=3) = 0.26  pi(a=3|s=3) = 0.22  --> best action: 1
#   State 4: pi(a=0|s=4) = 0.15  pi(a=1|s=4) = 0.35  pi(a=2|s=4) = 0.35  pi(a=3|s=4) = 0.16  --> best action: 2
#   State 5: pi(a=0|s=5) = 0.18  pi(a=1|s=5) = 0.33  pi(a=2|s=5) = 0.15  pi(a=3|s=5) = 0.33  --> best action: 3
#   State 6: pi(a=0|s=6) = 0.23  pi(a=1|s=6) = 0.23  pi(a=2|s=6) = 0.08  pi(a=3|s=6) = 0.46  --> best action: 3
#   State 7: pi(a=0|s=7) = 0.20  pi(a=1|s=7) = 0.28  pi(a=2|s=7) = 0.11  pi(a=3|s=7) = 0.42  --> best action: 3
#   State 8: pi(a=0|s=8) = 0.17  pi(a=1|s=8) = 0.20  pi(a=2|s=8) = 0.04  pi(a=3|s=8) = 0.58  --> best action: 3
#
#
# ======================================================================
#   PATH VISUALIZATION - Solver Policy (greedy)
# ======================================================================
#
# Initial State: 0
# Goal State: 8
# Terminal States: [8]
# Discount Factor (gamma): 0.9
#
# ----------------------------------------------------------------------
#
#   Step   0 | State: tensor(0)       | Action: tensor(1)       | Reward:  -0.100 | -> 3
#   Step   1 | State: tensor(3)       | Action: tensor(1)       | Reward:  -0.100 | -> 6
#   Step   2 | State: tensor(6)       | Action: tensor(3)       | Reward:  -0.100 | -> 7
#   Step   3 | State: tensor(7)       | Action: tensor(3)       | Reward:  -0.100 | -> 8 GOAL REACHED
#
#   ------------------------------------------------------------------
#   Trajectory Length: 4 steps
#   Discounted Return: -0.343900
#   Final State: 8
#
# ======================================================================
#    theta_lambda  reached_goal  trajectory_length  final_state
# 0  1.000000e-07         False                 50            0
# 1  2.000000e-07         False                 50            3
# 2  5.000000e-07         False                 50            3
# 3  1.000000e-06          True                  4            8

# %%
from rl_methods.fogas_generalization_clean import (
    FinalLinearSolver,
    RBFStateFeatures,
    RBFStateActionFeatures,
    LinearFunction,
    LinearQFunction,
)

# Normalized 2D coordinates for each 3x3 grid state
state_coords = torch.tensor(
    [[r / 2.0, c / 2.0] for r in range(3) for c in range(3)],
    dtype=torch.float64,
)

rbf_centers = torch.tensor(
    [
        [0.25, 0.25],  # top-left
        [0.75, 0.25],  # top-right
        [0.25, 0.75],  # bottom-left
        [0.75, 0.75],  # goal
    ],
    dtype=torch.float64,
)

state_rbf = RBFStateFeatures(
    n_states=N,
    centers=rbf_centers,
    state_coords=state_coords,
    bandwidth="nearest",
    bandwidth_scale=2.0,
    include_bias=True,
)

u_features = RBFStateActionFeatures(state_rbf, n_actions=A)
q_features = RBFStateActionFeatures(state_rbf, n_actions=A)
policy_features = RBFStateActionFeatures(state_rbf, n_actions=A)

solver_e = FinalLinearSolver(
    n_states=N,
    n_actions=A,
    gamma=gamma,
    x0=x_0,
    csv_path=dataset_path,
    u_function=LinearFunction(u_features),
    q_function=LinearQFunction(q_features),
    policy_features=policy_features,
    seed=SEED,
    device=DEVICE,

    theta_include_beta_cov=False,

    theta_mode="reg_fixed",
    theta_lambda=1e-6,
    theta_optimizer="adam",
    theta_inner_steps=40,
    theta_lr=1e-2,
    theta_start_mode="warm",

    beta_update="fogas_full",
)

solver_e.run(
    alpha=1e-3,
    eta=1e-4,
    rho=0.005,
    policy_optimizer="npg",
    policy_gradient="exact",
    reinforce_samples=1,
    tqdm_print=False,
    verbose=True,
    log_interval=50,
    T=1000,
    state_weight_update="normal",
)

mdp.print_policy(solver_e.pi)
# Out:
# [FinalLinearSolver] Iter 1/1000 iter=0 total_loss=-1.588967e-01 policy_objective=-1.588967e-01 beta_objective=0.000000e+00 q_objective=-1.588951e-01 policy_grad_norm=0.000000e+00 policy_direction_norm=0.000000e+00 beta_grad_norm=6.724882e-02 beta_direction_norm=2.268845e+00 theta_grad_norm=9.051996e-02 theta_norm=1.788850e+00 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=0 cg_residual_norm=0.000000e+00 cg_relative_residual=0.000000e+00
# [FinalLinearSolver] Iter 51/1000 iter=50 total_loss=-7.872775e+00 policy_objective=-9.672287e+00 beta_objective=2.309554e-01 q_objective=-7.866569e+00 policy_grad_norm=1.603691e-07 policy_direction_norm=3.200868e-06 beta_grad_norm=8.059156e+00 beta_direction_norm=1.086760e+02 theta_grad_norm=8.795002e-02 theta_norm=9.123133e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=6 cg_residual_norm=1.254163e-15 cg_relative_residual=7.820472e-09
# [FinalLinearSolver] Iter 101/1000 iter=100 total_loss=-1.421288e+01 policy_objective=-2.850230e+01 beta_objective=1.835683e+00 q_objective=-1.418836e+01 policy_grad_norm=2.070040e-06 policy_direction_norm=2.792044e-05 beta_grad_norm=1.605225e+01 beta_direction_norm=2.150867e+02 theta_grad_norm=8.071910e-02 theta_norm=1.806738e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=6 cg_residual_norm=8.866478e-12 cg_relative_residual=4.283240e-06
# [FinalLinearSolver] Iter 151/1000 iter=150 total_loss=-1.781140e+01 policy_objective=-6.591752e+01 beta_objective=6.181994e+00 q_objective=-1.775646e+01 policy_grad_norm=1.351305e-05 policy_direction_norm=1.210334e-04 beta_grad_norm=2.404535e+01 beta_direction_norm=3.214974e+02 theta_grad_norm=7.000681e-02 theta_norm=2.701162e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=7 cg_residual_norm=2.467208e-13 cg_relative_residual=1.825796e-08
# [FinalLinearSolver] Iter 201/1000 iter=200 total_loss=-1.730057e+01 policy_objective=-1.311862e+02 beta_objective=1.463764e+01 q_objective=-1.720311e+01 policy_grad_norm=9.903993e-05 policy_direction_norm=6.095984e-04 beta_grad_norm=3.203842e+01 beta_direction_norm=4.279078e+02 theta_grad_norm=5.914837e-02 theta_norm=3.595584e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=7 cg_residual_norm=6.915763e-12 cg_relative_residual=6.982802e-08
# [FinalLinearSolver] Iter 251/1000 iter=250 total_loss=-1.149326e+01 policy_objective=-2.267467e+02 beta_objective=2.735648e+01 q_objective=-1.134677e+01 policy_grad_norm=2.014615e+00 policy_direction_norm=1.326162e+01 beta_grad_norm=3.898707e+01 beta_direction_norm=5.101903e+02 theta_grad_norm=3.481464e-02 theta_norm=4.366675e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=1.243676e-04 cg_relative_residual=6.173270e-05
# [FinalLinearSolver] Iter 301/1000 iter=300 total_loss=-1.703770e+00 policy_objective=-3.215290e+02 beta_objective=3.971918e+01 q_objective=-1.523849e+00 policy_grad_norm=3.858238e+00 policy_direction_norm=4.206827e+01 beta_grad_norm=4.170406e+01 beta_direction_norm=5.061370e+02 theta_grad_norm=2.494203e-02 theta_norm=4.644661e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=2.047655e-04 cg_relative_residual=5.307228e-05
# [FinalLinearSolver] Iter 351/1000 iter=350 total_loss=8.494129e+00 policy_objective=-3.731690e+02 beta_objective=4.713596e+01 q_objective=8.682513e+00 policy_grad_norm=2.348172e+00 policy_direction_norm=6.061268e+01 beta_grad_norm=3.986879e+01 beta_direction_norm=4.250624e+02 theta_grad_norm=4.762198e-02 theta_norm=4.364527e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=1.909699e-04 cg_relative_residual=8.132704e-05
# [FinalLinearSolver] Iter 401/1000 iter=400 total_loss=1.573207e+01 policy_objective=-3.824489e+02 beta_objective=4.934329e+01 q_objective=1.591902e+01 policy_grad_norm=3.441086e+00 policy_direction_norm=6.637851e+01 beta_grad_norm=3.554563e+01 beta_direction_norm=3.301189e+02 theta_grad_norm=5.810741e-02 theta_norm=3.854119e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=2.767551e-04 cg_relative_residual=8.042670e-05
# [FinalLinearSolver] Iter 451/1000 iter=450 total_loss=1.875768e+01 policy_objective=-3.573216e+02 beta_objective=4.670538e+01 q_objective=1.894149e+01 policy_grad_norm=3.710822e+00 policy_direction_norm=5.923996e+01 beta_grad_norm=2.980598e+01 beta_direction_norm=2.404700e+02 theta_grad_norm=9.185150e-02 theta_norm=3.290875e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=9.248839e-05 cg_relative_residual=2.492396e-05
# [FinalLinearSolver] Iter 501/1000 iter=500 total_loss=1.754724e+01 policy_objective=-3.041915e+02 beta_objective=3.945045e+01 q_objective=1.772756e+01 policy_grad_norm=4.228973e+00 policy_direction_norm=4.466488e+01 beta_grad_norm=2.342480e+01 beta_direction_norm=1.599734e+02 theta_grad_norm=9.767132e-02 theta_norm=2.710856e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=2.808235e-04 cg_relative_residual=6.640465e-05
# [FinalLinearSolver] Iter 551/1000 iter=550 total_loss=1.282147e+01 policy_objective=-2.276426e+02 beta_objective=2.854476e+01 q_objective=1.299851e+01 policy_grad_norm=3.558549e+00 policy_direction_norm=3.130177e+01 beta_grad_norm=1.626095e+01 beta_direction_norm=9.078119e+01 theta_grad_norm=1.170008e-01 theta_norm=2.149964e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=1.855602e-03 cg_relative_residual=5.214491e-04
# [FinalLinearSolver] Iter 601/1000 iter=600 total_loss=5.801469e+00 policy_objective=-1.286666e+02 beta_objective=1.470205e+01 q_objective=5.976249e+00 policy_grad_norm=2.534942e+00 policy_direction_norm=2.312386e+01 beta_grad_norm=9.599754e+00 beta_direction_norm=5.005210e+01 theta_grad_norm=1.212951e-01 theta_norm=1.689001e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=2.011703e-04 cg_relative_residual=7.935891e-05
# [FinalLinearSolver] Iter 651/1000 iter=650 total_loss=-2.053097e+00 policy_objective=-2.199073e+01 beta_objective=3.397731e-01 q_objective=-1.878429e+00 policy_grad_norm=2.096910e+00 policy_direction_norm=3.484447e+01 beta_grad_norm=3.720199e+00 beta_direction_norm=9.728279e+01 theta_grad_norm=1.270985e-01 theta_norm=1.509520e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=1.911872e-04 cg_relative_residual=9.117565e-05
# [FinalLinearSolver] Iter 701/1000 iter=700 total_loss=-1.000805e+01 policy_objective=8.526210e+01 beta_objective=-1.419596e+01 q_objective=-9.831950e+00 policy_grad_norm=2.149314e+00 policy_direction_norm=4.344628e+01 beta_grad_norm=6.930878e+00 beta_direction_norm=1.663800e+02 theta_grad_norm=1.320866e-01 theta_norm=1.666385e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=4.837120e-04 cg_relative_residual=2.250542e-04
# [FinalLinearSolver] Iter 751/1000 iter=750 total_loss=-1.640834e+01 policy_objective=1.896359e+02 beta_objective=-2.741440e+01 q_objective=-1.622814e+01 policy_grad_norm=1.956893e+00 policy_direction_norm=6.042173e+01 beta_grad_norm=1.378849e+01 beta_direction_norm=2.455034e+02 theta_grad_norm=1.212200e-01 theta_norm=2.137782e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=4.247932e-04 cg_relative_residual=2.170753e-04
# [FinalLinearSolver] Iter 801/1000 iter=800 total_loss=-2.011346e+01 policy_objective=2.804505e+02 beta_objective=-3.780543e+01 q_objective=-1.992682e+01 policy_grad_norm=1.705143e+00 policy_direction_norm=7.433868e+01 beta_grad_norm=2.010426e+01 beta_direction_norm=3.292258e+02 theta_grad_norm=1.149768e-01 theta_norm=2.746389e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=5.377284e-04 cg_relative_residual=3.153568e-04
# [FinalLinearSolver] Iter 851/1000 iter=850 total_loss=-2.038820e+01 policy_objective=3.497997e+02 beta_objective=-4.457960e+01 q_objective=-2.019486e+01 policy_grad_norm=4.148771e+00 policy_direction_norm=7.007097e+01 beta_grad_norm=2.566839e+01 beta_direction_norm=4.209827e+02 theta_grad_norm=8.435575e-02 theta_norm=3.347726e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=3.388582e-04 cg_relative_residual=8.167677e-05
# [FinalLinearSolver] Iter 901/1000 iter=900 total_loss=-1.758207e+01 policy_objective=3.863857e+02 beta_objective=-4.703711e+01 q_objective=-1.738119e+01 policy_grad_norm=3.964526e+00 policy_direction_norm=6.204699e+01 beta_grad_norm=3.180126e+01 beta_direction_norm=5.054619e+02 theta_grad_norm=6.029212e-02 theta_norm=3.949281e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=4.417786e-04 cg_relative_residual=1.114329e-04
# [FinalLinearSolver] Iter 951/1000 iter=950 total_loss=-1.096011e+01 policy_objective=3.898767e+02 beta_objective=-4.525296e+01 q_objective=-1.075427e+01 policy_grad_norm=4.108630e+00 policy_direction_norm=5.825545e+01 beta_grad_norm=3.523543e+01 beta_direction_norm=5.874905e+02 theta_grad_norm=3.793135e-02 theta_norm=4.467996e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=7.387512e-04 cg_relative_residual=1.798047e-04
#   State 0: pi(a=0|s=0) = 0.24  pi(a=1|s=0) = 0.31  pi(a=2|s=0) = 0.23  pi(a=3|s=0) = 0.22  --> best action: 1
#   State 1: pi(a=0|s=1) = 0.17  pi(a=1|s=1) = 0.34  pi(a=2|s=1) = 0.33  pi(a=3|s=1) = 0.16  --> best action: 1
#   State 2: pi(a=0|s=2) = 0.21  pi(a=1|s=2) = 0.32  pi(a=2|s=2) = 0.15  pi(a=3|s=2) = 0.32  --> best action: 3
#   State 3: pi(a=0|s=3) = 0.21  pi(a=1|s=3) = 0.32  pi(a=2|s=3) = 0.26  pi(a=3|s=3) = 0.22  --> best action: 1
#   State 4: pi(a=0|s=4) = 0.15  pi(a=1|s=4) = 0.35  pi(a=2|s=4) = 0.35  pi(a=3|s=4) = 0.16  --> best action: 2
#   State 5: pi(a=0|s=5) = 0.18  pi(a=1|s=5) = 0.33  pi(a=2|s=5) = 0.15  pi(a=3|s=5) = 0.33  --> best action: 3
#   State 6: pi(a=0|s=6) = 0.23  pi(a=1|s=6) = 0.23  pi(a=2|s=6) = 0.08  pi(a=3|s=6) = 0.46  --> best action: 3
#   State 7: pi(a=0|s=7) = 0.20  pi(a=1|s=7) = 0.28  pi(a=2|s=7) = 0.11  pi(a=3|s=7) = 0.42  --> best action: 3
#   State 8: pi(a=0|s=8) = 0.17  pi(a=1|s=8) = 0.20  pi(a=2|s=8) = 0.04  pi(a=3|s=8) = 0.58  --> best action: 3

# %% [markdown]
# # 3grid walls

# %%
states = torch.arange(9, dtype=torch.long)
actions = torch.arange(4, dtype=torch.long)
N = len(states)
A = len(actions)
gamma = 0.9

x_0 = 0
dataset_path_3walls = str(DATASETS_DIR / "3grid_wall.csv")

goal = 8
pit = 5
wall = 4

step_cost = -0.1
goal_reward = 1.0
pit_reward = -1.0


def phi(x, a):
    vec = torch.zeros(N * A, dtype=torch.float64)
    vec[int(x) * A + int(a)] = 1.0
    return vec


omega = torch.full((N * A,), step_cost, dtype=torch.float64)
omega[goal * A : goal * A + A] = goal_reward
omega[pit * A : pit * A + A] = pit_reward


def to_rc(s):
    return divmod(int(s), 3)


def to_s(r, c):
    return r * 3 + c


def next_state(s, a):
    s = int(s)
    a = int(a)

    if s == goal or s == pit:
        return s

    r, c = to_rc(s)

    if a == 0:      # Up
        r2, c2 = max(0, r - 1), c
    elif a == 1:    # Down
        r2, c2 = min(2, r + 1), c
    elif a == 2:    # Left
        r2, c2 = r, max(0, c - 1)
    elif a == 3:    # Right
        r2, c2 = r, min(2, c + 1)
    else:
        raise ValueError(f"Unknown action: {a}")

    sp = to_s(r2, c2)

    if sp == wall:
        return s

    return sp


def transition_fn(s, a):
    probs = torch.zeros(N, dtype=torch.float64)
    probs[next_state(s, a)] = 1.0
    return probs


mdp = DiscreteMDP(
    states=states,
    actions=actions,
    gamma=gamma,
    x0=x_0,
    omega=omega,
    phi=phi,
    transition_fn=transition_fn,
    terminal_states=[goal, pit],
)

planner = Planner(mdp, mode="deterministic")

# %%
from rl_methods.fogas_generalization_clean import (
    FinalLinearSolver,
    RBFStateFeatures,
    RBFStateActionFeatures,
    LinearFunction,
    LinearQFunction,
)

# Normalized 2D coordinates for each 3x3 grid state
state_coords = torch.tensor(
    [[r / 2.0, c / 2.0] for r in range(3) for c in range(3)],
    dtype=torch.float64,
)

rbf_centers = torch.tensor(
    [
        [0.25, 0.25],  # top-left
        [0.75, 0.25],  # top-right
        [0.25, 0.75],  # bottom-left
        [0.75, 0.75],  # goal
    ],
    dtype=torch.float64,
)

state_rbf = RBFStateFeatures(
    n_states=N,
    centers=rbf_centers,
    state_coords=state_coords,
    bandwidth="nearest",
    bandwidth_scale=2.0,
    include_bias=True,
)

u_features = RBFStateActionFeatures(state_rbf, n_actions=A)
q_features = RBFStateActionFeatures(state_rbf, n_actions=A)
policy_features = RBFStateActionFeatures(state_rbf, n_actions=A)

solver_e = FinalLinearSolver(
    n_states=N,
    n_actions=A,
    gamma=gamma,
    x0=x_0,
    csv_path=dataset_path_3walls,
    u_function=LinearFunction(u_features),
    q_function=LinearQFunction(q_features),
    policy_features=policy_features,
    seed=SEED,
    device=DEVICE,

    theta_include_beta_cov=False,

    theta_mode="reg_adaptive",
    theta_lambda=1e-6,
    theta_optimizer="adam",
    theta_inner_steps=40,
    theta_lr=1e-2,
    theta_start_mode="warm",

    beta_update="fogas_full",
)

solver_e.run(
    alpha=2e-2,
    eta=2e-2,
    rho=0.005,
    policy_optimizer="npg",
    policy_gradient="exact",
    reinforce_samples=1,
    tqdm_print=False,
    verbose=True,
    log_interval=50,
    T=1000,
    state_weight_update="normal",
)

mdp.print_policy(solver_e.pi)
# Out:
# [FinalLinearSolver] Iter 1/1000 iter=0 total_loss=-1.566564e-01 policy_objective=-1.566564e-01 beta_objective=0.000000e+00 q_objective=-1.467142e-01 policy_grad_norm=1.776593e-17 policy_direction_norm=0.000000e+00 beta_grad_norm=6.224223e-02 beta_direction_norm=2.841854e+00 theta_grad_norm=7.947320e-02 theta_norm=1.762530e+00 theta_mode=reg_adaptive theta_optimizer=adam theta_start_mode=warm theta_lambda=6.400852e-03 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=0 cg_residual_norm=1.776593e-17 cg_relative_residual=0.000000e+00
# [FinalLinearSolver] Iter 51/1000 iter=50 total_loss=-1.631378e-01 policy_objective=-2.740456e+00 beta_objective=1.677738e-01 q_objective=-5.924939e-03 policy_grad_norm=6.995886e-01 policy_direction_norm=3.684557e+00 beta_grad_norm=8.567357e-01 beta_direction_norm=2.747859e+00 theta_grad_norm=4.011206e-02 theta_norm=7.093647e+00 theta_mode=reg_adaptive theta_optimizer=adam theta_start_mode=warm theta_lambda=2.866130e-03 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=8.305390e-06 cg_relative_residual=1.187182e-05
# [FinalLinearSolver] Iter 101/1000 iter=100 total_loss=-2.341794e-01 policy_objective=-1.066137e+00 beta_objective=-1.084576e-01 q_objective=-7.974732e-02 policy_grad_norm=8.903384e-01 policy_direction_norm=3.803508e+00 beta_grad_norm=9.839212e-01 beta_direction_norm=2.216829e+00 theta_grad_norm=1.393843e-01 theta_norm=3.751079e+00 theta_mode=reg_adaptive theta_optimizer=adam theta_start_mode=warm theta_lambda=1.026276e-02 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=6.806334e-05 cg_relative_residual=7.644660e-05
# [FinalLinearSolver] Iter 151/1000 iter=150 total_loss=-1.277900e-01 policy_objective=-9.231945e-01 beta_objective=-2.515080e-02 q_objective=-3.586269e-02 policy_grad_norm=2.057053e+00 policy_direction_norm=7.620531e+00 beta_grad_norm=2.494683e+00 beta_direction_norm=3.865169e+00 theta_grad_norm=1.372375e-02 theta_norm=4.757728e+00 theta_mode=reg_adaptive theta_optimizer=adam theta_start_mode=warm theta_lambda=1.166157e-03 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=8.783428e-05 cg_relative_residual=4.269908e-05
# [FinalLinearSolver] Iter 201/1000 iter=200 total_loss=-4.465661e-01 policy_objective=-9.741144e-01 beta_objective=-3.430117e-01 q_objective=-2.643761e-01 policy_grad_norm=2.072355e+00 policy_direction_norm=7.646838e+00 beta_grad_norm=2.374605e+00 beta_direction_norm=4.026138e+00 theta_grad_norm=1.156979e-01 theta_norm=4.555800e+00 theta_mode=reg_adaptive theta_optimizer=adam theta_start_mode=warm theta_lambda=9.609059e-03 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=3.918629e-05 cg_relative_residual=1.890906e-05
# [FinalLinearSolver] Iter 251/1000 iter=250 total_loss=-9.380702e-02 policy_objective=-5.837037e-01 beta_objective=-2.775870e-02 q_objective=-2.385211e-03 policy_grad_norm=8.406314e-01 policy_direction_norm=2.891258e+00 beta_grad_norm=1.009954e+00 beta_direction_norm=2.094842e+00 theta_grad_norm=3.108667e-02 theta_norm=2.865803e+00 theta_mode=reg_adaptive theta_optimizer=adam theta_start_mode=warm theta_lambda=2.210118e-03 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=1.818738e-05 cg_relative_residual=2.163538e-05
# [FinalLinearSolver] Iter 301/1000 iter=300 total_loss=-1.909755e-01 policy_objective=-1.221283e+00 beta_objective=-5.127263e-02 q_objective=-7.771830e-02 policy_grad_norm=8.785408e-01 policy_direction_norm=3.381109e+00 beta_grad_norm=9.974933e-01 beta_direction_norm=1.631531e+00 theta_grad_norm=6.868240e-02 theta_norm=3.335008e+00 theta_mode=reg_adaptive theta_optimizer=adam theta_start_mode=warm theta_lambda=5.260692e-03 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=5.500536e-05 cg_relative_residual=6.260991e-05
# [FinalLinearSolver] Iter 351/1000 iter=350 total_loss=-1.231062e-01 policy_objective=-1.012434e+00 beta_objective=-2.036436e-03 q_objective=-1.930859e-02 policy_grad_norm=9.351334e-01 policy_direction_norm=3.222737e+00 beta_grad_norm=1.070763e+00 beta_direction_norm=1.685363e+00 theta_grad_norm=6.251947e-02 theta_norm=2.909503e+00 theta_mode=reg_adaptive theta_optimizer=adam theta_start_mode=warm theta_lambda=4.518391e-03 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=2.842045e-05 cg_relative_residual=3.039186e-05
# [FinalLinearSolver] Iter 401/1000 iter=400 total_loss=-7.987949e-02 policy_objective=-1.320661e+00 beta_objective=7.928714e-02 q_objective=3.054613e-02 policy_grad_norm=4.473989e-01 policy_direction_norm=1.609167e+00 beta_grad_norm=5.308118e-01 beta_direction_norm=1.480483e+00 theta_grad_norm=7.126990e-02 theta_norm=3.444896e+00 theta_mode=reg_adaptive theta_optimizer=adam theta_start_mode=warm theta_lambda=4.889126e-03 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=1.849838e-05 cg_relative_residual=4.134651e-05
# [FinalLinearSolver] Iter 451/1000 iter=450 total_loss=-2.747318e-01 policy_objective=-1.276569e+00 beta_objective=-1.356548e-01 q_objective=-1.617518e-01 policy_grad_norm=1.529685e+00 policy_direction_norm=6.139578e+00 beta_grad_norm=1.843578e+00 beta_direction_norm=3.015962e+00 theta_grad_norm=6.571652e-02 theta_norm=3.269153e+00 theta_mode=reg_adaptive theta_optimizer=adam theta_start_mode=warm theta_lambda=5.525474e-03 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=1.045022e-04 cg_relative_residual=6.831613e-05
# [FinalLinearSolver] Iter 501/1000 iter=500 total_loss=-1.495851e+00 policy_objective=-1.841385e+00 beta_objective=-1.298853e+00 q_objective=-1.121381e+00 policy_grad_norm=2.865501e+00 policy_direction_norm=1.467991e+01 beta_grad_norm=3.832961e+00 beta_direction_norm=7.134603e+00 theta_grad_norm=2.030097e-01 theta_norm=5.294820e+00 theta_mode=reg_adaptive theta_optimizer=adam theta_start_mode=warm theta_lambda=2.101801e-02 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=4.189630e-04 cg_relative_residual=1.462093e-04
# [FinalLinearSolver] Iter 551/1000 iter=550 total_loss=-1.897992e+00 policy_objective=-1.189122e+00 beta_objective=-1.761815e+00 q_objective=-1.584844e+00 policy_grad_norm=1.593506e+00 policy_direction_norm=1.041068e+01 beta_grad_norm=1.945279e+00 beta_direction_norm=4.196753e+00 theta_grad_norm=7.040073e-01 theta_norm=2.837322e+00 theta_mode=reg_adaptive theta_optimizer=adam theta_start_mode=warm theta_lambda=5.833181e-02 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=4.332718e-04 cg_relative_residual=2.718985e-04
# [FinalLinearSolver] Iter 601/1000 iter=600 total_loss=-3.399901e+00 policy_objective=-2.320630e+00 beta_objective=-2.931575e+00 q_objective=-2.403753e+00 policy_grad_norm=3.050442e+00 policy_direction_norm=1.229950e+01 beta_grad_norm=5.323364e+00 beta_direction_norm=1.591604e+01 theta_grad_norm=2.695230e-01 theta_norm=7.358352e+00 theta_mode=reg_adaptive theta_optimizer=adam theta_start_mode=warm theta_lambda=3.455016e-02 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=1.368285e-04 cg_relative_residual=4.485530e-05
# [FinalLinearSolver] Iter 651/1000 iter=650 total_loss=-1.342179e+00 policy_objective=-2.385115e+00 beta_objective=-9.185820e-01 q_objective=-9.389155e-01 policy_grad_norm=1.337695e+00 policy_direction_norm=6.223498e+00 beta_grad_norm=2.288465e+00 beta_direction_norm=8.008905e+00 theta_grad_norm=3.399647e-01 theta_norm=4.851880e+00 theta_mode=reg_adaptive theta_optimizer=adam theta_start_mode=warm theta_lambda=2.918782e-02 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=1.669170e-04 cg_relative_residual=1.247796e-04
# [FinalLinearSolver] Iter 701/1000 iter=700 total_loss=-3.018019e-01 policy_objective=-1.034985e+00 beta_objective=-1.559055e-01 q_objective=-1.861498e-01 policy_grad_norm=4.119334e-01 policy_direction_norm=3.041007e+00 beta_grad_norm=6.530082e-01 beta_direction_norm=3.397597e+00 theta_grad_norm=2.202722e-01 theta_norm=2.577643e+00 theta_mode=reg_adaptive theta_optimizer=adam theta_start_mode=warm theta_lambda=1.653413e-02 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=1.032119e-04 cg_relative_residual=2.505548e-04
# [FinalLinearSolver] Iter 751/1000 iter=750 total_loss=2.854398e-01 policy_objective=-1.871337e+00 beta_objective=5.926257e-01 q_objective=4.763215e-01 policy_grad_norm=1.669619e+00 policy_direction_norm=1.135547e+01 beta_grad_norm=2.347240e+00 beta_direction_norm=9.382123e+00 theta_grad_norm=1.649025e-01 theta_norm=4.982133e+00 theta_mode=reg_adaptive theta_optimizer=adam theta_start_mode=warm theta_lambda=9.519492e-03 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=4.697213e-04 cg_relative_residual=2.813343e-04
# [FinalLinearSolver] Iter 801/1000 iter=800 total_loss=7.457161e-02 policy_objective=-7.743630e-02 beta_objective=1.184561e-01 q_objective=2.243294e-01 policy_grad_norm=5.961621e-01 policy_direction_norm=3.888941e+00 beta_grad_norm=8.473037e-01 beta_direction_norm=6.068305e+00 theta_grad_norm=1.870025e-01 theta_norm=3.600686e+00 theta_mode=reg_adaptive theta_optimizer=adam theta_start_mode=warm theta_lambda=1.214891e-02 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=1.619125e-04 cg_relative_residual=2.715915e-04
# [FinalLinearSolver] Iter 851/1000 iter=850 total_loss=2.068216e-01 policy_objective=-5.850047e-01 beta_objective=3.237890e-01 q_objective=3.870236e-01 policy_grad_norm=8.885011e-01 policy_direction_norm=5.803622e+00 beta_grad_norm=1.377265e+00 beta_direction_norm=6.532824e+00 theta_grad_norm=2.205363e-01 theta_norm=3.960258e+00 theta_mode=reg_adaptive theta_optimizer=adam theta_start_mode=warm theta_lambda=1.377876e-02 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=2.634370e-04 cg_relative_residual=2.964960e-04
# [FinalLinearSolver] Iter 901/1000 iter=900 total_loss=3.078801e-02 policy_objective=-4.343161e-01 beta_objective=2.607040e-02 q_objective=1.525080e-01 policy_grad_norm=1.550482e+00 policy_direction_norm=7.864000e+00 beta_grad_norm=2.176153e+00 beta_direction_norm=1.141468e+01 theta_grad_norm=6.947117e-02 theta_norm=4.837758e+00 theta_mode=reg_adaptive theta_optimizer=adam theta_start_mode=warm theta_lambda=4.208645e-03 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=1.188994e-04 cg_relative_residual=7.668547e-05
# [FinalLinearSolver] Iter 951/1000 iter=950 total_loss=-9.291868e-01 policy_objective=-1.492230e-01 beta_objective=-9.828436e-01 q_objective=-6.873778e-01 policy_grad_norm=1.981874e+00 policy_direction_norm=1.149194e+01 beta_grad_norm=2.520428e+00 beta_direction_norm=1.353003e+01 theta_grad_norm=2.057674e-01 theta_norm=4.281619e+00 theta_mode=reg_adaptive theta_optimizer=adam theta_start_mode=warm theta_lambda=1.838725e-02 theta_lr=1.000000e-02 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=1.414214e+01 effective_D_theta=1.414214e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=10 cg_residual_norm=3.554199e-04 cg_relative_residual=1.793352e-04
#   State 0: pi(a=0|s=0) = 0.23  pi(a=1|s=0) = 0.34  pi(a=2|s=0) = 0.28  pi(a=3|s=0) = 0.15  --> best action: 1
#   State 1: pi(a=0|s=1) = 0.16  pi(a=1|s=1) = 0.23  pi(a=2|s=1) = 0.22  pi(a=3|s=1) = 0.39  --> best action: 3
#   State 2: pi(a=0|s=2) = 0.10  pi(a=1|s=2) = 0.20  pi(a=2|s=2) = 0.21  pi(a=3|s=2) = 0.50  --> best action: 3
#   State 3: pi(a=0|s=3) = 0.18  pi(a=1|s=3) = 0.32  pi(a=2|s=3) = 0.25  pi(a=3|s=3) = 0.26  --> best action: 1
#   State 4: pi(a=0|s=4) = 0.09  pi(a=1|s=4) = 0.16  pi(a=2|s=4) = 0.14  pi(a=3|s=4) = 0.60  --> best action: 3
#   State 5: pi(a=0|s=5) = 0.05  pi(a=1|s=5) = 0.13  pi(a=2|s=5) = 0.13  pi(a=3|s=5) = 0.69  --> best action: 3
#   State 6: pi(a=0|s=6) = 0.12  pi(a=1|s=6) = 0.36  pi(a=2|s=6) = 0.28  pi(a=3|s=6) = 0.24  --> best action: 1
#   State 7: pi(a=0|s=7) = 0.07  pi(a=1|s=7) = 0.21  pi(a=2|s=7) = 0.18  pi(a=3|s=7) = 0.54  --> best action: 3
#   State 8: pi(a=0|s=8) = 0.04  pi(a=1|s=8) = 0.17  pi(a=2|s=8) = 0.17  pi(a=3|s=8) = 0.61  --> best action: 3

# %% [markdown]
# # 5grid

# %%
states = torch.arange(25, dtype=torch.long)
actions = torch.arange(4, dtype=torch.long)

N = len(states)
A = len(actions)
gamma = 0.99
x_0 = 0

dataset_path_5grid = str(DATASETS_DIR / "5grid.csv")

grid_size = 5
goal_grid = 24

wall_states = {6, 7, 12}
terminal_states = {goal_grid}


def state_to_pos(s):
    return divmod(int(s), grid_size)


def pos_to_state(row, col):
    return row * grid_size + col


def move_deterministic(s, a):
    s = int(s)
    a = int(a)

    if s in terminal_states:
        return s

    row, col = state_to_pos(s)

    if a == 0:      # Up
        new_row, new_col = row - 1, col
    elif a == 1:    # Down
        new_row, new_col = row + 1, col
    elif a == 2:    # Left
        new_row, new_col = row, col - 1
    elif a == 3:    # Right
        new_row, new_col = row, col + 1
    else:
        raise ValueError("action must be in {0, 1, 2, 3}")

    if not (0 <= new_row < grid_size and 0 <= new_col < grid_size):
        return s

    sp = pos_to_state(new_row, new_col)

    if sp in wall_states:
        return s

    return sp


def next_state(s, a):
    return move_deterministic(s, a)


def transition_fn(s, a):
    probs = torch.zeros(N, dtype=torch.float64)
    probs[next_state(s, a)] = 1.0
    return probs


def reward_fn(s, a):
    sp = next_state(s, a)

    if sp == goal_grid:
        return 1.0

    return -0.01


mdp = DiscreteMDP(
    states=states,
    actions=actions,
    gamma=gamma,
    x0=x_0,
    reward_fn=reward_fn,
    transition_fn=transition_fn,
    terminal_states=list(terminal_states),
).to(DEVICE)

planner = Planner(mdp)

# %%
def plot_5grid(values=None, policy=None, title="5x5 Grid World"):
    grid_data = np.full((grid_size, grid_size), ".", dtype="<U1")

    for s in wall_states:
        r, c = state_to_pos(s)
        grid_data[r, c] = "#"

    r, c = state_to_pos(x_0)
    grid_data[r, c] = "S"

    r, c = state_to_pos(goal_grid)
    grid_data[r, c] = "G"

    mapping = {".": 0, "#": 1, "S": 2, "G": 3}
    labels = {0: "Empty", 1: "Wall", 2: "Start", 3: "Goal"}
    colors = ["#F5F5F5", "#2C2C2C", "#457B9D", "#2DC653"]

    numeric_grid = np.vectorize(mapping.get)(grid_data)
    cmap = mcolors.ListedColormap(colors)

    fig, ax = plt.subplots(figsize=(7, 7))
    ax.imshow(
        numeric_grid,
        cmap=cmap,
        vmin=0,
        vmax=3,
        interpolation="nearest",
        origin="upper",
    )

    ax.set_xticks(np.arange(-0.5, grid_size, 1), minor=True)
    ax.set_yticks(np.arange(-0.5, grid_size, 1), minor=True)
    ax.grid(which="minor", color="#888888", linewidth=0.8, alpha=0.6)
    ax.tick_params(which="minor", bottom=False, left=False)

    ax.set_xticks(np.arange(grid_size))
    ax.set_yticks(np.arange(grid_size))
    ax.set_xlabel("Column", fontsize=10)
    ax.set_ylabel("Row", fontsize=10)

    if values is not None:
        if hasattr(values, "detach"):
            values = values.detach().cpu().numpy()
        values = np.asarray(values).reshape(-1)

    if policy is not None:
        if hasattr(policy, "detach"):
            policy = policy.detach().cpu().numpy()
        policy = np.asarray(policy)
        best_actions = policy.argmax(axis=1) if policy.ndim == 2 else policy

    arrow_delta = {
        0: (0.0, -0.28),  # Up
        1: (0.0, 0.28),   # Down
        2: (-0.28, 0.0),  # Left
        3: (0.28, 0.0),   # Right
    }

    for s in range(N):
        r, c = state_to_pos(s)

        if s == goal_grid:
            ax.text(c, r, "G", ha="center", va="center", fontsize=14, fontweight="bold", color="white")
        elif s in wall_states:
            ax.text(c, r, "#", ha="center", va="center", fontsize=14, fontweight="bold", color="white")
        elif s == x_0:
            ax.text(c, r, "S", ha="center", va="center", fontsize=14, fontweight="bold", color="white")
        else:
            ax.text(c - 0.38, r - 0.34, str(s), fontsize=8, color="#666666")

        if values is not None and s not in wall_states:
            ax.text(c, r + 0.28, f"{values[s]:.2f}", ha="center", va="center", fontsize=9)

        if policy is not None and s not in terminal_states and s not in wall_states:
            dx, dy = arrow_delta[int(best_actions[s])]
            ax.arrow(
                c,
                r,
                dx,
                dy,
                head_width=0.10,
                head_length=0.10,
                fc="black",
                ec="black",
                linewidth=1.4,
                length_includes_head=True,
                zorder=5,
            )

    patches = [
        mpatches.Patch(color=colors[i], label=f"{symbol}  {labels[i]}")
        for symbol, i in mapping.items()
    ]

    ax.legend(
        handles=patches,
        bbox_to_anchor=(1.02, 1),
        loc="upper left",
        fontsize=9,
        framealpha=0.9,
    )

    ax.set_title(title, fontsize=14, pad=12)
    plt.tight_layout()
    plt.show()


plot_5grid()

# %% [markdown]
# ## Data collection

# %%
# Initialize the clean collector.
# every episode starts from state 0.
collector = DiscreteDataBuffer(
    mdp=mdp,
    reset_probs={"custom": 1.0},
    initial_states=[x_0],              
    restricted_states=wall_states,     
    max_steps=50,
    terminal_states={goal_grid},
    seed=SEED,
)

# Epsilon-greedy around the optimal policy.
# epsilon=0.3 means 70% planner.pi_star, 30% random action.
epsilon_policy = (planner.pi_star, 0.3)

df = collector.collect(
    policies=[epsilon_policy, "random"],
    proportions=[0.9, 0.1],
    n_steps=8000,
    extra_terminal_steps=3,
    episode_based=True,
    save_path=str(dataset_path_5grid),
    verbose=True,
)

df.head()
# Out:
# Collected 8000 transitions over 461 episodes.
# Policy distribution:
# policy_id
# 0    0.746
# 1    0.254
# Name: proportion, dtype: float64
# Reset mode distribution:
# reset_mode
# custom    1.0
# Name: proportion, dtype: float64
# Saved FOGAS dataset to /home/mauro/Desktop/EMAI/Ljubljana/Thesis/Code/data/datasets_clean/generalization/5grid.csv
#    episode  step  state  action  reward  next_state  policy_id reset_mode  \
# 0        0     0      0       1   -0.01           5          0     custom
# 1        0     1      5       1   -0.01          10          0     custom
# 2        0     2     10       3   -0.01          11          0     custom
# 3        0     3     11       1   -0.01          16          0     custom
# 4        0     4     16       1   -0.01          21          0     custom
#
#    restricted_start
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %% [markdown]
# ## Solver

# %%
from rl_methods.fogas_generalization_clean import (
    FinalLinearSolver,
    RBFStateFeatures,
    RBFStateActionFeatures,
    LinearFunction,
    LinearQFunction,
)

# Normalized 2D coordinates for each 5x5 grid state
state_coords = torch.tensor(
    [[r / 4.0, c / 4.0] for r in range(5) for c in range(5)],
    dtype=torch.float64,
)

# Uniform 4x4 RBF center grid over [0, 1] x [0, 1]
center_axis = torch.linspace(0.0, 1.0, 4, dtype=torch.float64)
rbf_centers = torch.tensor(
    [[r, c] for r in center_axis for c in center_axis],
    dtype=torch.float64,
)

state_rbf = RBFStateFeatures(
    n_states=N,
    centers=rbf_centers,
    state_coords=state_coords,
    bandwidth="nearest",
    bandwidth_scale=2.0,
    include_bias=True,
)

u_features = RBFStateActionFeatures(state_rbf, n_actions=A)
q_features = RBFStateActionFeatures(state_rbf, n_actions=A)
policy_features = RBFStateActionFeatures(state_rbf, n_actions=A)

solver_e = FinalLinearSolver(
    n_states=N,
    n_actions=A,
    gamma=gamma,
    x0=x_0,
    csv_path=dataset_path_5grid,
    u_function=LinearFunction(u_features),
    q_function=LinearQFunction(q_features),
    policy_features=policy_features,
    seed=SEED,
    device=DEVICE,

    theta_include_beta_cov=False,

    theta_mode="reg_fixed",
    theta_lambda=3e-6,
    theta_optimizer="adam",
    theta_inner_steps=40,
    theta_lr=1.0,
    theta_start_mode="warm",

    beta_update="fogas_full",
)

solver_e.run(
    alpha=1e-3,
    eta=1e-3,
    rho=0.01,
    policy_optimizer="npg",
    policy_gradient="exact",
    fisher_damping=1e-3,
    cg_iters=50,
    cg_tol=1e-10,
    tqdm_print=False,
    verbose=True,
    log_interval=50,
    T=1000,
    state_weight_update="normal",
)
# Out:
# [FinalLinearSolver] Iter 1/1000 iter=0 total_loss=-3.530914e+00 policy_objective=-3.530914e+00 beta_objective=0.000000e+00 q_objective=-3.372681e+00 policy_grad_norm=5.471434e-16 policy_direction_norm=0.000000e+00 beta_grad_norm=1.123996e+01 beta_direction_norm=3.836123e+03 theta_grad_norm=1.146998e-02 theta_norm=3.247895e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=3.000000e-06 theta_lr=1.000000e+00 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=8.246211e+01 effective_D_theta=8.246211e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=0 cg_residual_norm=5.471434e-16 cg_relative_residual=0.000000e+00
# [FinalLinearSolver] Iter 51/1000 iter=50 total_loss=1.812060e+02 policy_objective=5.984799e+01 beta_objective=1.829851e+02 q_objective=1.826680e+02 policy_grad_norm=1.201701e+02 policy_direction_norm=7.266306e+02 beta_grad_norm=4.318380e+02 beta_direction_norm=1.453261e+04 theta_grad_norm=7.008174e-01 theta_norm=9.812790e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=3.000000e-06 theta_lr=1.000000e+00 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=8.246211e+01 effective_D_theta=8.246211e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=41 cg_residual_norm=5.500103e-11 cg_relative_residual=4.576932e-13
# [FinalLinearSolver] Iter 101/1000 iter=100 total_loss=-3.321870e+02 policy_objective=-9.145554e+01 beta_objective=-3.353787e+02 q_objective=-3.302262e+02 policy_grad_norm=5.097974e+01 policy_direction_norm=1.807184e+03 beta_grad_norm=4.617260e+02 beta_direction_norm=1.933557e+04 theta_grad_norm=1.376646e+00 theta_norm=1.140624e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=3.000000e-06 theta_lr=1.000000e+00 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=8.246211e+01 effective_D_theta=8.246211e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=40 cg_residual_norm=3.245174e-11 cg_relative_residual=6.365616e-13
# [FinalLinearSolver] Iter 151/1000 iter=150 total_loss=5.575543e+02 policy_objective=3.951895e+02 beta_objective=5.489187e+02 q_objective=5.599197e+02 policy_grad_norm=1.614602e+02 policy_direction_norm=2.910583e+03 beta_grad_norm=6.186662e+02 beta_direction_norm=2.963666e+04 theta_grad_norm=2.343054e+00 theta_norm=1.127422e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=3.000000e-06 theta_lr=1.000000e+00 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=8.246211e+01 effective_D_theta=8.246211e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=30 cg_residual_norm=2.396250e-11 cg_relative_residual=1.484112e-13
# [FinalLinearSolver] Iter 201/1000 iter=200 total_loss=-4.451199e+02 policy_objective=-1.423806e+02 beta_objective=-4.374296e+02 q_objective=-4.432496e+02 policy_grad_norm=2.457906e+01 policy_direction_norm=3.206263e+03 beta_grad_norm=4.512745e+02 beta_direction_norm=1.709097e+04 theta_grad_norm=1.834446e+00 theta_norm=1.186522e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=3.000000e-06 theta_lr=1.000000e+00 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=8.246211e+01 effective_D_theta=8.246211e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=25 cg_residual_norm=6.377767e-12 cg_relative_residual=2.594797e-13
# [FinalLinearSolver] Iter 251/1000 iter=250 total_loss=9.657094e+00 policy_objective=3.677295e+02 beta_objective=8.828499e+00 q_objective=1.162595e+01 policy_grad_norm=5.339000e+01 policy_direction_norm=9.290154e+02 beta_grad_norm=3.585962e+02 beta_direction_norm=1.727420e+04 theta_grad_norm=1.143632e+00 theta_norm=1.166077e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=3.000000e-06 theta_lr=1.000000e+00 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=8.246211e+01 effective_D_theta=8.246211e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=23 cg_residual_norm=5.158208e-11 cg_relative_residual=9.661375e-13
# [FinalLinearSolver] Iter 301/1000 iter=300 total_loss=-3.188942e+02 policy_objective=-9.371373e+01 beta_objective=-3.252958e+02 q_objective=-3.154149e+02 policy_grad_norm=3.830690e+02 policy_direction_norm=3.168821e+03 beta_grad_norm=5.422827e+02 beta_direction_norm=3.849478e+04 theta_grad_norm=1.385813e+00 theta_norm=1.510353e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=3.000000e-06 theta_lr=1.000000e+00 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=8.246211e+01 effective_D_theta=8.246211e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=23 cg_residual_norm=1.892057e-11 cg_relative_residual=4.939205e-14
# [FinalLinearSolver] Iter 351/1000 iter=350 total_loss=3.314255e+02 policy_objective=1.898535e+02 beta_objective=3.316921e+02 q_objective=3.350891e+02 policy_grad_norm=2.994646e+01 policy_direction_norm=1.308689e+03 beta_grad_norm=3.136821e+02 beta_direction_norm=1.404697e+04 theta_grad_norm=9.995405e-01 theta_norm=1.538099e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=3.000000e-06 theta_lr=1.000000e+00 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=8.246211e+01 effective_D_theta=8.246211e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=20 cg_residual_norm=8.038742e-11 cg_relative_residual=2.684372e-12
# [FinalLinearSolver] Iter 401/1000 iter=400 total_loss=-4.837981e+02 policy_objective=-1.683855e+02 beta_objective=-4.906550e+02 q_objective=-4.766443e+02 policy_grad_norm=4.566963e+01 policy_direction_norm=3.153441e+03 beta_grad_norm=6.049197e+02 beta_direction_norm=2.790316e+04 theta_grad_norm=1.156111e+00 theta_norm=2.167154e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=3.000000e-06 theta_lr=1.000000e+00 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=8.246211e+01 effective_D_theta=8.246211e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=22 cg_residual_norm=3.276561e-11 cg_relative_residual=7.174486e-13
# [FinalLinearSolver] Iter 451/1000 iter=450 total_loss=-4.773021e+01 policy_objective=2.245367e+02 beta_objective=-4.474331e+01 q_objective=-4.245632e+01 policy_grad_norm=6.225800e+01 policy_direction_norm=5.853298e+02 beta_grad_norm=2.027429e+02 beta_direction_norm=7.263249e+03 theta_grad_norm=2.650337e+00 theta_norm=1.816367e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=3.000000e-06 theta_lr=1.000000e+00 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=8.246211e+01 effective_D_theta=8.246211e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=18 cg_residual_norm=5.017893e-12 cg_relative_residual=8.059837e-14
# [FinalLinearSolver] Iter 501/1000 iter=500 total_loss=-6.438829e+02 policy_objective=-4.757180e+02 beta_objective=-6.465844e+02 q_objective=-6.372815e+02 policy_grad_norm=1.322897e+02 policy_direction_norm=2.865180e+03 beta_grad_norm=6.144093e+02 beta_direction_norm=3.217718e+04 theta_grad_norm=2.081206e+00 theta_norm=2.038766e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=3.000000e-06 theta_lr=1.000000e+00 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=8.246211e+01 effective_D_theta=8.246211e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=19 cg_residual_norm=2.526739e-11 cg_relative_residual=1.910005e-13
# [FinalLinearSolver] Iter 551/1000 iter=550 total_loss=-4.528535e+01 policy_objective=-3.484155e+02 beta_objective=-4.196718e+01 q_objective=-3.965813e+01 policy_grad_norm=1.315225e+01 policy_direction_norm=7.345795e+02 beta_grad_norm=4.364639e+02 beta_direction_norm=1.353523e+04 theta_grad_norm=1.264654e+00 theta_norm=1.886188e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=3.000000e-06 theta_lr=1.000000e+00 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=8.246211e+01 effective_D_theta=8.246211e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=15 cg_residual_norm=5.717552e-11 cg_relative_residual=4.347203e-12
# [FinalLinearSolver] Iter 601/1000 iter=600 total_loss=-6.405247e+02 policy_objective=1.236082e+02 beta_objective=-6.354722e+02 q_objective=-6.346206e+02 policy_grad_norm=5.520974e+01 policy_direction_norm=9.050585e+02 beta_grad_norm=3.837009e+02 beta_direction_norm=1.610855e+04 theta_grad_norm=1.866869e+00 theta_norm=2.038301e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=3.000000e-06 theta_lr=1.000000e+00 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=8.246211e+01 effective_D_theta=8.246211e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=15 cg_residual_norm=2.360535e-12 cg_relative_residual=4.275578e-14
# [FinalLinearSolver] Iter 651/1000 iter=650 total_loss=2.312450e+02 policy_objective=-6.413361e+02 beta_objective=2.249131e+02 q_objective=2.411839e+02 policy_grad_norm=2.924842e+01 policy_direction_norm=9.803400e+02 beta_grad_norm=1.749975e+02 beta_direction_norm=1.862683e+04 theta_grad_norm=3.147865e+00 theta_norm=2.608749e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=3.000000e-06 theta_lr=1.000000e+00 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=8.246211e+01 effective_D_theta=8.246211e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=15 cg_residual_norm=3.447068e-12 cg_relative_residual=1.178549e-13
# [FinalLinearSolver] Iter 701/1000 iter=700 total_loss=1.071971e+03 policy_objective=2.337383e+02 beta_objective=1.068002e+03 q_objective=1.080627e+03 policy_grad_norm=8.737536e+01 policy_direction_norm=3.010619e+03 beta_grad_norm=7.901692e+02 beta_direction_norm=2.858151e+04 theta_grad_norm=3.669397e+00 theta_norm=2.350292e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=3.000000e-06 theta_lr=1.000000e+00 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=8.246211e+01 effective_D_theta=8.246211e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=15 cg_residual_norm=3.266301e-12 cg_relative_residual=3.738240e-14
# [FinalLinearSolver] Iter 751/1000 iter=750 total_loss=1.562757e+03 policy_objective=3.454709e+02 beta_objective=1.562577e+03 q_objective=1.573589e+03 policy_grad_norm=2.527788e+00 policy_direction_norm=1.615488e+02 beta_grad_norm=6.796411e+02 beta_direction_norm=1.759020e+04 theta_grad_norm=1.208394e+01 theta_norm=2.516006e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=3.000000e-06 theta_lr=1.000000e+00 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=8.246211e+01 effective_D_theta=8.246211e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=7 cg_residual_norm=8.590338e-11 cg_relative_residual=3.398362e-11
# [FinalLinearSolver] Iter 801/1000 iter=800 total_loss=-4.653551e+03 policy_objective=-1.086113e+03 beta_objective=-4.665093e+03 q_objective=-4.637620e+03 policy_grad_norm=3.695163e+01 policy_direction_norm=8.006410e+02 beta_grad_norm=2.049348e+03 beta_direction_norm=1.098129e+05 theta_grad_norm=4.029772e+00 theta_norm=3.128588e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=3.000000e-06 theta_lr=1.000000e+00 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=8.246211e+01 effective_D_theta=8.246211e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=6 cg_residual_norm=5.170196e-13 cg_relative_residual=1.399180e-14
# [FinalLinearSolver] Iter 851/1000 iter=850 total_loss=2.528569e+03 policy_objective=1.693149e+03 beta_objective=2.532180e+03 q_objective=2.544259e+03 policy_grad_norm=5.337854e+01 policy_direction_norm=2.799155e+03 beta_grad_norm=7.788066e+02 beta_direction_norm=3.674708e+04 theta_grad_norm=4.294494e+00 theta_norm=3.082568e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=3.000000e-06 theta_lr=1.000000e+00 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=8.246211e+01 effective_D_theta=8.246211e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=6 cg_residual_norm=1.315867e-12 cg_relative_residual=2.465162e-14
# [FinalLinearSolver] Iter 901/1000 iter=900 total_loss=-1.098443e+02 policy_objective=3.048137e+02 beta_objective=-1.074440e+02 q_objective=-9.489292e+01 policy_grad_norm=1.336348e-01 policy_direction_norm=1.282572e+02 beta_grad_norm=9.471665e+02 beta_direction_norm=6.886942e+04 theta_grad_norm=2.193807e+00 theta_norm=3.162707e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=3.000000e-06 theta_lr=1.000000e+00 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=8.246211e+01 effective_D_theta=8.246211e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=4 cg_residual_norm=2.861853e-12 cg_relative_residual=2.141548e-11
# [FinalLinearSolver] Iter 951/1000 iter=950 total_loss=-2.203837e+03 policy_objective=-2.238011e+02 beta_objective=-2.206653e+03 q_objective=-2.187090e+03 policy_grad_norm=2.455485e+00 policy_direction_norm=3.820486e+01 beta_grad_norm=7.636658e+02 beta_direction_norm=5.810956e+03 theta_grad_norm=4.087878e+00 theta_norm=3.416407e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=3.000000e-06 theta_lr=1.000000e+00 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=8.246211e+01 effective_D_theta=8.246211e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=6 cg_residual_norm=9.284265e-13 cg_relative_residual=3.781031e-13
# tensor([[5.7451e-33, 1.0000e+00, 1.7648e-27, 6.0742e-27],
#         [2.8658e-41, 1.0000e+00, 1.2383e-34, 2.6174e-35],
#         [7.4016e-44, 1.0000e+00, 2.8553e-37, 4.2370e-37],
#         [7.6394e-40, 1.0000e+00, 1.6795e-34, 1.6531e-31],
#         [1.4394e-30, 1.0000e+00, 2.9908e-27, 1.4486e-20],
#         [3.6526e-32, 1.0000e+00, 5.9082e-27, 7.6791e-25],
#         [4.0267e-40, 1.0000e+00, 6.0905e-34, 1.5327e-32],
#         [2.4424e-42, 1.0000e+00, 2.0116e-36, 1.1417e-33],
#         [4.9822e-38, 1.0000e+00, 1.5013e-33, 1.3595e-27],
#         [1.2056e-28, 1.0000e+00, 2.7379e-26, 1.5428e-16],
#         [4.6817e-25, 1.0000e+00, 2.4057e-21, 3.9863e-17],
#         [2.1526e-31, 1.0000e+00, 4.5111e-27, 8.7102e-23],
#         [1.0137e-32, 1.0000e+00, 6.5716e-29, 1.1950e-22],
#         [1.5962e-28, 1.0000e+00, 3.2898e-26, 1.7740e-16],
#         [3.1169e-20, 1.0000e+00, 6.8850e-20, 1.5346e-06],
#         [5.2470e-14, 1.0000e+00, 1.6448e-12, 1.7850e-06],
#         [5.7610e-18, 1.0000e+00, 2.7638e-16, 2.2895e-09],
#         [3.7370e-18, 1.0000e+00, 3.5098e-17, 1.0039e-07],
#         [1.8843e-14, 9.2456e-01, 6.8600e-15, 7.5440e-02],
#         [5.7582e-15, 1.2015e-07, 5.0255e-17, 1.0000e+00],
#         [4.1205e-07, 2.7346e-05, 7.6523e-08, 9.9997e-01],
#         [2.0877e-08, 5.5472e-05, 2.6300e-09, 9.9994e-01],
#         [1.9075e-10, 7.7953e-08, 3.8648e-12, 1.0000e+00],
#         [1.0503e-12, 3.7810e-13, 1.3356e-15, 1.0000e+00],
#         [2.5840e-14, 5.4920e-19, 2.1567e-18, 1.0000e+00]])

# %%
mdp.print_policy(solver_e.pi)

evaluator = FOGASEvaluator(
    solver=solver_e,
    mdp=mdp,
    planner=planner,
)

solver_stats = evaluator.average_return_stats(
    policy_mode="solver",
    num_trajectories=100,
    max_steps=20,
    seed=SEED,
    terminal_states=terminal_states,
    compare_with_optimal=True,
)

greedy_stats = evaluator.average_return_stats(
    policy_mode="greedy",
    num_trajectories=100,
    max_steps=20,
    seed=SEED,
    terminal_states=terminal_states,
    compare_with_optimal=True,
)

print(f"Solver avg reward:  {solver_stats['policy']:.4f} +- {solver_stats['policy_std']:.4f}")
print(f"Greedy avg reward:  {greedy_stats['policy']:.4f} +- {greedy_stats['policy_std']:.4f}")
print(f"Optimal avg reward: {solver_stats['optimal']:.4f} +- {solver_stats['optimal_std']:.4f}")
# Out:
#   State 0: pi(a=0|s=0) = 0.00  pi(a=1|s=0) = 1.00  pi(a=2|s=0) = 0.00  pi(a=3|s=0) = 0.00  --> best action: 1
#   State 1: pi(a=0|s=1) = 0.00  pi(a=1|s=1) = 1.00  pi(a=2|s=1) = 0.00  pi(a=3|s=1) = 0.00  --> best action: 1
#   State 2: pi(a=0|s=2) = 0.00  pi(a=1|s=2) = 1.00  pi(a=2|s=2) = 0.00  pi(a=3|s=2) = 0.00  --> best action: 1
#   State 3: pi(a=0|s=3) = 0.00  pi(a=1|s=3) = 1.00  pi(a=2|s=3) = 0.00  pi(a=3|s=3) = 0.00  --> best action: 1
#   State 4: pi(a=0|s=4) = 0.00  pi(a=1|s=4) = 1.00  pi(a=2|s=4) = 0.00  pi(a=3|s=4) = 0.00  --> best action: 1
#   State 5: pi(a=0|s=5) = 0.00  pi(a=1|s=5) = 1.00  pi(a=2|s=5) = 0.00  pi(a=3|s=5) = 0.00  --> best action: 1
#   State 6: pi(a=0|s=6) = 0.00  pi(a=1|s=6) = 1.00  pi(a=2|s=6) = 0.00  pi(a=3|s=6) = 0.00  --> best action: 1
#   State 7: pi(a=0|s=7) = 0.00  pi(a=1|s=7) = 1.00  pi(a=2|s=7) = 0.00  pi(a=3|s=7) = 0.00  --> best action: 1
#   State 8: pi(a=0|s=8) = 0.00  pi(a=1|s=8) = 1.00  pi(a=2|s=8) = 0.00  pi(a=3|s=8) = 0.00  --> best action: 1
#   State 9: pi(a=0|s=9) = 0.00  pi(a=1|s=9) = 1.00  pi(a=2|s=9) = 0.00  pi(a=3|s=9) = 0.00  --> best action: 1
#   State 10: pi(a=0|s=10) = 0.00  pi(a=1|s=10) = 1.00  pi(a=2|s=10) = 0.00  pi(a=3|s=10) = 0.00  --> best action: 1
#   State 11: pi(a=0|s=11) = 0.00  pi(a=1|s=11) = 1.00  pi(a=2|s=11) = 0.00  pi(a=3|s=11) = 0.00  --> best action: 1
#   State 12: pi(a=0|s=12) = 0.00  pi(a=1|s=12) = 1.00  pi(a=2|s=12) = 0.00  pi(a=3|s=12) = 0.00  --> best action: 1
#   State 13: pi(a=0|s=13) = 0.00  pi(a=1|s=13) = 1.00  pi(a=2|s=13) = 0.00  pi(a=3|s=13) = 0.00  --> best action: 1
#   State 14: pi(a=0|s=14) = 0.00  pi(a=1|s=14) = 1.00  pi(a=2|s=14) = 0.00  pi(a=3|s=14) = 0.00  --> best action: 1
#   State 15: pi(a=0|s=15) = 0.00  pi(a=1|s=15) = 1.00  pi(a=2|s=15) = 0.00  pi(a=3|s=15) = 0.00  --> best action: 1
#   State 16: pi(a=0|s=16) = 0.00  pi(a=1|s=16) = 1.00  pi(a=2|s=16) = 0.00  pi(a=3|s=16) = 0.00  --> best action: 1
#   State 17: pi(a=0|s=17) = 0.00  pi(a=1|s=17) = 1.00  pi(a=2|s=17) = 0.00  pi(a=3|s=17) = 0.00  --> best action: 1
#   State 18: pi(a=0|s=18) = 0.00  pi(a=1|s=18) = 0.92  pi(a=2|s=18) = 0.00  pi(a=3|s=18) = 0.08  --> best action: 1
#   State 19: pi(a=0|s=19) = 0.00  pi(a=1|s=19) = 0.00  pi(a=2|s=19) = 0.00  pi(a=3|s=19) = 1.00  --> best action: 3
#   State 20: pi(a=0|s=20) = 0.00  pi(a=1|s=20) = 0.00  pi(a=2|s=20) = 0.00  pi(a=3|s=20) = 1.00  --> best action: 3
#   State 21: pi(a=0|s=21) = 0.00  pi(a=1|s=21) = 0.00  pi(a=2|s=21) = 0.00  pi(a=3|s=21) = 1.00  --> best action: 3
#   State 22: pi(a=0|s=22) = 0.00  pi(a=1|s=22) = 0.00  pi(a=2|s=22) = 0.00  pi(a=3|s=22) = 1.00  --> best action: 3
#   State 23: pi(a=0|s=23) = 0.00  pi(a=1|s=23) = 0.00  pi(a=2|s=23) = 0.00  pi(a=3|s=23) = 1.00  --> best action: 3
#   State 24: pi(a=0|s=24) = 0.00  pi(a=1|s=24) = 0.00  pi(a=2|s=24) = 0.00  pi(a=3|s=24) = 1.00  --> best action: 3
#
# Solver avg reward:  0.8641 +- 0.0000
# Greedy avg reward:  0.8641 +- 0.0000
# Optimal avg reward: 0.8641 +- 0.0000

# %% [markdown]
# # 5 stochastic grid

# %%
states = torch.arange(25, dtype=torch.long)
actions = torch.arange(4, dtype=torch.long)

N = len(states)
A = len(actions)
gamma = 0.9
x_0 = 0

dataset_path_5grid_stoch = str(DATASETS_DIR / "5grid_stochastic.csv")

grid_size = 5
goal_grid = 24
pit_grid = 18

wall_states = {6, 7, 12}
terminal_states = {goal_grid, pit_grid}


def state_to_pos(s):
    return divmod(int(s), grid_size)


def pos_to_state(row, col):
    return row * grid_size + col


def move_deterministic(s, a):
    s = int(s)
    a = int(a)

    if s in terminal_states:
        return s

    row, col = state_to_pos(s)

    if a == 0:      # Up
        new_row, new_col = row - 1, col
    elif a == 1:    # Down
        new_row, new_col = row + 1, col
    elif a == 2:    # Left
        new_row, new_col = row, col - 1
    elif a == 3:    # Right
        new_row, new_col = row, col + 1
    else:
        raise ValueError("action must be in {0, 1, 2, 3}")

    if not (0 <= new_row < grid_size and 0 <= new_col < grid_size):
        return s

    sp = pos_to_state(new_row, new_col)

    if sp in wall_states:
        return s

    return sp


def transition_probs(s, a, intended_prob=0.8):
    """
    Stochastic transition:
    intended_prob goes to the requested action.
    The remaining probability is uniform over all actions.
    
    With intended_prob=0.8 and A=4:
      intended action: 0.8 + 0.2 / 4 = 0.85
      other actions:   0.2 / 4 = 0.05 each
    """
    s = int(s)
    a = int(a)

    probs_by_state = {}

    for candidate_a in range(A):
        prob = (1.0 - intended_prob) / A
        if candidate_a == a:
            prob += intended_prob

        sp = move_deterministic(s, candidate_a)
        probs_by_state[sp] = probs_by_state.get(sp, 0.0) + prob

    return probs_by_state


def transition_fn(s, a):
    probs = torch.zeros(N, dtype=torch.float64)

    for sp, prob in transition_probs(s, a).items():
        probs[sp] = prob

    return probs


def next_state(s, a):
    """
    Sample one next state from the stochastic transition.
    Useful for manual rollouts, not used by DiscreteMDP planning.
    """
    probs = transition_fn(s, a)
    return int(torch.multinomial(probs.float(), num_samples=1).item())


def reward_from_next_state(sp):
    sp = int(sp)

    if sp == goal_grid:
        return 1.0

    if sp == pit_grid:
        return -1.0

    return -0.1


def reward_fn(s, a):
    """
    Expected one-step reward under P(. | s, a).
    """
    return sum(
        prob * reward_from_next_state(sp)
        for sp, prob in transition_probs(s, a).items()
    )


mdp = DiscreteMDP(
    states=states,
    actions=actions,
    gamma=gamma,
    x0=x_0,
    reward_fn=reward_fn,
    transition_fn=transition_fn,
    terminal_states=list(terminal_states),
).to(DEVICE)

planner = Planner(mdp)

# %%
def plot_5grid(values=None, policy=None, title="5x5 Grid World"):
    grid_data = np.full((grid_size, grid_size), ".", dtype="<U1")

    for s in wall_states:
        r, c = state_to_pos(s)
        grid_data[r, c] = "#"

    r, c = state_to_pos(pit_grid)
    grid_data[r, c] = "P"

    r, c = state_to_pos(x_0)
    grid_data[r, c] = "S"

    r, c = state_to_pos(goal_grid)
    grid_data[r, c] = "G"

    mapping = {".": 0, "#": 1, "S": 2, "G": 3, "P": 4}
    labels = {0: "Empty", 1: "Wall", 2: "Start", 3: "Goal", 4: "Pit"}
    colors = ["#F5F5F5", "#2C2C2C", "#457B9D", "#2DC653", "#E63946"]

    numeric_grid = np.vectorize(mapping.get)(grid_data)
    cmap = mcolors.ListedColormap(colors)

    fig, ax = plt.subplots(figsize=(7, 7))
    ax.imshow(
        numeric_grid,
        cmap=cmap,
        vmin=0,
        vmax=4,
        interpolation="nearest",
        origin="upper",
    )

    ax.set_xticks(np.arange(-0.5, grid_size, 1), minor=True)
    ax.set_yticks(np.arange(-0.5, grid_size, 1), minor=True)
    ax.grid(which="minor", color="#888888", linewidth=0.8, alpha=0.6)
    ax.tick_params(which="minor", bottom=False, left=False)

    ax.set_xticks(np.arange(grid_size))
    ax.set_yticks(np.arange(grid_size))
    ax.set_xlabel("Column", fontsize=10)
    ax.set_ylabel("Row", fontsize=10)

    if values is not None:
        if hasattr(values, "detach"):
            values = values.detach().cpu().numpy()
        values = np.asarray(values).reshape(-1)

    if policy is not None:
        if hasattr(policy, "detach"):
            policy = policy.detach().cpu().numpy()
        policy = np.asarray(policy)
        best_actions = policy.argmax(axis=1) if policy.ndim == 2 else policy

    arrow_delta = {
        0: (0.0, -0.28),  # Up
        1: (0.0, 0.28),   # Down
        2: (-0.28, 0.0),  # Left
        3: (0.28, 0.0),   # Right
    }

    for s in range(N):
        r, c = state_to_pos(s)

        if s == goal_grid:
            ax.text(c, r, "G", ha="center", va="center", fontsize=14, fontweight="bold", color="white")
        elif s == pit_grid:
            ax.text(c, r, "P", ha="center", va="center", fontsize=14, fontweight="bold", color="white")
        elif s in wall_states:
            ax.text(c, r, "#", ha="center", va="center", fontsize=14, fontweight="bold", color="white")
        elif s == x_0:
            ax.text(c, r, "S", ha="center", va="center", fontsize=14, fontweight="bold", color="white")
        else:
            ax.text(c - 0.38, r - 0.34, str(s), fontsize=8, color="#666666")

        if values is not None and s not in wall_states:
            ax.text(c, r + 0.28, f"{values[s]:.2f}", ha="center", va="center", fontsize=9)

        if policy is not None and s not in terminal_states and s not in wall_states:
            dx, dy = arrow_delta[int(best_actions[s])]
            ax.arrow(
                c,
                r,
                dx,
                dy,
                head_width=0.10,
                head_length=0.10,
                fc="black",
                ec="black",
                linewidth=1.4,
                length_includes_head=True,
                zorder=5,
            )

    patches = [
        mpatches.Patch(color=colors[i], label=f"{symbol}  {labels[i]}")
        for symbol, i in mapping.items()
    ]

    ax.legend(
        handles=patches,
        bbox_to_anchor=(1.02, 1),
        loc="upper left",
        fontsize=9,
        framealpha=0.9,
    )

    ax.set_title(title, fontsize=14, pad=12)
    plt.tight_layout()
    plt.show()


plot_5grid()

# %% [markdown]
# ## Data

# %%
# Initialize the clean collector.
# every episode starts from state 0.
collector = DiscreteDataBuffer(
    mdp=mdp,
    reset_probs={"occupancy": 1.0},
    occupancy=planner.mu_star,          # shape N*A is accepted
    restricted_states=wall_states,
    max_steps=50,
    terminal_states={goal_grid},
    seed=SEED,
)

# Epsilon-greedy around the optimal policy.
# epsilon=0.3 means 70% planner.pi_star, 30% random action.
epsilon_policy = (planner.pi_star, 0.3)

df = collector.collect(
    policies=[epsilon_policy, "random"],
    proportions=[0.7, 0.3],
    n_steps=8000,
    extra_terminal_steps=3,
    episode_based=True,
    save_path=str(dataset_path_5grid_stoch),
    verbose=True,
)

df.head()
# Out:
# Collected 8000 transitions over 460 episodes.
# Policy distribution:
# policy_id
# 0    0.40425
# 1    0.59575
# Name: proportion, dtype: float64
# Reset mode distribution:
# reset_mode
# occupancy    1.0
# Name: proportion, dtype: float64
# Saved FOGAS dataset to /home/mauro/Desktop/EMAI/Ljubljana/Thesis/Code/data/datasets_clean/generalization/5grid_stochastic.csv
#    episode  step  state  action  reward  next_state  policy_id reset_mode  \
# 0        0     0     15       0   -0.01          10          1  occupancy
# 1        0     1     10       2   -0.01          10          1  occupancy
# 2        0     2     10       2   -0.01          10          1  occupancy
# 3        0     3     10       3   -0.01          11          1  occupancy
# 4        0     4     11       3   -0.01          11          1  occupancy
#
#    restricted_start
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %% [markdown]
# ## Solver

# %%
state_rbf = RBFStateFeatures(
    n_states=N,
    centers=rbf_centers,
    state_coords=state_coords,
    bandwidth="nearest",
    bandwidth_scale=2.0,
    include_bias=True,
)

u_features = RBFStateActionFeatures(state_rbf, n_actions=A)
q_features = RBFStateActionFeatures(state_rbf, n_actions=A)
policy_features = RBFStateActionFeatures(state_rbf, n_actions=A)

solver_e = FinalLinearSolver(
    n_states=N,
    n_actions=A,
    gamma=gamma,
    x0=x_0,
    csv_path=dataset_path_5grid_stoch,  # important
    u_function=LinearFunction(u_features),
    q_function=LinearQFunction(q_features),
    policy_features=policy_features,
    seed=SEED,
    device=DEVICE,

    theta_include_beta_cov=False,

    theta_mode="reg_fixed",
    theta_lambda=1e-4,
    theta_optimizer="adam",
    theta_inner_steps=40,
    theta_lr=0.3,
    theta_start_mode="warm",

    beta_update="fogas_full",
)

solver_e.run(
    alpha=3e-3,
    eta=3e-4,
    rho=0.1,
    policy_optimizer="npg",
    policy_gradient="exact",
    fisher_damping=1e-3,
    cg_iters=50,
    cg_tol=1e-10,
    tqdm_print=False,
    verbose=True,
    log_interval=50,
    T=4000,
    state_weight_update="normal",
)

mdp.print_policy(solver_e.pi)
# Out:
# [FinalLinearSolver] Iter 1/4000 iter=0 total_loss=-1.059281e+01 policy_objective=-1.059281e+01 beta_objective=0.000000e+00 q_objective=-1.011811e+01 policy_grad_norm=0.000000e+00 policy_direction_norm=0.000000e+00 beta_grad_norm=1.728912e+01 beta_direction_norm=8.631003e+02 theta_grad_norm=1.146998e-01 theta_norm=9.743784e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=0 cg_residual_norm=0.000000e+00 cg_relative_residual=0.000000e+00
# [FinalLinearSolver] Iter 51/4000 iter=50 total_loss=-2.790530e+01 policy_objective=-1.991314e+02 beta_objective=1.304426e+01 q_objective=-1.663978e+01 policy_grad_norm=1.344771e+02 policy_direction_norm=4.659977e+02 beta_grad_norm=2.121190e+02 beta_direction_norm=2.461938e+03 theta_grad_norm=4.067225e-01 theta_norm=4.745419e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=40 cg_residual_norm=1.084266e-11 cg_relative_residual=8.062831e-14
# [FinalLinearSolver] Iter 101/4000 iter=100 total_loss=-1.253325e+01 policy_objective=1.319070e+02 beta_objective=-3.007584e+01 q_objective=-2.610141e+00 policy_grad_norm=3.910006e+01 policy_direction_norm=4.955322e+02 beta_grad_norm=1.892161e+02 beta_direction_norm=4.318981e+03 theta_grad_norm=2.218809e-01 theta_norm=4.441477e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=37 cg_residual_norm=7.206924e-12 cg_relative_residual=1.843200e-13
# [FinalLinearSolver] Iter 151/4000 iter=150 total_loss=-2.084954e+01 policy_objective=-2.620707e+02 beta_objective=1.203653e+01 q_objective=-1.526183e+01 policy_grad_norm=6.461510e+01 policy_direction_norm=2.081106e+02 beta_grad_norm=1.449072e+02 beta_direction_norm=2.844715e+03 theta_grad_norm=2.092578e-01 theta_norm=3.330727e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=37 cg_residual_norm=4.006821e-11 cg_relative_residual=6.201061e-13
# [FinalLinearSolver] Iter 201/4000 iter=200 total_loss=-1.964702e+01 policy_objective=3.088649e+01 beta_objective=-2.594972e+01 q_objective=-1.699496e+01 policy_grad_norm=2.776314e+01 policy_direction_norm=1.205666e+02 beta_grad_norm=6.533981e+01 beta_direction_norm=1.465440e+03 theta_grad_norm=6.988960e-01 theta_norm=2.291673e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=37 cg_residual_norm=3.050129e-11 cg_relative_residual=1.098626e-12
# [FinalLinearSolver] Iter 251/4000 iter=250 total_loss=-2.125190e+01 policy_objective=-8.399211e+01 beta_objective=1.958231e+00 q_objective=-1.793104e+01 policy_grad_norm=8.098146e+01 policy_direction_norm=3.445461e+02 beta_grad_norm=1.433667e+02 beta_direction_norm=3.634604e+03 theta_grad_norm=1.108407e-01 theta_norm=2.577154e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=41 cg_residual_norm=6.323462e-12 cg_relative_residual=7.808531e-14
# [FinalLinearSolver] Iter 301/4000 iter=300 total_loss=-6.813445e+00 policy_objective=-1.243162e+02 beta_objective=1.702669e+01 q_objective=-2.213214e+00 policy_grad_norm=1.625399e+01 policy_direction_norm=7.623163e+01 beta_grad_norm=4.098674e+01 beta_direction_norm=1.207200e+03 theta_grad_norm=4.571318e-02 theta_norm=3.032448e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=36 cg_residual_norm=9.907050e-12 cg_relative_residual=6.095151e-13
# [FinalLinearSolver] Iter 351/4000 iter=350 total_loss=-3.496333e+01 policy_objective=2.693186e+01 beta_objective=-3.485732e+01 q_objective=-3.142789e+01 policy_grad_norm=6.831988e+01 policy_direction_norm=2.908079e+02 beta_grad_norm=1.750133e+02 beta_direction_norm=3.337358e+03 theta_grad_norm=5.780781e-01 theta_norm=2.657125e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=37 cg_residual_norm=1.767441e-11 cg_relative_residual=2.587008e-13
# [FinalLinearSolver] Iter 401/4000 iter=400 total_loss=-1.873433e+01 policy_objective=-1.197258e+02 beta_objective=2.446259e+01 q_objective=-1.361314e+01 policy_grad_norm=6.147357e+01 policy_direction_norm=4.822309e+02 beta_grad_norm=2.879967e+02 beta_direction_norm=7.560390e+03 theta_grad_norm=6.241684e-02 theta_norm=3.203035e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=37 cg_residual_norm=3.419463e-12 cg_relative_residual=5.562493e-14
# [FinalLinearSolver] Iter 451/4000 iter=450 total_loss=-8.693835e+00 policy_objective=-1.856541e+02 beta_objective=4.269448e+01 q_objective=-3.672180e+00 policy_grad_norm=1.043743e+02 policy_direction_norm=6.456354e+02 beta_grad_norm=2.917447e+02 beta_direction_norm=7.819698e+03 theta_grad_norm=4.761810e-02 theta_norm=3.176331e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=37 cg_residual_norm=1.222919e-11 cg_relative_residual=1.171667e-13
# [FinalLinearSolver] Iter 501/4000 iter=500 total_loss=-1.464737e+01 policy_objective=-3.064411e+01 beta_objective=-3.730014e+00 q_objective=-1.087082e+01 policy_grad_norm=6.031818e+01 policy_direction_norm=1.551412e+02 beta_grad_norm=1.674950e+02 beta_direction_norm=3.346325e+03 theta_grad_norm=1.597565e-01 theta_norm=2.751492e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=31 cg_residual_norm=3.755885e-11 cg_relative_residual=6.226788e-13
# [FinalLinearSolver] Iter 551/4000 iter=550 total_loss=-8.422626e+00 policy_objective=-8.197892e+01 beta_objective=6.126748e+00 q_objective=-5.713689e+00 policy_grad_norm=2.932663e+01 policy_direction_norm=1.186914e+02 beta_grad_norm=5.658660e+01 beta_direction_norm=2.029694e+03 theta_grad_norm=1.012020e-01 theta_norm=2.326971e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=35 cg_residual_norm=4.461125e-11 cg_relative_residual=1.521186e-12
# [FinalLinearSolver] Iter 601/4000 iter=600 total_loss=-6.055584e+00 policy_objective=-3.076347e+01 beta_objective=-6.357020e+00 q_objective=-3.189078e+00 policy_grad_norm=2.022501e+01 policy_direction_norm=6.196835e+01 beta_grad_norm=6.576968e+01 beta_direction_norm=1.973869e+03 theta_grad_norm=2.344293e-01 theta_norm=2.405880e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=33 cg_residual_norm=6.559121e-11 cg_relative_residual=3.243074e-12
# [FinalLinearSolver] Iter 651/4000 iter=650 total_loss=-1.365954e+01 policy_objective=-1.219081e+02 beta_objective=5.310514e+00 q_objective=-1.123076e+01 policy_grad_norm=2.959117e+01 policy_direction_norm=1.880805e+02 beta_grad_norm=1.662188e+02 beta_direction_norm=2.411240e+03 theta_grad_norm=8.253543e-02 theta_norm=2.217815e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=33 cg_residual_norm=5.627484e-11 cg_relative_residual=1.901744e-12
# [FinalLinearSolver] Iter 701/4000 iter=700 total_loss=-1.811201e+01 policy_objective=-6.272649e+01 beta_objective=1.841109e-01 q_objective=-1.591617e+01 policy_grad_norm=6.785000e+01 policy_direction_norm=2.407683e+02 beta_grad_norm=1.950563e+02 beta_direction_norm=6.058363e+03 theta_grad_norm=1.412516e-01 theta_norm=2.117273e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=36 cg_residual_norm=2.299640e-12 cg_relative_residual=3.389300e-14
# [FinalLinearSolver] Iter 751/4000 iter=750 total_loss=-1.632761e+00 policy_objective=-9.485439e+01 beta_objective=8.904725e+00 q_objective=5.245518e-01 policy_grad_norm=1.579035e+01 policy_direction_norm=6.542092e+01 beta_grad_norm=4.973015e+01 beta_direction_norm=9.615493e+02 theta_grad_norm=6.425468e-02 theta_norm=2.106685e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=33 cg_residual_norm=6.601288e-11 cg_relative_residual=4.180585e-12
# [FinalLinearSolver] Iter 801/4000 iter=800 total_loss=6.298077e+00 policy_objective=5.922879e+01 beta_objective=1.369262e+00 q_objective=7.818471e+00 policy_grad_norm=1.970736e+01 policy_direction_norm=1.006006e+02 beta_grad_norm=1.012212e+02 beta_direction_norm=2.438861e+03 theta_grad_norm=1.544556e-01 theta_norm=1.776215e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=35 cg_residual_norm=5.505473e-13 cg_relative_residual=2.793613e-14
# [FinalLinearSolver] Iter 851/4000 iter=850 total_loss=-2.159700e+00 policy_objective=-8.584989e+01 beta_objective=8.469058e+00 q_objective=-7.117402e-01 policy_grad_norm=6.328366e+00 policy_direction_norm=4.249164e+01 beta_grad_norm=2.959339e+01 beta_direction_norm=7.322979e+02 theta_grad_norm=5.985845e-02 theta_norm=1.733807e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=34 cg_residual_norm=2.054776e-11 cg_relative_residual=3.246931e-12
# [FinalLinearSolver] Iter 901/4000 iter=900 total_loss=-3.651905e+00 policy_objective=1.550919e+01 beta_objective=-2.556029e-01 q_objective=-2.287174e+00 policy_grad_norm=3.981327e+01 policy_direction_norm=1.156995e+02 beta_grad_norm=9.726897e+01 beta_direction_norm=2.441912e+03 theta_grad_norm=4.585597e-02 theta_norm=1.690365e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=35 cg_residual_norm=1.248037e-11 cg_relative_residual=3.134726e-13
# [FinalLinearSolver] Iter 951/4000 iter=950 total_loss=-1.104176e+01 policy_objective=-1.642190e+02 beta_objective=1.388849e+01 q_objective=-9.629782e+00 policy_grad_norm=2.794449e+01 policy_direction_norm=1.295366e+02 beta_grad_norm=1.143380e+02 beta_direction_norm=2.809204e+03 theta_grad_norm=1.401349e-01 theta_norm=1.720952e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=36 cg_residual_norm=2.488090e-12 cg_relative_residual=8.903688e-14
# [FinalLinearSolver] Iter 1001/4000 iter=1000 total_loss=-3.078266e+00 policy_objective=-5.620542e+01 beta_objective=4.010521e+00 q_objective=-1.986230e+00 policy_grad_norm=1.147766e+01 policy_direction_norm=7.068006e+01 beta_grad_norm=4.374534e+01 beta_direction_norm=9.495924e+02 theta_grad_norm=8.249650e-02 theta_norm=1.530046e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=34 cg_residual_norm=1.505047e-12 cg_relative_residual=1.311284e-13
# [FinalLinearSolver] Iter 1051/4000 iter=1050 total_loss=1.238047e-02 policy_objective=-1.634015e+01 beta_objective=3.699122e+00 q_objective=5.909633e-01 policy_grad_norm=5.821852e+00 policy_direction_norm=3.039786e+01 beta_grad_norm=2.047856e+01 beta_direction_norm=5.467802e+02 theta_grad_norm=9.275808e-02 theta_norm=1.152593e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=34 cg_residual_norm=3.200806e-12 cg_relative_residual=5.497917e-13
# [FinalLinearSolver] Iter 1101/4000 iter=1100 total_loss=-5.487160e-01 policy_objective=-5.144409e+01 beta_objective=1.190744e+01 q_objective=5.766984e-01 policy_grad_norm=2.608618e+01 policy_direction_norm=1.373165e+02 beta_grad_norm=1.006310e+02 beta_direction_norm=1.765970e+03 theta_grad_norm=4.571566e-02 theta_norm=1.558130e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=34 cg_residual_norm=2.967974e-11 cg_relative_residual=1.137757e-12
# [FinalLinearSolver] Iter 1151/4000 iter=1150 total_loss=-6.760808e+01 policy_objective=-6.699346e+00 beta_objective=-9.288247e+01 q_objective=-6.496160e+01 policy_grad_norm=8.377718e+01 policy_direction_norm=4.657881e+02 beta_grad_norm=3.110038e+02 beta_direction_norm=1.429211e+04 theta_grad_norm=3.406111e-01 theta_norm=2.337331e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=34 cg_residual_norm=9.211861e-11 cg_relative_residual=1.099567e-12
# [FinalLinearSolver] Iter 1201/4000 iter=1200 total_loss=-2.660209e+01 policy_objective=-3.323357e+01 beta_objective=-3.797692e+01 q_objective=-2.366013e+01 policy_grad_norm=6.170237e+01 policy_direction_norm=3.873492e+02 beta_grad_norm=2.657735e+02 beta_direction_norm=1.201481e+04 theta_grad_norm=1.371919e-01 theta_norm=2.459501e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=34 cg_residual_norm=4.103321e-12 cg_relative_residual=6.650184e-14
# [FinalLinearSolver] Iter 1251/4000 iter=1250 total_loss=-6.589206e+00 policy_objective=-2.741870e+01 beta_objective=-8.572736e+00 q_objective=-4.969405e+00 policy_grad_norm=2.468413e+01 policy_direction_norm=1.714804e+02 beta_grad_norm=7.960547e+01 beta_direction_norm=1.687922e+03 theta_grad_norm=6.123841e-02 theta_norm=1.851871e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=34 cg_residual_norm=1.903211e-12 cg_relative_residual=7.710261e-14
# [FinalLinearSolver] Iter 1301/4000 iter=1300 total_loss=-7.768333e+00 policy_objective=-6.579641e+01 beta_objective=-3.342495e+00 q_objective=-6.032575e+00 policy_grad_norm=3.962969e+01 policy_direction_norm=2.607993e+02 beta_grad_norm=1.306803e+02 beta_direction_norm=4.360040e+03 theta_grad_norm=5.246919e-02 theta_norm=1.914025e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=34 cg_residual_norm=9.981913e-11 cg_relative_residual=2.518797e-12
# [FinalLinearSolver] Iter 1351/4000 iter=1350 total_loss=-1.977991e+01 policy_objective=1.921588e+01 beta_objective=-3.242462e+01 q_objective=-1.858840e+01 policy_grad_norm=5.502296e+01 policy_direction_norm=2.653980e+02 beta_grad_norm=1.597722e+02 beta_direction_norm=7.324618e+03 theta_grad_norm=1.866901e-01 theta_norm=1.610833e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=35 cg_residual_norm=2.882875e-12 cg_relative_residual=5.239404e-14
# [FinalLinearSolver] Iter 1401/4000 iter=1400 total_loss=-3.842871e+00 policy_objective=-1.297033e+02 beta_objective=1.480508e+01 q_objective=-2.686397e+00 policy_grad_norm=1.686980e+01 policy_direction_norm=1.693138e+02 beta_grad_norm=8.385223e+01 beta_direction_norm=1.976816e+03 theta_grad_norm=5.541147e-02 theta_norm=1.582985e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=34 cg_residual_norm=4.933175e-13 cg_relative_residual=2.924265e-14
# [FinalLinearSolver] Iter 1451/4000 iter=1450 total_loss=-7.758068e+00 policy_objective=4.681341e+00 beta_objective=-1.492671e+01 q_objective=-6.615008e+00 policy_grad_norm=4.352545e+01 policy_direction_norm=2.360879e+02 beta_grad_norm=1.272461e+02 beta_direction_norm=4.823123e+03 theta_grad_norm=8.268061e-02 theta_norm=1.580764e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=34 cg_residual_norm=1.234408e-12 cg_relative_residual=2.836060e-14
# [FinalLinearSolver] Iter 1501/4000 iter=1500 total_loss=-2.865157e+00 policy_objective=-2.131428e+00 beta_objective=-5.736061e-02 q_objective=-2.254859e+00 policy_grad_norm=2.158085e+01 policy_direction_norm=1.394005e+02 beta_grad_norm=6.843292e+01 beta_direction_norm=3.394599e+03 theta_grad_norm=6.210470e-02 theta_norm=1.200223e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=31 cg_residual_norm=9.463622e-11 cg_relative_residual=4.385195e-12
# [FinalLinearSolver] Iter 1551/4000 iter=1550 total_loss=-2.901923e+00 policy_objective=-1.280137e+02 beta_objective=1.952589e+01 q_objective=-1.603415e+00 policy_grad_norm=3.184430e+01 policy_direction_norm=2.006731e+02 beta_grad_norm=1.343213e+02 beta_direction_norm=5.912503e+03 theta_grad_norm=4.235609e-02 theta_norm=1.681013e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=34 cg_residual_norm=1.588388e-12 cg_relative_residual=4.987983e-14
# [FinalLinearSolver] Iter 1601/4000 iter=1600 total_loss=-2.001761e+01 policy_objective=-4.056859e+01 beta_objective=-3.809223e+01 q_objective=-1.736152e+01 policy_grad_norm=4.303565e+01 policy_direction_norm=3.816235e+02 beta_grad_norm=2.644443e+02 beta_direction_norm=1.066242e+04 theta_grad_norm=1.041514e-01 theta_norm=2.359058e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=34 cg_residual_norm=2.998124e-12 cg_relative_residual=6.966605e-14
# [FinalLinearSolver] Iter 1651/4000 iter=1650 total_loss=-6.903018e+00 policy_objective=-1.003100e+02 beta_objective=6.536172e+00 q_objective=-5.824182e+00 policy_grad_norm=2.352067e+01 policy_direction_norm=1.629223e+02 beta_grad_norm=7.664538e+01 beta_direction_norm=2.169540e+03 theta_grad_norm=1.555293e-01 theta_norm=1.552988e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=34 cg_residual_norm=6.977201e-13 cg_relative_residual=2.966413e-14
# [FinalLinearSolver] Iter 1701/4000 iter=1700 total_loss=2.013958e-01 policy_objective=3.655198e+00 beta_objective=-2.945351e+00 q_objective=1.122475e+00 policy_grad_norm=1.245256e+01 policy_direction_norm=1.034884e+02 beta_grad_norm=5.034531e+01 beta_direction_norm=1.185329e+03 theta_grad_norm=8.493247e-02 theta_norm=1.444879e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=33 cg_residual_norm=6.778836e-11 cg_relative_residual=5.443729e-12
# [FinalLinearSolver] Iter 1751/4000 iter=1750 total_loss=-4.146461e+00 policy_objective=-1.187362e+02 beta_objective=1.451425e+01 q_objective=-3.121155e+00 policy_grad_norm=3.141696e+01 policy_direction_norm=2.827015e+02 beta_grad_norm=1.246795e+02 beta_direction_norm=4.248851e+03 theta_grad_norm=7.255334e-02 theta_norm=1.519540e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=34 cg_residual_norm=1.762841e-12 cg_relative_residual=5.611112e-14
# [FinalLinearSolver] Iter 1801/4000 iter=1800 total_loss=-1.144691e+00 policy_objective=-8.250373e+01 beta_objective=2.945950e+00 q_objective=-8.698823e-02 policy_grad_norm=1.382271e+01 policy_direction_norm=1.458488e+02 beta_grad_norm=7.150257e+01 beta_direction_norm=1.821356e+03 theta_grad_norm=4.949679e-02 theta_norm=1.535485e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=33 cg_residual_norm=5.165235e-11 cg_relative_residual=3.736775e-12
# [FinalLinearSolver] Iter 1851/4000 iter=1850 total_loss=5.088577e+00 policy_objective=-7.307699e+01 beta_objective=1.732922e+01 q_objective=6.289817e+00 policy_grad_norm=2.221240e+01 policy_direction_norm=2.765086e+02 beta_grad_norm=9.237537e+01 beta_direction_norm=3.825590e+03 theta_grad_norm=9.102407e-02 theta_norm=1.626288e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=34 cg_residual_norm=5.308854e-13 cg_relative_residual=2.390040e-14
# [FinalLinearSolver] Iter 1901/4000 iter=1900 total_loss=-8.471547e+00 policy_objective=-1.060716e+02 beta_objective=5.300944e+00 q_objective=-7.516474e+00 policy_grad_norm=2.012406e+01 policy_direction_norm=1.764220e+02 beta_grad_norm=8.680647e+01 beta_direction_norm=4.580006e+03 theta_grad_norm=1.085146e-01 theta_norm=1.469132e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=32 cg_residual_norm=2.880655e-11 cg_relative_residual=1.431448e-12
# [FinalLinearSolver] Iter 1951/4000 iter=1950 total_loss=-2.332712e+00 policy_objective=-5.220978e+01 beta_objective=-1.537165e-02 q_objective=-1.528778e+00 policy_grad_norm=3.886753e+01 policy_direction_norm=2.550479e+02 beta_grad_norm=9.068037e+01 beta_direction_norm=3.328009e+03 theta_grad_norm=5.717015e-02 theta_norm=1.369209e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=33 cg_residual_norm=2.035539e-11 cg_relative_residual=5.237119e-13
# [FinalLinearSolver] Iter 2001/4000 iter=2000 total_loss=1.142860e+01 policy_objective=5.045511e+01 beta_objective=1.761283e+00 q_objective=1.228083e+01 policy_grad_norm=1.739758e+01 policy_direction_norm=1.553900e+02 beta_grad_norm=8.023280e+01 beta_direction_norm=2.346539e+03 theta_grad_norm=2.942076e-01 theta_norm=1.393714e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=33 cg_residual_norm=5.602483e-12 cg_relative_residual=3.220265e-13
# [FinalLinearSolver] Iter 2051/4000 iter=2050 total_loss=-6.327410e+00 policy_objective=-1.176699e+02 beta_objective=1.052568e+01 q_objective=-4.997997e+00 policy_grad_norm=2.983345e+01 policy_direction_norm=3.030655e+02 beta_grad_norm=1.184340e+02 beta_direction_norm=3.359316e+03 theta_grad_norm=5.873454e-02 theta_norm=1.704508e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=34 cg_residual_norm=1.518733e-12 cg_relative_residual=5.090707e-14
# [FinalLinearSolver] Iter 2101/4000 iter=2100 total_loss=-1.997539e+00 policy_objective=-6.186336e+01 beta_objective=5.670735e+00 q_objective=-1.245293e+00 policy_grad_norm=1.451393e+01 policy_direction_norm=1.078577e+02 beta_grad_norm=3.782829e+01 beta_direction_norm=1.786962e+03 theta_grad_norm=1.840460e-01 theta_norm=1.325502e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=32 cg_residual_norm=3.475666e-12 cg_relative_residual=2.394710e-13
# [FinalLinearSolver] Iter 2151/4000 iter=2150 total_loss=-3.692929e+00 policy_objective=-6.358812e+01 beta_objective=6.074640e+00 q_objective=-2.814500e+00 policy_grad_norm=3.251703e+01 policy_direction_norm=2.497067e+02 beta_grad_norm=9.150169e+01 beta_direction_norm=4.147556e+03 theta_grad_norm=4.874463e-02 theta_norm=1.412875e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=33 cg_residual_norm=6.940200e-12 cg_relative_residual=2.134328e-13
# [FinalLinearSolver] Iter 2201/4000 iter=2200 total_loss=-4.716336e+00 policy_objective=-4.191326e+01 beta_objective=4.417883e+00 q_objective=-4.103062e+00 policy_grad_norm=1.637821e+01 policy_direction_norm=1.058047e+02 beta_grad_norm=7.517304e+01 beta_direction_norm=3.965834e+03 theta_grad_norm=9.404722e-02 theta_norm=1.216903e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=33 cg_residual_norm=9.498393e-12 cg_relative_residual=5.799407e-13
# [FinalLinearSolver] Iter 2251/4000 iter=2250 total_loss=-1.519069e+00 policy_objective=-4.358887e+01 beta_objective=7.529558e+00 q_objective=-1.132992e+00 policy_grad_norm=1.498366e+01 policy_direction_norm=1.022763e+02 beta_grad_norm=5.528446e+01 beta_direction_norm=2.772613e+03 theta_grad_norm=4.254976e-02 theta_norm=1.017539e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=32 cg_residual_norm=3.886845e-11 cg_relative_residual=2.594056e-12
# [FinalLinearSolver] Iter 2301/4000 iter=2300 total_loss=-1.594300e+00 policy_objective=-8.423594e+01 beta_objective=1.344430e+01 q_objective=-1.051994e+00 policy_grad_norm=1.158803e+01 policy_direction_norm=1.170171e+02 beta_grad_norm=7.684999e+01 beta_direction_norm=3.336628e+03 theta_grad_norm=4.940354e-02 theta_norm=1.163564e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=33 cg_residual_norm=2.036861e-11 cg_relative_residual=1.757729e-12
# [FinalLinearSolver] Iter 2351/4000 iter=2350 total_loss=-7.320635e+00 policy_objective=4.996117e+01 beta_objective=-2.251214e+01 q_objective=-5.588377e+00 policy_grad_norm=3.975062e+01 policy_direction_norm=4.638499e+02 beta_grad_norm=1.841012e+02 beta_direction_norm=6.205630e+03 theta_grad_norm=6.247803e-02 theta_norm=1.931896e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=32 cg_residual_norm=6.621640e-12 cg_relative_residual=1.665796e-13
# [FinalLinearSolver] Iter 2401/4000 iter=2400 total_loss=-3.640905e+00 policy_objective=-7.022090e+01 beta_objective=2.989909e-01 q_objective=-2.979486e+00 policy_grad_norm=1.581611e+01 policy_direction_norm=1.098356e+02 beta_grad_norm=5.793292e+01 beta_direction_norm=3.011720e+03 theta_grad_norm=1.261215e-01 theta_norm=1.263149e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=32 cg_residual_norm=8.391050e-12 cg_relative_residual=5.305382e-13
# [FinalLinearSolver] Iter 2451/4000 iter=2450 total_loss=-1.734881e+01 policy_objective=-4.505798e+00 beta_objective=-1.429935e+01 q_objective=-1.639485e+01 policy_grad_norm=5.867405e+01 policy_direction_norm=3.458154e+02 beta_grad_norm=1.267246e+02 beta_direction_norm=3.854559e+03 theta_grad_norm=1.875824e-01 theta_norm=1.481319e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=32 cg_residual_norm=6.033655e-11 cg_relative_residual=1.028334e-12
# [FinalLinearSolver] Iter 2501/4000 iter=2500 total_loss=-4.191476e+00 policy_objective=-5.901071e+01 beta_objective=4.160540e+00 q_objective=-3.692552e+00 policy_grad_norm=1.410814e+01 policy_direction_norm=1.740827e+02 beta_grad_norm=6.894703e+01 beta_direction_norm=4.259996e+03 theta_grad_norm=7.410581e-02 theta_norm=1.128928e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=32 cg_residual_norm=4.285145e-11 cg_relative_residual=3.037357e-12
# [FinalLinearSolver] Iter 2551/4000 iter=2550 total_loss=-7.064068e+00 policy_objective=6.588708e+00 beta_objective=-1.539402e+00 q_objective=-6.469845e+00 policy_grad_norm=1.546418e+01 policy_direction_norm=2.012347e+02 beta_grad_norm=8.220299e+01 beta_direction_norm=2.626520e+03 theta_grad_norm=1.151138e-01 theta_norm=1.214269e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=33 cg_residual_norm=3.059110e-12 cg_relative_residual=1.978190e-13
# [FinalLinearSolver] Iter 2601/4000 iter=2600 total_loss=-8.593945e-01 policy_objective=-7.114585e+01 beta_objective=6.615710e+00 q_objective=-4.931568e-01 policy_grad_norm=8.979907e+00 policy_direction_norm=9.676517e+01 beta_grad_norm=3.717100e+01 beta_direction_norm=1.435130e+03 theta_grad_norm=6.915327e-02 theta_norm=1.014185e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=32 cg_residual_norm=2.902540e-12 cg_relative_residual=3.232260e-13
# [FinalLinearSolver] Iter 2651/4000 iter=2650 total_loss=1.191581e+00 policy_objective=3.683424e+01 beta_objective=-1.224153e+00 q_objective=1.644520e+00 policy_grad_norm=9.663372e+00 policy_direction_norm=1.372217e+02 beta_grad_norm=3.710624e+01 beta_direction_norm=1.272162e+03 theta_grad_norm=7.598530e-02 theta_norm=1.103249e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=31 cg_residual_norm=3.381059e-11 cg_relative_residual=3.498840e-12
# [FinalLinearSolver] Iter 2701/4000 iter=2700 total_loss=-1.470634e+00 policy_objective=-5.207971e+01 beta_objective=9.939306e+00 q_objective=-7.351659e-01 policy_grad_norm=3.243797e+01 policy_direction_norm=2.727474e+02 beta_grad_norm=1.160370e+02 beta_direction_norm=3.623834e+03 theta_grad_norm=7.170349e-02 theta_norm=1.334898e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=33 cg_residual_norm=1.079517e-11 cg_relative_residual=3.327943e-13
# [FinalLinearSolver] Iter 2751/4000 iter=2750 total_loss=-7.172778e+00 policy_objective=-3.127711e+01 beta_objective=-3.971412e+00 q_objective=-6.688852e+00 policy_grad_norm=2.326040e+01 policy_direction_norm=1.667337e+02 beta_grad_norm=4.535188e+01 beta_direction_norm=2.525181e+03 theta_grad_norm=1.641844e-01 theta_norm=1.119616e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=32 cg_residual_norm=2.656963e-11 cg_relative_residual=1.142269e-12
# [FinalLinearSolver] Iter 2801/4000 iter=2800 total_loss=-3.535076e+00 policy_objective=1.876685e+01 beta_objective=-1.510644e+00 q_objective=-3.109819e+00 policy_grad_norm=1.200588e+01 policy_direction_norm=9.964418e+01 beta_grad_norm=5.976769e+01 beta_direction_norm=3.132049e+03 theta_grad_norm=8.473086e-02 theta_norm=1.073535e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=33 cg_residual_norm=1.469907e-12 cg_relative_residual=1.224323e-13
# [FinalLinearSolver] Iter 2851/4000 iter=2850 total_loss=-6.859502e+00 policy_objective=-1.288354e+02 beta_objective=1.990868e+01 q_objective=-5.568151e+00 policy_grad_norm=2.851516e+01 policy_direction_norm=3.334546e+02 beta_grad_norm=1.922721e+02 beta_direction_norm=6.432948e+03 theta_grad_norm=4.340830e-02 theta_norm=1.695015e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=33 cg_residual_norm=2.574864e-12 cg_relative_residual=9.029805e-14
# [FinalLinearSolver] Iter 2901/4000 iter=2900 total_loss=-5.930609e+00 policy_objective=-4.056172e+01 beta_objective=-1.404225e+01 q_objective=-4.733138e+00 policy_grad_norm=2.021840e+01 policy_direction_norm=1.841355e+02 beta_grad_norm=1.229363e+02 beta_direction_norm=6.268384e+03 theta_grad_norm=5.565027e-02 theta_norm=1.644341e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=32 cg_residual_norm=3.765847e-12 cg_relative_residual=1.862584e-13
# [FinalLinearSolver] Iter 2951/4000 iter=2950 total_loss=-1.197936e+01 policy_objective=-1.752621e+01 beta_objective=-6.889491e+00 q_objective=-1.153865e+01 policy_grad_norm=2.236040e+01 policy_direction_norm=2.487896e+02 beta_grad_norm=9.917280e+01 beta_direction_norm=4.828909e+03 theta_grad_norm=2.029294e-01 theta_norm=1.095894e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=32 cg_residual_norm=1.549181e-12 cg_relative_residual=6.928235e-14
# [FinalLinearSolver] Iter 3001/4000 iter=3000 total_loss=2.319499e+00 policy_objective=-3.646660e+01 beta_objective=8.302434e+00 q_objective=2.580308e+00 policy_grad_norm=1.404189e+01 policy_direction_norm=1.284014e+02 beta_grad_norm=4.315769e+01 beta_direction_norm=1.954541e+03 theta_grad_norm=1.063287e-01 theta_norm=9.005549e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=29 cg_residual_norm=7.875905e-11 cg_relative_residual=5.608863e-12
# [FinalLinearSolver] Iter 3051/4000 iter=3050 total_loss=-1.389264e+01 policy_objective=-1.133396e+02 beta_objective=9.399753e+00 q_objective=-1.274555e+01 policy_grad_norm=3.581898e+01 policy_direction_norm=3.522754e+02 beta_grad_norm=1.724110e+02 beta_direction_norm=9.621731e+03 theta_grad_norm=1.254447e-01 theta_norm=1.615693e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=32 cg_residual_norm=2.433287e-11 cg_relative_residual=6.793290e-13
# [FinalLinearSolver] Iter 3101/4000 iter=3100 total_loss=-2.868337e+00 policy_objective=-3.453939e+01 beta_objective=-1.151064e+01 q_objective=-2.027445e+00 policy_grad_norm=3.103946e+01 policy_direction_norm=2.091344e+02 beta_grad_norm=1.125668e+02 beta_direction_norm=5.968685e+03 theta_grad_norm=1.560302e-01 theta_norm=1.405405e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=32 cg_residual_norm=2.619379e-11 cg_relative_residual=8.438870e-13
# [FinalLinearSolver] Iter 3151/4000 iter=3150 total_loss=-1.275933e+01 policy_objective=-5.467314e+01 beta_objective=-2.028071e+01 q_objective=-1.145449e+01 policy_grad_norm=1.741941e+01 policy_direction_norm=1.824665e+02 beta_grad_norm=1.522170e+02 beta_direction_norm=7.060434e+03 theta_grad_norm=1.722597e-01 theta_norm=1.710813e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=32 cg_residual_norm=9.519828e-12 cg_relative_residual=5.465070e-13
# [FinalLinearSolver] Iter 3201/4000 iter=3200 total_loss=3.817276e+00 policy_objective=-4.533153e+01 beta_objective=2.466340e+00 q_objective=4.870270e+00 policy_grad_norm=1.575595e+01 policy_direction_norm=2.288000e+02 beta_grad_norm=7.065250e+01 beta_direction_norm=2.502996e+03 theta_grad_norm=8.425102e-02 theta_norm=1.554628e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=33 cg_residual_norm=1.114436e-11 cg_relative_residual=7.073111e-13
# [FinalLinearSolver] Iter 3251/4000 iter=3250 total_loss=-3.390279e+00 policy_objective=-4.211345e+01 beta_objective=6.130821e+00 q_objective=-2.890747e+00 policy_grad_norm=2.290884e+01 policy_direction_norm=2.573636e+02 beta_grad_norm=9.113817e+01 beta_direction_norm=3.972092e+03 theta_grad_norm=6.178476e-02 theta_norm=1.145454e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=29 cg_residual_norm=3.332996e-11 cg_relative_residual=1.454895e-12
# [FinalLinearSolver] Iter 3301/4000 iter=3300 total_loss=7.612112e-02 policy_objective=3.613055e+01 beta_objective=-2.508195e+00 q_objective=3.848179e-01 policy_grad_norm=1.242245e+00 policy_direction_norm=1.890190e+01 beta_grad_norm=1.789318e+01 beta_direction_norm=5.250781e+02 theta_grad_norm=5.524673e-02 theta_norm=9.732711e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=28 cg_residual_norm=2.038292e-11 cg_relative_residual=1.640813e-11
# [FinalLinearSolver] Iter 3351/4000 iter=3350 total_loss=-3.524857e+00 policy_objective=-3.237742e+01 beta_objective=1.342826e+01 q_objective=-2.710097e+00 policy_grad_norm=2.528766e+01 policy_direction_norm=2.296241e+02 beta_grad_norm=1.645324e+02 beta_direction_norm=8.751851e+03 theta_grad_norm=2.155156e-02 theta_norm=1.401380e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=30 cg_residual_norm=9.098631e-11 cg_relative_residual=3.598052e-12
# [FinalLinearSolver] Iter 3401/4000 iter=3400 total_loss=2.639549e+00 policy_objective=-5.175056e+01 beta_objective=3.701489e+00 q_objective=2.994787e+00 policy_grad_norm=8.797356e+00 policy_direction_norm=1.063410e+02 beta_grad_norm=5.409045e+01 beta_direction_norm=3.517566e+03 theta_grad_norm=9.622734e-02 theta_norm=1.028680e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=29 cg_residual_norm=3.712512e-11 cg_relative_residual=4.220032e-12
# [FinalLinearSolver] Iter 3451/4000 iter=3450 total_loss=1.340664e+00 policy_objective=-4.032624e+01 beta_objective=1.455534e+01 q_objective=2.271295e+00 policy_grad_norm=1.116777e+01 policy_direction_norm=2.919023e+02 beta_grad_norm=1.240204e+02 beta_direction_norm=5.080610e+03 theta_grad_norm=8.760111e-02 theta_norm=1.478669e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=28 cg_residual_norm=7.899774e-11 cg_relative_residual=7.073728e-12
# [FinalLinearSolver] Iter 3501/4000 iter=3500 total_loss=-1.855328e+00 policy_objective=-5.036293e+01 beta_objective=-1.085945e+00 q_objective=-1.357057e+00 policy_grad_norm=1.141652e+01 policy_direction_norm=1.605837e+02 beta_grad_norm=7.387581e+01 beta_direction_norm=4.434341e+03 theta_grad_norm=8.543160e-02 theta_norm=1.152893e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=30 cg_residual_norm=2.771824e-11 cg_relative_residual=2.427906e-12
# [FinalLinearSolver] Iter 3551/4000 iter=3550 total_loss=-5.689185e+00 policy_objective=-6.782795e+01 beta_objective=2.692501e+00 q_objective=-4.639109e+00 policy_grad_norm=1.083733e+01 policy_direction_norm=1.257867e+02 beta_grad_norm=7.301344e+01 beta_direction_norm=3.870352e+03 theta_grad_norm=1.256728e-01 theta_norm=1.563859e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=30 cg_residual_norm=3.939209e-11 cg_relative_residual=3.634851e-12
# [FinalLinearSolver] Iter 3601/4000 iter=3600 total_loss=-2.065872e+00 policy_objective=-1.974503e-01 beta_objective=-1.556269e+01 q_objective=-1.426574e+00 policy_grad_norm=2.195521e+01 policy_direction_norm=1.982600e+02 beta_grad_norm=1.480243e+02 beta_direction_norm=6.898069e+03 theta_grad_norm=6.372631e-02 theta_norm=1.275754e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=30 cg_residual_norm=2.004473e-11 cg_relative_residual=9.129830e-13
# [FinalLinearSolver] Iter 3651/4000 iter=3650 total_loss=-6.166299e+00 policy_objective=-7.066747e+00 beta_objective=-2.290286e+00 q_objective=-5.025236e+00 policy_grad_norm=2.805376e+01 policy_direction_norm=4.430176e+02 beta_grad_norm=1.658528e+02 beta_direction_norm=8.291770e+03 theta_grad_norm=3.785109e-02 theta_norm=1.616911e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=30 cg_residual_norm=2.859440e-11 cg_relative_residual=1.019272e-12
# [FinalLinearSolver] Iter 3701/4000 iter=3700 total_loss=-4.105166e-01 policy_objective=-3.378802e+01 beta_objective=-5.099931e+00 q_objective=-8.790565e-03 policy_grad_norm=8.257689e+00 policy_direction_norm=7.083926e+01 beta_grad_norm=7.925378e+01 beta_direction_norm=3.727588e+03 theta_grad_norm=6.112160e-02 theta_norm=1.072919e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=29 cg_residual_norm=6.952982e-11 cg_relative_residual=8.420010e-12
# [FinalLinearSolver] Iter 3751/4000 iter=3750 total_loss=-1.525122e+00 policy_objective=-1.088057e+00 beta_objective=-4.040118e+00 q_objective=-1.355883e+00 policy_grad_norm=7.958117e+00 policy_direction_norm=8.298821e+01 beta_grad_norm=4.070249e+01 beta_direction_norm=1.871572e+03 theta_grad_norm=4.515410e-02 theta_norm=8.322677e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=28 cg_residual_norm=7.492042e-11 cg_relative_residual=9.414340e-12
# [FinalLinearSolver] Iter 3801/4000 iter=3800 total_loss=-3.754309e+00 policy_objective=4.970013e+01 beta_objective=-2.953664e+01 q_objective=-2.348245e+00 policy_grad_norm=3.707350e+01 policy_direction_norm=4.180250e+02 beta_grad_norm=2.553716e+02 beta_direction_norm=1.414627e+04 theta_grad_norm=8.965456e-03 theta_norm=1.780800e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=30 cg_residual_norm=7.484165e-11 cg_relative_residual=2.018737e-12
# [FinalLinearSolver] Iter 3851/4000 iter=3850 total_loss=-8.045938e+00 policy_objective=-7.521188e+01 beta_objective=1.360371e+01 q_objective=-7.153214e+00 policy_grad_norm=2.079707e+01 policy_direction_norm=2.196538e+02 beta_grad_norm=1.677208e+02 beta_direction_norm=7.296476e+03 theta_grad_norm=6.147285e-02 theta_norm=1.468369e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=30 cg_residual_norm=4.116196e-11 cg_relative_residual=1.979220e-12
# [FinalLinearSolver] Iter 3901/4000 iter=3900 total_loss=2.006286e+00 policy_objective=-8.069897e+01 beta_objective=1.406926e+01 q_objective=2.552854e+00 policy_grad_norm=1.039767e+01 policy_direction_norm=1.344557e+02 beta_grad_norm=7.365643e+01 beta_direction_norm=3.284100e+03 theta_grad_norm=6.622001e-02 theta_norm=1.208979e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=29 cg_residual_norm=5.313452e-12 cg_relative_residual=5.110232e-13
# [FinalLinearSolver] Iter 3951/4000 iter=3950 total_loss=-6.232517e-01 policy_objective=6.699140e+01 beta_objective=-1.179958e+01 q_objective=-2.885265e-01 policy_grad_norm=6.518331e+00 policy_direction_norm=8.091793e+01 beta_grad_norm=7.799537e+01 beta_direction_norm=3.347249e+03 theta_grad_norm=5.231165e-02 theta_norm=1.026316e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=npg policy_gradient=exact policy_direction=cg_fisher reinforce_samples=1 D_theta=2.607681e+01 effective_D_theta=2.607681e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None cg_iters_used=30 cg_residual_norm=1.568097e-12 cg_relative_residual=2.405673e-13
#   State 0: pi(a=0|s=0) = 0.00  pi(a=1|s=0) = 1.00  pi(a=2|s=0) = 0.00  pi(a=3|s=0) = 0.00  --> best action: 1
#   State 1: pi(a=0|s=1) = 0.10  pi(a=1|s=1) = 0.43  pi(a=2|s=1) = 0.46  pi(a=3|s=1) = 0.02  --> best action: 2
#   State 2: pi(a=0|s=2) = 0.04  pi(a=1|s=2) = 0.00  pi(a=2|s=2) = 0.64  pi(a=3|s=2) = 0.32  --> best action: 2
#   State 3: pi(a=0|s=3) = 0.01  pi(a=1|s=3) = 0.00  pi(a=2|s=3) = 0.21  pi(a=3|s=3) = 0.78  --> best action: 3
#   State 4: pi(a=0|s=4) = 0.00  pi(a=1|s=4) = 0.00  pi(a=2|s=4) = 0.10  pi(a=3|s=4) = 0.90  --> best action: 3
#   State 5: pi(a=0|s=5) = 0.00  pi(a=1|s=5) = 1.00  pi(a=2|s=5) = 0.00  pi(a=3|s=5) = 0.00  --> best action: 1
#   State 6: pi(a=0|s=6) = 0.00  pi(a=1|s=6) = 0.85  pi(a=2|s=6) = 0.15  pi(a=3|s=6) = 0.00  --> best action: 1
#   State 7: pi(a=0|s=7) = 0.01  pi(a=1|s=7) = 0.03  pi(a=2|s=7) = 0.93  pi(a=3|s=7) = 0.04  --> best action: 2
#   State 8: pi(a=0|s=8) = 0.02  pi(a=1|s=8) = 0.00  pi(a=2|s=8) = 0.80  pi(a=3|s=8) = 0.17  --> best action: 2
#   State 9: pi(a=0|s=9) = 0.07  pi(a=1|s=9) = 0.00  pi(a=2|s=9) = 0.66  pi(a=3|s=9) = 0.26  --> best action: 2
#   State 10: pi(a=0|s=10) = 0.00  pi(a=1|s=10) = 1.00  pi(a=2|s=10) = 0.00  pi(a=3|s=10) = 0.00  --> best action: 1
#   State 11: pi(a=0|s=11) = 0.00  pi(a=1|s=11) = 0.89  pi(a=2|s=11) = 0.11  pi(a=3|s=11) = 0.00  --> best action: 1
#   State 12: pi(a=0|s=12) = 0.01  pi(a=1|s=12) = 0.11  pi(a=2|s=12) = 0.84  pi(a=3|s=12) = 0.04  --> best action: 2
#   State 13: pi(a=0|s=13) = 0.06  pi(a=1|s=13) = 0.02  pi(a=2|s=13) = 0.82  pi(a=3|s=13) = 0.10  --> best action: 2
#   State 14: pi(a=0|s=14) = 0.43  pi(a=1|s=14) = 0.04  pi(a=2|s=14) = 0.49  pi(a=3|s=14) = 0.05  --> best action: 2
#   State 15: pi(a=0|s=15) = 0.00  pi(a=1|s=15) = 0.98  pi(a=2|s=15) = 0.02  pi(a=3|s=15) = 0.00  --> best action: 1
#   State 16: pi(a=0|s=16) = 0.00  pi(a=1|s=16) = 0.55  pi(a=2|s=16) = 0.37  pi(a=3|s=16) = 0.08  --> best action: 1
#   State 17: pi(a=0|s=17) = 0.00  pi(a=1|s=17) = 0.05  pi(a=2|s=17) = 0.45  pi(a=3|s=17) = 0.50  --> best action: 3
#   State 18: pi(a=0|s=18) = 0.15  pi(a=1|s=18) = 0.02  pi(a=2|s=18) = 0.38  pi(a=3|s=18) = 0.45  --> best action: 3
#   State 19: pi(a=0|s=19) = 0.89  pi(a=1|s=19) = 0.02  pi(a=2|s=19) = 0.07  pi(a=3|s=19) = 0.02  --> best action: 0
#   State 20: pi(a=0|s=20) = 0.00  pi(a=1|s=20) = 0.20  pi(a=2|s=20) = 0.19  pi(a=3|s=20) = 0.61  --> best action: 3
#   State 21: pi(a=0|s=21) = 0.00  pi(a=1|s=21) = 0.00  pi(a=2|s=21) = 0.02  pi(a=3|s=21) = 0.97  --> best action: 3
#   State 22: pi(a=0|s=22) = 0.00  pi(a=1|s=22) = 0.00  pi(a=2|s=22) = 0.01  pi(a=3|s=22) = 0.99  --> best action: 3
#   State 23: pi(a=0|s=23) = 0.04  pi(a=1|s=23) = 0.00  pi(a=2|s=23) = 0.01  pi(a=3|s=23) = 0.95  --> best action: 3
#   State 24: pi(a=0|s=24) = 0.94  pi(a=1|s=24) = 0.00  pi(a=2|s=24) = 0.01  pi(a=3|s=24) = 0.05  --> best action: 0

# %%
mdp.print_policy(solver_e.pi)

evaluator_stoch = FOGASEvaluator(
    solver=solver_e,
    mdp=mdp,
    planner=planner,
)

solver_stats = evaluator_stoch.average_return_stats(
    policy_mode="solver",
    num_trajectories=100,
    max_steps=20,
    seed=SEED,
    terminal_states=terminal_states,
    compare_with_optimal=True,
)

greedy_stats = evaluator_stoch.average_return_stats(
    policy_mode="greedy",
    num_trajectories=100,
    max_steps=20,
    seed=SEED,
    terminal_states=terminal_states,
    compare_with_optimal=True,
)

print(f"Solver avg reward:  {solver_stats['policy']:.4f} +- {solver_stats['policy_std']:.4f}")
print(f"Greedy avg reward:  {greedy_stats['policy']:.4f} +- {greedy_stats['policy_std']:.4f}")
print(f"Optimal avg reward: {solver_stats['optimal']:.4f} +- {solver_stats['optimal_std']:.4f}")
# Out:
#   State 0: pi(a=0|s=0) = 0.00  pi(a=1|s=0) = 1.00  pi(a=2|s=0) = 0.00  pi(a=3|s=0) = 0.00  --> best action: 1
#   State 1: pi(a=0|s=1) = 0.10  pi(a=1|s=1) = 0.43  pi(a=2|s=1) = 0.46  pi(a=3|s=1) = 0.02  --> best action: 2
#   State 2: pi(a=0|s=2) = 0.04  pi(a=1|s=2) = 0.00  pi(a=2|s=2) = 0.64  pi(a=3|s=2) = 0.32  --> best action: 2
#   State 3: pi(a=0|s=3) = 0.01  pi(a=1|s=3) = 0.00  pi(a=2|s=3) = 0.21  pi(a=3|s=3) = 0.78  --> best action: 3
#   State 4: pi(a=0|s=4) = 0.00  pi(a=1|s=4) = 0.00  pi(a=2|s=4) = 0.10  pi(a=3|s=4) = 0.90  --> best action: 3
#   State 5: pi(a=0|s=5) = 0.00  pi(a=1|s=5) = 1.00  pi(a=2|s=5) = 0.00  pi(a=3|s=5) = 0.00  --> best action: 1
#   State 6: pi(a=0|s=6) = 0.00  pi(a=1|s=6) = 0.85  pi(a=2|s=6) = 0.15  pi(a=3|s=6) = 0.00  --> best action: 1
#   State 7: pi(a=0|s=7) = 0.01  pi(a=1|s=7) = 0.03  pi(a=2|s=7) = 0.93  pi(a=3|s=7) = 0.04  --> best action: 2
#   State 8: pi(a=0|s=8) = 0.02  pi(a=1|s=8) = 0.00  pi(a=2|s=8) = 0.80  pi(a=3|s=8) = 0.17  --> best action: 2
#   State 9: pi(a=0|s=9) = 0.07  pi(a=1|s=9) = 0.00  pi(a=2|s=9) = 0.66  pi(a=3|s=9) = 0.26  --> best action: 2
#   State 10: pi(a=0|s=10) = 0.00  pi(a=1|s=10) = 1.00  pi(a=2|s=10) = 0.00  pi(a=3|s=10) = 0.00  --> best action: 1
#   State 11: pi(a=0|s=11) = 0.00  pi(a=1|s=11) = 0.89  pi(a=2|s=11) = 0.11  pi(a=3|s=11) = 0.00  --> best action: 1
#   State 12: pi(a=0|s=12) = 0.01  pi(a=1|s=12) = 0.11  pi(a=2|s=12) = 0.84  pi(a=3|s=12) = 0.04  --> best action: 2
#   State 13: pi(a=0|s=13) = 0.06  pi(a=1|s=13) = 0.02  pi(a=2|s=13) = 0.82  pi(a=3|s=13) = 0.10  --> best action: 2
#   State 14: pi(a=0|s=14) = 0.43  pi(a=1|s=14) = 0.04  pi(a=2|s=14) = 0.49  pi(a=3|s=14) = 0.05  --> best action: 2
#   State 15: pi(a=0|s=15) = 0.00  pi(a=1|s=15) = 0.98  pi(a=2|s=15) = 0.02  pi(a=3|s=15) = 0.00  --> best action: 1
#   State 16: pi(a=0|s=16) = 0.00  pi(a=1|s=16) = 0.55  pi(a=2|s=16) = 0.37  pi(a=3|s=16) = 0.08  --> best action: 1
#   State 17: pi(a=0|s=17) = 0.00  pi(a=1|s=17) = 0.05  pi(a=2|s=17) = 0.45  pi(a=3|s=17) = 0.50  --> best action: 3
#   State 18: pi(a=0|s=18) = 0.15  pi(a=1|s=18) = 0.02  pi(a=2|s=18) = 0.38  pi(a=3|s=18) = 0.45  --> best action: 3
#   State 19: pi(a=0|s=19) = 0.89  pi(a=1|s=19) = 0.02  pi(a=2|s=19) = 0.07  pi(a=3|s=19) = 0.02  --> best action: 0
#   State 20: pi(a=0|s=20) = 0.00  pi(a=1|s=20) = 0.20  pi(a=2|s=20) = 0.19  pi(a=3|s=20) = 0.61  --> best action: 3
#   State 21: pi(a=0|s=21) = 0.00  pi(a=1|s=21) = 0.00  pi(a=2|s=21) = 0.02  pi(a=3|s=21) = 0.97  --> best action: 3
#   State 22: pi(a=0|s=22) = 0.00  pi(a=1|s=22) = 0.00  pi(a=2|s=22) = 0.01  pi(a=3|s=22) = 0.99  --> best action: 3
#   State 23: pi(a=0|s=23) = 0.04  pi(a=1|s=23) = 0.00  pi(a=2|s=23) = 0.01  pi(a=3|s=23) = 0.95  --> best action: 3
#   State 24: pi(a=0|s=24) = 0.94  pi(a=1|s=24) = 0.00  pi(a=2|s=24) = 0.01  pi(a=3|s=24) = 0.05  --> best action: 0
#
# Solver avg reward:  -0.3227 +- 0.2262
# Greedy avg reward:  -0.2534 +- 0.2499
# Optimal avg reward: -0.2103 +- 0.1644
