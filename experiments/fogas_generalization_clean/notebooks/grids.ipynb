# %%
# %load_ext autoreload
# %autoreload 2

import os
import random
import numpy as np
import pandas as pd
import sys
import torch
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches

SEED = 42
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.set_default_dtype(torch.float64)

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
if torch.backends.cudnn.is_available():
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

def find_root(current_path, marker="setup.py"):
    current_path = Path(current_path).resolve()
    for parent in [current_path] + list(current_path.parents):
        if (parent / marker).exists():
            return parent
    return current_path

PROJECT_ROOT = find_root(Path.cwd())

DATASETS_DIR = PROJECT_ROOT / "data" / "datasets_clean" / "generalization"
RESULTS_DIR = PROJECT_ROOT / "data" / "results_clean" / "generalization"
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

# Add project root to the Python path
if str(PROJECT_ROOT / "src") not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / "src"))

from rl_methods.mdp_clean import DiscreteMDP, Planner
from rl_methods.fogas_clean import FOGASEvaluator, FOGASHyperOptimizer
from rl_methods.fogas_generalization_clean import *
from rl_methods.fogas_generalization_clean import (
    FinalLinearSolver,
    TabularFeatures,
    LinearFunction,
    LinearQFunction,
)
from rl_methods.data_collection_clean import DiscreteDataBuffer
from rl_methods.fogas_clean import FOGASEvaluator
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 3grid empty

# %%
states = torch.arange(9, dtype=torch.long)
actions = torch.arange(4, dtype=torch.long)

N = len(states)
A = len(actions)
gamma = 0.9
x_0 = 0

dataset_path = DATASETS_DIR / "3grid.csv"
goal_grid = 8


def phi(x, a):
    vec = torch.zeros(N * A, dtype=torch.float64, device=DEVICE)
    vec[int(x) * A + int(a)] = 1.0
    return vec


omega = torch.full(
    (N * A,),
    -0.1,
    dtype=torch.float64,
    device=DEVICE,
)
omega[goal_grid * A : goal_grid * A + A] = 1.0


def to_rc(s):
    return divmod(int(s), 3)


def to_s(r, c):
    return r * 3 + c


def next_state(s, a):
    s = int(s)
    a = int(a)

    if s == goal_grid:
        return goal_grid

    r, c = to_rc(s)

    if a == 0:      # Up
        r = max(0, r - 1)
    elif a == 1:    # Down
        r = min(2, r + 1)
    elif a == 2:    # Left
        c = max(0, c - 1)
    elif a == 3:    # Right
        c = min(2, c + 1)

    return to_s(r, c)


def psi(xp):
    v = torch.zeros(N * A, dtype=torch.float64, device=DEVICE)
    for x in states:
        for a in actions:
            if next_state(x, a) == int(xp):
                v[int(x) * A + int(a)] = 1.0
    return v


mdp = DiscreteMDP(
    states=states,
    actions=actions,
    gamma=gamma,
    x0=x_0,
    phi=phi,
    omega=omega,
    psi=psi,
    terminal_states=[goal_grid],
).to(DEVICE)

planner = Planner(mdp)

# %%
from rl_methods.fogas_generalization_clean import (
    FinalLinearSolver,
    TabularFeatures,
    LinearFunction,
    LinearQFunction,
)

u_features = TabularFeatures(N, A)
q_features = TabularFeatures(N, A)
policy_features = TabularFeatures(N, A)

solver_e = FinalLinearSolver(
    n_states=N,
    n_actions=A,
    gamma=gamma,
    x0=x_0,
    csv_path=dataset_path,
    u_function=LinearFunction(u_features),
    q_function=LinearQFunction(q_features),
    policy_features=policy_features,
    seed=SEED,
    device=DEVICE,

    theta_include_beta_cov=False,

    theta_mode="reg_fixed",
    theta_lambda=1e-3,
    theta_optimizer="adam",
    theta_inner_steps=40,
    theta_lr=0.3,
    theta_start_mode="warm",

    beta_update="fogas_full",
)

solver_e.run(
    alpha=1e-3,
    eta=1e-4,
    rho=0.05,
    policy_optimizer="adam",
    policy_gradient="reinforce",
    reinforce_samples=1,
    tqdm_print=False,
    verbose=True,
    log_interval=50,
    T=2500,
    state_weight_update="normal",
)

mdp.print_policy(solver_e.pi)
# Out:
# [FinalLinearSolver] Iter 1/2500 iter=0 total_loss=-1.126195e+00 policy_objective=-1.126195e+00 beta_objective=0.000000e+00 q_objective=-8.725320e-01 policy_grad_norm=0.000000e+00 policy_direction_norm=0.000000e+00 beta_grad_norm=1.137741e+00 beta_direction_norm=2.147210e+01 theta_grad_norm=2.747610e-02 theta_norm=2.252390e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=1.897367e+01 effective_D_theta=1.897367e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 51/2500 iter=50 total_loss=-1.754472e+00 policy_objective=-1.993909e+00 beta_objective=2.935044e-01 q_objective=-8.768817e-01 policy_grad_norm=4.560201e-02 policy_direction_norm=4.560201e-02 beta_grad_norm=1.636261e+00 beta_direction_norm=3.200756e+01 theta_grad_norm=8.857740e-05 theta_norm=4.187615e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=1.897367e+01 effective_D_theta=1.897367e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 101/2500 iter=100 total_loss=-1.380443e+00 policy_objective=-1.698736e+00 beta_objective=3.517161e-01 q_objective=-6.899259e-01 policy_grad_norm=2.770414e-01 policy_direction_norm=2.770414e-01 beta_grad_norm=1.163730e+00 beta_direction_norm=2.312190e+01 theta_grad_norm=9.219512e-05 theta_norm=3.712319e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=1.897367e+01 effective_D_theta=1.897367e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 151/2500 iter=150 total_loss=-1.159422e+00 policy_objective=-1.513314e+00 beta_objective=3.497622e-01 q_objective=-5.787328e-01 policy_grad_norm=3.064918e-01 policy_direction_norm=3.064918e-01 beta_grad_norm=9.087004e-01 beta_direction_norm=1.796426e+01 theta_grad_norm=8.296304e-05 theta_norm=3.401853e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=1.897367e+01 effective_D_theta=1.897367e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 201/2500 iter=200 total_loss=-1.011021e+00 policy_objective=-1.386183e+00 beta_objective=3.322977e-01 q_objective=-5.037685e-01 policy_grad_norm=3.340674e-01 policy_direction_norm=3.340674e-01 beta_grad_norm=7.468795e-01 beta_direction_norm=1.484503e+01 theta_grad_norm=7.359236e-05 theta_norm=3.176838e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=1.897367e+01 effective_D_theta=1.897367e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 251/2500 iter=250 total_loss=-8.976700e-01 policy_objective=-1.291708e+00 beta_objective=3.158978e-01 q_objective=-4.472737e-01 policy_grad_norm=4.847615e-02 policy_direction_norm=4.847615e-02 beta_grad_norm=6.495157e-01 beta_direction_norm=1.272135e+01 theta_grad_norm=7.930221e-05 theta_norm=2.990638e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=1.897367e+01 effective_D_theta=1.897367e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 301/2500 iter=300 total_loss=-8.106428e-01 policy_objective=-1.219189e+00 beta_objective=2.991569e-01 q_objective=-4.038624e-01 policy_grad_norm=2.204542e-01 policy_direction_norm=2.204542e-01 beta_grad_norm=5.735790e-01 beta_direction_norm=1.132924e+01 theta_grad_norm=7.727796e-05 theta_norm=2.839106e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=1.897367e+01 effective_D_theta=1.897367e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 351/2500 iter=350 total_loss=-7.408063e-01 policy_objective=-1.166404e+00 beta_objective=2.882750e-01 q_objective=-3.680281e-01 policy_grad_norm=2.730953e-02 policy_direction_norm=2.730953e-02 beta_grad_norm=5.224054e-01 beta_direction_norm=1.037980e+01 theta_grad_norm=7.210634e-05 theta_norm=2.714700e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=1.897367e+01 effective_D_theta=1.897367e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter
+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=1.897367e+01 effective_D_theta=1.897367e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 2251/2500 iter=2250 total_loss=-2.274123e-01 policy_objective=-6.814637e-01 beta_objective=7.959144e-02 q_objective=-1.057524e-01 policy_grad_norm=1.019106e-03 policy_direction_norm=1.019106e-03 beta_grad_norm=7.473089e-02 beta_direction_norm=2.353078e+00 theta_grad_norm=6.662549e-05 theta_norm=1.454779e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=1.897367e+01 effective_D_theta=1.897367e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 2301/2500 iter=2300 total_loss=-2.258261e-01 policy_objective=-6.773456e-01 beta_objective=7.709357e-02 q_objective=-1.048842e-01 policy_grad_norm=1.292908e-03 policy_direction_norm=1.292908e-03 beta_grad_norm=7.200649e-02 beta_direction_norm=2.291626e+00 theta_grad_norm=6.519583e-05 theta_norm=1.448859e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=1.897367e+01 effective_D_theta=1.897367e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 2351/2500 iter=2350 total_loss=-2.242685e-01 policy_objective=-6.736245e-01 beta_objective=7.323255e-02 q_objective=-1.040647e-01 policy_grad_norm=2.867569e-03 policy_direction_norm=2.867569e-03 beta_grad_norm=6.848951e-02 beta_direction_norm=2.230594e+00 theta_grad_norm=6.716758e-05 theta_norm=1.442804e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=1.897367e+01 effective_D_theta=1.897367e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 2401/2500 iter=2400 total_loss=-2.227958e-01 policy_objective=-6.712975e-01 beta_objective=7.236335e-02 q_objective=-1.032918e-01 policy_grad_norm=1.042430e-03 policy_direction_norm=1.042430e-03 beta_grad_norm=6.715780e-02 beta_direction_norm=2.165084e+00 theta_grad_norm=6.879829e-05 theta_norm=1.437018e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=1.897367e+01 effective_D_theta=1.897367e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 2451/2500 iter=2450 total_loss=-2.217213e-01 policy_objective=-6.706488e-01 beta_objective=7.052272e-02 q_objective=-1.025632e-01 policy_grad_norm=1.646782e-03 policy_direction_norm=1.646782e-03 beta_grad_norm=6.474198e-02 beta_direction_norm=2.112821e+00 theta_grad_norm=6.802418e-05 theta_norm=1.433705e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=1.897367e+01 effective_D_theta=1.897367e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
#   State 0: pi(a=0|s=0) = 0.16  pi(a=1|s=0) = 0.41  pi(a=2|s=0) = 0.15  pi(a=3|s=0) = 0.28  --> best action: 1
#   State 1: pi(a=0|s=1) = 0.13  pi(a=1|s=1) = 0.39  pi(a=2|s=1) = 0.03  pi(a=3|s=1) = 0.45  --> best action: 3
#   State 2: pi(a=0|s=2) = 0.27  pi(a=1|s=2) = 0.43  pi(a=2|s=2) = 0.02  pi(a=3|s=2) = 0.28  --> best action: 1
#   State 3: pi(a=0|s=3) = 0.03  pi(a=1|s=3) = 0.44  pi(a=2|s=3) = 0.12  pi(a=3|s=3) = 0.40  --> best action: 1
#   State 4: pi(a=0|s=4) = 0.01  pi(a=1|s=4) = 0.38  pi(a=2|s=4) = 0.01  pi(a=3|s=4) = 0.60  --> best action: 3
#   State 5: pi(a=0|s=5) = 0.12  pi(a=1|s=5) = 0.60  pi(a=2|s=5) = 0.01  pi(a=3|s=5) = 0.27  --> best action: 1
#   State 6: pi(a=0|s=6) = 0.02  pi(a=1|s=6) = 0.23  pi(a=2|s=6) = 0.22  pi(a=3|s=6) = 0.53  --> best action: 3
#   State 7: pi(a=0|s=7) = 0.01  pi(a=1|s=7) = 0.29  pi(a=2|s=7) = 0.01  pi(a=3|s=7) = 0.69  --> best action: 3
#   State 8: pi(a=0|s=8) = 0.25  pi(a=1|s=8) = 0.25  pi(a=2|s=8) = 0.25  pi(a=3|s=8) = 0.25  --> best action: 0

# %% [markdown]
# # 3grid walls

# %%
states = torch.arange(9, dtype=torch.long)
actions = torch.arange(4, dtype=torch.long)
N = len(states)
A = len(actions)
gamma = 0.9

x_0 = 0
dataset_path_3walls = str(DATASETS_DIR / "3grid_wall.csv")

goal = 8
pit = 5
wall = 4

step_cost = -0.1
goal_reward = 1.0
pit_reward = -1.0


def phi(x, a):
    vec = torch.zeros(N * A, dtype=torch.float64)
    vec[int(x) * A + int(a)] = 1.0
    return vec


omega = torch.full((N * A,), step_cost, dtype=torch.float64)
omega[goal * A : goal * A + A] = goal_reward
omega[pit * A : pit * A + A] = pit_reward


def to_rc(s):
    return divmod(int(s), 3)


def to_s(r, c):
    return r * 3 + c


def next_state(s, a):
    s = int(s)
    a = int(a)

    if s == goal or s == pit:
        return s

    r, c = to_rc(s)

    if a == 0:      # Up
        r2, c2 = max(0, r - 1), c
    elif a == 1:    # Down
        r2, c2 = min(2, r + 1), c
    elif a == 2:    # Left
        r2, c2 = r, max(0, c - 1)
    elif a == 3:    # Right
        r2, c2 = r, min(2, c + 1)
    else:
        raise ValueError(f"Unknown action: {a}")

    sp = to_s(r2, c2)

    if sp == wall:
        return s

    return sp


def transition_fn(s, a):
    probs = torch.zeros(N, dtype=torch.float64)
    probs[next_state(s, a)] = 1.0
    return probs


mdp = DiscreteMDP(
    states=states,
    actions=actions,
    gamma=gamma,
    x0=x_0,
    omega=omega,
    phi=phi,
    transition_fn=transition_fn,
    terminal_states=[goal, pit],
)

planner = Planner(mdp, mode="deterministic")

# %%
u_features = TabularFeatures(N, A)
q_features = TabularFeatures(N, A)
policy_features = TabularFeatures(N, A)

solver_e = FinalLinearSolver(
    n_states=N,
    n_actions=A,
    gamma=gamma,
    x0=x_0,
    csv_path=dataset_path_3walls,
    u_function=LinearFunction(u_features),
    q_function=LinearQFunction(q_features),
    policy_features=policy_features,
    seed=SEED,
    device=DEVICE,

    theta_include_beta_cov=False,

    theta_mode="reg_fixed",
    theta_lambda=1e-3,
    theta_optimizer="adam",
    theta_inner_steps=40,
    theta_lr=0.3,
    theta_start_mode="warm",

    beta_update="fogas_full",
)

solver_e.run(
    alpha=1e-3,
    eta=1e-4,
    rho=0.05,
    policy_optimizer="adam",
    policy_gradient="reinforce",
    reinforce_samples=1,
    tqdm_print=False,
    verbose=True,
    log_interval=50,
    T=2500,
    state_weight_update="normal",
)

mdp.print_policy(solver_e.pi)
# Out:
# [FinalLinearSolver] Iter 1/2500 iter=0 total_loss=-1.126195e+00 policy_objective=-1.126195e+00 beta_objective=0.000000e+00 q_objective=-8.725320e-01 policy_grad_norm=0.000000e+00 policy_direction_norm=0.000000e+00 beta_grad_norm=1.504430e+00 beta_direction_norm=2.147039e+01 theta_grad_norm=2.747610e-02 theta_norm=2.252390e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=1.897367e+01 effective_D_theta=1.897367e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 51/2500 iter=50 total_loss=-1.586657e+00 policy_objective=-1.837240e+00 beta_objective=3.264511e-01 q_objective=-7.932125e-01 policy_grad_norm=1.382767e-01 policy_direction_norm=1.382767e-01 beta_grad_norm=1.894157e+00 beta_direction_norm=2.699531e+01 theta_grad_norm=8.639847e-05 theta_norm=3.981543e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=1.897367e+01 effective_D_theta=1.897367e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter
+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=1.897367e+01 effective_D_theta=1.897367e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 2401/2500 iter=2400 total_loss=-2.669581e-01 policy_objective=-8.730043e-01 beta_objective=8.715616e-02 q_objective=-1.245567e-01 policy_grad_norm=5.488585e-04 policy_direction_norm=5.488585e-04 beta_grad_norm=9.249829e-02 beta_direction_norm=2.952667e+00 theta_grad_norm=7.137473e-05 theta_norm=1.577126e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=1.897367e+01 effective_D_theta=1.897367e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 2451/2500 iter=2450 total_loss=-2.651776e-01 policy_objective=-8.740005e-01 beta_objective=8.690571e-02 q_objective=-1.233354e-01 policy_grad_norm=1.677635e-03 policy_direction_norm=1.677635e-03 beta_grad_norm=8.994552e-02 beta_direction_norm=2.909211e+00 theta_grad_norm=7.122054e-05 theta_norm=1.572516e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=1 D_theta=1.897367e+01 effective_D_theta=1.897367e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
#   State 0: pi(a=0|s=0) = 0.16  pi(a=1|s=0) = 0.37  pi(a=2|s=0) = 0.17  pi(a=3|s=0) = 0.29  --> best action: 1
#   State 1: pi(a=0|s=1) = 0.20  pi(a=1|s=1) = 0.20  pi(a=2|s=1) = 0.07  pi(a=3|s=1) = 0.53  --> best action: 3
#   State 2: pi(a=0|s=2) = 0.22  pi(a=1|s=2) = 0.53  pi(a=2|s=2) = 0.01  pi(a=3|s=2) = 0.23  --> best action: 1
#   State 3: pi(a=0|s=3) = 0.05  pi(a=1|s=3) = 0.60  pi(a=2|s=3) = 0.17  pi(a=3|s=3) = 0.17  --> best action: 1
#   State 4: pi(a=0|s=4) = 0.25  pi(a=1|s=4) = 0.25  pi(a=2|s=4) = 0.25  pi(a=3|s=4) = 0.25  --> best action: 0
#   State 5: pi(a=0|s=5) = 0.25  pi(a=1|s=5) = 0.25  pi(a=2|s=5) = 0.25  pi(a=3|s=5) = 0.25  --> best action: 0
#   State 6: pi(a=0|s=6) = 0.01  pi(a=1|s=6) = 0.19  pi(a=2|s=6) = 0.18  pi(a=3|s=6) = 0.62  --> best action: 3
#   State 7: pi(a=0|s=7) = 0.22  pi(a=1|s=7) = 0.21  pi(a=2|s=7) = 0.01  pi(a=3|s=7) = 0.56  --> best action: 3
#   State 8: pi(a=0|s=8) = 0.25  pi(a=1|s=8) = 0.25  pi(a=2|s=8) = 0.25  pi(a=3|s=8) = 0.25  --> best action: 0

# %% [markdown]
# # 5grid

# %%
states = torch.arange(25, dtype=torch.long)
actions = torch.arange(4, dtype=torch.long)

N = len(states)
A = len(actions)
gamma = 0.99
x_0 = 0

dataset_path_5grid = str(DATASETS_DIR / "5grid.csv")

grid_size = 5
goal_grid = 24

wall_states = {6, 7, 12}
terminal_states = {goal_grid}


def state_to_pos(s):
    return divmod(int(s), grid_size)


def pos_to_state(row, col):
    return row * grid_size + col


def move_deterministic(s, a):
    s = int(s)
    a = int(a)

    if s in terminal_states:
        return s

    row, col = state_to_pos(s)

    if a == 0:      # Up
        new_row, new_col = row - 1, col
    elif a == 1:    # Down
        new_row, new_col = row + 1, col
    elif a == 2:    # Left
        new_row, new_col = row, col - 1
    elif a == 3:    # Right
        new_row, new_col = row, col + 1
    else:
        raise ValueError("action must be in {0, 1, 2, 3}")

    if not (0 <= new_row < grid_size and 0 <= new_col < grid_size):
        return s

    sp = pos_to_state(new_row, new_col)

    if sp in wall_states:
        return s

    return sp


def next_state(s, a):
    return move_deterministic(s, a)


def transition_fn(s, a):
    probs = torch.zeros(N, dtype=torch.float64)
    probs[next_state(s, a)] = 1.0
    return probs


def reward_fn(s, a):
    sp = next_state(s, a)

    if sp == goal_grid:
        return 1.0

    return -0.01


mdp = DiscreteMDP(
    states=states,
    actions=actions,
    gamma=gamma,
    x0=x_0,
    reward_fn=reward_fn,
    transition_fn=transition_fn,
    terminal_states=list(terminal_states),
).to(DEVICE)

planner = Planner(mdp)

# %%
def plot_5grid(values=None, policy=None, title="5x5 Grid World"):
    grid_data = np.full((grid_size, grid_size), ".", dtype="<U1")

    for s in wall_states:
        r, c = state_to_pos(s)
        grid_data[r, c] = "#"

    r, c = state_to_pos(x_0)
    grid_data[r, c] = "S"

    r, c = state_to_pos(goal_grid)
    grid_data[r, c] = "G"

    mapping = {".": 0, "#": 1, "S": 2, "G": 3}
    labels = {0: "Empty", 1: "Wall", 2: "Start", 3: "Goal"}
    colors = ["#F5F5F5", "#2C2C2C", "#457B9D", "#2DC653"]

    numeric_grid = np.vectorize(mapping.get)(grid_data)
    cmap = mcolors.ListedColormap(colors)

    fig, ax = plt.subplots(figsize=(7, 7))
    ax.imshow(
        numeric_grid,
        cmap=cmap,
        vmin=0,
        vmax=3,
        interpolation="nearest",
        origin="upper",
    )

    ax.set_xticks(np.arange(-0.5, grid_size, 1), minor=True)
    ax.set_yticks(np.arange(-0.5, grid_size, 1), minor=True)
    ax.grid(which="minor", color="#888888", linewidth=0.8, alpha=0.6)
    ax.tick_params(which="minor", bottom=False, left=False)

    ax.set_xticks(np.arange(grid_size))
    ax.set_yticks(np.arange(grid_size))
    ax.set_xlabel("Column", fontsize=10)
    ax.set_ylabel("Row", fontsize=10)

    if values is not None:
        if hasattr(values, "detach"):
            values = values.detach().cpu().numpy()
        values = np.asarray(values).reshape(-1)

    if policy is not None:
        if hasattr(policy, "detach"):
            policy = policy.detach().cpu().numpy()
        policy = np.asarray(policy)
        best_actions = policy.argmax(axis=1) if policy.ndim == 2 else policy

    arrow_delta = {
        0: (0.0, -0.28),  # Up
        1: (0.0, 0.28),   # Down
        2: (-0.28, 0.0),  # Left
        3: (0.28, 0.0),   # Right
    }

    for s in range(N):
        r, c = state_to_pos(s)

        if s == goal_grid:
            ax.text(c, r, "G", ha="center", va="center", fontsize=14, fontweight="bold", color="white")
        elif s in wall_states:
            ax.text(c, r, "#", ha="center", va="center", fontsize=14, fontweight="bold", color="white")
        elif s == x_0:
            ax.text(c, r, "S", ha="center", va="center", fontsize=14, fontweight="bold", color="white")
        else:
            ax.text(c - 0.38, r - 0.34, str(s), fontsize=8, color="#666666")

        if values is not None and s not in wall_states:
            ax.text(c, r + 0.28, f"{values[s]:.2f}", ha="center", va="center", fontsize=9)

        if policy is not None and s not in terminal_states and s not in wall_states:
            dx, dy = arrow_delta[int(best_actions[s])]
            ax.arrow(
                c,
                r,
                dx,
                dy,
                head_width=0.10,
                head_length=0.10,
                fc="black",
                ec="black",
                linewidth=1.4,
                length_includes_head=True,
                zorder=5,
            )

    patches = [
        mpatches.Patch(color=colors[i], label=f"{symbol}  {labels[i]}")
        for symbol, i in mapping.items()
    ]

    ax.legend(
        handles=patches,
        bbox_to_anchor=(1.02, 1),
        loc="upper left",
        fontsize=9,
        framealpha=0.9,
    )

    ax.set_title(title, fontsize=14, pad=12)
    plt.tight_layout()
    plt.show()


plot_5grid()

# %% [markdown]
# ## Data collection

# %%
# Initialize the clean collector.
# every episode starts from state 0.
collector = DiscreteDataBuffer(
    mdp=mdp,
    reset_probs={"custom": 1.0},
    initial_states=[x_0],              
    restricted_states=wall_states,     
    max_steps=50,
    terminal_states={goal_grid},
    seed=SEED,
)

# Epsilon-greedy around the optimal policy.
# epsilon=0.3 means 70% planner.pi_star, 30% random action.
epsilon_policy = (planner.pi_star, 0.3)

df = collector.collect(
    policies=[epsilon_policy, "random"],
    proportions=[0.9, 0.1],
    n_steps=8000,
    extra_terminal_steps=3,
    episode_based=True,
    save_path=str(dataset_path_5grid),
    verbose=True,
)

df.head()
# Out:
# Collected 8000 transitions over 461 episodes.
# Policy distribution:
# policy_id
# 0    0.746
# 1    0.254
# Name: proportion, dtype: float64
# Reset mode distribution:
# reset_mode
# custom    1.0
# Name: proportion, dtype: float64
# Saved FOGAS dataset to /home/mauro/Desktop/EMAI/Ljubljana/Thesis/Code/data/datasets_clean/generalization/5grid.csv
#    episode  step  state  action  reward  next_state  policy_id reset_mode  \
# 0        0     0      0       1   -0.01           5          0     custom
# 1        0     1      5       1   -0.01          10          0     custom
# 2        0     2     10       3   -0.01          11          0     custom
# 3        0     3     11       1   -0.01          16          0     custom
# 4        0     4     16       1   -0.01          21          0     custom
#
#    restricted_start
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %% [markdown]
# ## Solver

# %%
u_features = TabularFeatures(N, A)
q_features = TabularFeatures(N, A)
policy_features = TabularFeatures(N, A)

solver_e = FinalLinearSolver(
    n_states=N,
    n_actions=A,
    gamma=gamma,
    x0=x_0,
    csv_path=dataset_path_5grid,
    u_function=LinearFunction(u_features),
    q_function=LinearQFunction(q_features),
    policy_features=policy_features,
    seed=SEED,
    device=DEVICE,

    theta_include_beta_cov=False,

    theta_mode="reg_fixed",
    theta_lambda=1e-3,
    theta_optimizer="adam",
    theta_inner_steps=40,
    theta_lr=3e-1,
    theta_start_mode="warm",

    beta_update="fogas_full",
)

solver_e.run(
    alpha=1e-3,
    eta=1e-4,
    rho=0.05,
    policy_optimizer="adam",
    policy_gradient="reinforce",
    reinforce_samples=4,
    tqdm_print=False,
    verbose=True,
    log_interval=50,
    T=1000,
    state_weight_update="normal",
)

mdp.print_policy(solver_e.pi)
# Out:
# [FinalLinearSolver] Iter 1/1000 iter=0 total_loss=-2.334070e-02 policy_objective=-2.334070e-02 beta_objective=0.000000e+00 q_objective=-1.244493e-02 policy_grad_norm=0.000000e+00 policy_direction_norm=0.000000e+00 beta_grad_norm=2.010787e-01 beta_direction_norm=5.251294e+00 theta_grad_norm=3.318592e-04 theta_norm=4.668141e+00 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples
beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 801/1000 iter=800 total_loss=5.110677e-03 policy_objective=-1.437574e-02 beta_objective=1.442442e-02 q_objective=-3.723777e-03 policy_grad_norm=7.985209e-04 policy_direction_norm=7.985209e-04 beta_grad_norm=1.250336e-01 beta_direction_norm=2.434380e+00 theta_grad_norm=1.048374e-04 theta_norm=2.734489e+00 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=4 D_theta=1.000000e+02 effective_D_theta=1.000000e+02 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 851/1000 iter=850 total_loss=6.166242e-03 policy_objective=-1.470780e-02 beta_objective=1.502048e-02 q_objective=-3.618551e-03 policy_grad_norm=4.222205e-04 policy_direction_norm=4.222205e-04 beta_grad_norm=1.260346e-01 beta_direction_norm=2.373230e+00 theta_grad_norm=1.044054e-04 theta_norm=2.693251e+00 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=4 D_theta=1.000000e+02 effective_D_theta=1.000000e+02 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 901/1000 iter=900 total_loss=7.188635e-03 policy_objective=-1.477392e-02 beta_objective=1.594616e-02 q_objective=-3.524618e-03 policy_grad_norm=4.607743e-04 policy_direction_norm=4.607743e-04 beta_grad_norm=1.251261e-01 beta_direction_norm=2.390400e+00 theta_grad_norm=1.050620e-04 theta_norm=2.659823e+00 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=4 D_theta=1.000000e+02 effective_D_theta=1.000000e+02 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 951/1000 iter=950 total_loss=8.184284e-03 policy_objective=-1.519669e-02 beta_objective=1.652266e-02 q_objective=-3.441389e-03 policy_grad_norm=2.543328e-04 policy_direction_norm=2.543328e-04 beta_grad_norm=1.260275e-01 beta_direction_norm=2.337187e+00 theta_grad_norm=1.057260e-04 theta_norm=2.632345e+00 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-03 theta_lr=3.000000e-01 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=reinforce policy_direction=adam_gradient reinforce_samples=4 D_theta=1.000000e+02 effective_D_theta=1.000000e+02 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
#   State 0: pi(a=0|s=0) = 0.13  pi(a=1|s=0) = 0.49  pi(a=2|s=0) = 0.13  pi(a=3|s=0) = 0.26  --> best action: 1
#   State 1: pi(a=0|s=1) = 0.25  pi(a=1|s=1) = 0.25  pi(a=2|s=1) = 0.04  pi(a=3|s=1) = 0.46  --> best action: 3
#   State 2: pi(a=0|s=2) = 0.29  pi(a=1|s=2) = 0.27  pi(a=2|s=2) = 0.04  pi(a=3|s=2) = 0.40  --> best action: 3
#   State 3: pi(a=0|s=3) = 0.24  pi(a=1|s=3) = 0.26  pi(a=2|s=3) = 0.25  pi(a=3|s=3) = 0.24  --> best action: 1
#   State 4: pi(a=0|s=4) = 0.25  pi(a=1|s=4) = 0.26  pi(a=2|s=4) = 0.25  pi(a=3|s=4) = 0.24  --> best action: 1
#   State 5: pi(a=0|s=5) = 0.06  pi(a=1|s=5) = 0.62  pi(a=2|s=5) = 0.16  pi(a=3|s=5) = 0.16  --> best action: 1
#   State 6: pi(a=0|s=6) = 0.25  pi(a=1|s=6) = 0.25  pi(a=2|s=6) = 0.25  pi(a=3|s=6) = 0.25  --> best action: 0
#   State 7: pi(a=0|s=7) = 0.25  pi(a=1|s=7) = 0.25  pi(a=2|s=7) = 0.25  pi(a=3|s=7) = 0.25  --> best action: 0
#   State 8: pi(a=0|s=8) = 0.25  pi(a=1|s=8) = 0.27  pi(a=2|s=8) = 0.23  pi(a=3|s=8) = 0.25  --> best action: 1
#   State 9: pi(a=0|s=9) = 0.25  pi(a=1|s=9) = 0.26  pi(a=2|s=9) = 0.24  pi(a=3|s=9) = 0.25  --> best action: 1
#   State 10: pi(a=0|s=10) = 0.04  pi(a=1|s=10) = 0.52  pi(a=2|s=10) = 0.18  pi(a=3|s=10) = 0.25  --> best action: 1
#   State 11: pi(a=0|s=11) = 0.31  pi(a=1|s=11) = 0.29  pi(a=2|s=11) = 0.10  pi(a=3|s=11) = 0.31  --> best action: 3
#   State 12: pi(a=0|s=12) = 0.25  pi(a=1|s=12) = 0.25  pi(a=2|s=12) = 0.25  pi(a=3|s=12) = 0.25  --> best action: 0
#   State 13: pi(a=0|s=13) = 0.27  pi(a=1|s=13) = 0.21  pi(a=2|s=13) = 0.27  pi(a=3|s=13) = 0.25  --> best action: 2
#   State 14: pi(a=0|s=14) = 0.26  pi(a=1|s=14) = 0.22  pi(a=2|s=14) = 0.26  pi(a=3|s=14) = 0.26  --> best action: 0
#   State 15: pi(a=0|s=15) = 0.08  pi(a=1|s=15) = 0.43  pi(a=2|s=15) = 0.22  pi(a=3|s=15) = 0.27  --> best action: 1
#   State 16: pi(a=0|s=16) = 0.25  pi(a=1|s=16) = 0.27  pi(a=2|s=16) = 0.25  pi(a=3|s=16) = 0.24  --> best action: 1
#   State 17: pi(a=0|s=17) = 0.28  pi(a=1|s=17) = 0.16  pi(a=2|s=17) = 0.30  pi(a=3|s=17) = 0.27  --> best action: 2
#   State 18: pi(a=0|s=18) = 0.09  pi(a=1|s=18) = 0.75  pi(a=2|s=18) = 0.08  pi(a=3|s=18) = 0.08  --> best action: 1
#   State 19: pi(a=0|s=19) = 0.10  pi(a=1|s=19) = 0.70  pi(a=2|s=19) = 0.10  pi(a=3|s=19) = 0.10  --> best action: 1
#   State 20: pi(a=0|s=20) = 0.15  pi(a=1|s=20) = 0.22  pi(a=2|s=20) = 0.23  pi(a=3|s=20) = 0.40  --> best action: 3
#   State 21: pi(a=0|s=21) = 0.23  pi(a=1|s=21) = 0.23  pi(a=2|s=21) = 0.24  pi(a=3|s=21) = 0.30  --> best action: 3
#   State 22: pi(a=0|s=22) = 0.04  pi(a=1|s=22) = 0.05  pi(a=2|s=22) = 0.05  pi(a=3|s=22) = 0.86  --> best action: 3
#   State 23: pi(a=0|s=23) = 0.04  pi(a=1|s=23) = 0.04  pi(a=2|s=23) = 0.04  pi(a=3|s=23) = 0.88  --> best action: 3
#   State 24: pi(a=0|s=24) = 0.66  pi(a=1|s=24) = 0.11  pi(a=2|s=24) = 0.11  pi(a=3|s=24) = 0.12  --> best action: 0

# %% [markdown]
# # 5 stochastic grid

# %%
states = torch.arange(25, dtype=torch.long)
actions = torch.arange(4, dtype=torch.long)

N = len(states)
A = len(actions)
gamma = 0.9
x_0 = 0

dataset_path_5grid_stoch = str(DATASETS_DIR / "5grid_stochastic.csv")

grid_size = 5
goal_grid = 24
pit_grid = 18

wall_states = {6, 7, 12}
terminal_states = {goal_grid, pit_grid}


def state_to_pos(s):
    return divmod(int(s), grid_size)


def pos_to_state(row, col):
    return row * grid_size + col


def move_deterministic(s, a):
    s = int(s)
    a = int(a)

    if s in terminal_states:
        return s

    row, col = state_to_pos(s)

    if a == 0:      # Up
        new_row, new_col = row - 1, col
    elif a == 1:    # Down
        new_row, new_col = row + 1, col
    elif a == 2:    # Left
        new_row, new_col = row, col - 1
    elif a == 3:    # Right
        new_row, new_col = row, col + 1
    else:
        raise ValueError("action must be in {0, 1, 2, 3}")

    if not (0 <= new_row < grid_size and 0 <= new_col < grid_size):
        return s

    sp = pos_to_state(new_row, new_col)

    if sp in wall_states:
        return s

    return sp


def transition_probs(s, a, intended_prob=0.8):
    """
    Stochastic transition:
    intended_prob goes to the requested action.
    The remaining probability is uniform over all actions.
    
    With intended_prob=0.8 and A=4:
      intended action: 0.8 + 0.2 / 4 = 0.85
      other actions:   0.2 / 4 = 0.05 each
    """
    s = int(s)
    a = int(a)

    probs_by_state = {}

    for candidate_a in range(A):
        prob = (1.0 - intended_prob) / A
        if candidate_a == a:
            prob += intended_prob

        sp = move_deterministic(s, candidate_a)
        probs_by_state[sp] = probs_by_state.get(sp, 0.0) + prob

    return probs_by_state


def transition_fn(s, a):
    probs = torch.zeros(N, dtype=torch.float64)

    for sp, prob in transition_probs(s, a).items():
        probs[sp] = prob

    return probs


def next_state(s, a):
    """
    Sample one next state from the stochastic transition.
    Useful for manual rollouts, not used by DiscreteMDP planning.
    """
    probs = transition_fn(s, a)
    return int(torch.multinomial(probs.float(), num_samples=1).item())


def reward_from_next_state(sp):
    sp = int(sp)

    if sp == goal_grid:
        return 1.0

    if sp == pit_grid:
        return -1.0

    return -0.1


def reward_fn(s, a):
    """
    Expected one-step reward under P(. | s, a).
    """
    return sum(
        prob * reward_from_next_state(sp)
        for sp, prob in transition_probs(s, a).items()
    )


mdp = DiscreteMDP(
    states=states,
    actions=actions,
    gamma=gamma,
    x0=x_0,
    reward_fn=reward_fn,
    transition_fn=transition_fn,
    terminal_states=list(terminal_states),
).to(DEVICE)

planner = Planner(mdp)

# %%
def plot_5grid(values=None, policy=None, title="5x5 Grid World"):
    grid_data = np.full((grid_size, grid_size), ".", dtype="<U1")

    for s in wall_states:
        r, c = state_to_pos(s)
        grid_data[r, c] = "#"

    r, c = state_to_pos(pit_grid)
    grid_data[r, c] = "P"

    r, c = state_to_pos(x_0)
    grid_data[r, c] = "S"

    r, c = state_to_pos(goal_grid)
    grid_data[r, c] = "G"

    mapping = {".": 0, "#": 1, "S": 2, "G": 3, "P": 4}
    labels = {0: "Empty", 1: "Wall", 2: "Start", 3: "Goal", 4: "Pit"}
    colors = ["#F5F5F5", "#2C2C2C", "#457B9D", "#2DC653", "#E63946"]

    numeric_grid = np.vectorize(mapping.get)(grid_data)
    cmap = mcolors.ListedColormap(colors)

    fig, ax = plt.subplots(figsize=(7, 7))
    ax.imshow(
        numeric_grid,
        cmap=cmap,
        vmin=0,
        vmax=4,
        interpolation="nearest",
        origin="upper",
    )

    ax.set_xticks(np.arange(-0.5, grid_size, 1), minor=True)
    ax.set_yticks(np.arange(-0.5, grid_size, 1), minor=True)
    ax.grid(which="minor", color="#888888", linewidth=0.8, alpha=0.6)
    ax.tick_params(which="minor", bottom=False, left=False)

    ax.set_xticks(np.arange(grid_size))
    ax.set_yticks(np.arange(grid_size))
    ax.set_xlabel("Column", fontsize=10)
    ax.set_ylabel("Row", fontsize=10)

    if values is not None:
        if hasattr(values, "detach"):
            values = values.detach().cpu().numpy()
        values = np.asarray(values).reshape(-1)

    if policy is not None:
        if hasattr(policy, "detach"):
            policy = policy.detach().cpu().numpy()
        policy = np.asarray(policy)
        best_actions = policy.argmax(axis=1) if policy.ndim == 2 else policy

    arrow_delta = {
        0: (0.0, -0.28),  # Up
        1: (0.0, 0.28),   # Down
        2: (-0.28, 0.0),  # Left
        3: (0.28, 0.0),   # Right
    }

    for s in range(N):
        r, c = state_to_pos(s)

        if s == goal_grid:
            ax.text(c, r, "G", ha="center", va="center", fontsize=14, fontweight="bold", color="white")
        elif s == pit_grid:
            ax.text(c, r, "P", ha="center", va="center", fontsize=14, fontweight="bold", color="white")
        elif s in wall_states:
            ax.text(c, r, "#", ha="center", va="center", fontsize=14, fontweight="bold", color="white")
        elif s == x_0:
            ax.text(c, r, "S", ha="center", va="center", fontsize=14, fontweight="bold", color="white")
        else:
            ax.text(c - 0.38, r - 0.34, str(s), fontsize=8, color="#666666")

        if values is not None and s not in wall_states:
            ax.text(c, r + 0.28, f"{values[s]:.2f}", ha="center", va="center", fontsize=9)

        if policy is not None and s not in terminal_states and s not in wall_states:
            dx, dy = arrow_delta[int(best_actions[s])]
            ax.arrow(
                c,
                r,
                dx,
                dy,
                head_width=0.10,
                head_length=0.10,
                fc="black",
                ec="black",
                linewidth=1.4,
                length_includes_head=True,
                zorder=5,
            )

    patches = [
        mpatches.Patch(color=colors[i], label=f"{symbol}  {labels[i]}")
        for symbol, i in mapping.items()
    ]

    ax.legend(
        handles=patches,
        bbox_to_anchor=(1.02, 1),
        loc="upper left",
        fontsize=9,
        framealpha=0.9,
    )

    ax.set_title(title, fontsize=14, pad=12)
    plt.tight_layout()
    plt.show()


plot_5grid()

# %% [markdown]
# ## Data

# %%
# Initialize the clean collector.
# every episode starts from state 0.
collector = DiscreteDataBuffer(
    mdp=mdp,
    reset_probs={"occupancy": 1.0},
    occupancy=planner.mu_star,          # shape N*A is accepted
    restricted_states=wall_states,
    max_steps=50,
    terminal_states={goal_grid},
    seed=SEED,
)

# Epsilon-greedy around the optimal policy.
# epsilon=0.3 means 70% planner.pi_star, 30% random action.
epsilon_policy = (planner.pi_star, 0.3)

df = collector.collect(
    policies=[epsilon_policy, "random"],
    proportions=[0.7, 0.3],
    n_steps=8000,
    extra_terminal_steps=3,
    episode_based=True,
    save_path=str(dataset_path_5grid_stoch),
    verbose=True,
)

df.head()
# Out:
# Collected 8000 transitions over 460 episodes.
# Policy distribution:
# policy_id
# 0    0.40425
# 1    0.59575
# Name: proportion, dtype: float64
# Reset mode distribution:
# reset_mode
# occupancy    1.0
# Name: proportion, dtype: float64
# Saved FOGAS dataset to /home/mauro/Desktop/EMAI/Ljubljana/Thesis/Code/data/datasets_clean/generalization/5grid_stochastic.csv
#    episode  step  state  action  reward  next_state  policy_id reset_mode  \
# 0        0     0     15       0   -0.01          10          1  occupancy
# 1        0     1     10       2   -0.01          10          1  occupancy
# 2        0     2     10       2   -0.01          10          1  occupancy
# 3        0     3     10       3   -0.01          11          1  occupancy
# 4        0     4     11       3   -0.01          11          1  occupancy
#
#    restricted_start
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %% [markdown]
# ## Solver

# %%
u_features = TabularFeatures(N, A)
q_features = TabularFeatures(N, A)
policy_features = TabularFeatures(N, A)

solver_e = FinalLinearSolver(
    n_states=N,
    n_actions=A,
    gamma=gamma,
    x0=x_0,
    csv_path=dataset_path_5grid_stoch,
    u_function=LinearFunction(u_features),
    q_function=LinearQFunction(q_features),
    policy_features=policy_features,
    seed=SEED,
    device=DEVICE,

    theta_include_beta_cov=False,

    theta_mode="reg_fixed",
    theta_lambda=1e-4,
    theta_optimizer="adam",
    theta_inner_steps=40,
    theta_lr=3e-2,
    theta_start_mode="warm",

    beta_update="fogas_full",
)

solver_e.run(
    alpha=1e-3,
    eta=1e-4,
    rho=1.0,
    policy_optimizer="adam",
    policy_gradient="exact",
    reinforce_samples=4,
    tqdm_print=False,
    verbose=True,
    log_interval=50,
    T=1000,
    state_weight_update="normal",
)

mdp.print_policy(solver_e.pi)
# Out:
# [FinalLinearSolver] Iter 1/1000 iter=0 total_loss=-1.199404e-01 policy_objective=-1.199404e-01 beta_objective=0.000000e+00 q_objective=-1.196527e-01 policy_grad_norm=0.000000e+00 policy_direction_norm=0.000000e+00 beta_grad_norm=1.198970e-01 beta_direction_norm=3.351366e+00 theta_grad_norm=4.976012e-02 theta_norm=2.398809e+00 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=3.162278e+01 effective_D_theta=3.162278e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 51/1000 iter=50 total_loss=-5.833368e+00 policy_objective=-6.037225e+00 beta_objective=2.830666e-01 q_objective=-5.060818e+00 policy_grad_norm=5.043377e-03 policy_direction_norm=5.043377e-03 beta_grad_norm=1.144553e+00 beta_direction_norm=9.901879e+01 theta_grad_norm=3.505194e-02 theta_norm=1.243467e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=3.162278e+01 effective_D_theta=3.162278e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 101/1000 iter=100 total_loss=-1.029220e+01 policy_objective=-1.171465e+01 beta_objective=1.818161e+00 q_objective=-7.086161e+00 policy_grad_norm=5.058806e-02 policy_direction_norm=5.058806e-02 beta_grad_norm=2.036082e+00 beta_direction_norm=1.751047e+02 theta_grad_norm=1.604919e-02 theta_norm=2.532582e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=3.162278e+01 effective_D_theta=3.162278e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 151/1000 iter=150 total_loss=-1.130236e+01 policy_objective=-1.446804e+01 beta_objective=3.628626e+00 q_objective=-5.639658e+00 policy_grad_norm=7.095038e-01 policy_direction_norm=7.095038e-01 beta_grad_norm=2.013084e+00 beta_direction_norm=1.781351e+02 theta_grad_norm=1.787842e-04 theta_norm=3.365718e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=3.162278e+01 effective_D_theta=3.162278e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter
+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
#   State 0: pi(a=0|s=0) = 0.11  pi(a=1|s=0) = 0.46  pi(a=2|s=0) = 0.12  pi(a=3|s=0) = 0.30  --> best action: 1
#   State 1: pi(a=0|s=1) = 0.20  pi(a=1|s=1) = 0.20  pi(a=2|s=1) = 0.07  pi(a=3|s=1) = 0.54  --> best action: 3
#   State 2: pi(a=0|s=2) = 0.22  pi(a=1|s=2) = 0.22  pi(a=2|s=2) = 0.02  pi(a=3|s=2) = 0.54  --> best action: 3
#   State 3: pi(a=0|s=3) = 0.20  pi(a=1|s=3) = 0.42  pi(a=2|s=3) = 0.01  pi(a=3|s=3) = 0.36  --> best action: 1
#   State 4: pi(a=0|s=4) = 0.29  pi(a=1|s=4) = 0.41  pi(a=2|s=4) = 0.01  pi(a=3|s=4) = 0.29  --> best action: 1
#   State 5: pi(a=0|s=5) = 0.07  pi(a=1|s=5) = 0.62  pi(a=2|s=5) = 0.15  pi(a=3|s=5) = 0.15  --> best action: 1
#   State 6: pi(a=0|s=6) = 0.25  pi(a=1|s=6) = 0.25  pi(a=2|s=6) = 0.25  pi(a=3|s=6) = 0.25  --> best action: 0
#   State 7: pi(a=0|s=7) = 0.25  pi(a=1|s=7) = 0.25  pi(a=2|s=7) = 0.25  pi(a=3|s=7) = 0.25  --> best action: 0
#   State 8: pi(a=0|s=8) = 0.01  pi(a=1|s=8) = 0.43  pi(a=2|s=8) = 0.23  pi(a=3|s=8) = 0.33  --> best action: 1
#   State 9: pi(a=0|s=9) = 0.06  pi(a=1|s=9) = 0.54  pi(a=2|s=9) = 0.06  pi(a=3|s=9) = 0.35  --> best action: 1
#   State 10: pi(a=0|s=10) = 0.03  pi(a=1|s=10) = 0.53  pi(a=2|s=10) = 0.11  pi(a=3|s=10) = 0.33  --> best action: 1
#   State 11: pi(a=0|s=11) = 0.20  pi(a=1|s=11) = 0.56  pi(a=2|s=11) = 0.02  pi(a=3|s=11) = 0.21  --> best action: 1
#   State 12: pi(a=0|s=12) = 0.25  pi(a=1|s=12) = 0.25  pi(a=2|s=12) = 0.25  pi(a=3|s=12) = 0.25  --> best action: 0
#   State 13: pi(a=0|s=13) = 0.05  pi(a=1|s=13) = 0.54  pi(a=2|s=13) = 0.18  pi(a=3|s=13) = 0.24  --> best action: 1
#   State 14: pi(a=0|s=14) = 0.10  pi(a=1|s=14) = 0.68  pi(a=2|s=14) = 0.10  pi(a=3|s=14) = 0.12  --> best action: 1
#   State 15: pi(a=0|s=15) = 0.02  pi(a=1|s=15) = 0.53  pi(a=2|s=15) = 0.12  pi(a=3|s=15) = 0.33  --> best action: 1
#   State 16: pi(a=0|s=16) = 0.02  pi(a=1|s=16) = 0.40  pi(a=2|s=16) = 0.02  pi(a=3|s=16) = 0.57  --> best action: 3
#   State 17: pi(a=0|s=17) = 0.13  pi(a=1|s=17) = 0.49  pi(a=2|s=17) = 0.01  pi(a=3|s=17) = 0.36  --> best action: 1
#   State 18: pi(a=0|s=18) = 0.05  pi(a=1|s=18) = 0.78  pi(a=2|s=18) = 0.03  pi(a=3|s=18) = 0.15  --> best action: 1
#   State 19: pi(a=0|s=19) = 0.04  pi(a=1|s=19) = 0.88  pi(a=2|s=19) = 0.04  pi(a=3|s=19) = 0.04  --> best action: 1
#   State 20: pi(a=0|s=20) = 0.06  pi(a=1|s=20) = 0.18  pi(a=2|s=20) = 0.17  pi(a=3|s=20) = 0.59  --> best action: 3
#   State 21: pi(a=0|s=21) = 0.18  pi(a=1|s=21) = 0.16  pi(a=2|s=21) = 0.21  pi(a=3|s=21) = 0.45  --> best action: 3
#   State 22: pi(a=0|s=22) = 0.02  pi(a=1|s=22) = 0.07  pi(a=2|s=22) = 0.02  pi(a=3|s=22) = 0.89  --> best action: 3
#   State 23: pi(a=0|s=23) = 0.04  pi(a=1|s=23) = 0.06  pi(a=2|s=23) = 0.04  pi(a=3|s=23) = 0.85  --> best action: 3
#   State 24: pi(a=0|s=24) = 0.62  pi(a=1|s=24) = 0.12  pi(a=2|s=24) = 0.13  pi(a=3|s=24) = 0.13  --> best action: 0

# %% [markdown]
# # 10 grid

# %%
states = torch.arange(100, dtype=torch.long)
actions = torch.arange(4, dtype=torch.long)

N = len(states)
A = len(actions)
gamma = 0.9
x_0 = 0

dataset_path_10grid = str(DATASETS_DIR / "10grid_tabular.csv")
dataset_path_10grid_prueba = str(DATASETS_DIR / "10grid_tabular_prueba.csv")

grid_size = 10
goal_grid = 99

pit_grids = {18, 32, 57, 61, 75}

wall_states = {
    4, 11, 14, 17, 21, 22, 27, 34, 37,
    40, 42, 43, 44, 45, 46, 47, 49,
    54, 62, 64, 66, 72, 76, 82, 84, 86, 87, 94
}

terminal_states = {goal_grid, *pit_grids}


def state_to_pos(s):
    return divmod(int(s), grid_size)


def pos_to_state(row, col):
    return row * grid_size + col


def move_deterministic(s, a):
    s = int(s)
    a = int(a)

    if s in terminal_states:
        return s

    row, col = state_to_pos(s)

    if a == 0:      # Up
        new_row, new_col = row - 1, col
    elif a == 1:    # Down
        new_row, new_col = row + 1, col
    elif a == 2:    # Left
        new_row, new_col = row, col - 1
    elif a == 3:    # Right
        new_row, new_col = row, col + 1
    else:
        raise ValueError("action must be in {0, 1, 2, 3}")

    if not (0 <= new_row < grid_size and 0 <= new_col < grid_size):
        return s

    sp = pos_to_state(new_row, new_col)

    if sp in wall_states:
        return s

    return sp


def transition_probs(s, a, intended_prob=0.8):
    probs_by_state = {}

    for candidate_a in range(A):
        prob = (1.0 - intended_prob) / A

        if candidate_a == int(a):
            prob += intended_prob

        sp = move_deterministic(s, candidate_a)
        probs_by_state[sp] = probs_by_state.get(sp, 0.0) + prob

    return probs_by_state


def transition_fn(s, a):
    probs = torch.zeros(N, dtype=torch.float64)

    for sp, prob in transition_probs(s, a).items():
        probs[sp] = prob

    return probs


def next_state(s, a):
    """
    Sample one next state from the stochastic transition.
    Useful for manual rollouts, not used by DiscreteMDP planning.
    """
    probs = transition_fn(s, a)
    return int(torch.multinomial(probs.float(), num_samples=1).item())


def reward_from_next_state(sp):
    sp = int(sp)

    if sp == goal_grid:
        return 1.0

    if sp in pit_grids:
        return -5.0

    return -0.1


def reward_fn(s, a):
    """
    Expected one-step reward under P(. | s, a).
    """
    if int(s) in terminal_states:
        return 0.0

    return sum(
        prob * reward_from_next_state(sp)
        for sp, prob in transition_probs(s, a).items()
    )


mdp = DiscreteMDP(
    states=states,
    actions=actions,
    gamma=gamma,
    x0=x_0,
    reward_fn=reward_fn,
    transition_fn=transition_fn,
    terminal_states=list(terminal_states),
).to(DEVICE)

planner = Planner(mdp)

# %%
from matplotlib.colors import BoundaryNorm, ListedColormap
from matplotlib.patches import Patch

def plot_four_rooms_grid(
    grid_size=10,
    start=0,
    goal=99,
    pits=None,
    walls=None,
    centers=None,
    show_state_ids=True,
    figsize=(6.5, 6.5),
    save_path=None,
):
    pits = set(pits or [])
    walls = set(walls or [])

    # Codes:
    # 0 = free, 1 = wall, 2 = pit, 3 = start, 4 = goal
    grid = np.zeros((grid_size, grid_size), dtype=int)

    for s in walls:
        r, c = divmod(int(s), grid_size)
        grid[r, c] = 1

    for s in pits:
        r, c = divmod(int(s), grid_size)
        grid[r, c] = 2

    sr, sc = divmod(int(start), grid_size)
    gr, gc = divmod(int(goal), grid_size)
    grid[sr, sc] = 3
    grid[gr, gc] = 4

    cmap = ListedColormap([
        "#ffffff",  # free
        "#2f2f2f",  # wall
        "#d95f5f",  # pit
        "#4c78a8",  # start
        "#59a14f",  # goal
    ])
    norm = BoundaryNorm(np.arange(-0.5, 5.5, 1), cmap.N)

    fig, ax = plt.subplots(figsize=figsize)
    ax.imshow(grid, cmap=cmap, norm=norm)

    # Grid lines
    ax.set_xticks(np.arange(-0.5, grid_size, 1), minor=True)
    ax.set_yticks(np.arange(-0.5, grid_size, 1), minor=True)
    ax.grid(which="minor", color="#9a9a9a", linewidth=0.8)

    # Axis ticks
    ax.set_xticks(np.arange(grid_size))
    ax.set_yticks(np.arange(grid_size))
    ax.set_xlabel("Column")
    ax.set_ylabel("Row")

    # Put row 0 at the top, matching divmod indexing
    ax.set_xlim(-0.5, grid_size - 0.5)
    ax.set_ylim(grid_size - 0.5, -0.5)

    if show_state_ids:
        for s in range(grid_size * grid_size):
            r, c = divmod(s, grid_size)

            if s in walls:
                color = "white"
            elif s in pits or s == start or s == goal:
                color = "white"
            else:
                color = "#333333"

            ax.text(
                c,
                r,
                str(s),
                ha="center",
                va="center",
                fontsize=8,
                color=color,
            )

    # Optional: plot k-means/RBF centers if passed in normalized coordinates
    if centers is not None:
        centers_np = centers.detach().cpu().numpy() if hasattr(centers, "detach") else np.asarray(centers)

        # Your centers are [row_normalized, col_normalized]
        rows = centers_np[:, 0] * (grid_size - 1)
        cols = centers_np[:, 1] * (grid_size - 1)

        ax.scatter(
            cols,
            rows,
            s=45,
            marker="x",
            linewidths=1.8,
            color="#f28e2b",
            label="RBF centers",
            zorder=5,
        )

    legend_items = [
        Patch(facecolor="#ffffff", edgecolor="#9a9a9a", label="Free state"),
        Patch(facecolor="#2f2f2f", label="Wall"),
        Patch(facecolor="#d95f5f", label="Pit"),
        Patch(facecolor="#4c78a8", label="Start"),
        Patch(facecolor="#59a14f", label="Goal"),
    ]

    ax.legend(
        handles=legend_items,
        loc="upper center",
        bbox_to_anchor=(0.5, -0.08),
        ncol=3,
        frameon=False,
    )

    ax.set_title("10x10 Four-Rooms Gridworld")
    fig.tight_layout()

    if save_path is not None:
        fig.savefig(save_path, dpi=300, bbox_inches="tight")

    return fig, ax

fig, ax = plot_four_rooms_grid(
    grid_size=10,
    start=0,
    goal=99,
    pits=pit_grids,
    walls=wall_states,
)

plt.show()

# %% [markdown]
# ## Solver

# %%
u_features = TabularFeatures(N, A)
q_features = TabularFeatures(N, A)
policy_features = TabularFeatures(N, A)

solver_e = FinalLinearSolver(
    n_states=N,
    n_actions=A,
    gamma=gamma,
    x0=x_0,
    csv_path=dataset_path_10grid,
    u_function=LinearFunction(u_features),
    q_function=LinearQFunction(q_features),
    policy_features=policy_features,
    seed=SEED,
    device=DEVICE,

    theta_include_beta_cov=False,

    theta_mode="reg_fixed",
    theta_lambda=5e-4,
    theta_optimizer="adam",
    theta_inner_steps=40,
    theta_lr=3e-2,
    theta_start_mode="warm",

    beta_update="fogas_full",
)

solver_e.run(
    alpha=2e-3,
    eta=1e-4,
    rho=1.0,
    policy_optimizer="adam",
    policy_gradient="exact",
    reinforce_samples=4,
    tqdm_print=False,
    verbose=True,
    log_interval=50,
    T=1000,
    state_weight_update="normal",
)

evaluator_e = FOGASEvaluator(
    solver=solver_e,
    mdp=mdp,
    planner=planner,      # optional; omit if you do not have planner
)

evaluator_e.print_solver_policy(policy_mode="solver")

evaluator_e.print_optimal_path(
    policy_mode="greedy",
    max_steps=50,
    seed=SEED,
    goal_state=99,
    terminal_states=99,
    show_value_info=False,  # set True only if evaluator has planner
)
# Out:
# [FinalLinearSolver] Iter 1/1000 iter=0 total_loss=-1.196999e-01 policy_objective=-1.196999e-01 beta_objective=0.000000e+00 q_objective=-1.182671e-01 policy_grad_norm=0.000000e+00 policy_direction_norm=0.000000e+00 beta_grad_norm=8.974382e-02 beta_direction_norm=2.025931e+01 theta_grad_norm=4.880300e-02 theta_norm=2.393999e+00 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 51/1000 iter=50 total_loss=-4.203149e+00 policy_objective=-4.504972e+00 beta_objective=3.661087e-01 q_objective=-2.103285e+00 policy_grad_norm=3.822667e-02 policy_direction_norm=3.822667e-02 beta_grad_norm=1.664996e+00 beta_direction_norm=8.415609e+01 theta_grad_norm=1.149815e-05 theta_norm=9.172464e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 101/1000 iter=100 total_loss=-3.288836e+00 policy_objective=-3.900551e+00 beta_objective=6.950578e-01 q_objective=-1.647355e+00 policy_grad_norm=2.847507e-02 policy_direction_norm=2.847507e-02 beta_grad_norm=1.339500e+00 beta_direction_norm=6.844253e+01 theta_grad_norm=1.282848e-05 theta_norm=8.119402e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 151/1000 iter=150 total_loss=-2.688927e+00 policy_objective=-3.470073e+00 beta_objective=8.292506e-01 q_objective=-1.349544e+00 policy_grad_norm=2.376582e-02 policy_direction_norm=2.376582e-02 beta_grad_norm=1.095202e+00 beta_direction_norm=5.718382e+01 theta_grad_norm=1.108214e-05 theta_norm=7.346301e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 201/1000 iter=200 total_loss=-2.280334e+00 policy_objective=-3.155529e+00 beta_objective=8.664625e-01 q_objective=-1.146823e+00 policy_grad_norm=1.992930e-02 policy_direction_norm=1.992930e-02 beta_grad_norm=9.157243e-01 beta_direction_norm=4.910499e+01 theta_grad_norm=9.631281e-06 theta_norm=6.772235e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter
+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 701/1000 iter=700 total_loss=-1.037284e+00 policy_objective=-2.060167e+00 beta_objective=5.991614e-01 q_objective=-5.421975e-01 policy_grad_norm=5.116715e-03 policy_direction_norm=5.116715e-03 beta_grad_norm=3.526416e-01 beta_direction_norm=2.701718e+01 theta_grad_norm=9.183412e-06 theta_norm=4.657249e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 751/1000 iter=750 total_loss=-9.906156e-01 policy_objective=-2.019476e+00 beta_objective=5.863710e-01 q_objective=-5.205730e-01 policy_grad_norm=4.628059e-03 policy_direction_norm=4.628059e-03 beta_grad_norm=3.359710e-01 beta_direction_norm=2.652558e+01 theta_grad_norm=9.263160e-06 theta_norm=4.563399e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 801/1000 iter=800 total_loss=-9.481325e-01 policy_objective=-1.983101e+00 beta_objective=5.759063e-01 q_objective=-5.010352e-01 policy_grad_norm=4.199754e-03 policy_direction_norm=4.199754e-03 beta_grad_norm=3.214074e-01 beta_direction_norm=2.609596e+01 theta_grad_norm=8.878595e-06 theta_norm=4.476923e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 851/1000 iter=850 total_loss=-9.091852e-01 policy_objective=-1.950330e+00 beta_objective=5.673692e-01 q_objective=-4.832608e-01 policy_grad_norm=3.822376e-03 policy_direction_norm=3.822376e-03 beta_grad_norm=3.085528e-01 beta_direction_norm=2.571731e+01 theta_grad_norm=9.631017e-06 theta_norm=4.396767e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 901/1000 iter=900 total_loss=-8.732711e-01 policy_objective=-1.920581e+00 beta_objective=5.604048e-01 q_objective=-4.669981e-01 policy_grad_norm=3.488112e-03 policy_direction_norm=3.488112e-03 beta_grad_norm=2.971362e-01 beta_direction_norm=2.537507e+01 theta_grad_norm=9.514227e-06 theta_norm=4.322120e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 951/1000 iter=950 total_loss=-8.399563e-01 policy_objective=-1.893295e+00 beta_objective=5.546061e-01 q_objective=-4.520463e-01 policy_grad_norm=3.191709e-03 policy_direction_norm=3.191709e-03 beta_grad_norm=2.868954e-01 beta_direction_norm=2.506626e+01 theta_grad_norm=9.321775e-06 theta_norm=4.252173e+01 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-04 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
#   State 0: pi(a=0|s=0) = 0.10  pi(a=1|s=0) = 0.26  pi(a=2|s=0) = 0.10  pi(a=3|s=0) = 0.54  --> best action: 3
#   State 1: pi(a=0|s=1) = 0.15  pi(a=1|s=1) = 0.16  pi(a=2|s=1) = 0.02  pi(a=3|s=1) = 0.67  --> best action: 3
#   State 2: pi(a=0|s=2) = 0.17  pi(a=1|s=2) = 0.55  pi(a=2|s=2) = 0.00  pi(a=3|s=2) = 0.27  --> best action: 1
#   State 3: pi(a=0|s=3) = 0.32  pi(a=1|s=3) = 0.35  pi(a=2|s=3) = 0.00  pi(a=3|s=3) = 0.32  --> best action: 1
#   State 4: pi(a=0|s=4) = 0.25  pi(a=1|s=4) = 0.25  pi(a=2|s=4) = 0.25  pi(a=3|s=4) = 0.25  --> best action: 0
#   State 5: pi(a=0|s=5) = 0.08  pi(a=1|s=5) = 0.10  pi(a=2|s=5) = 0.09  pi(a=3|s=5) = 0.74  --> best action: 3
#   State 6: pi(a=0|s=6) = 0.06  pi(a=1|s=6) = 0.06  pi(a=2|s=6) = 0.05  pi(a=3|s=6) = 0.83  --> best action: 3
#   State 7: pi(a=0|s=7) = 0.03  pi(a=1|s=7) = 0.06  pi(a=2|s=7) = 0.06  pi(a=3|s=7) = 0.85  --> best action: 3
#   State 8: pi(a=0|s=8) = 0.04  pi(a=1|s=8) = 0.27  pi(a=2|s=8) = 0.03  pi(a=3|s=8) = 0.66  --> best action: 3
#   State 9: pi(a=0|s=9) = 0.03  pi(a=1|s=9) = 0.89  pi(a=2|s=9) = 0.05  pi(a=3|s=9) = 0.04  --> best action: 1
#   State 10: pi(a=0|s=10) = 0.01  pi(a=1|s=10) = 0.46  pi(a=2|s=10) = 0.27  pi(a=3|s=10) = 0.27  --> best action: 1
#   State 11: pi(a=0|s=11) = 0.25  pi(a=1|s=11) = 0.25  pi(a=2|s=11) = 0.25  pi(a=3|s=11) = 0.25  --> best action: 0
#   State 12: pi(a=0|s=12) = 0.02  pi(a=1|s=12) = 0.21  pi(a=2|s=12) = 0.21  pi(a=3|s=12) = 0.56  --> best action: 3
#   State 13: pi(a=0|s=13) = 0.23  pi(a=1|s=13) = 0.50  pi(a=2|s=13) = 0.02  pi(a=3|s=13) = 0.25  --> best action: 1
#   State 14: pi(a=0|s=14) = 0.25  pi(a=1|s=14) = 0.25  pi(a=2|s=14) = 0.25  pi(a=3|s=14) = 0.25  --> best action: 0
#   State 15: pi(a=0|s=15) = 0.10  pi(a=1|s=15) = 0.06  pi(a=2|s=15) = 0.08  pi(a=3|s=15) = 0.76  --> best action: 3
#   State 16: pi(a=0|s=16) = 0.83  pi(a=1|s=16) = 0.05  pi(a=2|s=16) = 0.06  pi(a=3|s=16) = 0.06  --> best action: 0
#   State 17: pi(a=0|s=17) = 0.25  pi(a=1|s=17) = 0.25  pi(a=2|s=17) = 0.25  pi(a=3|s=17) = 0.25  --> best action: 0
#   State 18: pi(a=0|s=18) = 0.78  pi(a=1|s=18) = 0.06  pi(a=2|s=18) = 0.12  pi(a=3|s=18) = 0.05  --> best action: 0
#   State 19: pi(a=0|s=19) = 0.05  pi(a=1|s=19) = 0.72  pi(a=2|s=19) = 0.18  pi(a=3|s=19) = 0.05  --> best action: 1
#   State 20: pi(a=0|s=20) = 0.00  pi(a=1|s=20) = 0.40  pi(a=2|s=20) = 0.30  pi(a=3|s=20) = 0.30  --> best action: 1
#   State 21: pi(a=0|s=21) = 0.25  pi(a=1|s=21) = 0.25  pi(a=2|s=21) = 0.25  pi(a=3|s=21) = 0.25  --> best action: 0
#   State 22: pi(a=0|s=22) = 0.25  pi(a=1|s=22) = 0.25  pi(a=2|s=22) = 0.25  pi(a=3|s=22) = 0.25  --> best action: 0
#   State 23: pi(a=0|s=23) = 0.10  pi(a=1|s=23) = 0.07  pi(a=2|s=23) = 0.08  pi(a=3|s=23) = 0.75  --> best action: 3
#   State 24: pi(a=0|s=24) = 0.02  pi(a=1|s=24) = 0.03  pi(a=2|s=24) = 0.08  pi(a=3|s=24) = 0.87  --> best action: 3
#   State 25: pi(a=0|s=25) = 0.86  pi(a=1|s=25) = 0.05  pi(a=2|s=25) = 0.05  pi(a=3|s=25) = 0.04  --> best action: 0
#   State 26: pi(a=0|s=26) = 0.79  pi(a=1|s=26) = 0.08  pi(a=2|s=26) = 0.07  pi(a=3|s=26) = 0.05  --> best action: 0
#   State 27: pi(a=0|s=27) = 0.25  pi(a=1|s=27) = 0.25  pi(a=2|s=27) = 0.25  pi(a=3|s=27) = 0.25  --> best action: 0
#   State 28: pi(a=0|s=28) = 0.15  pi(a=1|s=28) = 0.76  pi(a=2|s=28) = 0.05  pi(a=3|s=28) = 0.05  --> best action: 1
#   State 29: pi(a=0|s=29) = 0.05  pi(a=1|s=29) = 0.86  pi(a=2|s=29) = 0.05  pi(a=3|s=29) = 0.04  --> best action: 1
#   State 30: pi(a=0|s=30) = 0.07  pi(a=1|s=30) = 0.31  pi(a=2|s=30) = 0.26  pi(a=3|s=30) = 0.37  --> best action: 3
#   State 31: pi(a=0|s=31) = 0.10  pi(a=1|s=31) = 0.08  pi(a=2|s=31) = 0.33  pi(a=3|s=31) = 0.49  --> best action: 3
#   State 32: pi(a=0|s=32) = 0.27  pi(a=1|s=32) = 0.14  pi(a=2|s=32) = 0.32  pi(a=3|s=32) = 0.27  --> best action: 2
#   State 33: pi(a=0|s=33) = 0.65  pi(a=1|s=33) = 0.07  pi(a=2|s=33) = 0.17  pi(a=3|s=33) = 0.11  --> best action: 0
#   State 34: pi(a=0|s=34) = 0.25  pi(a=1|s=34) = 0.25  pi(a=2|s=34) = 0.25  pi(a=3|s=34) = 0.25  --> best action: 0
#   State 35: pi(a=0|s=35) = 0.69  pi(a=1|s=35) = 0.12  pi(a=2|s=35) = 0.10  pi(a=3|s=35) = 0.09  --> best action: 0
#   State 36: pi(a=0|s=36) = 0.46  pi(a=1|s=36) = 0.18  pi(a=2|s=36) = 0.18  pi(a=3|s=36) = 0.18  --> best action: 0
#   State 37: pi(a=0|s=37) = 0.25  pi(a=1|s=37) = 0.25  pi(a=2|s=37) = 0.25  pi(a=3|s=37) = 0.25  --> best action: 0
#   State 38: pi(a=0|s=38) = 0.06  pi(a=1|s=38) = 0.80  pi(a=2|s=38) = 0.09  pi(a=3|s=38) = 0.04  --> best action: 1
#   State 39: pi(a=0|s=39) = 0.05  pi(a=1|s=39) = 0.04  pi(a=2|s=39) = 0.81  pi(a=3|s=39) = 0.10  --> best action: 2
#   State 40: pi(a=0|s=40) = 0.25  pi(a=1|s=40) = 0.25  pi(a=2|s=40) = 0.25  pi(a=3|s=40) = 0.25  --> best action: 0
#   State 41: pi(a=0|s=41) = 0.18  pi(a=1|s=41) = 0.37  pi(a=2|s=41) = 0.23  pi(a=3|s=41) = 0.23  --> best action: 1
#   State 42: pi(a=0|s=42) = 0.25  pi(a=1|s=42) = 0.25  pi(a=2|s=42) = 0.25  pi(a=3|s=42) = 0.25  --> best action: 0
#   State 43: pi(a=0|s=43) = 0.25  pi(a=1|s=43) = 0.25  pi(a=2|s=43) = 0.25  pi(a=3|s=43) = 0.25  --> best action: 0
#   State 44: pi(a=0|s=44) = 0.25  pi(a=1|s=44) = 0.25  pi(a=2|s=44) = 0.25  pi(a=3|s=44) = 0.25  --> best action: 0
#   State 45: pi(a=0|s=45) = 0.25  pi(a=1|s=45) = 0.25  pi(a=2|s=45) = 0.25  pi(a=3|s=45) = 0.25  --> best action: 0
#   State 46: pi(a=0|s=46) = 0.25  pi(a=1|s=46) = 0.25  pi(a=2|s=46) = 0.25  pi(a=3|s=46) = 0.25  --> best action: 0
#   State 47: pi(a=0|s=47) = 0.25  pi(a=1|s=47) = 0.25  pi(a=2|s=47) = 0.25  pi(a=3|s=47) = 0.25  --> best action: 0
#   State 48: pi(a=0|s=48) = 0.06  pi(a=1|s=48) = 0.81  pi(a=2|s=48) = 0.05  pi(a=3|s=48) = 0.09  --> best action: 1
#   State 49: pi(a=0|s=49) = 0.25  pi(a=1|s=49) = 0.25  pi(a=2|s=49) = 0.25  pi(a=3|s=49) = 0.25  --> best action: 0
#   State 50: pi(a=0|s=50) = 0.29  pi(a=1|s=50) = 0.29  pi(a=2|s=50) = 0.21  pi(a=3|s=50) = 0.21  --> best action: 1
#   State 51: pi(a=0|s=51) = 0.26  pi(a=1|s=51) = 0.22  pi(a=2|s=51) = 0.26  pi(a=3|s=51) = 0.26  --> best action: 0
#   State 52: pi(a=0|s=52) = 0.42  pi(a=1|s=52) = 0.21  pi(a=2|s=52) = 0.21  pi(a=3|s=52) = 0.17  --> best action: 0
#   State 53: pi(a=0|s=53) = 0.25  pi(a=1|s=53) = 0.25  pi(a=2|s=53) = 0.26  pi(a=3|s=53) = 0.25  --> best action: 2
#   State 54: pi(a=0|s=54) = 0.25  pi(a=1|s=54) = 0.25  pi(a=2|s=54) = 0.25  pi(a=3|s=54) = 0.25  --> best action: 0
#   State 55: pi(a=0|s=55) = 0.25  pi(a=1|s=55) = 0.25  pi(a=2|s=55) = 0.25  pi(a=3|s=55) = 0.25  --> best action: 0
#   State 56: pi(a=0|s=56) = 0.25  pi(a=1|s=56) = 0.25  pi(a=2|s=56) = 0.25  pi(a=3|s=56) = 0.25  --> best action: 0
#   State 57: pi(a=0|s=57) = 0.81  pi(a=1|s=57) = 0.03  pi(a=2|s=57) = 0.05  pi(a=3|s=57) = 0.11  --> best action: 0
#   State 58: pi(a=0|s=58) = 0.06  pi(a=1|s=58) = 0.76  pi(a=2|s=58) = 0.13  pi(a=3|s=58) = 0.05  --> best action: 1
#   State 59: pi(a=0|s=59) = 0.10  pi(a=1|s=59) = 0.71  pi(a=2|s=59) = 0.09  pi(a=3|s=59) = 0.10  --> best action: 1
#   State 60: pi(a=0|s=60) = 0.23  pi(a=1|s=60) = 0.25  pi(a=2|s=60) = 0.23  pi(a=3|s=60) = 0.29  --> best action: 3
#   State 61: pi(a=0|s=61) = 0.34  pi(a=1|s=61) = 0.22  pi(a=2|s=61) = 0.34  pi(a=3|s=61) = 0.10  --> best action: 0
#   State 62: pi(a=0|s=62) = 0.25  pi(a=1|s=62) = 0.25  pi(a=2|s=62) = 0.25  pi(a=3|s=62) = 0.25  --> best action: 0
#   State 63: pi(a=0|s=63) = 0.25  pi(a=1|s=63) = 0.25  pi(a=2|s=63) = 0.25  pi(a=3|s=63) = 0.25  --> best action: 0
#   State 64: pi(a=0|s=64) = 0.25  pi(a=1|s=64) = 0.25  pi(a=2|s=64) = 0.25  pi(a=3|s=64) = 0.25  --> best action: 0
#   State 65: pi(a=0|s=65) = 0.25  pi(a=1|s=65) = 0.25  pi(a=2|s=65) = 0.25  pi(a=3|s=65) = 0.25  --> best action: 0
#   State 66: pi(a=0|s=66) = 0.25  pi(a=1|s=66) = 0.25  pi(a=2|s=66) = 0.25  pi(a=3|s=66) = 0.25  --> best action: 0
#   State 67: pi(a=0|s=67) = 0.10  pi(a=1|s=67) = 0.63  pi(a=2|s=67) = 0.11  pi(a=3|s=67) = 0.16  --> best action: 1
#   State 68: pi(a=0|s=68) = 0.04  pi(a=1|s=68) = 0.86  pi(a=2|s=68) = 0.06  pi(a=3|s=68) = 0.04  --> best action: 1
#   State 69: pi(a=0|s=69) = 0.08  pi(a=1|s=69) = 0.80  pi(a=2|s=69) = 0.06  pi(a=3|s=69) = 0.06  --> best action: 1
#   State 70: pi(a=0|s=70) = 0.26  pi(a=1|s=70) = 0.25  pi(a=2|s=70) = 0.25  pi(a=3|s=70) = 0.25  --> best action: 0
#   State 71: pi(a=0|s=71) = 0.25  pi(a=1|s=71) = 0.25  pi(a=2|s=71) = 0.25  pi(a=3|s=71) = 0.25  --> best action: 0
#   State 72: pi(a=0|s=72) = 0.25  pi(a=1|s=72) = 0.25  pi(a=2|s=72) = 0.25  pi(a=3|s=72) = 0.25  --> best action: 0
#   State 73: pi(a=0|s=73) = 0.25  pi(a=1|s=73) = 0.25  pi(a=2|s=73) = 0.25  pi(a=3|s=73) = 0.25  --> best action: 0
#   State 74: pi(a=0|s=74) = 0.25  pi(a=1|s=74) = 0.25  pi(a=2|s=74) = 0.25  pi(a=3|s=74) = 0.25  --> best action: 0
#   State 75: pi(a=0|s=75) = 0.25  pi(a=1|s=75) = 0.25  pi(a=2|s=75) = 0.25  pi(a=3|s=75) = 0.25  --> best action: 0
#   State 76: pi(a=0|s=76) = 0.25  pi(a=1|s=76) = 0.25  pi(a=2|s=76) = 0.25  pi(a=3|s=76) = 0.25  --> best action: 0
#   State 77: pi(a=0|s=77) = 0.07  pi(a=1|s=77) = 0.08  pi(a=2|s=77) = 0.08  pi(a=3|s=77) = 0.77  --> best action: 3
#   State 78: pi(a=0|s=78) = 0.06  pi(a=1|s=78) = 0.83  pi(a=2|s=78) = 0.07  pi(a=3|s=78) = 0.05  --> best action: 1
#   State 79: pi(a=0|s=79) = 0.06  pi(a=1|s=79) = 0.81  pi(a=2|s=79) = 0.06  pi(a=3|s=79) = 0.07  --> best action: 1
#   State 80: pi(a=0|s=80) = 0.25  pi(a=1|s=80) = 0.25  pi(a=2|s=80) = 0.25  pi(a=3|s=80) = 0.25  --> best action: 0
#   State 81: pi(a=0|s=81) = 0.25  pi(a=1|s=81) = 0.25  pi(a=2|s=81) = 0.25  pi(a=3|s=81) = 0.25  --> best action: 0
#   State 82: pi(a=0|s=82) = 0.25  pi(a=1|s=82) = 0.25  pi(a=2|s=82) = 0.25  pi(a=3|s=82) = 0.25  --> best action: 0
#   State 83: pi(a=0|s=83) = 0.25  pi(a=1|s=83) = 0.25  pi(a=2|s=83) = 0.25  pi(a=3|s=83) = 0.25  --> best action: 0
#   State 84: pi(a=0|s=84) = 0.25  pi(a=1|s=84) = 0.25  pi(a=2|s=84) = 0.25  pi(a=3|s=84) = 0.25  --> best action: 0
#   State 85: pi(a=0|s=85) = 0.25  pi(a=1|s=85) = 0.25  pi(a=2|s=85) = 0.25  pi(a=3|s=85) = 0.25  --> best action: 0
#   State 86: pi(a=0|s=86) = 0.25  pi(a=1|s=86) = 0.25  pi(a=2|s=86) = 0.25  pi(a=3|s=86) = 0.25  --> best action: 0
#   State 87: pi(a=0|s=87) = 0.25  pi(a=1|s=87) = 0.25  pi(a=2|s=87) = 0.25  pi(a=3|s=87) = 0.25  --> best action: 0
#   State 88: pi(a=0|s=88) = 0.10  pi(a=1|s=88) = 0.75  pi(a=2|s=88) = 0.09  pi(a=3|s=88) = 0.07  --> best action: 1
#   State 89: pi(a=0|s=89) = 0.33  pi(a=1|s=89) = 0.08  pi(a=2|s=89) = 0.36  pi(a=3|s=89) = 0.23  --> best action: 2
#   State 90: pi(a=0|s=90) = 0.25  pi(a=1|s=90) = 0.25  pi(a=2|s=90) = 0.25  pi(a=3|s=90) = 0.25  --> best action: 0
#   State 91: pi(a=0|s=91) = 0.25  pi(a=1|s=91) = 0.25  pi(a=2|s=91) = 0.25  pi(a=3|s=91) = 0.25  --> best action: 0
#   State 92: pi(a=0|s=92) = 0.25  pi(a=1|s=92) = 0.25  pi(a=2|s=92) = 0.25  pi(a=3|s=92) = 0.25  --> best action: 0
#   State 93: pi(a=0|s=93) = 0.25  pi(a=1|s=93) = 0.25  pi(a=2|s=93) = 0.25  pi(a=3|s=93) = 0.25  --> best action: 0
#   State 94: pi(a=0|s=94) = 0.25  pi(a=1|s=94) = 0.25  pi(a=2|s=94) = 0.25  pi(a=3|s=94) = 0.25  --> best action: 0
#   State 95: pi(a=0|s=95) = 0.25  pi(a=1|s=95) = 0.25  pi(a=2|s=95) = 0.25  pi(a=3|s=95) = 0.25  --> best action: 0
#   State 96: pi(a=0|s=96) = 0.25  pi(a=1|s=96) = 0.25  pi(a=2|s=96) = 0.25  pi(a=3|s=96) = 0.25  --> best action: 0
#   State 97: pi(a=0|s=97) = 0.25  pi(a=1|s=97) = 0.17  pi(a=2|s=97) = 0.17  pi(a=3|s=97) = 0.41  --> best action: 3
#   State 98: pi(a=0|s=98) = 0.39  pi(a=1|s=98) = 0.26  pi(a=2|s=98) = 0.25  pi(a=3|s=98) = 0.10  --> best action: 0
#   State 99: pi(a=0|s=99) = 0.78  pi(a=1|s=99) = 0.08  pi(a=2|s=99) = 0.06  pi(a=3|s=99) = 0.07  --> best action: 0
#
#
# ======================================================================
#   PATH VISUALIZATION - Solver Policy (greedy)
# ======================================================================
#
# Initial State: 0
# Goal State: 99
# Terminal States: [99]
# Discount Factor (gamma): 0.9
#
# ----------------------------------------------------------------------
#
#   Step   0 | State: tensor(0)       | Action: tensor(3)       | Reward:  -0.100 | -> 1
#   Step   1 | State: tensor(1)       | Action: tensor(3)       | Reward:  -0.100 | -> 2
#   Step   2 | State: tensor(2)       | Action: tensor(1)       | Reward:  -0.100 | -> 12
#   Step   3 | State: tensor(12)      | Action: tensor(3)       | Reward:  -0.100 | -> 13
#   Step   4 | State: tensor(13)      | Action: tensor(1)       | Reward:  -0.100 | -> 23
#   Step   5 | State: tensor(23)      | Action: tensor(3)       | Reward:  -0.100 | -> 24
#   Step   6 | State: tensor(24)      | Action: tensor(3)       | Reward:  -0.100 | -> 25
#   Step   7 | State: tensor(25)      | Action: tensor(0)       | Reward:  -0.100 | -> 15
#   Step   8 | State: tensor(15)      | Action: tensor(3)       | Reward:  -0.100 | -> 16
#   Step   9 | State: tensor(16)      | Action: tensor(0)       | Reward:  -0.100 | -> 6
#   Step  10 | State: tensor(6)       | Action: tensor(3)       | Reward:  -0.100 | -> 7
#   Step  11 | State: tensor(7)       | Action: tensor(3)       | Reward:  -0.100 | -> 8
#   Step  12 | State: tensor(8)       | Action: tensor(3)       | Reward:  -0.345 | -> 9
#   Step  13 | State: tensor(9)       | Action: tensor(1)       | Reward:  -0.100 | -> 19
#   Step  14 | State: tensor(19)      | Action: tensor(1)       | Reward:  -0.345 | -> 19 SELF-LOOP
#   Step  15 | State: tensor(19)      | Action: tensor(1)       | Reward:  -0.345 | -> 9
#   Step  16 | State: tensor(9)       | Action: tensor(1)       | Reward:  -0.100 | -> 19
#   Step  17 | State: tensor(19)      | Action: tensor(1)       | Reward:  -0.345 | -> 29
#   Step  18 | State: tensor(29)      | Action: tensor(1)       | Reward:  -0.100 | -> 39
#   Step  19 | State: tensor(39)      | Action: tensor(2)       | Reward:  -0.100 | -> 38
#   Step  20 | State: tensor(38)      | Action: tensor(1)       | Reward:  -0.100 | -> 48
#   Step  21 | State: tensor(48)      | Action: tensor(1)       | Reward:  -0.100 | -> 58
#   Step  22 | State: tensor(58)      | Action: tensor(1)       | Reward:  -0.345 | -> 68
#   Step  23 | State: tensor(68)      | Action: tensor(1)       | Reward:  -0.100 | -> 78
#   Step  24 | State: tensor(78)      | Action: tensor(1)       | Reward:  -0.100 | -> 88
#   Step  25 | State: tensor(88)      | Action: tensor(1)       | Reward:  -0.100 | -> 98
#   Step  26 | State: tensor(98)      | Action: tensor(0)       | Reward:  -0.045 | -> 88
#   Step  27 | State: tensor(88)      | Action: tensor(1)       | Reward:  -0.100 | -> 98
#   Step  28 | State: tensor(98)      | Action: tensor(0)       | Reward:  -0.045 | -> 99 GOAL REACHED
#
#   ------------------------------------------------------------------
#   Trajectory Length: 29 steps
#   Discounted Return: -1.187139
#   Final State: 99
#
# ======================================================================

# %% [markdown]
# This is the grid search used! Worked with reg_adaptive so we knew also for this:

# %%
theta_lambda_grid = [
    1e-7,
    2e-7,
    5e-7,
    1e-6,
    2e-6,
    5e-6,
    1e-5,
    2e-5,
    5e-5,
    1e-4,
    2e-4,
    5e-4,
    1e-3,
    2e-3,
    5e-3,
    1e-2,
    2e-2,
    5e-2,
    1e-1,
    2e-1,
]

grid_results = []
best = None

for theta_lambda in theta_lambda_grid:
    print(f"\n{'=' * 80}")
    print(f"Trying theta_mode='reg_fixed', theta_lambda={theta_lambda:.6e}")
    print(f"{'=' * 80}")

    u_features = TabularFeatures(N, A)
    q_features = TabularFeatures(N, A)
    policy_features = TabularFeatures(N, A)

    solver_e = FinalLinearSolver(
        n_states=N,
        n_actions=A,
        gamma=gamma,
        x0=x_0,
        csv_path=dataset_path_10grid,
        u_function=LinearFunction(u_features),
        q_function=LinearQFunction(q_features),
        policy_features=policy_features,
        seed=SEED,
        device=DEVICE,

        theta_include_beta_cov=False,

        theta_mode="reg_fixed",
        theta_lambda=float(theta_lambda),
        theta_optimizer="adam",
        theta_inner_steps=40,
        theta_lr=3e-2,
        theta_start_mode="warm",

        beta_update="fogas_full",
    )

    solver_e.run(
        alpha=1e-3,
        eta=1e-4,
        rho=0.5,
        policy_optimizer="adam",
        policy_gradient="exact",
        reinforce_samples=4,
        tqdm_print=False,
        verbose=True,
        log_interval=50,
        T=1000,
        state_weight_update="normal",
    )

    evaluator_e = FOGASEvaluator(
        solver=solver_e,
        mdp=mdp,
        planner=planner,
    )

    trajectory = evaluator_e.simulate_trajectory(
        policy_mode="greedy",
        max_steps=50,
        seed=SEED,
        goal_state=99,
        terminal_states=99,
    )

    reached_goal = any(step["reached_goal"] for step in trajectory)
    final_state = trajectory[-1]["next_state"] if trajectory else x_0

    result = {
        "theta_lambda": float(theta_lambda),
        "reached_goal": reached_goal,
        "trajectory_length": len(trajectory),
        "final_state": final_state,
        "solver": solver_e,
        "evaluator": evaluator_e,
        "trajectory": trajectory,
    }
    grid_results.append(result)

    print(
        f"lambda={theta_lambda:.6e} | "
        f"reached_goal={reached_goal} | "
        f"steps={len(trajectory)} | "
        f"final_state={final_state}"
    )

    if reached_goal:
        best = result
        print(f"\nFOUND working theta_lambda: {theta_lambda:.6e}")
        break

if best is None:
    print("\nNo reg_fixed lambda in the 20-value grid reached goal state 99.")
    best = max(grid_results, key=lambda r: r["final_state"])
else:
    solver_e = best["solver"]
    evaluator_e = best["evaluator"]

    evaluator_e.print_solver_policy(policy_mode="solver")

    evaluator_e.print_optimal_path(
        policy_mode="greedy",
        max_steps=50,
        seed=SEED,
        goal_state=99,
        terminal_states=99,
        show_value_info=False,
    )

summary = pd.DataFrame(
    [
        {
            "theta_lambda": r["theta_lambda"],
            "reached_goal": r["reached_goal"],
            "trajectory_length": r["trajectory_length"],
            "final_state": r["final_state"],
        }
        for r in grid_results
    ]
)

summary
# Out:
# ================================================================================
# Trying theta_mode='reg_fixed', theta_lambda=1.000000e-07
# ================================================================================
# [FinalLinearSolver] Iter 1/1000 iter=0 total_loss=-1.199999e-01 policy_objective=-1.199999e-01 beta_objective=0.000000e+00 q_objective=-1.199996e-01 policy_grad_norm=0.000000e+00 policy_direction_norm=0.000000e+00 beta_grad_norm=8.980158e-02 beta_direction_norm=2.025995e+01 theta_grad_norm=4.999976e-02 theta_norm=2.399998e+00 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter
+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 951/1000 iter=950 total_loss=2.493686e+01 policy_objective=-6.505187e+02 beta_objective=5.447916e+01 q_objective=2.721928e+01 policy_grad_norm=5.393995e+00 policy_direction_norm=5.393995e+00 beta_grad_norm=5.477721e+00 beta_direction_norm=7.667410e+02 theta_grad_norm=3.519121e-02 theta_norm=6.026745e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# lambda=1.000000e-07 | reached_goal=False | steps=50 | final_state=18
#
# ================================================================================
# Trying theta_mode='reg_fixed', theta_lambda=2.000000e-07
# ================================================================================
# [FinalLinearSolver] Iter 1/1000 iter=0 total_loss=-1.199998e-01 policy_objective=-1.199998e-01 beta_objective=0.000000e+00 q_objective=-1.199993e-01 policy_grad_norm=0.000000e+00 policy_direction_norm=0.000000e+00 beta_grad_norm=8.980157e-02 beta_direction_norm=2.025995e+01 theta_grad_norm=4.999952e-02 theta_norm=2.399997e+00 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 51/1000 iter=50 total_loss=-6.085286e+00 policy_objective=-6.302511e+00 beta_objective=3.470495e-02 q_objective=-6.079224e+00 policy_grad_norm=6.200471e-03 policy_direction_norm=6.200471e-03 beta_grad_norm=5.303351e-01 beta_direction_norm=4.219071e+01 theta_grad_norm=4.927850e-02 theta_norm=2.768889e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 101/1000 iter=100 total_loss=-1.186670e+01 policy_objective=-1.374761e+01 beta_objective=2.532877e-01 q_objective=-1.182892e+01 policy_grad_norm=3.405791e-02 policy_direction_norm=3.405791e-02 beta_grad_norm=9.407464e-01 beta_direction_norm=7.990119e+01 theta_grad_norm=4.776812e-02 theta_norm=6.287695e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 151/1000 iter=150 total_loss=-1.723744e+01 policy_objective=-2.410115e+01 beta_objective=8.825329e-01 q_objective=-1.713032e+01 policy_grad_norm=9.392360e-02 policy_direction_norm=9.392360e-02 beta_grad_norm=1.414511e+00 beta_direction_norm=1.287244e+02 theta_grad_norm=4.551343e-02 theta_norm=1.033863e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 201/1000 iter=200 total_loss=-2.189310e+01 policy_objective=-3.937052e+01 beta_objective=2.226862e+00 q_objective=-2.167178e+01 policy_grad_norm=2.090710e-01 policy_direction_norm=2.090710e-01 beta_grad_norm=1.981185e+00 beta_direction_norm=1.868734e+02 theta_grad_norm=4.249028e-02 theta_norm=1.471509e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 251/1000 iter=250 total_loss=-2.545153e+01 policy_objective=-6.189414e+01 beta_objective=4.668422e+00 q_objective=-2.506026e+01 policy_grad_norm=3.728069e-01 policy_direction_norm=3.728069e-01 beta_grad_norm=2.678506e+00 beta_direction_norm=2.506272e+02 theta_grad_norm=3.860446e-02 theta_norm=1.947081e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 301/1000 iter=300 total_loss=-2.743943e+01 policy_objective=-9.347536e+01 beta_objective=8.680515e+00 q_objective=-2.682809e+01 policy_grad_norm=5.856681e-01 policy_direction_norm=5.856681e-01 beta_grad_norm=3.484605e+00 beta_direction_norm=3.179671e+02 theta_grad_norm=3.340913e-02 theta_norm=2.426190e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 351/1000 iter=350 total_loss=-2.736097e+01 policy_objective=-1.348205e+02 beta_objective=1.475896e+01 q_objective=-2.649652e+01 policy_grad_norm=7.639928e-01 policy_direction_norm=7.639928e-01 beta_grad_norm=4.537399e+00 beta_direction_norm=3.791919e+02 theta_grad_norm=2.659735e-02 theta_norm=2.876625e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter
+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 851/1000 iter=850 total_loss=2.196778e+01 policy_objective=-6.160973e+02 beta_objective=5.055141e+01 q_objective=2.528151e+01 policy_grad_norm=5.849404e+00 policy_direction_norm=5.849404e+00 beta_grad_norm=4.688854e+00 beta_direction_norm=6.442644e+02 theta_grad_norm=3.469017e-02 theta_norm=5.438803e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 901/1000 iter=900 total_loss=2.325062e+01 policy_objective=-6.341642e+02 beta_objective=5.027613e+01 q_objective=2.672699e+01 policy_grad_norm=6.194090e+00 policy_direction_norm=6.194090e+00 beta_grad_norm=4.628042e+00 beta_direction_norm=6.158617e+02 theta_grad_norm=3.384240e-02 theta_norm=5.548972e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 951/1000 iter=950 total_loss=2.319203e+01 policy_objective=-6.409156e+02 beta_objective=5.204929e+01 q_objective=2.686904e+01 policy_grad_norm=5.780149e+00 policy_direction_norm=5.780149e+00 beta_grad_norm=4.843009e+00 beta_direction_norm=7.047650e+02 theta_grad_norm=3.565674e-02 theta_norm=5.691506e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=2.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# lambda=2.000000e-07 | reached_goal=False | steps=50 | final_state=28
#
# ================================================================================
# Trying theta_mode='reg_fixed', theta_lambda=5.000000e-07
# ================================================================================
# [FinalLinearSolver] Iter 1/1000 iter=0 total_loss=-1.199997e-01 policy_objective=-1.199997e-01 beta_objective=0.000000e+00 q_objective=-1.199982e-01 policy_grad_norm=0.000000e+00 policy_direction_norm=0.000000e+00 beta_grad_norm=8.980153e-02 beta_direction_norm=2.025995e+01 theta_grad_norm=4.999880e-02 theta_norm=2.399993e+00 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 51/1000 iter=50 total_loss=-6.080773e+00 policy_objective=-6.296136e+00 beta_objective=3.920926e-02 q_objective=-6.067026e+00 policy_grad_norm=8.133225e-03 policy_direction_norm=8.133225e-03 beta_grad_norm=5.489324e-01 beta_direction_norm=4.102097e+01 theta_grad_norm=4.913782e-02 theta_norm=2.490218e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 101/1000 iter=100 total_loss=-1.184758e+01 policy_objective=-1.368047e+01 beta_objective=2.723821e-01 q_objective=-1.177024e+01 policy_grad_norm=4.235872e-02 policy_direction_norm=4.235872e-02 beta_grad_norm=9.834922e-01 beta_direction_norm=7.808839e+01 theta_grad_norm=4.738368e-02 theta_norm=5.650206e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 151/1000 iter=150 total_loss=-1.718929e+01 policy_objective=-2.384409e+01 beta_objective=9.306591e-01 q_objective=-1.697971e+01 policy_grad_norm=1.143720e-01 policy_direction_norm=1.143720e-01 beta_grad_norm=1.472895e+00 beta_direction_norm=1.244976e+02 theta_grad_norm=4.489652e-02 theta_norm=9.194234e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 201/1000 iter=200 total_loss=-2.180851e+01 policy_objective=-3.869245e+01 beta_objective=2.311413e+00 q_objective=-2.137642e+01 policy_grad_norm=2.329274e-01 policy_direction_norm=2.329274e-01 beta_grad_norm=2.047161e+00 beta_direction_norm=1.765452e+02 theta_grad_norm=4.155079e-02 theta_norm=1.313049e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 251/1000 iter=250 total_loss=-2.533964e+01 policy_objective=-6.064041e+01 beta_objective=4.780266e+00 q_objective=-2.457482e+01 policy_grad_norm=4.044825e-01 policy_direction_norm=4.044825e-01 beta_grad_norm=2.709127e+00 beta_direction_norm=2.339346e+02 theta_grad_norm=3.742455e-02 theta_norm=1.741623e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter
+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 751/1000 iter=750 total_loss=1.053319e+01 policy_objective=-5.277706e+02 beta_objective=4.300217e+01 q_objective=1.645397e+01 policy_grad_norm=3.962162e+00 policy_direction_norm=3.962162e+00 beta_grad_norm=4.036115e+00 beta_direction_norm=6.726041e+02 theta_grad_norm=2.369306e-02 theta_norm=4.789500e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 801/1000 iter=800 total_loss=1.468724e+01 policy_objective=-5.377180e+02 beta_objective=4.397131e+01 q_objective=2.066899e+01 policy_grad_norm=4.980682e+00 policy_direction_norm=4.980682e+00 beta_grad_norm=4.079137e+00 beta_direction_norm=6.966787e+02 theta_grad_norm=2.314919e-02 theta_norm=4.803788e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 851/1000 iter=850 total_loss=1.773554e+01 policy_objective=-5.567984e+02 beta_objective=4.539309e+01 q_objective=2.363328e+01 policy_grad_norm=4.145785e+00 policy_direction_norm=4.145785e+00 beta_grad_norm=4.385127e+00 beta_direction_norm=6.370239e+02 theta_grad_norm=2.749897e-02 theta_norm=4.756514e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 901/1000 iter=900 total_loss=1.861449e+01 policy_objective=-5.659679e+02 beta_objective=4.625415e+01 q_objective=2.439674e+01 policy_grad_norm=6.785413e+00 policy_direction_norm=6.785413e+00 beta_grad_norm=4.261198e+00 beta_direction_norm=6.342605e+02 theta_grad_norm=2.903429e-02 theta_norm=4.694277e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 951/1000 iter=950 total_loss=1.953450e+01 policy_objective=-5.538868e+02 beta_objective=4.387134e+01 q_objective=2.521818e+01 policy_grad_norm=7.355913e+00 policy_direction_norm=7.355913e+00 beta_grad_norm=3.531816e+00 beta_direction_norm=6.150659e+02 theta_grad_norm=3.295086e-02 theta_norm=4.638312e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=5.000000e-07 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# lambda=5.000000e-07 | reached_goal=False | steps=50 | final_state=18
#
# ================================================================================
# Trying theta_mode='reg_fixed', theta_lambda=1.000000e-06
# ================================================================================
# [FinalLinearSolver] Iter 1/1000 iter=0 total_loss=-1.199994e-01 policy_objective=-1.199994e-01 beta_objective=0.000000e+00 q_objective=-1.199965e-01 policy_grad_norm=0.000000e+00 policy_direction_norm=0.000000e+00 beta_grad_norm=8.980148e-02 beta_direction_norm=2.025995e+01 theta_grad_norm=4.999760e-02 theta_norm=2.399987e+00 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 51/1000 iter=50 total_loss=-6.072980e+00 policy_objective=-6.289413e+00 beta_objective=4.698673e-02 q_objective=-6.049607e+00 policy_grad_norm=1.081215e-02 policy_direction_norm=1.081215e-02 beta_grad_norm=6.092982e-01 beta_direction_norm=4.228430e+01 theta_grad_norm=4.891912e-02 theta_norm=2.246140e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 101/1000 iter=100 total_loss=-1.181228e+01 policy_objective=-1.360163e+01 beta_objective=3.076583e-01 q_objective=-1.168467e+01 policy_grad_norm=5.740845e-02 policy_direction_norm=5.740845e-02 beta_grad_norm=1.080460e+00 beta_direction_norm=7.638958e+01 theta_grad_norm=4.678467e-02 theta_norm=5.106604e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 151/1000 iter=150 total_loss=-1.712023e+01 policy_objective=-2.355111e+01 beta_objective=9.996665e-01 q_objective=-1.677130e+01 policy_grad_norm=1.427965e-01 policy_direction_norm=1.427965e-01 beta_grad_norm=1.576014e+00 beta_direction_norm=1.191466e+02 theta_grad_norm=4.384244e-02 theta_norm=8.385498e+02 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 201/1000 iter=200 total_loss=-2.170158e+01 policy_objective=-3.796303e+01 beta_objective=2.418277e+00 q_objective=-2.098910e+01 policy_grad_norm=2.746115e-01 policy_direction_norm=2.746115e-01 beta_grad_norm=2.120852e+00 beta_direction_norm=1.704662e+02 theta_grad_norm=4.007858e-02 theta_norm=1.194656e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 251/1000 iter=250 total_loss=-2.519950e+01 policy_objective=-5.895882e+01 beta_objective=4.920318e+00 q_objective=-2.394712e+01 policy_grad_norm=4.510845e-01 policy_direction_norm=4.510845e-01 beta_grad_norm=2.766591e+00 beta_direction_norm=2.266873e+02 theta_grad_norm=3.545863e-02 theta_norm=1.581148e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 301/1000 iter=300 total_loss=-2.718164e+01 policy_objective=-8.857072e+01 beta_objective=8.938128e+00 q_objective=-2.522313e+01 policy_grad_norm=6.343334e-01 policy_direction_norm=6.343334e-01 beta_grad_norm=3.567576e+00 beta_direction_norm=2.823794e+02 theta_grad_norm=2.976172e-02 theta_norm=1.974939e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# [FinalLinearSolver] Iter 351/1000 iter=350 total_loss=-2.726982e+01 policy_objective=-1.292401e+02 beta_objective=1.484989e+01 q_objective=-2.440172e+01 policy_grad_norm=7.957335e-01 policy_direction_norm=7.957335e-01 beta_grad_norm=4.408706e+00 beta_direction_norm=3.383316e+02 theta_grad_norm=2.294821e-02 theta_norm=2.387959e+03 theta_mode=reg_fixed theta_optimizer=adam theta_start_mode=warm theta_lambda=1.000000e-06 theta_lr=3.000000e-02 theta_include_beta_cov=False policy_optimizer=adam policy_gradient=exact policy_direction=adam_gradient reinforce_samples=4 D_theta=6.324555e+01 effective_D_theta=6.324555e+01 beta_update=fogas_full beta_diag_min=None beta_diag_max=None
# ...
# lambda=5.000000e-04 | reached_goal=True | steps=29 | final_state=99
#
# FOUND working theta_lambda: 5.000000e-04
#   State 0: pi(a=0|s=0) = 0.13  pi(a=1|s=0) = 0.26  pi(a=2|s=0) = 0.12  pi(a=3|s=0) = 0.50  --> best action: 3
#   State 1: pi(a=0|s=1) = 0.16  pi(a=1|s=1) = 0.16  pi(a=2|s=1) = 0.06  pi(a=3|s=1) = 0.62  --> best action: 3
#   State 2: pi(a=0|s=2) = 0.17  pi(a=1|s=2) = 0.53  pi(a=2|s=2) = 0.02  pi(a=3|s=2) = 0.28  --> best action: 1
#   State 3: pi(a=0|s=3) = 0.32  pi(a=1|s=3) = 0.35  pi(a=2|s=3) = 0.02  pi(a=3|s=3) = 0.32  --> best action: 1
#   State 4: pi(a=0|s=4) = 0.25  pi(a=1|s=4) = 0.25  pi(a=2|s=4) = 0.25  pi(a=3|s=4) = 0.25  --> best action: 0
#   State 5: pi(a=0|s=5) = 0.10  pi(a=1|s=5) = 0.11  pi(a=2|s=5) = 0.10  pi(a=3|s=5) = 0.69  --> best action: 3
#   State 6: pi(a=0|s=6) = 0.07  pi(a=1|s=6) = 0.07  pi(a=2|s=6) = 0.07  pi(a=3|s=6) = 0.78  --> best action: 3
#   State 7: pi(a=0|s=7) = 0.06  pi(a=1|s=7) = 0.07  pi(a=2|s=7) = 0.07  pi(a=3|s=7) = 0.80  --> best action: 3
#   State 8: pi(a=0|s=8) = 0.05  pi(a=1|s=8) = 0.36  pi(a=2|s=8) = 0.05  pi(a=3|s=8) = 0.54  --> best action: 3
#   State 9: pi(a=0|s=9) = 0.06  pi(a=1|s=9) = 0.81  pi(a=2|s=9) = 0.07  pi(a=3|s=9) = 0.06  --> best action: 1
#   State 10: pi(a=0|s=10) = 0.03  pi(a=1|s=10) = 0.43  pi(a=2|s=10) = 0.27  pi(a=3|s=10) = 0.27  --> best action: 1
#   State 11: pi(a=0|s=11) = 0.25  pi(a=1|s=11) = 0.25  pi(a=2|s=11) = 0.25  pi(a=3|s=11) = 0.25  --> best action: 0
#   State 12: pi(a=0|s=12) = 0.03  pi(a=1|s=12) = 0.22  pi(a=2|s=12) = 0.22  pi(a=3|s=12) = 0.54  --> best action: 3
#   State 13: pi(a=0|s=13) = 0.23  pi(a=1|s=13) = 0.47  pi(a=2|s=13) = 0.05  pi(a=3|s=13) = 0.26  --> best action: 1
#   State 14: pi(a=0|s=14) = 0.25  pi(a=1|s=14) = 0.25  pi(a=2|s=14) = 0.25  pi(a=3|s=14) = 0.25  --> best action: 0
#   State 15: pi(a=0|s=15) = 0.11  pi(a=1|s=15) = 0.08  pi(a=2|s=15) = 0.09  pi(a=3|s=15) = 0.72  --> best action: 3
#   State 16: pi(a=0|s=16) = 0.77  pi(a=1|s=16) = 0.07  pi(a=2|s=16) = 0.08  pi(a=3|s=16) = 0.08  --> best action: 0
#   State 17: pi(a=0|s=17) = 0.25  pi(a=1|s=17) = 0.25  pi(a=2|s=17) = 0.25  pi(a=3|s=17) = 0.25  --> best action: 0
#   State 18: pi(a=0|s=18) = 0.75  pi(a=1|s=18) = 0.07  pi(a=2|s=18) = 0.11  pi(a=3|s=18) = 0.07  --> best action: 0
#   State 19: pi(a=0|s=19) = 0.06  pi(a=1|s=19) = 0.63  pi(a=2|s=19) = 0.25  pi(a=3|s=19) = 0.06  --> best action: 1
#   State 20: pi(a=0|s=20) = 0.01  pi(a=1|s=20) = 0.39  pi(a=2|s=20) = 0.30  pi(a=3|s=20) = 0.30  --> best action: 1
#   State 21: pi(a=0|s=21) = 0.25  pi(a=1|s=21) = 0.25  pi(a=2|s=21) = 0.25  pi(a=3|s=21) = 0.25  --> best action: 0
#   State 22: pi(a=0|s=22) = 0.25  pi(a=1|s=22) = 0.25  pi(a=2|s=22) = 0.25  pi(a=3|s=22) = 0.25  --> best action: 0
#   State 23: pi(a=0|s=23) = 0.10  pi(a=1|s=23) = 0.07  pi(a=2|s=23) = 0.07  pi(a=3|s=23) = 0.75  --> best action: 3
#   State 24: pi(a=0|s=24) = 0.07  pi(a=1|s=24) = 0.08  pi(a=2|s=24) = 0.11  pi(a=3|s=24) = 0.74  --> best action: 3
#   State 25: pi(a=0|s=25) = 0.77  pi(a=1|s=25) = 0.08  pi(a=2|s=25) = 0.08  pi(a=3|s=25) = 0.07  --> best action: 0
#   State 26: pi(a=0|s=26) = 0.70  pi(a=1|s=26) = 0.10  pi(a=2|s=26) = 0.10  pi(a=3|s=26) = 0.09  --> best action: 0
#   State 27: pi(a=0|s=27) = 0.25  pi(a=1|s=27) = 0.25  pi(a=2|s=27) = 0.25  pi(a=3|s=27) = 0.25  --> best action: 0
#   State 28: pi(a=0|s=28) = 0.21  pi(a=1|s=28) = 0.62  pi(a=2|s=28) = 0.08  pi(a=3|s=28) = 0.08  --> best action: 1
#   State 29: pi(a=0|s=29) = 0.07  pi(a=1|s=29) = 0.79  pi(a=2|s=29) = 0.07  pi(a=3|s=29) = 0.07  --> best action: 1
#   State 30: pi(a=0|s=30) = 0.21  pi(a=1|s=30) = 0.24  pi(a=2|s=30) = 0.30  pi(a=3|s=30) = 0.25  --> best action: 2
#   State 31: pi(a=0|s=31) = 0.13  pi(a=1|s=31) = 0.12  pi(a=2|s=31) = 0.30  pi(a=3|s=31) = 0.44  --> best action: 3
#   State 32: pi(a=0|s=32) = 0.27  pi(a=1|s=32) = 0.14  pi(a=2|s=32) = 0.32  pi(a=3|s=32) = 0.27  --> best action: 2
#   State 33: pi(a=0|s=33) = 0.53  pi(a=1|s=33) = 0.11  pi(a=2|s=33) = 0.21  pi(a=3|s=33) = 0.15  --> best action: 0
#   State 34: pi(a=0|s=34) = 0.25  pi(a=1|s=34) = 0.25  pi(a=2|s=34) = 0.25  pi(a=3|s=34) = 0.25  --> best action: 0
#   State 35: pi(a=0|s=35) = 0.62  pi(a=1|s=35) = 0.14  pi(a=2|s=35) = 0.13  pi(a=3|s=35) = 0.12  --> best action: 0
#   State 36: pi(a=0|s=36) = 0.38  pi(a=1|s=36) = 0.21  pi(a=2|s=36) = 0.21  pi(a=3|s=36) = 0.21  --> best action: 0
#   State 37: pi(a=0|s=37) = 0.25  pi(a=1|s=37) = 0.25  pi(a=2|s=37) = 0.25  pi(a=3|s=37) = 0.25  --> best action: 0
#   State 38: pi(a=0|s=38) = 0.08  pi(a=1|s=38) = 0.76  pi(a=2|s=38) = 0.10  pi(a=3|s=38) = 0.07  --> best action: 1
#   State 39: pi(a=0|s=39) = 0.07  pi(a=1|s=39) = 0.07  pi(a=2|s=39) = 0.76  pi(a=3|s=39) = 0.10  --> best action: 2
#   State 40: pi(a=0|s=40) = 0.25  pi(a=1|s=40) = 0.25  pi(a=2|s=40) = 0.25  pi(a=3|s=40) = 0.25  --> best action: 0
#   State 41: pi(a=0|s=41) = 0.20  pi(a=1|s=41) = 0.32  pi(a=2|s=41) = 0.24  pi(a=3|s=41) = 0.24  --> best action: 1
#   State 42: pi(a=0|s=42) = 0.25  pi(a=1|s=42) = 0.25  pi(a=2|s=42) = 0.25  pi(a=3|s=42) = 0.25  --> best action: 0
#   State 43: pi(a=0|s=43) = 0.25  pi(a=1|s=43) = 0.25  pi(a=2|s=43) = 0.25  pi(a=3|s=43) = 0.25  --> best action: 0
#   State 44: pi(a=0|s=44) = 0.25  pi(a=1|s=44) = 0.25  pi(a=2|s=44) = 0.25  pi(a=3|s=44) = 0.25  --> best action: 0
#   State 45: pi(a=0|s=45) = 0.25  pi(a=1|s=45) = 0.25  pi(a=2|s=45) = 0.25  pi(a=3|s=45) = 0.25  --> best action: 0
#   State 46: pi(a=0|s=46) = 0.25  pi(a=1|s=46) = 0.25  pi(a=2|s=46) = 0.25  pi(a=3|s=46) = 0.25  --> best action: 0
#   State 47: pi(a=0|s=47) = 0.25  pi(a=1|s=47) = 0.25  pi(a=2|s=47) = 0.25  pi(a=3|s=47) = 0.25  --> best action: 0
#   State 48: pi(a=0|s=48) = 0.08  pi(a=1|s=48) = 0.76  pi(a=2|s=48) = 0.07  pi(a=3|s=48) = 0.09  --> best action: 1
#   State 49: pi(a=0|s=49) = 0.25  pi(a=1|s=49) = 0.25  pi(a=2|s=49) = 0.25  pi(a=3|s=49) = 0.25  --> best action: 0
#   State 50: pi(a=0|s=50) = 0.27  pi(a=1|s=50) = 0.27  pi(a=2|s=50) = 0.23  pi(a=3|s=50) = 0.23  --> best action: 1
#   State 51: pi(a=0|s=51) = 0.26  pi(a=1|s=51) = 0.23  pi(a=2|s=51) = 0.26  pi(a=3|s=51) = 0.26  --> best action: 2
#   State 52: pi(a=0|s=52) = 0.34  pi(a=1|s=52) = 0.23  pi(a=2|s=52) = 0.23  pi(a=3|s=52) = 0.20  --> best action: 0
#   State 53: pi(a=0|s=53) = 0.25  pi(a=1|s=53) = 0.25  pi(a=2|s=53) = 0.25  pi(a=3|s=53) = 0.25  --> best action: 2
#   State 54: pi(a=0|s=54) = 0.25  pi(a=1|s=54) = 0.25  pi(a=2|s=54) = 0.25  pi(a=3|s=54) = 0.25  --> best action: 0
#   State 55: pi(a=0|s=55) = 0.25  pi(a=1|s=55) = 0.25  pi(a=2|s=55) = 0.25  pi(a=3|s=55) = 0.25  --> best action: 0
#   State 56: pi(a=0|s=56) = 0.25  pi(a=1|s=56) = 0.25  pi(a=2|s=56) = 0.25  pi(a=3|s=56) = 0.25  --> best action: 0
#   State 57: pi(a=0|s=57) = 0.78  pi(a=1|s=57) = 0.06  pi(a=2|s=57) = 0.07  pi(a=3|s=57) = 0.09  --> best action: 0
#   State 58: pi(a=0|s=58) = 0.07  pi(a=1|s=58) = 0.70  pi(a=2|s=58) = 0.16  pi(a=3|s=58) = 0.07  --> best action: 1
#   State 59: pi(a=0|s=59) = 0.15  pi(a=1|s=59) = 0.57  pi(a=2|s=59) = 0.14  pi(a=3|s=59) = 0.15  --> best action: 1
#   State 60: pi(a=0|s=60) = 0.24  pi(a=1|s=60) = 0.25  pi(a=2|s=60) = 0.24  pi(a=3|s=60) = 0.27  --> best action: 3
#   State 61: pi(a=0|s=61) = 0.34  pi(a=1|s=61) = 0.22  pi(a=2|s=61) = 0.34  pi(a=3|s=61) = 0.10  --> best action: 0
#   State 62: pi(a=0|s=62) = 0.25  pi(a=1|s=62) = 0.25  pi(a=2|s=62) = 0.25  pi(a=3|s=62) = 0.25  --> best action: 0
#   State 63: pi(a=0|s=63) = 0.25  pi(a=1|s=63) = 0.25  pi(a=2|s=63) = 0.25  pi(a=3|s=63) = 0.25  --> best action: 0
#   State 64: pi(a=0|s=64) = 0.25  pi(a=1|s=64) = 0.25  pi(a=2|s=64) = 0.25  pi(a=3|s=64) = 0.25  --> best action: 0
#   State 65: pi(a=0|s=65) = 0.25  pi(a=1|s=65) = 0.25  pi(a=2|s=65) = 0.25  pi(a=3|s=65) = 0.25  --> best action: 0
#   State 66: pi(a=0|s=66) = 0.25  pi(a=1|s=66) = 0.25  pi(a=2|s=66) = 0.25  pi(a=3|s=66) = 0.25  --> best action: 0
#   State 67: pi(a=0|s=67) = 0.15  pi(a=1|s=67) = 0.49  pi(a=2|s=67) = 0.16  pi(a=3|s=67) = 0.21  --> best action: 1
#   State 68: pi(a=0|s=68) = 0.07  pi(a=1|s=68) = 0.79  pi(a=2|s=68) = 0.07  pi(a=3|s=68) = 0.07  --> best action: 1
#   State 69: pi(a=0|s=69) = 0.13  pi(a=1|s=69) = 0.66  pi(a=2|s=69) = 0.11  pi(a=3|s=69) = 0.11  --> best action: 1
#   State 70: pi(a=0|s=70) = 0.25  pi(a=1|s=70) = 0.25  pi(a=2|s=70) = 0.25  pi(a=3|s=70) = 0.25  --> best action: 0
#   State 71: pi(a=0|s=71) = 0.25  pi(a=1|s=71) = 0.25  pi(a=2|s=71) = 0.25  pi(a=3|s=71) = 0.25  --> best action: 0
#   State 72: pi(a=0|s=72) = 0.25  pi(a=1|s=72) = 0.25  pi(a=2|s=72) = 0.25  pi(a=3|s=72) = 0.25  --> best action: 0
#   State 73: pi(a=0|s=73) = 0.25  pi(a=1|s=73) = 0.25  pi(a=2|s=73) = 0.25  pi(a=3|s=73) = 0.25  --> best action: 0
#   State 74: pi(a=0|s=74) = 0.25  pi(a=1|s=74) = 0.25  pi(a=2|s=74) = 0.25  pi(a=3|s=74) = 0.25  --> best action: 0
#   State 75: pi(a=0|s=75) = 0.25  pi(a=1|s=75) = 0.25  pi(a=2|s=75) = 0.25  pi(a=3|s=75) = 0.25  --> best action: 0
#   State 76: pi(a=0|s=76) = 0.25  pi(a=1|s=76) = 0.25  pi(a=2|s=76) = 0.25  pi(a=3|s=76) = 0.25  --> best action: 0
#   State 77: pi(a=0|s=77) = 0.11  pi(a=1|s=77) = 0.12  pi(a=2|s=77) = 0.12  pi(a=3|s=77) = 0.65  --> best action: 3
#   State 78: pi(a=0|s=78) = 0.08  pi(a=1|s=78) = 0.77  pi(a=2|s=78) = 0.08  pi(a=3|s=78) = 0.07  --> best action: 1
#   State 79: pi(a=0|s=79) = 0.10  pi(a=1|s=79) = 0.69  pi(a=2|s=79) = 0.10  pi(a=3|s=79) = 0.11  --> best action: 1
#   State 80: pi(a=0|s=80) = 0.25  pi(a=1|s=80) = 0.25  pi(a=2|s=80) = 0.25  pi(a=3|s=80) = 0.25  --> best action: 0
#   State 81: pi(a=0|s=81) = 0.25  pi(a=1|s=81) = 0.25  pi(a=2|s=81) = 0.25  pi(a=3|s=81) = 0.25  --> best action: 0
#   State 82: pi(a=0|s=82) = 0.25  pi(a=1|s=82) = 0.25  pi(a=2|s=82) = 0.25  pi(a=3|s=82) = 0.25  --> best action: 0
#   State 83: pi(a=0|s=83) = 0.25  pi(a=1|s=83) = 0.25  pi(a=2|s=83) = 0.25  pi(a=3|s=83) = 0.25  --> best action: 0
#   State 84: pi(a=0|s=84) = 0.25  pi(a=1|s=84) = 0.25  pi(a=2|s=84) = 0.25  pi(a=3|s=84) = 0.25  --> best action: 0
#   State 85: pi(a=0|s=85) = 0.25  pi(a=1|s=85) = 0.25  pi(a=2|s=85) = 0.25  pi(a=3|s=85) = 0.25  --> best action: 0
#   State 86: pi(a=0|s=86) = 0.25  pi(a=1|s=86) = 0.25  pi(a=2|s=86) = 0.25  pi(a=3|s=86) = 0.25  --> best action: 0
#   State 87: pi(a=0|s=87) = 0.25  pi(a=1|s=87) = 0.25  pi(a=2|s=87) = 0.25  pi(a=3|s=87) = 0.25  --> best action: 0
#   State 88: pi(a=0|s=88) = 0.10  pi(a=1|s=88) = 0.71  pi(a=2|s=88) = 0.10  pi(a=3|s=88) = 0.09  --> best action: 1
#   State 89: pi(a=0|s=89) = 0.33  pi(a=1|s=89) = 0.09  pi(a=2|s=89) = 0.36  pi(a=3|s=89) = 0.23  --> best action: 2
#   State 90: pi(a=0|s=90) = 0.25  pi(a=1|s=90) = 0.25  pi(a=2|s=90) = 0.25  pi(a=3|s=90) = 0.25  --> best action: 0
#   State 91: pi(a=0|s=91) = 0.25  pi(a=1|s=91) = 0.25  pi(a=2|s=91) = 0.25  pi(a=3|s=91) = 0.25  --> best action: 0
#   State 92: pi(a=0|s=92) = 0.25  pi(a=1|s=92) = 0.25  pi(a=2|s=92) = 0.25  pi(a=3|s=92) = 0.25  --> best action: 0
#   State 93: pi(a=0|s=93) = 0.25  pi(a=1|s=93) = 0.25  pi(a=2|s=93) = 0.25  pi(a=3|s=93) = 0.25  --> best action: 0
#   State 94: pi(a=0|s=94) = 0.25  pi(a=1|s=94) = 0.25  pi(a=2|s=94) = 0.25  pi(a=3|s=94) = 0.25  --> best action: 0
#   State 95: pi(a=0|s=95) = 0.25  pi(a=1|s=95) = 0.25  pi(a=2|s=95) = 0.25  pi(a=3|s=95) = 0.25  --> best action: 0
#   State 96: pi(a=0|s=96) = 0.25  pi(a=1|s=96) = 0.25  pi(a=2|s=96) = 0.25  pi(a=3|s=96) = 0.25  --> best action: 0
#   State 97: pi(a=0|s=97) = 0.26  pi(a=1|s=97) = 0.20  pi(a=2|s=97) = 0.20  pi(a=3|s=97) = 0.34  --> best action: 3
#   State 98: pi(a=0|s=98) = 0.41  pi(a=1|s=98) = 0.27  pi(a=2|s=98) = 0.25  pi(a=3|s=98) = 0.08  --> best action: 0
#   State 99: pi(a=0|s=99) = 0.73  pi(a=1|s=99) = 0.10  pi(a=2|s=99) = 0.08  pi(a=3|s=99) = 0.09  --> best action: 0
#
#
# ======================================================================
#   PATH VISUALIZATION - Solver Policy (greedy)
# ======================================================================
#
# Initial State: 0
# Goal State: 99
# Terminal States: [99]
# Discount Factor (gamma): 0.9
#
# ----------------------------------------------------------------------
#
#   Step   0 | State: tensor(0)       | Action: tensor(3)       | Reward:  -0.100 | -> 1
#   Step   1 | State: tensor(1)       | Action: tensor(3)       | Reward:  -0.100 | -> 2
#   Step   2 | State: tensor(2)       | Action: tensor(1)       | Reward:  -0.100 | -> 12
#   Step   3 | State: tensor(12)      | Action: tensor(3)       | Reward:  -0.100 | -> 13
#   Step   4 | State: tensor(13)      | Action: tensor(1)       | Reward:  -0.100 | -> 23
#   Step   5 | State: tensor(23)      | Action: tensor(3)       | Reward:  -0.100 | -> 24
#   Step   6 | State: tensor(24)      | Action: tensor(3)       | Reward:  -0.100 | -> 25
#   Step   7 | State: tensor(25)      | Action: tensor(0)       | Reward:  -0.100 | -> 15
#   Step   8 | State: tensor(15)      | Action: tensor(3)       | Reward:  -0.100 | -> 16
#   Step   9 | State: tensor(16)      | Action: tensor(0)       | Reward:  -0.100 | -> 6
#   Step  10 | State: tensor(6)       | Action: tensor(3)       | Reward:  -0.100 | -> 7
#   Step  11 | State: tensor(7)       | Action: tensor(3)       | Reward:  -0.100 | -> 8
#   Step  12 | State: tensor(8)       | Action: tensor(3)       | Reward:  -0.345 | -> 9
#   Step  13 | State: tensor(9)       | Action: tensor(1)       | Reward:  -0.100 | -> 19
#   Step  14 | State: tensor(19)      | Action: tensor(1)       | Reward:  -0.345 | -> 19 SELF-LOOP
#   Step  15 | State: tensor(19)      | Action: tensor(1)       | Reward:  -0.345 | -> 9
#   Step  16 | State: tensor(9)       | Action: tensor(1)       | Reward:  -0.100 | -> 19
#   Step  17 | State: tensor(19)      | Action: tensor(1)       | Reward:  -0.345 | -> 29
#   Step  18 | State: tensor(29)      | Action: tensor(1)       | Reward:  -0.100 | -> 39
#   Step  19 | State: tensor(39)      | Action: tensor(2)       | Reward:  -0.100 | -> 38
#   Step  20 | State: tensor(38)      | Action: tensor(1)       | Reward:  -0.100 | -> 48
#   Step  21 | State: tensor(48)      | Action: tensor(1)       | Reward:  -0.100 | -> 58
#   Step  22 | State: tensor(58)      | Action: tensor(1)       | Reward:  -0.345 | -> 68
#   Step  23 | State: tensor(68)      | Action: tensor(1)       | Reward:  -0.100 | -> 78
#   Step  24 | State: tensor(78)      | Action: tensor(1)       | Reward:  -0.100 | -> 88
#   Step  25 | State: tensor(88)      | Action: tensor(1)       | Reward:  -0.100 | -> 98
#   Step  26 | State: tensor(98)      | Action: tensor(0)       | Reward:  -0.045 | -> 88
#   Step  27 | State: tensor(88)      | Action: tensor(1)       | Reward:  -0.100 | -> 98
#   Step  28 | State: tensor(98)      | Action: tensor(0)       | Reward:  -0.045 | -> 99 GOAL REACHED
#
#   ------------------------------------------------------------------
#   Trajectory Length: 29 steps
#   Discounted Return: -1.187139
#   Final State: 99
#
# ======================================================================
#     theta_lambda  reached_goal  trajectory_length  final_state
# 0   1.000000e-07         False                 50           18
# 1   2.000000e-07         False                 50           28
# 2   5.000000e-07         False                 50           18
# 3   1.000000e-06         False                 50           16
# 4   2.000000e-06         False                 50           24
# 5   5.000000e-06         False                 50           25
# 6   1.000000e-05         False                 50           25
# 7   2.000000e-05         False                 50           18
# 8   5.000000e-05         False                 50           18
# 9   1.000000e-04         False                 50           18
# 10  2.000000e-04         False                 50           18
# 11  5.000000e-04          True                 29           99
